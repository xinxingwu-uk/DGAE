# %%
import numpy as np
import pandas as pd

# %%
def print_results(p_model_name,p_features_used,p_used_number,all_data=False):
    print("Model name: ", p_model_name)
    print("\n")
    mean_time_read=np.array(pd.read_csv("./log/"+p_model_name+"_time_"+str(p_features_used)+".csv",header=None))[0]
    mean_roc_read=np.array(pd.read_csv("./log/"+p_model_name+"_roc_"+str(p_features_used)+".csv",header=None))[0]
    mean_ap_read=np.array(pd.read_csv("./log/"+p_model_name+"_ap_"+str(p_features_used)+".csv",header=None))[0]
    
    if all_data:
        print("AUC scores\n", mean_roc_read[0:p_used_number])
    print("Mean AUC score: ", np.mean(mean_roc_read[0:p_used_number]),
          "\nStd of AUC scores: ",np.std(mean_roc_read[0:p_used_number]), "\n \n")
    
    if all_data:
        print("AP scores\n", mean_ap_read[0:p_used_number])
    print("Mean AP score: ", np.mean(mean_ap_read[0:p_used_number]),
          "\nStd of AP scores: ", np.std(mean_ap_read[0:p_used_number]), "\n \n")

    if all_data:
        print("Total Running times\n", mean_time_read[0:p_used_number])
    print("Mean total running time: ", np.mean(mean_time_read[0:p_used_number]),
          "\nStd of total running time: ", np.std(mean_time_read[0:p_used_number]), "\n \n")

# %%
p_model_name=['linear_ae','gcn_ae','deep6_gcn_ae','deep12_gcn_ae','deep18_gcn_ae','deep36_gcn_ae']

for p_model_name_i in p_model_name:
    p_features_used=False
    p_used_number=10
    print_results(p_model_name_i,p_features_used,p_used_number,all_data=False)
    print("----------------------------------------------------------\n")
# Out:
# Model name:  linear_ae
#
#
# Mean AUC score:  0.11358024691358024
# Std of AUC scores:  0.06314425606194776
#
#
# Mean AP score:  0.3829647132098113
# Std of AP scores:  0.04604796766232566
#
#
# Mean total running time:  1.1728532314300537
# Std of total running time:  0.05444219957181822
#
#
# ----------------------------------------------------------
#
# Model name:  gcn_ae
#
#
# Mean AUC score:  0.14691358024691356
# Std of AUC scores:  0.07123146536667484
#
#
# Mean AP score:  0.39251621109464246
# Std of AP scores:  0.05284035821951993
#
#
# Mean total running time:  1.3727836608886719
# Std of total running time:  0.0753622440761429
#
#
# ----------------------------------------------------------
#
# Model name:  deep6_gcn_ae
#
#
# Mean AUC score:  0.13641975308641976
# Std of AUC scores:  0.0773183570317904
#
#
# Mean AP score:  0.3875625844743492
# Std of AP scores:  0.04821725589152864
#
#
# Mean total running time:  2.5436545610427856
# Std of total running time:  0.2858084721636305
#
#
# ----------------------------------------------------------
#
# Model name:  deep12_gcn_ae
#
#
# Mean AUC score:  0.12901234567901235
# Std of AUC scores:  0.05551781983159852
#
#
# Mean AP score:  0.3884740803858451
# Std of AP scores:  0.04684188488806032
#
#
# Mean total running time:  3.8471699476242067
# Std of total running time:  0.5459661099764476
#
#
# ----------------------------------------------------------
#
# Model name:  deep18_gcn_ae
#
#
# Mean AUC score:  0.4438271604938272
# Std of AUC scores:  0.25042944368482106
#
#
# Mean AP score:  0.5746367684602979
# Std of AP scores:  0.1832641194895426
#
#
# Mean total running time:  5.058588981628418
# Std of total running time:  0.8371041089060258
#
#
# ----------------------------------------------------------
#
# Model name:  deep36_gcn_ae
#
#
# Mean AUC score:  0.5
# Std of AUC scores:  0.0
#
#
# Mean AP score:  0.5
# Std of AP scores:  0.0
#
#
# Mean total running time:  9.279744052886963
# Std of total running time:  1.7726261557495695
#
#
# ----------------------------------------------------------

# %%
for p_model_name_i in p_model_name:
    p_features_used=True
    p_used_number=10
    print_results(p_model_name_i,p_features_used,p_used_number,all_data=False)
    print("----------------------------------------------------------\n")
# Out:
# Model name:  linear_ae
#
#
# Mean AUC score:  0.21975308641975308
# Std of AUC scores:  0.07236716488766838
#
#
# Mean AP score:  0.44534894934404745
# Std of AP scores:  0.05641094086737077
#
#
# Mean total running time:  2.049413537979126
# Std of total running time:  0.06935187717528153
#
#
# ----------------------------------------------------------
#
# Model name:  gcn_ae
#
#
# Mean AUC score:  0.34629629629629627
# Std of AUC scores:  0.11133208479458942
#
#
# Mean AP score:  0.5709473478591126
# Std of AP scores:  0.07120390176693689
#
#
# Mean total running time:  2.1798373460769653
# Std of total running time:  0.08298132965592125
#
#
# ----------------------------------------------------------
#
# Model name:  deep6_gcn_ae
#
#
# Mean AUC score:  0.19506172839506172
# Std of AUC scores:  0.07881920839265366
#
#
# Mean AP score:  0.45142847620788806
# Std of AP scores:  0.07996511477714857
#
#
# Mean total running time:  3.2105925559997557
# Std of total running time:  0.2727769789273023
#
#
# ----------------------------------------------------------
#
# Model name:  deep12_gcn_ae
#
#
# Mean AUC score:  0.34197530864197534
# Std of AUC scores:  0.16021343027461743
#
#
# Mean AP score:  0.5756545388163035
# Std of AP scores:  0.1243459668297583
#
#
# Mean total running time:  4.502235960960388
# Std of total running time:  0.5498672886688775
#
#
# ----------------------------------------------------------
#
# Model name:  deep18_gcn_ae
#
#
# Mean AUC score:  0.24814814814814815
# Std of AUC scores:  0.12559263567442977
#
#
# Mean AP score:  0.49375919650429456
# Std of AP scores:  0.09381998526069867
#
#
# Mean total running time:  5.883184504508972
# Std of total running time:  0.8493000765966187
#
#
# ----------------------------------------------------------
#
# Model name:  deep36_gcn_ae
#
#
# Mean AUC score:  0.5
# Std of AUC scores:  0.0
#
#
# Mean AP score:  0.5
# Std of AP scores:  0.0
#
#
# Mean total running time:  10.324979686737061
# Std of total running time:  1.993713875461814
#
#
# ----------------------------------------------------------
