# %%
import numpy as np
import pandas as pd

# %%
def print_results(p_model_name,p_features_used,p_used_number,all_data=False):
    print("Model name: ", p_model_name)
    print("\n")
    mean_time_read=np.array(pd.read_csv("./log/"+p_model_name+"_time_"+str(p_features_used)+".csv",header=None))[0]
    mean_roc_read=np.array(pd.read_csv("./log/"+p_model_name+"_roc_"+str(p_features_used)+".csv",header=None))[0]
    mean_ap_read=np.array(pd.read_csv("./log/"+p_model_name+"_ap_"+str(p_features_used)+".csv",header=None))[0]
    
    if all_data:
        print("AUC scores\n", mean_roc_read[0:p_used_number])
    print("Mean AUC score: ", np.mean(mean_roc_read[0:p_used_number]),
          "\nStd of AUC scores: ",np.std(mean_roc_read[0:p_used_number]), "\n \n")
    
    if all_data:
        print("AP scores\n", mean_ap_read[0:p_used_number])
    print("Mean AP score: ", np.mean(mean_ap_read[0:p_used_number]),
          "\nStd of AP scores: ", np.std(mean_ap_read[0:p_used_number]), "\n \n")

    if all_data:
        print("Total Running times\n", mean_time_read[0:p_used_number])
    print("Mean total running time: ", np.mean(mean_time_read[0:p_used_number]),
          "\nStd of total running time: ", np.std(mean_time_read[0:p_used_number]), "\n \n")

# %%
p_model_name=['linear_ae','gcn_ae','deep6_gcn_ae','deep12_gcn_ae','deep18_gcn_ae','deep36_gcn_ae']

for p_model_name_i in p_model_name:
    p_features_used=False
    p_used_number=10
    print_results(p_model_name_i,p_features_used,p_used_number,all_data=False)
    print("----------------------------------------------------------\n")
# Out:
# Model name:  linear_ae
#
#
# Mean AUC score:  0.533029513888889
# Std of AUC scores:  0.05972905082993488
#
#
# Mean AP score:  0.6241739697225744
# Std of AP scores:  0.05284260040684298
#
#
# Mean total running time:  35.36685564517975
# Std of total running time:  1.044346448848071
#
#
# ----------------------------------------------------------
#
# Model name:  gcn_ae
#
#
# Mean AUC score:  0.47634548611111116
# Std of AUC scores:  0.0645611760313034
#
#
# Mean AP score:  0.5437317016324646
# Std of AP scores:  0.05135136354502637
#
#
# Mean total running time:  36.15377337932587
# Std of total running time:  0.7759718919740861
#
#
# ----------------------------------------------------------
#
# Model name:  deep6_gcn_ae
#
#
# Mean AUC score:  0.42504340277777775
# Std of AUC scores:  0.04497260873047397
#
#
# Mean AP score:  0.5550611609679196
# Std of AP scores:  0.037154372798379943
#
#
# Mean total running time:  39.71137986183167
# Std of total running time:  0.5178751346496314
#
#
# ----------------------------------------------------------
#
# Model name:  deep12_gcn_ae
#
#
# Mean AUC score:  0.6719618055555555
# Std of AUC scores:  0.052520786590535176
#
#
# Mean AP score:  0.7548827359369499
# Std of AP scores:  0.047700905902538705
#
#
# Mean total running time:  43.160472416877745
# Std of total running time:  0.42114090352818356
#
#
# ----------------------------------------------------------
#
# Model name:  deep18_gcn_ae
#
#
# Mean AUC score:  0.5476345486111112
# Std of AUC scores:  0.07405105692389126
#
#
# Mean AP score:  0.5668626386736293
# Std of AP scores:  0.09334340223176472
#
#
# Mean total running time:  47.47577199935913
# Std of total running time:  0.35700489070823244
#
#
# ----------------------------------------------------------
#
# Model name:  deep36_gcn_ae
#
#
# Mean AUC score:  0.5
# Std of AUC scores:  0.0
#
#
# Mean AP score:  0.5
# Std of AP scores:  0.0
#
#
# Mean total running time:  60.65096254348755
# Std of total running time:  1.2783033098754126
#
#
# ----------------------------------------------------------

# %%
for p_model_name_i in p_model_name:
    p_features_used=True
    p_used_number=10
    print_results(p_model_name_i,p_features_used,p_used_number,all_data=False)
    print("----------------------------------------------------------\n")
# Out:
# Model name:  linear_ae
#
#
# Mean AUC score:  0.4520833333333334
# Std of AUC scores:  0.037525686250148176
#
#
# Mean AP score:  0.5373868416584202
# Std of AP scores:  0.03786958301625431
#
#
# Mean total running time:  36.68874788284302
# Std of total running time:  0.5703658626805702
#
#
# ----------------------------------------------------------
#
# Model name:  gcn_ae
#
#
# Mean AUC score:  0.4632595486111112
# Std of AUC scores:  0.06255415842270173
#
#
# Mean AP score:  0.5462198109753791
# Std of AP scores:  0.05766506883637823
#
#
# Mean total running time:  36.77252185344696
# Std of total running time:  0.766921197402228
#
#
# ----------------------------------------------------------
#
# Model name:  deep6_gcn_ae
#
#
# Mean AUC score:  0.37669270833333335
# Std of AUC scores:  0.057972107476144896
#
#
# Mean AP score:  0.4971395002105722
# Std of AP scores:  0.04694903449404387
#
#
# Mean total running time:  40.49343321323395
# Std of total running time:  0.5685933929179834
#
#
# ----------------------------------------------------------
#
# Model name:  deep12_gcn_ae
#
#
# Mean AUC score:  0.601953125
# Std of AUC scores:  0.07808350315751798
#
#
# Mean AP score:  0.7042650526841843
# Std of AP scores:  0.05219008241454004
#
#
# Mean total running time:  44.16629288196564
# Std of total running time:  0.3813679795459487
#
#
# ----------------------------------------------------------
#
# Model name:  deep18_gcn_ae
#
#
# Mean AUC score:  0.5668185763888889
# Std of AUC scores:  0.0401585300822784
#
#
# Mean AP score:  0.6698460118615308
# Std of AP scores:  0.029577377950272436
#
#
# Mean total running time:  48.281545996665955
# Std of total running time:  0.94102928128129
#
#
# ----------------------------------------------------------
#
# Model name:  deep36_gcn_ae
#
#
# Mean AUC score:  0.5
# Std of AUC scores:  0.0
#
#
# Mean AP score:  0.5
# Std of AP scores:  0.0
#
#
# Mean total running time:  61.62013258934021
# Std of total running time:  1.6033061581634682
#
#
# ----------------------------------------------------------
