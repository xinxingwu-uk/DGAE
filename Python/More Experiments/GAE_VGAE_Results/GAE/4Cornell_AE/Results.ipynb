# %%
import numpy as np
import pandas as pd

# %%
def print_results(p_model_name,p_features_used,p_used_number,all_data=False):
    print("Model name: ", p_model_name)
    print("\n")
    mean_time_read=np.array(pd.read_csv("./log/"+p_model_name+"_time_"+str(p_features_used)+".csv",header=None))[0]
    mean_roc_read=np.array(pd.read_csv("./log/"+p_model_name+"_roc_"+str(p_features_used)+".csv",header=None))[0]
    mean_ap_read=np.array(pd.read_csv("./log/"+p_model_name+"_ap_"+str(p_features_used)+".csv",header=None))[0]
    
    if all_data:
        print("AUC scores\n", mean_roc_read[0:p_used_number])
    print("Mean AUC score: ", np.mean(mean_roc_read[0:p_used_number]),
          "\nStd of AUC scores: ",np.std(mean_roc_read[0:p_used_number]), "\n \n")
    
    if all_data:
        print("AP scores\n", mean_ap_read[0:p_used_number])
    print("Mean AP score: ", np.mean(mean_ap_read[0:p_used_number]),
          "\nStd of AP scores: ", np.std(mean_ap_read[0:p_used_number]), "\n \n")

    if all_data:
        print("Total Running times\n", mean_time_read[0:p_used_number])
    print("Mean total running time: ", np.mean(mean_time_read[0:p_used_number]),
          "\nStd of total running time: ", np.std(mean_time_read[0:p_used_number]), "\n \n")

# %%
p_model_name=['linear_ae','gcn_ae','deep6_gcn_ae','deep12_gcn_ae','deep18_gcn_ae','deep36_gcn_ae']

for p_model_name_i in p_model_name:
    p_features_used=False
    p_used_number=10
    print_results(p_model_name_i,p_features_used,p_used_number,all_data=False)
    print("----------------------------------------------------------\n")
# Out:
# Model name:  linear_ae
#
#
# Mean AUC score:  0.128125
# Std of AUC scores:  0.09395810236483068
#
#
# Mean AP score:  0.3979603382728383
# Std of AP scores:  0.0640864433762544
#
#
# Mean total running time:  1.0426513671875
# Std of total running time:  0.0693155818311319
#
#
# ----------------------------------------------------------
#
# Model name:  gcn_ae
#
#
# Mean AUC score:  0.1484375
# Std of AUC scores:  0.10464084781408263
#
#
# Mean AP score:  0.39576395826395827
# Std of AP scores:  0.057960531580735344
#
#
# Mean total running time:  1.2384667158126832
# Std of total running time:  0.08293769222166825
#
#
# ----------------------------------------------------------
#
# Model name:  deep6_gcn_ae
#
#
# Mean AUC score:  0.159375
# Std of AUC scores:  0.084375
#
#
# Mean AP score:  0.4121783424908424
# Std of AP scores:  0.059525108547307616
#
#
# Mean total running time:  2.2009058952331544
# Std of total running time:  0.2697124191229683
#
#
# ----------------------------------------------------------
#
# Model name:  deep12_gcn_ae
#
#
# Mean AUC score:  0.17578125
# Std of AUC scores:  0.10169762645491044
#
#
# Mean AP score:  0.428130099067599
# Std of AP scores:  0.08817772502950731
#
#
# Mean total running time:  3.4589054584503174
# Std of total running time:  0.5397137757990339
#
#
# ----------------------------------------------------------
#
# Model name:  deep18_gcn_ae
#
#
# Mean AUC score:  0.26953125
# Std of AUC scores:  0.23020376715871202
#
#
# Mean AP score:  0.4749234792984793
# Std of AP scores:  0.1436683693992825
#
#
# Mean total running time:  4.7652446031570435
# Std of total running time:  0.8522626299988079
#
#
# ----------------------------------------------------------
#
# Model name:  deep36_gcn_ae
#
#
# Mean AUC score:  0.5
# Std of AUC scores:  0.0
#
#
# Mean AP score:  0.5
# Std of AP scores:  0.0
#
#
# Mean total running time:  8.777802228927612
# Std of total running time:  1.8013529503694947
#
#
# ----------------------------------------------------------

# %%
for p_model_name_i in p_model_name:
    p_features_used=True
    p_used_number=10
    print_results(p_model_name_i,p_features_used,p_used_number,all_data=False)
    print("----------------------------------------------------------\n")
# Out:
# Model name:  linear_ae
#
#
# Mean AUC score:  0.1953125
# Std of AUC scores:  0.12832492024641978
#
#
# Mean AP score:  0.4415502553002553
# Std of AP scores:  0.0927410348575977
#
#
# Mean total running time:  1.6326448917388916
# Std of total running time:  0.07861907586497906
#
#
# ----------------------------------------------------------
#
# Model name:  gcn_ae
#
#
# Mean AUC score:  0.1671875
# Std of AUC scores:  0.08502354912757995
#
#
# Mean AP score:  0.40203057359307354
# Std of AP scores:  0.043286151036493276
#
#
# Mean total running time:  1.7588889360427857
# Std of total running time:  0.07328271595634801
#
#
# ----------------------------------------------------------
#
# Model name:  deep6_gcn_ae
#
#
# Mean AUC score:  0.1453125
# Std of AUC scores:  0.08729048577164639
#
#
# Mean AP score:  0.3888861832611833
# Std of AP scores:  0.05052022935060624
#
#
# Mean total running time:  2.738712954521179
# Std of total running time:  0.27423148202230013
#
#
# ----------------------------------------------------------
#
# Model name:  deep12_gcn_ae
#
#
# Mean AUC score:  0.15625
# Std of AUC scores:  0.07874751980221345
#
#
# Mean AP score:  0.42093961593961593
# Std of AP scores:  0.07264566862879739
#
#
# Mean total running time:  4.0833343982696535
# Std of total running time:  0.6200545850006165
#
#
# ----------------------------------------------------------
#
# Model name:  deep18_gcn_ae
#
#
# Mean AUC score:  0.16875
# Std of AUC scores:  0.10569709078304852
#
#
# Mean AP score:  0.41932269119769117
# Std of AP scores:  0.07437680451266032
#
#
# Mean total running time:  5.258217024803161
# Std of total running time:  0.8498480436299309
#
#
# ----------------------------------------------------------
#
# Model name:  deep36_gcn_ae
#
#
# Mean AUC score:  0.5
# Std of AUC scores:  0.0
#
#
# Mean AP score:  0.5
# Std of AP scores:  0.0
#
#
# Mean total running time:  9.382568216323852
# Std of total running time:  2.0412956570673186
#
#
# ----------------------------------------------------------
