# %%
import numpy as np
import pandas as pd

# %%
def print_results(p_model_name,p_features_used,p_used_number,all_data=False):
    print("Model name: ", p_model_name)
    print("\n")
    mean_time_read=np.array(pd.read_csv("./log/"+p_model_name+"_time_"+str(p_features_used)+".csv",header=None))[0]
    mean_roc_read=np.array(pd.read_csv("./log/"+p_model_name+"_roc_"+str(p_features_used)+".csv",header=None))[0]
    mean_ap_read=np.array(pd.read_csv("./log/"+p_model_name+"_ap_"+str(p_features_used)+".csv",header=None))[0]
    
    if all_data:
        print("AUC scores\n", mean_roc_read[0:p_used_number])
    print("Mean AUC score: ", np.mean(mean_roc_read[0:p_used_number]),
          "\nStd of AUC scores: ",np.std(mean_roc_read[0:p_used_number]), "\n \n")
    
    if all_data:
        print("AP scores\n", mean_ap_read[0:p_used_number])
    print("Mean AP score: ", np.mean(mean_ap_read[0:p_used_number]),
          "\nStd of AP scores: ", np.std(mean_ap_read[0:p_used_number]), "\n \n")

    if all_data:
        print("Total Running times\n", mean_time_read[0:p_used_number])
    print("Mean total running time: ", np.mean(mean_time_read[0:p_used_number]),
          "\nStd of total running time: ", np.std(mean_time_read[0:p_used_number]), "\n \n")

# %%
p_model_name=['linear_ae','gcn_ae','deep6_gcn_ae','deep12_gcn_ae','deep18_gcn_ae','deep36_gcn_ae']

for p_model_name_i in p_model_name:
    p_features_used=False
    p_used_number=10
    print_results(p_model_name_i,p_features_used,p_used_number,all_data=False)
    print("----------------------------------------------------------\n")
# Out:
# Model name:  linear_ae
#
#
# Mean AUC score:  0.716796875
# Std of AUC scores:  0.0774433150182482
#
#
# Mean AP score:  0.8065226644577598
# Std of AP scores:  0.05691101000932784
#
#
# Mean total running time:  0.9525764942169189
# Std of total running time:  0.06735301402778626
#
#
# ----------------------------------------------------------
#
# Model name:  gcn_ae
#
#
# Mean AUC score:  0.7484375
# Std of AUC scores:  0.07502034229335734
#
#
# Mean AP score:  0.8166966002134487
# Std of AP scores:  0.06441118377962186
#
#
# Mean total running time:  1.2015674829483032
# Std of total running time:  0.07819371365241459
#
#
# ----------------------------------------------------------
#
# Model name:  deep6_gcn_ae
#
#
# Mean AUC score:  0.75
# Std of AUC scores:  0.10927730011449084
#
#
# Mean AP score:  0.8266311553291027
# Std of AP scores:  0.07190528638421854
#
#
# Mean total running time:  2.0433932542800903
# Std of total running time:  0.24580619155454442
#
#
# ----------------------------------------------------------
#
# Model name:  deep12_gcn_ae
#
#
# Mean AUC score:  0.78671875
# Std of AUC scores:  0.08861593086530774
#
#
# Mean AP score:  0.8556670078903407
# Std of AP scores:  0.053343940110581176
#
#
# Mean total running time:  3.336824727058411
# Std of total running time:  0.6201408174312875
#
#
# ----------------------------------------------------------
#
# Model name:  deep18_gcn_ae
#
#
# Mean AUC score:  0.5986328125
# Std of AUC scores:  0.1478433059946963
#
#
# Mean AP score:  0.6397053814846003
# Std of AP scores:  0.16339681213457416
#
#
# Mean total running time:  4.5076704025268555
# Std of total running time:  0.8335186290772312
#
#
# ----------------------------------------------------------
#
# Model name:  deep36_gcn_ae
#
#
# Mean AUC score:  0.5
# Std of AUC scores:  0.0
#
#
# Mean AP score:  0.5
# Std of AP scores:  0.0
#
#
# Mean total running time:  8.27228090763092
# Std of total running time:  1.7776094657642072
#
#
# ----------------------------------------------------------

# %%
for p_model_name_i in p_model_name:
    p_features_used=True
    p_used_number=10
    print_results(p_model_name_i,p_features_used,p_used_number,all_data=False)
    print("----------------------------------------------------------\n")
# Out:
# Model name:  linear_ae
#
#
# Mean AUC score:  0.733203125
# Std of AUC scores:  0.06240348993959092
#
#
# Mean AP score:  0.7409563654928579
# Std of AP scores:  0.0686631204436039
#
#
# Mean total running time:  0.973542332649231
# Std of total running time:  0.12937087313706802
#
#
# ----------------------------------------------------------
#
# Model name:  gcn_ae
#
#
# Mean AUC score:  0.7828125
# Std of AUC scores:  0.059091634679220885
#
#
# Mean AP score:  0.7909985502156661
# Std of AP scores:  0.05836022631978037
#
#
# Mean total running time:  1.1666756868362427
# Std of total running time:  0.10757030323968339
#
#
# ----------------------------------------------------------
#
# Model name:  deep6_gcn_ae
#
#
# Mean AUC score:  0.758203125
# Std of AUC scores:  0.05411108050300904
#
#
# Mean AP score:  0.8006419238191421
# Std of AP scores:  0.060019287374995
#
#
# Mean total running time:  2.064614176750183
# Std of total running time:  0.2692854501931644
#
#
# ----------------------------------------------------------
#
# Model name:  deep12_gcn_ae
#
#
# Mean AUC score:  0.765625
# Std of AUC scores:  0.08741625456687104
#
#
# Mean AP score:  0.8353319240914828
# Std of AP scores:  0.05231006759872238
#
#
# Mean total running time:  3.2609936237335204
# Std of total running time:  0.5552040435279264
#
#
# ----------------------------------------------------------
#
# Model name:  deep18_gcn_ae
#
#
# Mean AUC score:  0.640234375
# Std of AUC scores:  0.16420380819274566
#
#
# Mean AP score:  0.6422570011368597
# Std of AP scores:  0.16344292196168222
#
#
# Mean total running time:  4.471273183822632
# Std of total running time:  0.8253951354110228
#
#
# ----------------------------------------------------------
#
# Model name:  deep36_gcn_ae
#
#
# Mean AUC score:  0.5
# Std of AUC scores:  0.0
#
#
# Mean AP score:  0.5
# Std of AP scores:  0.0
#
#
# Mean total running time:  8.560472655296326
# Std of total running time:  2.050773098634743
#
#
# ----------------------------------------------------------
