# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def print_results(p_path,p_model_name,p_features_used,p_used_number,all_data=False):
    print("Model name: ", p_model_name)
    print("\n")
    mean_time_read=np.array(pd.read_csv(p_path+p_model_name+"_time_"+str(p_features_used)+".csv",header=None))[0]
    mean_roc_read=np.array(pd.read_csv(p_path+p_model_name+"_roc_"+str(p_features_used)+".csv",header=None))[0]
    mean_ap_read=np.array(pd.read_csv(p_path+p_model_name+"_ap_"+str(p_features_used)+".csv",header=None))[0]
    if all_data:
        print("AUC scores\n", mean_roc_read[0:p_used_number])
        
    AUC_mean=np.mean(mean_roc_read[0:p_used_number])
    AUC_std=np.std(mean_roc_read[0:p_used_number])
    
    print("Mean AUC score: ",AUC_mean,
          "\nStd of AUC scores: ",AUC_std, "\n \n")
    
    if all_data:
        print("AP scores\n", mean_ap_read[0:p_used_number])
        
    AP_mean=np.mean(mean_ap_read[0:p_used_number])
    AP_std=np.std(mean_ap_read[0:p_used_number])
    print("Mean AP score: ", AP_mean ,
          "\nStd of AP scores: ", AP_std, "\n \n")

    if all_data:
        print("Total Running times\n", mean_time_read[0:p_used_number])
    print("Mean total running time: ", np.mean(mean_time_read[0:p_used_number]),
          "\nStd of total running time: ", np.std(mean_time_read[0:p_used_number]), "\n \n")
    
    return AUC_mean,AUC_std,AP_mean,AP_std

# %%
datasets_name=['1Cora','2Citeseer','3Pubmed']
p_model_name=['linear_ae','gcn_ae','deep6_gcn_ae','deep12_gcn_ae','deep18_gcn_ae']

adj_AUC_mean_gather_all_datasets=[]
adj_AUC_std_gather_all_datasets=[]
adj_AP_mean_gather_all_datasets=[]
adj_AP_std_gather_all_datasets=[]
    
for datasets_name_i in datasets_name:
    p_path="./GAE/"+datasets_name_i+"_AE/log/"

    adj_AUC_mean_gather=[]
    adj_AUC_std_gather=[]
    adj_AP_mean_gather=[]
    adj_AP_std_gather=[]

    for p_model_name_i in p_model_name:
        p_features_used=False
        p_used_number=10
        AUC_mean_,AUC_std_,AP_mean_,AP_std_=print_results(p_path,p_model_name_i,p_features_used,p_used_number,all_data=False)
        adj_AUC_mean_gather.append(AUC_mean_)
        adj_AUC_std_gather.append(AUC_std_)
        adj_AP_mean_gather.append(AP_mean_)
        adj_AP_std_gather.append(AP_std_)
        print("----------------------------------------------------------\n")
    
    adj_AUC_mean_gather_all_datasets.append(adj_AUC_mean_gather)
    adj_AUC_std_gather_all_datasets.append(adj_AUC_std_gather)
    adj_AP_mean_gather_all_datasets.append(adj_AP_mean_gather)
    adj_AP_std_gather_all_datasets.append(adj_AP_std_gather)
# Out:
# Model name:  linear_ae
#
#
# Mean AUC score:  0.8314335197260639
# Std of AUC scores:  0.014646786990660675
#
#
# Mean AP score:  0.8748369309049654
# Std of AP scores:  0.011199036315196424
#
#
# Mean total running time:  50.38894519805908
# Std of total running time:  0.7346360987336035
#
#
# ----------------------------------------------------------
#
# Model name:  gcn_ae
#
#
# Mean AUC score:  0.8383980426962975
# Std of AUC scores:  0.016031810667255193
#
#
# Mean AP score:  0.8750977927246911
# Std of AP scores:  0.012866417270410267
#
#
# Mean total running time:  51.46350798606873
# Std of total running time:  0.7553709488886452
#
#
# ----------------------------------------------------------
#
# Model name:  deep6_gcn_ae
#
#
# Mean AUC score:  0.807639641521051
# Std of AUC scores:  0.013014399659602703
#
#
# Mean AP score:  0.8185397724839097
# Std of AP scores:  0.015563768222912097
#
#
# Mean total running time:  56.25525624752045
# Std of total running time:  1.260528819861597
#
#
# ----------------------------------------------------------
#
# Model name:  deep12_gcn_ae
#
#
# Mean AUC score:  0.7237863168772436
# Std of AUC scores:  0.01999887000880749
#
#
# Mean AP score:  0.7320640627978112
# Std of AP scores:  0.017560372298758314
#
#
# Mean total running time:  61.40138425827026
# Std of total running time:  2.156902671602174
#
#
# ----------------------------------------------------------
#
# Model name:  deep18_gcn_ae
#
#
# Mean AUC score:  0.5
# Std of AUC scores:  0.0
#
#
# Mean AP score:  0.5
# Std of AP scores:  0.0
#
#
# Mean total running time:  65.35602886676789
# Std of total running time:  1.4953333673622096
#
#
# ----------------------------------------------------------
#
# Model name:  linear_ae
#
#
# Mean AUC score:  0.7644786861490158
# Std of AUC scores:  0.017182919093673827
#
#
# Mean AP score:  0.8264901388364759
# Std of AP scores:  0.011328595254742373
#
#
# Mean total running time:  83.85591688156128
# Std of total running time:  1.1054522002402665
#
#
# ----------------------------------------------------------
#
# Model name:  gcn_ae
#
#
# Mean AUC score:  0.7719693273759207
# Std of AUC scores:  0.012958055029594585
#
#
# Mean AP score:  0.8297599469352892
# Std of AP scores:  0.009668684179824442
#
#
# Mean total running time:  84.58550639152527
# Std of total running time:  1.083717236653302
#
#
# ----------------------------------------------------------
#
# Model name:  deep6_gcn_ae
#
#
# Mean AUC score:  0.7974162540755947
# Std of AUC scores:  0.021424902851815385
#
#
# Mean AP score:  0.8087973194381333
# Std of AP scores:  0.015814221245344578
#
#
# Mean total running time:  88.92131958007812
# Std of total running time:  1.3141276112934441
#
#
# ----------------------------------------------------------
#
# Model name:  deep12_gcn_ae
#
#
# Mean AUC score:  0.7167134404057481
# Std of AUC scores:  0.019204155632117904
#
#
# Mean AP score:  0.7304903952057035
# Std of AP scores:  0.01753362294968565
#
#
# Mean total running time:  94.3188849925995
# Std of total running time:  1.6376968832224772
#
#
# ----------------------------------------------------------
#
# Model name:  deep18_gcn_ae
#
#
# Mean AUC score:  0.5006593406593407
# Std of AUC scores:  0.001978021978021971
#
#
# Mean AP score:  0.5006593406593407
# Std of AP scores:  0.001978021978021971
#
#
# Mean total running time:  99.74288611412048
# Std of total running time:  2.1908193768138977
#
#
# ----------------------------------------------------------
#
# Model name:  linear_ae
#
#
# Mean AUC score:  0.8205888200069401
# Std of AUC scores:  0.00376269785447826
#
#
# Mean AP score:  0.87799842330394
# Std of AP scores:  0.0029754373443126275
#
#
# Mean total running time:  382.72001616954805
# Std of total running time:  1.9166828937406162
#
#
# ----------------------------------------------------------
#
# Model name:  gcn_ae
#
#
# Mean AUC score:  0.8175577254851489
# Std of AUC scores:  0.006018080837287873
#
#
# Mean AP score:  0.8730333285712701
# Std of AP scores:  0.003854297047283666
#
#
# Mean total running time:  609.5963213920593
# Std of total running time:  2.3052348685227932
#
#
# ----------------------------------------------------------
#
# Model name:  deep6_gcn_ae
#
#
# Mean AUC score:  0.8438239972419164
# Std of AUC scores:  0.011276857830238506
#
#
# Mean AP score:  0.8678028886194327
# Std of AP scores:  0.0036632498917286652
#
#
# Mean total running time:  619.0718251466751
# Std of total running time:  2.868308225736904
#
#
# ----------------------------------------------------------
#
# Model name:  deep12_gcn_ae
#
#
# Mean AUC score:  0.8193092379103728
# Std of AUC scores:  0.020111149657176496
#
#
# Mean AP score:  0.8447187550310868
# Std of AP scores:  0.016114763056241793
#
#
# Mean total running time:  611.9867008209228
# Std of total running time:  1.092151927289544
#
#
# ----------------------------------------------------------
#
# Model name:  deep18_gcn_ae
#
#
# Mean AUC score:  0.5
# Std of AUC scores:  0.0
#
#
# Mean AP score:  0.5
# Std of AP scores:  0.0
#
#
# Mean total running time:  615.8706569194794
# Std of total running time:  5.210737017812328
#
#
# ----------------------------------------------------------

# %%
plt.style.use('seaborn-dark')
legend_names=['Cora','Citeseer','Pubmed']

x_names=['1','2','6','12','18']
x_names_dis = np.arange(len(x_names))

fig, (ax1, ax2) = plt.subplots(1,2,figsize=(26,8))

ax1.grid(True,linestyle='--',linewidth = 2.5,zorder=-1,axis="y")
ax1.set_xticks(x_names_dis)
ax1.set_xticklabels(x_names,rotation = 0, ha="center")
ax1.set_xlabel('Number of layers', fontsize = 40)
ax1.set_yticks(np.arange(0.4,0.91,0.15))
ax1.set_yticklabels(['40','55','70','85'],rotation = 0, ha="right")
ax1.set_ylabel('AUC', fontsize = 40)
ax1.tick_params(labelsize=40)
ax1.set_ylim([0.36, 0.91])

ax2.grid(True,linestyle='--',linewidth = 2.5,zorder=-1,axis="y")
ax2.set_xticks(x_names_dis)
ax2.set_xticklabels(x_names,rotation = 0, ha="center")
ax2.set_xlabel('Number of layers', fontsize =40)
ax2.set_yticks(np.arange(0.4,0.91,0.15))
ax2.set_yticklabels(['40','55','70','85'],rotation = 0, ha="right")
ax2.set_ylabel('AP', fontsize = 40)
ax2.tick_params(labelsize=40)
ax2.set_ylim([0.36, 0.91])

markers=['o','+','v','2','s','X','d','>','*','<']
cs=['orange','blue','darkcyan','fuchsia','chocolate','dodgerblue','aqua','green','red','purple']

for i in np.arange(len(legend_names)):
    ax1.plot(x_names_dis, adj_AUC_mean_gather_all_datasets[i], marker=markers[i], c=cs[i],ms=18)
    ax1.fill_between(x_names_dis, np.array(adj_AUC_mean_gather_all_datasets[i])-np.array(adj_AUC_std_gather_all_datasets[i]), np.array(adj_AUC_mean_gather_all_datasets[i])+np.array(adj_AUC_std_gather_all_datasets[i]), color=cs[i], alpha=0.1,linewidth=0.0)

for i in np.arange(len(legend_names)):
    ax2.plot(x_names_dis, np.array(adj_AP_mean_gather_all_datasets[i]), marker=markers[i], c=cs[i],ms=18)
    ax2.fill_between(x_names_dis, np.array(adj_AP_mean_gather_all_datasets[i])-np.array(adj_AP_std_gather_all_datasets[i]),np.array(adj_AP_mean_gather_all_datasets[i])+np.array(adj_AP_std_gather_all_datasets[i]), color=cs[i], alpha=0.1,linewidth=0.0)

plt.subplots_adjust(right=1,wspace =0.18,hspace =0)

fig.legend(labels=legend_names,fontsize=40, loc='upper center', bbox_to_anchor=(0.5,1.02),ncol=3,handletextpad=0.1,columnspacing=1.4, fancybox=True,framealpha=0.1,shadow=True)

plt.show()

# %%
fea_AUC_mean_gather_all_datasets=[]
fea_AUC_std_gather_all_datasets=[]
fea_AP_mean_gather_all_datasets=[]
fea_AP_std_gather_all_datasets=[]
    
for datasets_name_i in datasets_name:
    p_path="./GAE/"+datasets_name_i+"_AE/log/"

    fea_AUC_mean_gather=[]
    fea_AUC_std_gather=[]
    fea_AP_mean_gather=[]
    fea_AP_std_gather=[]

    for p_model_name_i in p_model_name:
        p_features_used=True
        p_used_number=10
        AUC_mean_,AUC_std_,AP_mean_,AP_std_=print_results(p_path,p_model_name_i,p_features_used,p_used_number,all_data=False)
        fea_AUC_mean_gather.append(AUC_mean_)
        fea_AUC_std_gather.append(AUC_std_)
        fea_AP_mean_gather.append(AP_mean_)
        fea_AP_std_gather.append(AP_std_)
        print("----------------------------------------------------------\n")
        
    fea_AUC_mean_gather_all_datasets.append(fea_AUC_mean_gather)
    fea_AUC_std_gather_all_datasets.append(fea_AUC_std_gather)
    fea_AP_mean_gather_all_datasets.append(fea_AP_mean_gather)
    fea_AP_std_gather_all_datasets.append(fea_AP_std_gather)
# Out:
# Model name:  linear_ae
#
#
# Mean AUC score:  0.9186087877031206
# Std of AUC scores:  0.010617277131275873
#
#
# Mean AP score:  0.932033032696132
# Std of AP scores:  0.00801514009746312
#
#
# Mean total running time:  51.666830968856814
# Std of total running time:  0.46239075676598423
#
#
# ----------------------------------------------------------
#
# Model name:  gcn_ae
#
#
# Mean AUC score:  0.9161340731432441
# Std of AUC scores:  0.009203674745407432
#
#
# Mean AP score:  0.9281461861468927
# Std of AP scores:  0.008181539172444845
#
#
# Mean total running time:  53.12503952980042
# Std of total running time:  0.6512541129569998
#
#
# ----------------------------------------------------------
#
# Model name:  deep6_gcn_ae
#
#
# Mean AUC score:  0.8357773224978307
# Std of AUC scores:  0.010140316417395934
#
#
# Mean AP score:  0.8532294838423354
# Std of AP scores:  0.009708533312740058
#
#
# Mean total running time:  56.81506969928741
# Std of total running time:  1.0416864913899126
#
#
# ----------------------------------------------------------
#
# Model name:  deep12_gcn_ae
#
#
# Mean AUC score:  0.7498781185976258
# Std of AUC scores:  0.032720665457366495
#
#
# Mean AP score:  0.7580611322338574
# Std of AP scores:  0.0315584584980325
#
#
# Mean total running time:  61.71422500610352
# Std of total running time:  1.0596674109415158
#
#
# ----------------------------------------------------------
#
# Model name:  deep18_gcn_ae
#
#
# Mean AUC score:  0.63896442215253
# Std of AUC scores:  0.10346503544599438
#
#
# Mean AP score:  0.6428714728475715
# Std of AP scores:  0.10754699850996978
#
#
# Mean total running time:  66.20743527412415
# Std of total running time:  1.1519596005211266
#
#
# ----------------------------------------------------------
#
# Model name:  linear_ae
#
#
# Mean AUC score:  0.9088559352735176
# Std of AUC scores:  0.007946709829267406
#
#
# Mean AP score:  0.9224404385833326
# Std of AP scores:  0.009467368839338818
#
#
# Mean total running time:  87.3160655260086
# Std of total running time:  1.1343169018153367
#
#
# ----------------------------------------------------------
#
# Model name:  gcn_ae
#
#
# Mean AUC score:  0.8903939137785291
# Std of AUC scores:  0.012713593288953367
#
#
# Mean AP score:  0.8925882705132867
# Std of AP scores:  0.008717569267799716
#
#
# Mean total running time:  88.33668241500854
# Std of total running time:  1.1994687957436077
#
#
# ----------------------------------------------------------
#
# Model name:  deep6_gcn_ae
#
#
# Mean AUC score:  0.7994565873686753
# Std of AUC scores:  0.01637420849535668
#
#
# Mean AP score:  0.8362751458880036
# Std of AP scores:  0.015885843389982536
#
#
# Mean total running time:  91.54564995765686
# Std of total running time:  1.102124850921136
#
#
# ----------------------------------------------------------
#
# Model name:  deep12_gcn_ae
#
#
# Mean AUC score:  0.7683849776597029
# Std of AUC scores:  0.022713881691771343
#
#
# Mean AP score:  0.7830642430018899
# Std of AP scores:  0.01948128303600958
#
#
# Mean total running time:  97.2236543416977
# Std of total running time:  1.3586226127382648
#
#
# ----------------------------------------------------------
#
# Model name:  deep18_gcn_ae
#
#
# Mean AUC score:  0.749809926337399
# Std of AUC scores:  0.013245329533298319
#
#
# Mean AP score:  0.7655099228295829
# Std of AP scores:  0.00974051756649292
#
#
# Mean total running time:  103.1602341890335
# Std of total running time:  1.773720625163325
#
#
# ----------------------------------------------------------
#
# Model name:  linear_ae
#
#
# Mean AUC score:  0.960059916129332
# Std of AUC scores:  0.0005723138616961473
#
#
# Mean AP score:  0.9597700914408156
# Std of AP scores:  0.0011451381894620068
#
#
# Mean total running time:  174.1831225156784
# Std of total running time:  1.479603430277128
#
#
# ----------------------------------------------------------
#
# Model name:  gcn_ae
#
#
# Mean AUC score:  0.9612626373136297
# Std of AUC scores:  0.0014193239352568807
#
#
# Mean AP score:  0.9625905979972578
# Std of AP scores:  0.0016566199920171989
#
#
# Mean total running time:  163.87514963150025
# Std of total running time:  2.295236762406429
#
#
# ----------------------------------------------------------
#
# Model name:  deep6_gcn_ae
#
#
# Mean AUC score:  0.8527190486362718
# Std of AUC scores:  0.008643837296022014
#
#
# Mean AP score:  0.8909884939484385
# Std of AP scores:  0.005387415746788303
#
#
# Mean total running time:  164.9373825788498
# Std of total running time:  2.0722619477610564
#
#
# ----------------------------------------------------------
#
# Model name:  deep12_gcn_ae
#
#
# Mean AUC score:  0.8735021094941287
# Std of AUC scores:  0.02160426423261175
#
#
# Mean AP score:  0.8925632475517002
# Std of AP scores:  0.01713491737734254
#
#
# Mean total running time:  177.52860424518585
# Std of total running time:  1.4303631569569397
#
#
# ----------------------------------------------------------
#
# Model name:  deep18_gcn_ae
#
#
# Mean AUC score:  0.5452064041952847
# Std of AUC scores:  0.09211012527561185
#
#
# Mean AP score:  0.5429785577560043
# Std of AP scores:  0.08733580784193973
#
#
# Mean total running time:  169.20534982681275
# Std of total running time:  1.1113729370274368
#
#
# ----------------------------------------------------------

# %%
plt.style.use('seaborn-dark')

legend_names=['Cora','Citeseer','Pubmed']
x_names=['1','2','6','12','18']
x_names_dis = np.arange(len(x_names))

fig, (ax1, ax2) = plt.subplots(1,2,figsize=(26,8))

ax1.grid(True,linestyle='--',linewidth = 2.5,zorder=-1,axis="y")
ax1.set_xticks(x_names_dis)
ax1.set_xticklabels(x_names,rotation = 0, ha="center")
ax1.set_xlabel('Number of layers', fontsize = 40)
ax1.set_yticks(np.arange(0.4,1.01,0.2))
ax1.set_yticklabels(['40','60','80','100'],rotation = 0, ha="right")
ax1.set_ylabel('AUC', fontsize = 40)
ax1.tick_params(labelsize=40)
ax1.set_ylim([0.36, 1.01])

ax2.grid(True,linestyle='--',linewidth = 2.5,zorder=-1,axis="y")
ax2.set_xticks(x_names_dis)
ax2.set_xticklabels(x_names,rotation = 0, ha="center")
ax2.set_xlabel('Number of layers', fontsize =40)
ax2.set_yticks(np.arange(0.4,1.01,0.2))
ax2.set_yticklabels(['40','60','80','100'],rotation = 0, ha="right")
ax2.set_ylabel('AP', fontsize = 40)
ax2.tick_params(labelsize=40)
ax2.set_ylim([0.36, 1.01])

markers=['o','+','v','2','s','X','d','>','*','<']
cs=['orange','blue','darkcyan','fuchsia','chocolate','dodgerblue','aqua','green','red','purple']

for i in np.arange(len(legend_names)):
    ax1.plot(x_names_dis, fea_AUC_mean_gather_all_datasets[i], marker=markers[i], c=cs[i],ms=18)
    ax1.fill_between(x_names_dis, np.array(fea_AUC_mean_gather_all_datasets[i])-np.array(fea_AUC_std_gather_all_datasets[i]), np.array(fea_AUC_mean_gather_all_datasets[i])+np.array(fea_AUC_std_gather_all_datasets[i]), color=cs[i], alpha=0.1,linewidth=0.0)

for i in np.arange(len(legend_names)):
    ax2.plot(x_names_dis, np.array(fea_AP_mean_gather_all_datasets[i]), marker=markers[i], c=cs[i],ms=18)
    ax2.fill_between(x_names_dis, np.array(fea_AP_mean_gather_all_datasets[i])-np.array(fea_AP_std_gather_all_datasets[i]),np.array(fea_AP_mean_gather_all_datasets[i])+np.array(fea_AP_std_gather_all_datasets[i]), color=cs[i], alpha=0.1,linewidth=0.0)

plt.subplots_adjust(right=1,wspace =0.18,hspace =0)

fig.legend(labels=legend_names,fontsize=40, loc='upper center', bbox_to_anchor=(0.5,1.03),ncol=3,handletextpad=0.1,columnspacing=1.4, fancybox=True,framealpha=0.1,shadow=True)

plt.show()
