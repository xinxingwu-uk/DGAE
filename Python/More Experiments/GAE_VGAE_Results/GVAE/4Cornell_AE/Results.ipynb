# %%
import numpy as np
import pandas as pd

# %%
def print_results(p_model_name,p_features_used,p_used_number,all_data=False):
    print("Model name: ", p_model_name)
    print("\n")
    mean_time_read=np.array(pd.read_csv("./log/"+p_model_name+"_time_"+str(p_features_used)+".csv",header=None))[0]
    mean_roc_read=np.array(pd.read_csv("./log/"+p_model_name+"_roc_"+str(p_features_used)+".csv",header=None))[0]
    mean_ap_read=np.array(pd.read_csv("./log/"+p_model_name+"_ap_"+str(p_features_used)+".csv",header=None))[0]
    
    if all_data:
        print("AUC scores\n", mean_roc_read[0:p_used_number])
    print("Mean AUC score: ", np.mean(mean_roc_read[0:p_used_number]),
          "\nStd of AUC scores: ",np.std(mean_roc_read[0:p_used_number]), "\n \n")
    
    if all_data:
        print("AP scores\n", mean_ap_read[0:p_used_number])
    print("Mean AP score: ", np.mean(mean_ap_read[0:p_used_number]),
          "\nStd of AP scores: ", np.std(mean_ap_read[0:p_used_number]), "\n \n")

    if all_data:
        print("Total Running times\n", mean_time_read[0:p_used_number])
    print("Mean total running time: ", np.mean(mean_time_read[0:p_used_number]),
          "\nStd of total running time: ", np.std(mean_time_read[0:p_used_number]), "\n \n")

# %%
p_model_name=['linear_vae','gcn_vae','deep6_gcn_vae','deep12_gcn_vae','deep18_gcn_vae','deep36_gcn_vae']

for p_model_name_i in p_model_name:
    p_features_used=False
    p_used_number=10
    print_results(p_model_name_i,p_features_used,p_used_number,all_data=False)
    print("----------------------------------------------------------\n")
# Out:
# Model name:  linear_vae
#
#
# Mean AUC score:  0.1625
# Std of AUC scores:  0.07564824023068878
#
#
# Mean AP score:  0.4038749098124098
# Std of AP scores:  0.0620208194843873
#
#
# Mean total running time:  1.401114010810852
# Std of total running time:  0.11141756313328914
#
#
# ----------------------------------------------------------
#
# Model name:  gcn_vae
#
#
# Mean AUC score:  0.1953125
# Std of AUC scores:  0.11207602400268311
#
#
# Mean AP score:  0.41640026640026634
# Std of AP scores:  0.05986546220362932
#
#
# Mean total running time:  1.61232328414917
# Std of total running time:  0.14606867297841816
#
#
# ----------------------------------------------------------
#
# Model name:  deep6_gcn_vae
#
#
# Mean AUC score:  0.1984375
# Std of AUC scores:  0.07396750236590391
#
#
# Mean AP score:  0.43112685925185923
# Std of AP scores:  0.057111479498340154
#
#
# Mean total running time:  2.6215436697006225
# Std of total running time:  0.3681729249548233
#
#
# ----------------------------------------------------------
#
# Model name:  deep12_gcn_vae
#
#
# Mean AUC score:  0.4671875
# Std of AUC scores:  0.353515409185017
#
#
# Mean AP score:  0.6225038156288156
# Std of AP scores:  0.24933749413068693
#
#
# Mean total running time:  3.843588185310364
# Std of total running time:  0.6417898837448816
#
#
# ----------------------------------------------------------
#
# Model name:  deep18_gcn_vae
#
#
# Mean AUC score:  0.8078125
# Std of AUC scores:  0.09883352875542793
#
#
# Mean AP score:  0.8639224664224665
# Std of AP scores:  0.0691998245723737
#
#
# Mean total running time:  5.109465265274048
# Std of total running time:  0.8930589684833642
#
#
# ----------------------------------------------------------
#
# Model name:  deep36_gcn_vae
#
#
# Mean AUC score:  0.825
# Std of AUC scores:  0.09901862198596786
#
#
# Mean AP score:  0.8932827242202241
# Std of AP scores:  0.06350029745605149
#
#
# Mean total running time:  9.106363105773926
# Std of total running time:  1.8420742066580262
#
#
# ----------------------------------------------------------

# %%
for p_model_name_i in p_model_name:
    p_features_used=True
    p_used_number=10
    print_results(p_model_name_i,p_features_used,p_used_number,all_data=False)
    print("----------------------------------------------------------\n")
# Out:
# Model name:  linear_vae
#
#
# Mean AUC score:  0.171875
# Std of AUC scores:  0.1267456236917078
#
#
# Mean AP score:  0.4271245074370074
# Std of AP scores:  0.09545144128014928
#
#
# Mean total running time:  2.251863884925842
# Std of total running time:  0.11214160872515305
#
#
# ----------------------------------------------------------
#
# Model name:  gcn_vae
#
#
# Mean AUC score:  0.190625
# Std of AUC scores:  0.13199195051214296
#
#
# Mean AP score:  0.4277822177822177
# Std of AP scores:  0.08003061521748708
#
#
# Mean total running time:  2.168863868713379
# Std of total running time:  0.15089328009615674
#
#
# ----------------------------------------------------------
#
# Model name:  deep6_gcn_vae
#
#
# Mean AUC score:  0.2
# Std of AUC scores:  0.10072975913303873
#
#
# Mean AP score:  0.42783865440115443
# Std of AP scores:  0.08042594213161514
#
#
# Mean total running time:  3.1616258144378664
# Std of total running time:  0.3918201719346772
#
#
# ----------------------------------------------------------
#
# Model name:  deep12_gcn_vae
#
#
# Mean AUC score:  0.321875
# Std of AUC scores:  0.26463049120424503
#
#
# Mean AP score:  0.5402845765345765
# Std of AP scores:  0.189583936334609
#
#
# Mean total running time:  4.446418619155883
# Std of total running time:  0.661007095134371
#
#
# ----------------------------------------------------------
#
# Model name:  deep18_gcn_vae
#
#
# Mean AUC score:  0.81875
# Std of AUC scores:  0.09354143466934853
#
#
# Mean AP score:  0.876027306027306
# Std of AP scores:  0.0669687844778775
#
#
# Mean total running time:  5.678684711456299
# Std of total running time:  0.9256127484502794
#
#
# ----------------------------------------------------------
#
# Model name:  deep36_gcn_vae
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-1869d0a33e0d> in <module>
#       2     p_features_used=True
#       3     p_used_number=10
# ----> 4     print_results(p_model_name_i,p_features_used,p_used_number,all_data=False)
#       5     print("----------------------------------------------------------\n")
#
# <ipython-input-2-63f0d183224e> in print_results(p_model_name, p_features_used, p_used_number, all_data)
#       2     print("Model name: ", p_model_name)
#       3     print("\n")
# ----> 4     mean_time_read=np.array(pd.read_csv("./log/"+p_model_name+"_time_"+str(p_features_used)+".csv",header=None))[0]
#       5     mean_roc_read=np.array(pd.read_csv("./log/"+p_model_name+"_roc_"+str(p_features_used)+".csv",header=None))[0]
#       6     mean_ap_read=np.array(pd.read_csv("./log/"+p_model_name+"_ap_"+str(p_features_used)+".csv",header=None))[0]
#
# /usr/local/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# --> 688     return _read(filepath_or_buffer, kwds)
#     689
#     690
#
# /usr/local/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     # Create the parser.
# --> 454     parser = TextFileReader(fp_or_buf, **kwds)
#     455
#     456     if chunksize or iterator:
#
# /usr/local/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     946             self.options["has_index_names"] = kwds["has_index_names"]
#     947
# --> 948         self._make_engine(self.engine)
#     949
#     950     def close(self):
#
# /usr/local/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1178     def _make_engine(self, engine="c"):
#    1179         if engine == "c":
# -> 1180             self._engine = CParserWrapper(self.f, **self.options)
#    1181         else:
#    1182             if engine == "python":
#
# /usr/local/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    2008         kwds["usecols"] = self.usecols
#    2009
# -> 2010         self._reader = parsers.TextReader(src, **kwds)
#    2011         self.unnamed_cols = self._reader.unnamed_cols
#    2012
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: './log/deep36_gcn_vae_time_True.csv'
