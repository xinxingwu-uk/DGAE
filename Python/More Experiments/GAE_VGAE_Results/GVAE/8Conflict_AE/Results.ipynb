# %%
import numpy as np
import pandas as pd

# %%
def print_results(p_model_name,p_features_used,p_used_number,all_data=False):
    print("Model name: ", p_model_name)
    print("\n")
    mean_time_read=np.array(pd.read_csv("./log/"+p_model_name+"_time_"+str(p_features_used)+".csv",header=None))[0]
    mean_roc_read=np.array(pd.read_csv("./log/"+p_model_name+"_roc_"+str(p_features_used)+".csv",header=None))[0]
    mean_ap_read=np.array(pd.read_csv("./log/"+p_model_name+"_ap_"+str(p_features_used)+".csv",header=None))[0]
    
    if all_data:
        print("AUC scores\n", mean_roc_read[0:p_used_number])
    print("Mean AUC score: ", np.mean(mean_roc_read[0:p_used_number]),
          "\nStd of AUC scores: ",np.std(mean_roc_read[0:p_used_number]), "\n \n")
    
    if all_data:
        print("AP scores\n", mean_ap_read[0:p_used_number])
    print("Mean AP score: ", np.mean(mean_ap_read[0:p_used_number]),
          "\nStd of AP scores: ", np.std(mean_ap_read[0:p_used_number]), "\n \n")

    if all_data:
        print("Total Running times\n", mean_time_read[0:p_used_number])
    print("Mean total running time: ", np.mean(mean_time_read[0:p_used_number]),
          "\nStd of total running time: ", np.std(mean_time_read[0:p_used_number]), "\n \n")

# %%
p_model_name=['linear_vae','gcn_vae','deep6_gcn_vae','deep12_gcn_vae','deep18_gcn_vae','deep36_gcn_vae']

for p_model_name_i in p_model_name:
    p_features_used=False
    p_used_number=10
    print_results(p_model_name_i,p_features_used,p_used_number,all_data=False)
    print("----------------------------------------------------------\n")
# Out:
# Model name:  linear_vae
#
#
# Mean AUC score:  0.785546875
# Std of AUC scores:  0.09434139638708781
#
#
# Mean AP score:  0.8575461484839032
# Std of AP scores:  0.06063564266350991
#
#
# Mean total running time:  21.815032267570494
# Std of total running time:  1.6629295732982354
#
#
# ----------------------------------------------------------
#
# Model name:  gcn_vae
#
#
# Mean AUC score:  0.7609375
# Std of AUC scores:  0.0910214925683764
#
#
# Mean AP score:  0.842016847139265
# Std of AP scores:  0.056845299925608675
#
#
# Mean total running time:  1.5183122873306274
# Std of total running time:  0.1477249886186692
#
#
# ----------------------------------------------------------
#
# Model name:  deep6_gcn_vae
#
#
# Mean AUC score:  0.793359375
# Std of AUC scores:  0.09238012846259537
#
#
# Mean AP score:  0.8597988048077762
# Std of AP scores:  0.058143617666351136
#
#
# Mean total running time:  2.4941799879074096
# Std of total running time:  0.3625624418934775
#
#
# ----------------------------------------------------------
#
# Model name:  deep12_gcn_vae
#
#
# Mean AUC score:  0.783984375
# Std of AUC scores:  0.10280267454000468
#
#
# Mean AP score:  0.8551378656319125
# Std of AP scores:  0.06433011460753386
#
#
# Mean total running time:  3.7294246912002564
# Std of total running time:  0.7597107215942162
#
#
# ----------------------------------------------------------
#
# Model name:  deep18_gcn_vae
#
#
# Mean AUC score:  0.796875
# Std of AUC scores:  0.05367363761661771
#
#
# Mean AP score:  0.8522307720422523
# Std of AP scores:  0.037970747256622084
#
#
# Mean total running time:  4.863258314132691
# Std of total running time:  0.9345458744145282
#
#
# ----------------------------------------------------------
#
# Model name:  deep36_gcn_vae
#
#
# Mean AUC score:  0.806640625
# Std of AUC scores:  0.0380433455755159
#
#
# Mean AP score:  0.8541521382840269
# Std of AP scores:  0.030466962098833775
#
#
# Mean total running time:  8.60530641078949
# Std of total running time:  1.8401417064204906
#
#
# ----------------------------------------------------------

# %%
for p_model_name_i in p_model_name:
    p_features_used=True
    p_used_number=10
    print_results(p_model_name_i,p_features_used,p_used_number,all_data=False)
    print("----------------------------------------------------------\n")
# Out:
# Model name:  linear_vae
#
#
# Mean AUC score:  0.71328125
# Std of AUC scores:  0.0452248613700197
#
#
# Mean AP score:  0.7317297789972151
# Std of AP scores:  0.050325824720889804
#
#
# Mean total running time:  22.129985094070435
# Std of total running time:  1.9376908503419068
#
#
# ----------------------------------------------------------
#
# Model name:  gcn_vae
#
#
# Mean AUC score:  0.766015625
# Std of AUC scores:  0.07079801988149545
#
#
# Mean AP score:  0.7864706698964866
# Std of AP scores:  0.06407216636582798
#
#
# Mean total running time:  1.5185168981552124
# Std of total running time:  0.14641809284599303
#
#
# ----------------------------------------------------------
#
# Model name:  deep6_gcn_vae
#
#
# Mean AUC score:  0.78203125
# Std of AUC scores:  0.07491042828355075
#
#
# Mean AP score:  0.847084289182852
# Std of AP scores:  0.048597498985781314
#
#
# Mean total running time:  2.473905825614929
# Std of total running time:  0.3554003923629361
#
#
# ----------------------------------------------------------
#
# Model name:  deep12_gcn_vae
#
#
# Mean AUC score:  0.78359375
# Std of AUC scores:  0.08634844924780062
#
#
# Mean AP score:  0.8500916097828701
# Std of AP scores:  0.0508518734879934
#
#
# Mean total running time:  3.6837156772613526
# Std of total running time:  0.6251994483008857
#
#
# ----------------------------------------------------------
#
# Model name:  deep18_gcn_vae
#
#
# Mean AUC score:  0.795703125
# Std of AUC scores:  0.0488531186032747
#
#
# Mean AP score:  0.8497365514030613
# Std of AP scores:  0.042012208309118636
#
#
# Mean total running time:  4.918400692939758
# Std of total running time:  0.9408916446476663
#
#
# ----------------------------------------------------------
#
# Model name:  deep36_gcn_vae
#
#
# Mean AUC score:  0.7828125
# Std of AUC scores:  0.0453259678261259
#
#
# Mean AP score:  0.8405251955091997
# Std of AP scores:  0.028873106977062565
#
#
# Mean total running time:  8.646054458618163
# Std of total running time:  1.8507479225576295
#
#
# ----------------------------------------------------------
