# %%
import numpy as np
import pandas as pd

# %%
def print_results(p_model_name,p_features_used,p_used_number,all_data=False):
    print("Model name: ", p_model_name)
    print("\n")
    mean_time_read=np.array(pd.read_csv("./log/"+p_model_name+"_time_"+str(p_features_used)+".csv",header=None))[0]
    mean_roc_read=np.array(pd.read_csv("./log/"+p_model_name+"_roc_"+str(p_features_used)+".csv",header=None))[0]
    mean_ap_read=np.array(pd.read_csv("./log/"+p_model_name+"_ap_"+str(p_features_used)+".csv",header=None))[0]
    
    if all_data:
        print("AUC scores\n", mean_roc_read[0:p_used_number])
    print("Mean AUC score: ", np.mean(mean_roc_read[0:p_used_number]),
          "\nStd of AUC scores: ",np.std(mean_roc_read[0:p_used_number]), "\n \n")
    
    if all_data:
        print("AP scores\n", mean_ap_read[0:p_used_number])
    print("Mean AP score: ", np.mean(mean_ap_read[0:p_used_number]),
          "\nStd of AP scores: ", np.std(mean_ap_read[0:p_used_number]), "\n \n")

    if all_data:
        print("Total Running times\n", mean_time_read[0:p_used_number])
    print("Mean total running time: ", np.mean(mean_time_read[0:p_used_number]),
          "\nStd of total running time: ", np.std(mean_time_read[0:p_used_number]), "\n \n")

# %%
p_model_name=['linear_vae','gcn_vae','deep6_gcn_vae','deep12_gcn_vae','deep18_gcn_vae','deep36_gcn_vae']

for p_model_name_i in p_model_name:
    p_features_used=False
    p_used_number=10
    print_results(p_model_name_i,p_features_used,p_used_number,all_data=False)
    print("----------------------------------------------------------\n")
# Out:
# Model name:  linear_vae
#
#
# Mean AUC score:  0.4802951388888889
# Std of AUC scores:  0.08315324326709807
#
#
# Mean AP score:  0.5799603316477089
# Std of AP scores:  0.07863088788215274
#
#
# Mean total running time:  35.290795016288754
# Std of total running time:  1.4042391681644726
#
#
# ----------------------------------------------------------
#
# Model name:  gcn_vae
#
#
# Mean AUC score:  0.42795138888888884
# Std of AUC scores:  0.05004812679471356
#
#
# Mean AP score:  0.5146075548272552
# Std of AP scores:  0.043059870685093475
#
#
# Mean total running time:  36.101630902290346
# Std of total running time:  0.42137209431900635
#
#
# ----------------------------------------------------------
#
# Model name:  deep6_gcn_vae
#
#
# Mean AUC score:  0.26640625
# Std of AUC scores:  0.060169400919423445
#
#
# Mean AP score:  0.42524679726729275
# Std of AP scores:  0.06515155822125876
#
#
# Mean total running time:  40.87479169368744
# Std of total running time:  0.6522932409681308
#
#
# ----------------------------------------------------------
#
# Model name:  deep12_gcn_vae
#
#
# Mean AUC score:  0.671657986111111
# Std of AUC scores:  0.22654397822997993
#
#
# Mean AP score:  0.6813247041875582
# Std of AP scores:  0.13665028380394625
#
#
# Mean total running time:  42.90763404369354
# Std of total running time:  0.892148394710568
#
#
# ----------------------------------------------------------
#
# Model name:  deep18_gcn_vae
#
#
# Mean AUC score:  0.7798611111111111
# Std of AUC scores:  0.0344574322022101
#
#
# Mean AP score:  0.7389832341715522
# Std of AP scores:  0.04796179959944167
#
#
# Mean total running time:  47.47775731086731
# Std of total running time:  1.8526850712997773
#
#
# ----------------------------------------------------------
#
# Model name:  deep36_gcn_vae
#
#
# Mean AUC score:  0.7574435763888889
# Std of AUC scores:  0.04347542206264952
#
#
# Mean AP score:  0.7282276155840741
# Std of AP scores:  0.052030138420751146
#
#
# Mean total running time:  59.44583466053009
# Std of total running time:  1.7794058596115165
#
#
# ----------------------------------------------------------

# %%
for p_model_name_i in p_model_name:
    p_features_used=True
    p_used_number=10
    print_results(p_model_name_i,p_features_used,p_used_number,all_data=False)
    print("----------------------------------------------------------\n")
# Out:
# Model name:  linear_vae
#
#
# Mean AUC score:  0.5111111111111111
# Std of AUC scores:  0.06297321277705556
#
#
# Mean AP score:  0.5912978079066274
# Std of AP scores:  0.06024689738458779
#
#
# Mean total running time:  36.395325446128844
# Std of total running time:  1.4010030475813313
#
#
# ----------------------------------------------------------
#
# Model name:  gcn_vae
#
#
# Mean AUC score:  0.5262803819444445
# Std of AUC scores:  0.04896397479224775
#
#
# Mean AP score:  0.5863617859350166
# Std of AP scores:  0.05889632781713467
#
#
# Mean total running time:  37.1407616853714
# Std of total running time:  0.7246536646224983
#
#
# ----------------------------------------------------------
#
# Model name:  deep6_gcn_vae
#
#
# Mean AUC score:  0.3663411458333333
# Std of AUC scores:  0.06069358609754306
#
#
# Mean AP score:  0.4766830247396846
# Std of AP scores:  0.041388341824566535
#
#
# Mean total running time:  39.44936606884003
# Std of total running time:  0.6358557847599321
#
#
# ----------------------------------------------------------
#
# Model name:  deep12_gcn_vae
#
#
# Mean AUC score:  0.43734809027777777
# Std of AUC scores:  0.18278329069873334
#
#
# Mean AP score:  0.5280936181452346
# Std of AP scores:  0.12353774821012818
#
#
# Mean total running time:  43.5951523065567
# Std of total running time:  0.9518833859436961
#
#
# ----------------------------------------------------------
#
# Model name:  deep18_gcn_vae
#
#
# Mean AUC score:  0.7037760416666666
# Std of AUC scores:  0.04745196138541501
#
#
# Mean AP score:  0.6966096037535041
# Std of AP scores:  0.051609694827565146
#
#
# Mean total running time:  48.30989105701447
# Std of total running time:  1.5263782358229503
#
#
# ----------------------------------------------------------
#
# Model name:  deep36_gcn_vae
#
#
# Mean AUC score:  0.6844618055555555
# Std of AUC scores:  0.0460872309485566
#
#
# Mean AP score:  0.6706535839007376
# Std of AP scores:  0.04029751055790549
#
#
# Mean total running time:  60.38448348045349
# Std of total running time:  1.872440099013571
#
#
# ----------------------------------------------------------
