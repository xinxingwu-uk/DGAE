# %%
import numpy as np
import pandas as pd

# %%
def print_results(p_model_name,p_features_used,p_used_number,all_data=False):
    print("Model name: ", p_model_name)
    print("\n")
    mean_time_read=np.array(pd.read_csv("./log/"+p_model_name+"_time_"+str(p_features_used)+".csv",header=None))[0]
    mean_roc_read=np.array(pd.read_csv("./log/"+p_model_name+"_roc_"+str(p_features_used)+".csv",header=None))[0]
    mean_ap_read=np.array(pd.read_csv("./log/"+p_model_name+"_ap_"+str(p_features_used)+".csv",header=None))[0]
    
    if all_data:
        print("AUC scores\n", mean_roc_read[0:p_used_number])
    print("Mean AUC score: ", np.mean(mean_roc_read[0:p_used_number]),
          "\nStd of AUC scores: ",np.std(mean_roc_read[0:p_used_number]), "\n \n")
    
    if all_data:
        print("AP scores\n", mean_ap_read[0:p_used_number])
    print("Mean AP score: ", np.mean(mean_ap_read[0:p_used_number]),
          "\nStd of AP scores: ", np.std(mean_ap_read[0:p_used_number]), "\n \n")

    if all_data:
        print("Total Running times\n", mean_time_read[0:p_used_number])
    print("Mean total running time: ", np.mean(mean_time_read[0:p_used_number]),
          "\nStd of total running time: ", np.std(mean_time_read[0:p_used_number]), "\n \n")

# %%
p_model_name=['linear_vae','gcn_vae','deep6_gcn_vae','deep12_gcn_vae','deep18_gcn_vae','deep36_gcn_vae']

for p_model_name_i in p_model_name:
    p_features_used=False
    p_used_number=10
    print_results(p_model_name_i,p_features_used,p_used_number,all_data=False)
    print("----------------------------------------------------------\n")
# Out:
# Model name:  linear_vae
#
#
# Mean AUC score:  0.0703125
# Std of AUC scores:  0.06375689300969739
#
#
# Mean AP score:  0.35951766983016975
# Std of AP scores:  0.024119640404664123
#
#
# Mean total running time:  1.3773857831954956
# Std of total running time:  0.10904513275804607
#
#
# ----------------------------------------------------------
#
# Model name:  gcn_vae
#
#
# Mean AUC score:  0.084375
# Std of AUC scores:  0.07911868063232602
#
#
# Mean AP score:  0.36642739205239205
# Std of AP scores:  0.029136895717182636
#
#
# Mean total running time:  1.629748272895813
# Std of total running time:  0.15229098094899057
#
#
# ----------------------------------------------------------
#
# Model name:  deep6_gcn_vae
#
#
# Mean AUC score:  0.0875
# Std of AUC scores:  0.06257807623281496
#
#
# Mean AP score:  0.3836793761793761
# Std of AP scores:  0.04519837281977351
#
#
# Mean total running time:  2.6022226333618166
# Std of total running time:  0.3532101954462896
#
#
# ----------------------------------------------------------
#
# Model name:  deep12_gcn_vae
#
#
# Mean AUC score:  0.584375
# Std of AUC scores:  0.40656237990005906
#
#
# Mean AP score:  0.7149213633588634
# Std of AP scores:  0.2766947927192801
#
#
# Mean total running time:  3.8554226875305178
# Std of total running time:  0.6448840334726139
#
#
# ----------------------------------------------------------
#
# Model name:  deep18_gcn_vae
#
#
# Mean AUC score:  0.915625
# Std of AUC scores:  0.09196211855976351
#
#
# Mean AP score:  0.9471241952491953
# Std of AP scores:  0.05670468655003655
#
#
# Mean total running time:  5.1733564853668215
# Std of total running time:  0.9504349503121099
#
#
# ----------------------------------------------------------
#
# Model name:  deep36_gcn_vae
#
#
# Mean AUC score:  0.9203125
# Std of AUC scores:  0.07888690975852712
#
#
# Mean AP score:  0.9492442279942279
# Std of AP scores:  0.05005545101755556
#
#
# Mean total running time:  9.007935285568237
# Std of total running time:  1.8146474234959036
#
#
# ----------------------------------------------------------

# %%
for p_model_name_i in p_model_name:
    p_features_used=True
    p_used_number=10
    print_results(p_model_name_i,p_features_used,p_used_number,all_data=False)
    print("----------------------------------------------------------\n")
# Out:
# Model name:  linear_vae
#
#
# Mean AUC score:  0.13125
# Std of AUC scores:  0.1630100169468122
#
#
# Mean AP score:  0.42150290681540675
# Std of AP scores:  0.11195307542789798
#
#
# Mean total running time:  2.242813754081726
# Std of total running time:  0.11277819006848705
#
#
# ----------------------------------------------------------
#
# Model name:  gcn_vae
#
#
# Mean AUC score:  0.096875
# Std of AUC scores:  0.09369790219103094
#
#
# Mean AP score:  0.37985361860361866
# Std of AP scores:  0.06299224171319966
#
#
# Mean total running time:  2.1535671234130858
# Std of total running time:  0.1437538638931142
#
#
# ----------------------------------------------------------
#
# Model name:  deep6_gcn_vae
#
#
# Mean AUC score:  0.071875
# Std of AUC scores:  0.06218671481916375
#
#
# Mean AP score:  0.3807329476079476
# Std of AP scores:  0.047887804302352566
#
#
# Mean total running time:  3.113680386543274
# Std of total running time:  0.3340755019925408
#
#
# ----------------------------------------------------------
#
# Model name:  deep12_gcn_vae
#
#
# Mean AUC score:  0.15625
# Std of AUC scores:  0.10077822185373188
#
#
# Mean AP score:  0.4302838134088134
# Std of AP scores:  0.09472013609386006
#
#
# Mean total running time:  4.409640979766846
# Std of total running time:  0.6561980622144086
#
#
# ----------------------------------------------------------
#
# Model name:  deep18_gcn_vae
#
#
# Mean AUC score:  0.921875
# Std of AUC scores:  0.08866413099444442
#
#
# Mean AP score:  0.9504534007659007
# Std of AP scores:  0.056007750875004245
#
#
# Mean total running time:  5.706759285926819
# Std of total running time:  0.9497703738051725
#
#
# ----------------------------------------------------------
#
# Model name:  deep36_gcn_vae
#
#
# Mean AUC score:  0.9140625
# Std of AUC scores:  0.09813942967151379
#
#
# Mean AP score:  0.9458200133200133
# Std of AP scores:  0.06151662019962782
#
#
# Mean total running time:  9.570310068130492
# Std of total running time:  1.8251052065222517
#
#
# ----------------------------------------------------------
