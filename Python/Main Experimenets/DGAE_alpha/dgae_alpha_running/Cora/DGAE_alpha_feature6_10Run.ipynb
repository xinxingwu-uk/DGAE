# %% [markdown]
# # Import libraries

# %%
import numpy as np
import random as rn
import os
from keras import backend as K
import  tensorflow.compat.v1  as tf
tf.disable_v2_behavior() 
import tensorflow as tf

#--------------------------------------------------------------------------------------------------------------------
# Reproducible
seed=0
os.environ['PYTHONHASHSEED'] = str(seed)

np.random.seed(seed)
rn.seed(seed)
session_conf =tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
tf.compat.v1.set_random_seed(seed)
#--------------------------------------------------------------------------------------------------------------------

import scipy.sparse as sp
import time
import pandas as pd
import sys

from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

sys.path.append(r"../../")

from dgae_alpha.evaluation import get_roc_score
from dgae_alpha.input_data import load_data, load_label
from dgae_alpha.model import *
from dgae_alpha.optimizer import *
from dgae_alpha.preprocessing import *
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.8/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %% [markdown]
# # Parameters setting

# %%
layers_no=6
data_path="../../Datasets/"
path_now="./log/"

dataset='cora'
model_name='DGAE_alpha_feature'

dropout=0.0
epochs=200
features_used=True
learning_rate=0.01
nb_run=10
prop_val=5
prop_test=10
validation=True
verbose=True

# %% [markdown]
# # Load data

# %%
adj_init, features_init = load_data(dataset,data_path)
num_adj=adj_init.shape[1]

# %% [markdown]
# # Training and testing

# %%
loss_coeff_adj=0.001
loss_coeff_AE=0.05
results_output_path = path_now+model_name+"/"
mkdir(results_output_path)

for seed_i in np.arange(nb_run):
    
    seed=seed_i
    lost_list=[]
    roc_list=[]
    ap_list=[]
    mean_time=[]
    
    adj, val_edges, val_edges_false, test_edges, test_edges_false =mask_test_edges(adj_init, seed,prop_test, prop_val)
                
    t_start = time.time()

    if features_used:
        features = features_init
    
    num_nodes = adj.shape[0]

    if not features_used:
        features = sp.identity(adj.shape[0])

    features = sparse_to_tuple(features)
    num_features = features[2][1]
    features_nonzero = features[1].shape[0]
        
    placeholders = {
        'features': tf.sparse_placeholder(tf.float32),
        'adj': tf.sparse_placeholder(tf.float32),
        'adj_orig': tf.sparse_placeholder(tf.float32),
        'dropout': tf.placeholder_with_default(0., shape = ())
    }

#--------------------------------------------------------------------------------------------------------------------
# Create model
    if model_name=='DGAE_alpha_feature':
        model = DGAE_alpha_feature(placeholders, layers_no,num_features, features_nonzero)
    elif model_name=='DGAE_alpha_no_feature':
        model=DGAE_alpha_no_feature(placeholders, layers_no,num_features, num_adj,features_nonzero)
    else:
        raise ValueError('Undefined model!')

    pos_weight = float(adj.shape[0] * adj.shape[0] - adj.sum()) / adj.sum()
    norm = adj.shape[0] * adj.shape[0] / float((adj.shape[0] * adj.shape[0]- adj.sum()) * 2)
    
    with tf.name_scope('optimizer'):
        if model_name in ('DGAE_alpha_feature'):
            opt =OptimizerAE_FeatureReconstrution(preds_adj = model.reconstructions,\
                                                  preds_Features=model.feature_reconstruction,\
                                                  labels_adj = tf.reshape(tf.sparse_tensor_to_dense(placeholders['adj_orig'],\
                                                                                                    validate_indices = False), [-1]),\
                                                  labels_Features=placeholders['features'],\
                                                  labels_adj_rec=placeholders['adj'],\
                                                  loss_coeff_adj=loss_coeff_adj,\
                                                  loss_coeff_AE=loss_coeff_AE,\
                                                  pos_weight = pos_weight,\
                                                  norm = norm)
                
        elif model_name in ('DGAE_alpha_no_feature'):
            opt =OptimizerAE_AdjReconstrution(preds_adj = model.reconstructions,\
                                              preds_adj_rec=model.adj_reconstruction,\
                                              labels_adj = tf.reshape(tf.sparse_tensor_to_dense(placeholders['adj_orig'],
                                                                                                validate_indices = False), [-1]),\
                                              labels_Features=placeholders['features'],\
                                              labels_adj_rec=placeholders['adj'],\
                                              loss_coeff_adj=loss_coeff_adj,\
                                              loss_coeff_AE=loss_coeff_AE,\
                                              pos_weight = pos_weight,\
                                              norm = norm)

    adj_norm = preprocess_graph(adj)
    adj_label = sparse_to_tuple(adj + sp.eye(adj.shape[0]))

    sess = tf.Session()
    sess.run(tf.global_variables_initializer())
    
    for epoch in range(epochs):
        t = time.time()
        feed_dict = construct_feed_dict(adj_norm, adj_label, features,placeholders)
        feed_dict.update({placeholders['dropout']: dropout})
        outs = sess.run([opt.opt_op, opt.cost, opt.accuracy],feed_dict = feed_dict)
        avg_cost = outs[1]
        if verbose:
            lost_list.append(avg_cost)
            print("Epoch:", '%04d' % (epoch + 1), "training loss=", "{:.5f}".format(avg_cost),"time=", "{:.5f}".format(time.time() - t))
                    
            if validation:
                feed_dict.update({placeholders['dropout']: 0})
                emb = sess.run(model.z_mean, feed_dict = feed_dict)
                feed_dict.update({placeholders['dropout']: dropout})
                val_roc, val_ap = get_roc_score(val_edges, val_edges_false, emb)
                roc_list.append(val_roc)
                ap_list.append(val_ap)
                print("validation roc=", "{:.5f}".format(val_roc), "validation ap=", "{:.5f}".format(val_ap))

    emb = sess.run(model.z_mean, feed_dict = feed_dict)   
    mean_time.append(time.time() - t_start)
    
    roc_score, ap_score = get_roc_score(test_edges, test_edges_false, emb)
    print("testing roc=", "{:.5f}".format(roc_score), "testing ap=", "{:.5f}".format(ap_score))
    
    roc_list.append(roc_score)
    ap_list.append(ap_score)
    
    mean_time_=np.array(mean_time)
    write_to_csv(mean_time_.reshape(1,len(mean_time_)),results_output_path+"layers_"+str(layers_no)+"_time_10run.csv")

    roc_list_=np.array(roc_list)
    write_to_csv(roc_list_.reshape(1,len(roc_list_)),results_output_path+"layers_"+str(layers_no)+"_roc_10run.csv")

    ap_list_=np.array(ap_list)
    write_to_csv(ap_list_.reshape(1,len(ap_list_)),results_output_path+"layers_"+str(layers_no)+"_ap_10run.csv")
# Out:
# Failure
# WARNING:tensorflow:From /usr/local/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:201: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:201: calling weighted_cross_entropy_with_logits (from tensorflow.python.ops.nn_impl) with targets is deprecated and will be removed in a future version.
# Instructions for updating:
# targets is deprecated, use labels instead
# Epoch: 0001 training loss= 0.00102 time= 0.96153
# validation roc= 0.71097 validation ap= 0.75518
# Epoch: 0002 training loss= 0.00099 time= 0.20521
# validation roc= 0.69696 validation ap= 0.74583
# Epoch: 0003 training loss= 0.00107 time= 0.15192
# validation roc= 0.77036 validation ap= 0.80247
# Epoch: 0004 training loss= 0.00095 time= 0.13774
# validation roc= 0.70010 validation ap= 0.72469
# Epoch: 0005 training loss= 0.00095 time= 0.15342
# validation roc= 0.67387 validation ap= 0.70662
# Epoch: 0006 training loss= 0.00095 time= 0.14025
# validation roc= 0.71837 validation ap= 0.73927
# Epoch: 0007 training loss= 0.00093 time= 0.14021
# validation roc= 0.77204 validation ap= 0.77691
# Epoch: 0008 training loss= 0.00090 time= 0.15225
# validation roc= 0.79719 validation ap= 0.79091
# Epoch: 0009 training loss= 0.00088 time= 0.24148
# validation roc= 0.81707 validation ap= 0.80641
# Epoch: 0010 training loss= 0.00085 time= 0.41196
# validation roc= 0.83400 validation ap= 0.82341
# Epoch: 0011 training loss= 0.00082 time= 0.15195
# validation roc= 0.84113 validation ap= 0.83130
# Epoch: 0012 training loss= 0.00080 time= 0.15417
# validation roc= 0.84557 validation ap= 0.83685
# Epoch: 0013 training loss= 0.00079 time= 0.14717
# validation roc= 0.85255 validation ap= 0.84357
# Epoch: 0014 training loss= 0.00077 time= 0.13235
# validation roc= 0.85507 validation ap= 0.84530
# Epoch: 0015 training loss= 0.00075 time= 0.31117
# validation roc= 0.85773 validation ap= 0.84602
# Epoch: 0016 training loss= 0.00075 time= 0.13836
# validation roc= 0.86099 validation ap= 0.84888
# Epoch: 0017 training loss= 0.00074 time= 0.17567
# validation roc= 0.86297 validation ap= 0.85308
# Epoch: 0018 training loss= 0.00074 time= 0.12981
# validation roc= 0.86546 validation ap= 0.85798
# Epoch: 0019 training loss= 0.00073 time= 0.20491
# validation roc= 0.86763 validation ap= 0.86216
# Epoch: 0020 training loss= 0.00072 time= 0.11746
# validation roc= 0.87142 validation ap= 0.86717
# Epoch: 0021 training loss= 0.00071 time= 0.12664
# validation roc= 0.87612 validation ap= 0.87193
# Epoch: 0022 training loss= 0.00071 time= 0.12543
# validation roc= 0.87904 validation ap= 0.87306
# Epoch: 0023 training loss= 0.00070 time= 0.12583
# validation roc= 0.88052 validation ap= 0.87199
# Epoch: 0024 training loss= 0.00070 time= 0.13395
# validation roc= 0.88159 validation ap= 0.87044
# Epoch: 0025 training loss= 0.00070 time= 0.12961
# validation roc= 0.88278 validation ap= 0.87091
# Epoch: 0026 training loss= 0.00069 time= 0.23957
# validation roc= 0.88326 validation ap= 0.87140
# Epoch: 0027 training loss= 0.00069 time= 0.11991
# validation roc= 0.88469 validation ap= 0.87481
# Epoch: 0028 training loss= 0.00069 time= 0.11700
# validation roc= 0.88728 validation ap= 0.87995
# Epoch: 0029 training loss= 0.00068 time= 0.19007
# validation roc= 0.89047 validation ap= 0.88519
# Epoch: 0030 training loss= 0.00068 time= 0.13603
# validation roc= 0.89283 validation ap= 0.88922
# Epoch: 0031 training loss= 0.00067 time= 0.14504
# validation roc= 0.89497 validation ap= 0.89238
# Epoch: 0032 training loss= 0.00067 time= 0.11611
# validation roc= 0.89719 validation ap= 0.89457
# Epoch: 0033 training loss= 0.00067 time= 0.12315
# validation roc= 0.89935 validation ap= 0.89636
# Epoch: 0034 training loss= 0.00066 time= 0.13762
# validation roc= 0.90150 validation ap= 0.89834
# Epoch: 0035 training loss= 0.00066 time= 0.12071
# validation roc= 0.90410 validation ap= 0.90066
# Epoch: 0036 training loss= 0.00066 time= 0.12364
# validation roc= 0.90679 validation ap= 0.90248
# Epoch: 0037 training loss= 0.00066 time= 0.11205
# validation roc= 0.90873 validation ap= 0.90379
# Epoch: 0038 training loss= 0.00065 time= 0.09734
# validation roc= 0.90980 validation ap= 0.90445
# Epoch: 0039 training loss= 0.00065 time= 0.12326
# validation roc= 0.91078 validation ap= 0.90573
# Epoch: 0040 training loss= 0.00065 time= 0.10881
# validation roc= 0.91213 validation ap= 0.90774
# Epoch: 0041 training loss= 0.00065 time= 0.21282
# validation roc= 0.91324 validation ap= 0.90912
# Epoch: 0042 training loss= 0.00065 time= 0.08984
# validation roc= 0.91411 validation ap= 0.91033
# Epoch: 0043 training loss= 0.00064 time= 0.09757
# validation roc= 0.91483 validation ap= 0.91115
# Epoch: 0044 training loss= 0.00064 time= 0.10879
# validation roc= 0.91557 validation ap= 0.91202
# Epoch: 0045 training loss= 0.00064 time= 0.10579
# validation roc= 0.91622 validation ap= 0.91324
# Epoch: 0046 training loss= 0.00064 time= 0.08539
# validation roc= 0.91662 validation ap= 0.91398
# Epoch: 0047 training loss= 0.00064 time= 0.09007
# validation roc= 0.91709 validation ap= 0.91516
# Epoch: 0048 training loss= 0.00064 time= 0.09780
# validation roc= 0.91694 validation ap= 0.91545
# Epoch: 0049 training loss= 0.00063 time= 0.09357
# validation roc= 0.91722 validation ap= 0.91636
# Epoch: 0050 training loss= 0.00063 time= 0.08941
# validation roc= 0.91755 validation ap= 0.91699
# Epoch: 0051 training loss= 0.00063 time= 0.09062
# validation roc= 0.91795 validation ap= 0.91739
# Epoch: 0052 training loss= 0.00063 time= 0.10582
# validation roc= 0.91850 validation ap= 0.91793
# Epoch: 0053 training loss= 0.00063 time= 0.10277
# validation roc= 0.91875 validation ap= 0.91811
# Epoch: 0054 training loss= 0.00063 time= 0.08748
# validation roc= 0.91953 validation ap= 0.91854
# Epoch: 0055 training loss= 0.00062 time= 0.09416
# validation roc= 0.92086 validation ap= 0.91994
# Epoch: 0056 training loss= 0.00062 time= 0.09583
# validation roc= 0.92194 validation ap= 0.92100
# Epoch: 0057 training loss= 0.00062 time= 0.09592
# validation roc= 0.92231 validation ap= 0.92093
# Epoch: 0058 training loss= 0.00062 time= 0.09232
# validation roc= 0.92270 validation ap= 0.92117
# Epoch: 0059 training loss= 0.00062 time= 0.08810
# validation roc= 0.92286 validation ap= 0.92129
# Epoch: 0060 training loss= 0.00062 time= 0.09799
# validation roc= 0.92390 validation ap= 0.92256
# Epoch: 0061 training loss= 0.00062 time= 0.08311
# validation roc= 0.92495 validation ap= 0.92344
# Epoch: 0062 training loss= 0.00061 time= 0.10321
# validation roc= 0.92559 validation ap= 0.92448
# Epoch: 0063 training loss= 0.00061 time= 0.09129
# validation roc= 0.92620 validation ap= 0.92552
# Epoch: 0064 training loss= 0.00061 time= 0.08527
# validation roc= 0.92605 validation ap= 0.92567
# Epoch: 0065 training loss= 0.00061 time= 0.09322
# validation roc= 0.92627 validation ap= 0.92628
# Epoch: 0066 training loss= 0.00061 time= 0.09850
# validation roc= 0.92682 validation ap= 0.92684
# Epoch: 0067 training loss= 0.00061 time= 0.08874
# validation roc= 0.92793 validation ap= 0.92783
# Epoch: 0068 training loss= 0.00061 time= 0.10861
# validation roc= 0.92842 validation ap= 0.92858
# Epoch: 0069 training loss= 0.00061 time= 0.08798
# validation roc= 0.92841 validation ap= 0.92868
# Epoch: 0070 training loss= 0.00061 time= 0.09488
# validation roc= 0.92813 validation ap= 0.92880
# Epoch: 0071 training loss= 0.00061 time= 0.09004
# validation roc= 0.92810 validation ap= 0.92871
# Epoch: 0072 training loss= 0.00060 time= 0.08921
# validation roc= 0.92815 validation ap= 0.92868
# Epoch: 0073 training loss= 0.00060 time= 0.10119
# validation roc= 0.92822 validation ap= 0.92880
# Epoch: 0074 training loss= 0.00060 time= 0.13047
# validation roc= 0.92822 validation ap= 0.92882
# Epoch: 0075 training loss= 0.00060 time= 0.09224
# validation roc= 0.92793 validation ap= 0.92864
# Epoch: 0076 training loss= 0.00060 time= 0.10443
# validation roc= 0.92787 validation ap= 0.92858
# Epoch: 0077 training loss= 0.00060 time= 0.12563
# validation roc= 0.92787 validation ap= 0.92878
# Epoch: 0078 training loss= 0.00060 time= 0.08227
# validation roc= 0.92764 validation ap= 0.92891
# Epoch: 0079 training loss= 0.00060 time= 0.10082
# validation roc= 0.92776 validation ap= 0.92923
# Epoch: 0080 training loss= 0.00060 time= 0.11458
# validation roc= 0.92767 validation ap= 0.92917
# Epoch: 0081 training loss= 0.00060 time= 0.08799
# validation roc= 0.92776 validation ap= 0.92950
# Epoch: 0082 training loss= 0.00059 time= 0.10398
# validation roc= 0.92758 validation ap= 0.92940
# Epoch: 0083 training loss= 0.00059 time= 0.09684
# validation roc= 0.92744 validation ap= 0.92937
# Epoch: 0084 training loss= 0.00059 time= 0.09342
# validation roc= 0.92740 validation ap= 0.92966
# Epoch: 0085 training loss= 0.00059 time= 0.09212
# validation roc= 0.92734 validation ap= 0.92962
# Epoch: 0086 training loss= 0.00059 time= 0.08746
# validation roc= 0.92713 validation ap= 0.92947
# Epoch: 0087 training loss= 0.00059 time= 0.09072
# validation roc= 0.92715 validation ap= 0.92951
# Epoch: 0088 training loss= 0.00059 time= 0.08357
# validation roc= 0.92693 validation ap= 0.92941
# Epoch: 0089 training loss= 0.00059 time= 0.09303
# validation roc= 0.92660 validation ap= 0.92915
# Epoch: 0090 training loss= 0.00059 time= 0.14672
# validation roc= 0.92634 validation ap= 0.92894
# Epoch: 0091 training loss= 0.00059 time= 0.08402
# validation roc= 0.92599 validation ap= 0.92860
# Epoch: 0092 training loss= 0.00059 time= 0.09636
# validation roc= 0.92562 validation ap= 0.92853
# Epoch: 0093 training loss= 0.00058 time= 0.08624
# validation roc= 0.92547 validation ap= 0.92854
# Epoch: 0094 training loss= 0.00058 time= 0.08964
# validation roc= 0.92536 validation ap= 0.92858
# Epoch: 0095 training loss= 0.00058 time= 0.09926
# validation roc= 0.92536 validation ap= 0.92869
# Epoch: 0096 training loss= 0.00058 time= 0.11445
# validation roc= 0.92533 validation ap= 0.92868
# Epoch: 0097 training loss= 0.00058 time= 0.10145
# validation roc= 0.92531 validation ap= 0.92882
# Epoch: 0098 training loss= 0.00058 time= 0.09892
# validation roc= 0.92553 validation ap= 0.92913
# Epoch: 0099 training loss= 0.00058 time= 0.08004
# validation roc= 0.92539 validation ap= 0.92894
# Epoch: 0100 training loss= 0.00058 time= 0.08985
# validation roc= 0.92533 validation ap= 0.92891
# Epoch: 0101 training loss= 0.00058 time= 0.08518
# validation roc= 0.92549 validation ap= 0.92928
# Epoch: 0102 training loss= 0.00058 time= 0.09917
# validation roc= 0.92557 validation ap= 0.92933
# Epoch: 0103 training loss= 0.00058 time= 0.09936
# validation roc= 0.92589 validation ap= 0.92971
# Epoch: 0104 training loss= 0.00058 time= 0.07922
# validation roc= 0.92646 validation ap= 0.93034
# Epoch: 0105 training loss= 0.00058 time= 0.09790
# validation roc= 0.92648 validation ap= 0.93025
# Epoch: 0106 training loss= 0.00058 time= 0.09040
# validation roc= 0.92689 validation ap= 0.93071
# Epoch: 0107 training loss= 0.00058 time= 0.10037
# validation roc= 0.92702 validation ap= 0.93070
# Epoch: 0108 training loss= 0.00058 time= 0.07867
# validation roc= 0.92721 validation ap= 0.93093
# Epoch: 0109 training loss= 0.00057 time= 0.07779
# validation roc= 0.92738 validation ap= 0.93096
# Epoch: 0110 training loss= 0.00057 time= 0.08821
# validation roc= 0.92755 validation ap= 0.93096
# Epoch: 0111 training loss= 0.00057 time= 0.09447
# validation roc= 0.92771 validation ap= 0.93106
# Epoch: 0112 training loss= 0.00057 time= 0.08212
# validation roc= 0.92763 validation ap= 0.93083
# Epoch: 0113 training loss= 0.00057 time= 0.08469
# validation roc= 0.92797 validation ap= 0.93110
# Epoch: 0114 training loss= 0.00057 time= 0.12986
# validation roc= 0.92816 validation ap= 0.93125
# Epoch: 0115 training loss= 0.00057 time= 0.09051
# validation roc= 0.92835 validation ap= 0.93131
# Epoch: 0116 training loss= 0.00057 time= 0.08365
# validation roc= 0.92839 validation ap= 0.93121
# Epoch: 0117 training loss= 0.00057 time= 0.12081
# validation roc= 0.92855 validation ap= 0.93136
# Epoch: 0118 training loss= 0.00057 time= 0.11062
# validation roc= 0.92864 validation ap= 0.93146
# Epoch: 0119 training loss= 0.00057 time= 0.10839
# validation roc= 0.92888 validation ap= 0.93163
# Epoch: 0120 training loss= 0.00057 time= 0.19106
# validation roc= 0.92896 validation ap= 0.93160
# Epoch: 0121 training loss= 0.00057 time= 0.14171
# validation roc= 0.92910 validation ap= 0.93171
# Epoch: 0122 training loss= 0.00057 time= 0.19725
# validation roc= 0.92929 validation ap= 0.93187
# Epoch: 0123 training loss= 0.00057 time= 0.10422
# validation roc= 0.92946 validation ap= 0.93193
# Epoch: 0124 training loss= 0.00057 time= 0.11959
# validation roc= 0.92962 validation ap= 0.93197
# Epoch: 0125 training loss= 0.00057 time= 0.11576
# validation roc= 0.92984 validation ap= 0.93230
# Epoch: 0126 training loss= 0.00057 time= 0.15745
# validation roc= 0.93014 validation ap= 0.93257
# Epoch: 0127 training loss= 0.00057 time= 0.40105
# validation roc= 0.93024 validation ap= 0.93278
# Epoch: 0128 training loss= 0.00056 time= 0.13841
# validation roc= 0.93063 validation ap= 0.93322
# Epoch: 0129 training loss= 0.00056 time= 0.12640
# validation roc= 0.93094 validation ap= 0.93348
# Epoch: 0130 training loss= 0.00056 time= 0.12841
# validation roc= 0.93131 validation ap= 0.93384
# Epoch: 0131 training loss= 0.00056 time= 0.12752
# validation roc= 0.93149 validation ap= 0.93416
# Epoch: 0132 training loss= 0.00056 time= 0.15912
# validation roc= 0.93165 validation ap= 0.93436
# Epoch: 0133 training loss= 0.00056 time= 0.12397
# validation roc= 0.93209 validation ap= 0.93495
# Epoch: 0134 training loss= 0.00056 time= 0.11986
# validation roc= 0.93234 validation ap= 0.93521
# Epoch: 0135 training loss= 0.00056 time= 0.10053
# validation roc= 0.93287 validation ap= 0.93588
# Epoch: 0136 training loss= 0.00056 time= 0.10376
# validation roc= 0.93318 validation ap= 0.93627
# Epoch: 0137 training loss= 0.00056 time= 0.11699
# validation roc= 0.93334 validation ap= 0.93643
# Epoch: 0138 training loss= 0.00056 time= 0.12107
# validation roc= 0.93357 validation ap= 0.93679
# Epoch: 0139 training loss= 0.00056 time= 0.12263
# validation roc= 0.93367 validation ap= 0.93707
# Epoch: 0140 training loss= 0.00056 time= 0.13769
# validation roc= 0.93403 validation ap= 0.93763
# Epoch: 0141 training loss= 0.00056 time= 0.11957
# validation roc= 0.93420 validation ap= 0.93788
# Epoch: 0142 training loss= 0.00056 time= 0.09876
# validation roc= 0.93420 validation ap= 0.93791
# Epoch: 0143 training loss= 0.00056 time= 0.08423
# validation roc= 0.93455 validation ap= 0.93846
# Epoch: 0144 training loss= 0.00056 time= 0.09369
# validation roc= 0.93465 validation ap= 0.93869
# Epoch: 0145 training loss= 0.00056 time= 0.09519
# validation roc= 0.93488 validation ap= 0.93891
# Epoch: 0146 training loss= 0.00056 time= 0.32590
# validation roc= 0.93473 validation ap= 0.93877
# Epoch: 0147 training loss= 0.00056 time= 0.10199
# validation roc= 0.93523 validation ap= 0.93954
# Epoch: 0148 training loss= 0.00056 time= 0.14983
# validation roc= 0.93415 validation ap= 0.93823
# Epoch: 0149 training loss= 0.00056 time= 0.13492
# validation roc= 0.93536 validation ap= 0.94016
# Epoch: 0150 training loss= 0.00056 time= 0.12668
# validation roc= 0.93512 validation ap= 0.93957
# Epoch: 0151 training loss= 0.00055 time= 0.14610
# validation roc= 0.93491 validation ap= 0.93977
# Epoch: 0152 training loss= 0.00055 time= 0.11431
# validation roc= 0.93512 validation ap= 0.94014
# Epoch: 0153 training loss= 0.00055 time= 0.10342
# validation roc= 0.93500 validation ap= 0.93956
# Epoch: 0154 training loss= 0.00055 time= 0.14946
# validation roc= 0.93551 validation ap= 0.94080
# Epoch: 0155 training loss= 0.00055 time= 0.12094
# validation roc= 0.93535 validation ap= 0.94087
# Epoch: 0156 training loss= 0.00055 time= 0.11678
# validation roc= 0.93520 validation ap= 0.94007
# Epoch: 0157 training loss= 0.00055 time= 0.12868
# validation roc= 0.93594 validation ap= 0.94148
# Epoch: 0158 training loss= 0.00055 time= 0.13072
# validation roc= 0.93562 validation ap= 0.94134
# Epoch: 0159 training loss= 0.00055 time= 0.13232
# validation roc= 0.93522 validation ap= 0.94046
# Epoch: 0160 training loss= 0.00055 time= 0.13295
# validation roc= 0.93614 validation ap= 0.94182
# Epoch: 0161 training loss= 0.00055 time= 0.19310
# validation roc= 0.93601 validation ap= 0.94181
# Epoch: 0162 training loss= 0.00055 time= 0.11393
# validation roc= 0.93542 validation ap= 0.94098
# Epoch: 0163 training loss= 0.00055 time= 0.12127
# validation roc= 0.93608 validation ap= 0.94180
# Epoch: 0164 training loss= 0.00055 time= 0.25538
# validation roc= 0.93603 validation ap= 0.94192
# Epoch: 0165 training loss= 0.00055 time= 0.11428
# validation roc= 0.93549 validation ap= 0.94135
# Epoch: 0166 training loss= 0.00055 time= 0.09068
# validation roc= 0.93587 validation ap= 0.94165
# Epoch: 0167 training loss= 0.00055 time= 0.09016
# validation roc= 0.93630 validation ap= 0.94214
# Epoch: 0168 training loss= 0.00055 time= 0.08864
# validation roc= 0.93587 validation ap= 0.94163
# Epoch: 0169 training loss= 0.00055 time= 0.09298
# validation roc= 0.93579 validation ap= 0.94176
# Epoch: 0170 training loss= 0.00055 time= 0.09374
# validation roc= 0.93649 validation ap= 0.94228
# Epoch: 0171 training loss= 0.00055 time= 0.09332
# validation roc= 0.93611 validation ap= 0.94197
# Epoch: 0172 training loss= 0.00055 time= 0.10766
# validation roc= 0.93587 validation ap= 0.94184
# Epoch: 0173 training loss= 0.00055 time= 0.11820
# validation roc= 0.93627 validation ap= 0.94209
# Epoch: 0174 training loss= 0.00055 time= 0.12917
# validation roc= 0.93614 validation ap= 0.94202
# Epoch: 0175 training loss= 0.00055 time= 0.14239
# validation roc= 0.93606 validation ap= 0.94200
# Epoch: 0176 training loss= 0.00055 time= 0.11693
# validation roc= 0.93623 validation ap= 0.94217
# Epoch: 0177 training loss= 0.00055 time= 0.12075
# validation roc= 0.93616 validation ap= 0.94216
# Epoch: 0178 training loss= 0.00055 time= 0.12165
# validation roc= 0.93597 validation ap= 0.94200
# Epoch: 0179 training loss= 0.00055 time= 0.12139
# validation roc= 0.93610 validation ap= 0.94210
# Epoch: 0180 training loss= 0.00055 time= 0.12750
# validation roc= 0.93624 validation ap= 0.94237
# Epoch: 0181 training loss= 0.00054 time= 0.14418
# validation roc= 0.93566 validation ap= 0.94181
# Epoch: 0182 training loss= 0.00054 time= 0.12568
# validation roc= 0.93585 validation ap= 0.94194
# Epoch: 0183 training loss= 0.00054 time= 0.15287
# validation roc= 0.93598 validation ap= 0.94212
# Epoch: 0184 training loss= 0.00054 time= 0.12976
# validation roc= 0.93545 validation ap= 0.94155
# Epoch: 0185 training loss= 0.00054 time= 0.12371
# validation roc= 0.93552 validation ap= 0.94175
# Epoch: 0186 training loss= 0.00054 time= 0.11425
# validation roc= 0.93556 validation ap= 0.94170
# Epoch: 0187 training loss= 0.00054 time= 0.12572
# validation roc= 0.93529 validation ap= 0.94142
# Epoch: 0188 training loss= 0.00054 time= 0.12129
# validation roc= 0.93530 validation ap= 0.94151
# Epoch: 0189 training loss= 0.00054 time= 0.12187
# validation roc= 0.93552 validation ap= 0.94180
# Epoch: 0190 training loss= 0.00054 time= 0.12113
# validation roc= 0.93530 validation ap= 0.94142
# Epoch: 0191 training loss= 0.00054 time= 0.12372
# validation roc= 0.93530 validation ap= 0.94154
# Epoch: 0192 training loss= 0.00054 time= 0.12007
# validation roc= 0.93504 validation ap= 0.94102
# Epoch: 0193 training loss= 0.00054 time= 0.11821
# validation roc= 0.93496 validation ap= 0.94122
# Epoch: 0194 training loss= 0.00054 time= 0.12694
# validation roc= 0.93449 validation ap= 0.94026
# Epoch: 0195 training loss= 0.00054 time= 0.12181
# validation roc= 0.93474 validation ap= 0.94113
# Epoch: 0196 training loss= 0.00054 time= 0.14064
# validation roc= 0.93394 validation ap= 0.93928
# Epoch: 0197 training loss= 0.00054 time= 0.12701
# validation roc= 0.93455 validation ap= 0.94140
# Epoch: 0198 training loss= 0.00054 time= 0.10787
# validation roc= 0.93429 validation ap= 0.94013
# Epoch: 0199 training loss= 0.00054 time= 0.12739
# validation roc= 0.93415 validation ap= 0.94036
# Epoch: 0200 training loss= 0.00054 time= 0.12624
# validation roc= 0.93470 validation ap= 0.94109
# testing roc= 0.93639 testing ap= 0.94365
# Epoch: 0001 training loss= 0.00102 time= 1.47154
# validation roc= 0.68817 validation ap= 0.71991
# Epoch: 0002 training loss= 0.00099 time= 0.45621
# validation roc= 0.67097 validation ap= 0.71136
# Epoch: 0003 training loss= 0.00107 time= 0.25331
# validation roc= 0.75774 validation ap= 0.77902
# Epoch: 0004 training loss= 0.00095 time= 0.35566
# validation roc= 0.71230 validation ap= 0.73269
# Epoch: 0005 training loss= 0.00095 time= 0.36825
# validation roc= 0.68580 validation ap= 0.71312
# Epoch: 0006 training loss= 0.00095 time= 0.34443
# validation roc= 0.73776 validation ap= 0.75533
# Epoch: 0007 training loss= 0.00093 time= 0.11699
# validation roc= 0.78878 validation ap= 0.79950
# Epoch: 0008 training loss= 0.00090 time= 0.12343
# validation roc= 0.81389 validation ap= 0.81641
# Epoch: 0009 training loss= 0.00088 time= 0.11271
# validation roc= 0.83199 validation ap= 0.83103
# Epoch: 0010 training loss= 0.00085 time= 0.36641
# validation roc= 0.84586 validation ap= 0.84528
# Epoch: 0011 training loss= 0.00082 time= 0.11075
# validation roc= 0.85199 validation ap= 0.85123
# Epoch: 0012 training loss= 0.00080 time= 0.31454
# validation roc= 0.85583 validation ap= 0.85566
# Epoch: 0013 training loss= 0.00078 time= 0.13273
# validation roc= 0.86283 validation ap= 0.86476
# Epoch: 0014 training loss= 0.00076 time= 0.12905
# validation roc= 0.86620 validation ap= 0.86824
# Epoch: 0015 training loss= 0.00075 time= 0.11859
# validation roc= 0.87032 validation ap= 0.87141
# Epoch: 0016 training loss= 0.00075 time= 0.22250
# validation roc= 0.87413 validation ap= 0.87414
# Epoch: 0017 training loss= 0.00074 time= 0.12187
# validation roc= 0.87779 validation ap= 0.87770
# Epoch: 0018 training loss= 0.00073 time= 0.13551
# validation roc= 0.88144 validation ap= 0.88052
# Epoch: 0019 training loss= 0.00073 time= 0.10525
# validation roc= 0.88577 validation ap= 0.88361
# Epoch: 0020 training loss= 0.00072 time= 0.10406
# validation roc= 0.89072 validation ap= 0.88783
# Epoch: 0021 training loss= 0.00071 time= 0.09194
# validation roc= 0.89455 validation ap= 0.89128
# Epoch: 0022 training loss= 0.00070 time= 0.18860
# validation roc= 0.89695 validation ap= 0.89399
# Epoch: 0023 training loss= 0.00070 time= 0.12662
# validation roc= 0.89685 validation ap= 0.89201
# Epoch: 0024 training loss= 0.00070 time= 0.12524
# validation roc= 0.89780 validation ap= 0.89190
# Epoch: 0025 training loss= 0.00070 time= 0.13533
# validation roc= 0.89851 validation ap= 0.89110
# Epoch: 0026 training loss= 0.00069 time= 0.12166
# validation roc= 0.89949 validation ap= 0.89163
# Epoch: 0027 training loss= 0.00069 time= 0.12844
# validation roc= 0.90033 validation ap= 0.89281
# Epoch: 0028 training loss= 0.00068 time= 0.13179
# validation roc= 0.90181 validation ap= 0.89618
# Epoch: 0029 training loss= 0.00068 time= 0.12227
# validation roc= 0.90292 validation ap= 0.89874
# Epoch: 0030 training loss= 0.00068 time= 0.13637
# validation roc= 0.90311 validation ap= 0.89989
# Epoch: 0031 training loss= 0.00067 time= 0.11287
# validation roc= 0.90319 validation ap= 0.90039
# Epoch: 0032 training loss= 0.00067 time= 0.13561
# validation roc= 0.90233 validation ap= 0.89951
# Epoch: 0033 training loss= 0.00067 time= 0.14293
# validation roc= 0.90205 validation ap= 0.89931
# Epoch: 0034 training loss= 0.00066 time= 0.10977
# validation roc= 0.90215 validation ap= 0.90031
# Epoch: 0035 training loss= 0.00066 time= 0.09340
# validation roc= 0.90309 validation ap= 0.90264
# Epoch: 0036 training loss= 0.00066 time= 0.11211
# validation roc= 0.90377 validation ap= 0.90450
# Epoch: 0037 training loss= 0.00065 time= 0.09580
# validation roc= 0.90397 validation ap= 0.90539
# Epoch: 0038 training loss= 0.00065 time= 0.15206
# validation roc= 0.90410 validation ap= 0.90590
# Epoch: 0039 training loss= 0.00065 time= 0.28892
# validation roc= 0.90395 validation ap= 0.90568
# Epoch: 0040 training loss= 0.00065 time= 0.13409
# validation roc= 0.90441 validation ap= 0.90654
# Epoch: 0041 training loss= 0.00065 time= 0.11634
# validation roc= 0.90526 validation ap= 0.90782
# Epoch: 0042 training loss= 0.00065 time= 0.08623
# validation roc= 0.90595 validation ap= 0.90881
# Epoch: 0043 training loss= 0.00064 time= 0.10488
# validation roc= 0.90720 validation ap= 0.91023
# Epoch: 0044 training loss= 0.00064 time= 0.10122
# validation roc= 0.90799 validation ap= 0.91115
# Epoch: 0045 training loss= 0.00064 time= 0.11361
# validation roc= 0.90877 validation ap= 0.91199
# Epoch: 0046 training loss= 0.00064 time= 0.12309
# validation roc= 0.90954 validation ap= 0.91243
# Epoch: 0047 training loss= 0.00064 time= 0.12221
# validation roc= 0.90984 validation ap= 0.91262
# Epoch: 0048 training loss= 0.00063 time= 0.14151
# validation roc= 0.91036 validation ap= 0.91293
# Epoch: 0049 training loss= 0.00063 time= 0.11682
# validation roc= 0.91112 validation ap= 0.91381
# Epoch: 0050 training loss= 0.00063 time= 0.12371
# validation roc= 0.91169 validation ap= 0.91463
# Epoch: 0051 training loss= 0.00063 time= 0.14544
# validation roc= 0.91236 validation ap= 0.91559
# Epoch: 0052 training loss= 0.00063 time= 0.12972
# validation roc= 0.91265 validation ap= 0.91623
# Epoch: 0053 training loss= 0.00063 time= 0.22458
# validation roc= 0.91300 validation ap= 0.91666
# Epoch: 0054 training loss= 0.00063 time= 0.26033
# validation roc= 0.91365 validation ap= 0.91723
# Epoch: 0055 training loss= 0.00062 time= 0.10112
# validation roc= 0.91428 validation ap= 0.91788
# Epoch: 0056 training loss= 0.00062 time= 0.11210
# validation roc= 0.91482 validation ap= 0.91861
# Epoch: 0057 training loss= 0.00062 time= 0.10290
# validation roc= 0.91576 validation ap= 0.91990
# Epoch: 0058 training loss= 0.00062 time= 0.09525
# validation roc= 0.91623 validation ap= 0.92032
# Epoch: 0059 training loss= 0.00062 time= 0.15756
# validation roc= 0.91638 validation ap= 0.92021
# Epoch: 0060 training loss= 0.00062 time= 0.14132
# validation roc= 0.91699 validation ap= 0.92098
# Epoch: 0061 training loss= 0.00062 time= 0.13242
# validation roc= 0.91749 validation ap= 0.92118
# Epoch: 0062 training loss= 0.00061 time= 0.13443
# validation roc= 0.91775 validation ap= 0.92131
# Epoch: 0063 training loss= 0.00061 time= 0.11679
# validation roc= 0.91782 validation ap= 0.92165
# Epoch: 0064 training loss= 0.00061 time= 0.12407
# validation roc= 0.91785 validation ap= 0.92167
# Epoch: 0065 training loss= 0.00061 time= 0.11138
# validation roc= 0.91771 validation ap= 0.92149
# Epoch: 0066 training loss= 0.00061 time= 0.11973
# validation roc= 0.91778 validation ap= 0.92121
# Epoch: 0067 training loss= 0.00061 time= 0.12560
# validation roc= 0.91806 validation ap= 0.92124
# Epoch: 0068 training loss= 0.00061 time= 0.11726
# validation roc= 0.91814 validation ap= 0.92130
# Epoch: 0069 training loss= 0.00061 time= 0.12482
# validation roc= 0.91833 validation ap= 0.92156
# Epoch: 0070 training loss= 0.00061 time= 0.11895
# validation roc= 0.91855 validation ap= 0.92213
# Epoch: 0071 training loss= 0.00061 time= 0.11623
# validation roc= 0.91891 validation ap= 0.92250
# Epoch: 0072 training loss= 0.00060 time= 0.09891
# validation roc= 0.91927 validation ap= 0.92251
# Epoch: 0073 training loss= 0.00060 time= 0.09140
# validation roc= 0.91972 validation ap= 0.92278
# Epoch: 0074 training loss= 0.00060 time= 0.09526
# validation roc= 0.92022 validation ap= 0.92340
# Epoch: 0075 training loss= 0.00060 time= 0.09793
# validation roc= 0.92098 validation ap= 0.92447
# Epoch: 0076 training loss= 0.00060 time= 0.08723
# validation roc= 0.92161 validation ap= 0.92540
# Epoch: 0077 training loss= 0.00060 time= 0.10191
# validation roc= 0.92203 validation ap= 0.92587
# Epoch: 0078 training loss= 0.00060 time= 0.09605
# validation roc= 0.92258 validation ap= 0.92665
# Epoch: 0079 training loss= 0.00060 time= 0.07884
# validation roc= 0.92312 validation ap= 0.92712
# Epoch: 0080 training loss= 0.00060 time= 0.09195
# validation roc= 0.92378 validation ap= 0.92800
# Epoch: 0081 training loss= 0.00060 time= 0.09531
# validation roc= 0.92424 validation ap= 0.92852
# Epoch: 0082 training loss= 0.00059 time= 0.08150
# validation roc= 0.92492 validation ap= 0.92927
# Epoch: 0083 training loss= 0.00059 time= 0.09217
# validation roc= 0.92536 validation ap= 0.92985
# Epoch: 0084 training loss= 0.00059 time= 0.09005
# validation roc= 0.92583 validation ap= 0.93050
# Epoch: 0085 training loss= 0.00059 time= 0.11340
# validation roc= 0.92596 validation ap= 0.93080
# Epoch: 0086 training loss= 0.00059 time= 0.08667
# validation roc= 0.92637 validation ap= 0.93145
# Epoch: 0087 training loss= 0.00059 time= 0.09759
# validation roc= 0.92677 validation ap= 0.93211
# Epoch: 0088 training loss= 0.00059 time= 0.08834
# validation roc= 0.92713 validation ap= 0.93250
# Epoch: 0089 training loss= 0.00059 time= 0.08404
# validation roc= 0.92716 validation ap= 0.93283
# Epoch: 0090 training loss= 0.00059 time= 0.09846
# validation roc= 0.92699 validation ap= 0.93307
# Epoch: 0091 training loss= 0.00059 time= 0.09285
# validation roc= 0.92695 validation ap= 0.93334
# Epoch: 0092 training loss= 0.00059 time= 0.09254
# validation roc= 0.92702 validation ap= 0.93359
# Epoch: 0093 training loss= 0.00059 time= 0.08733
# validation roc= 0.92712 validation ap= 0.93386
# Epoch: 0094 training loss= 0.00058 time= 0.09419
# validation roc= 0.92728 validation ap= 0.93418
# Epoch: 0095 training loss= 0.00058 time= 0.10560
# validation roc= 0.92725 validation ap= 0.93437
# Epoch: 0096 training loss= 0.00058 time= 0.11155
# validation roc= 0.92721 validation ap= 0.93465
# Epoch: 0097 training loss= 0.00058 time= 0.08526
# validation roc= 0.92722 validation ap= 0.93502
# Epoch: 0098 training loss= 0.00058 time= 0.10134
# validation roc= 0.92709 validation ap= 0.93513
# Epoch: 0099 training loss= 0.00058 time= 0.08801
# validation roc= 0.92713 validation ap= 0.93541
# Epoch: 0100 training loss= 0.00058 time= 0.10486
# validation roc= 0.92711 validation ap= 0.93554
# Epoch: 0101 training loss= 0.00058 time= 0.09626
# validation roc= 0.92728 validation ap= 0.93593
# Epoch: 0102 training loss= 0.00058 time= 0.09560
# validation roc= 0.92718 validation ap= 0.93595
# Epoch: 0103 training loss= 0.00058 time= 0.07955
# validation roc= 0.92702 validation ap= 0.93585
# Epoch: 0104 training loss= 0.00058 time= 0.08373
# validation roc= 0.92670 validation ap= 0.93573
# Epoch: 0105 training loss= 0.00058 time= 0.08668
# validation roc= 0.92667 validation ap= 0.93572
# Epoch: 0106 training loss= 0.00058 time= 0.10708
# validation roc= 0.92667 validation ap= 0.93578
# Epoch: 0107 training loss= 0.00058 time= 0.08617
# validation roc= 0.92682 validation ap= 0.93594
# Epoch: 0108 training loss= 0.00058 time= 0.09383
# validation roc= 0.92682 validation ap= 0.93601
# Epoch: 0109 training loss= 0.00058 time= 0.08217
# validation roc= 0.92654 validation ap= 0.93583
# Epoch: 0110 training loss= 0.00057 time= 0.08388
# validation roc= 0.92664 validation ap= 0.93589
# Epoch: 0111 training loss= 0.00057 time= 0.08079
# validation roc= 0.92653 validation ap= 0.93584
# Epoch: 0112 training loss= 0.00057 time= 0.07986
# validation roc= 0.92637 validation ap= 0.93576
# Epoch: 0113 training loss= 0.00057 time= 0.09543
# validation roc= 0.92622 validation ap= 0.93560
# Epoch: 0114 training loss= 0.00057 time= 0.09043
# validation roc= 0.92615 validation ap= 0.93554
# Epoch: 0115 training loss= 0.00057 time= 0.09444
# validation roc= 0.92595 validation ap= 0.93538
# Epoch: 0116 training loss= 0.00057 time= 0.10042
# validation roc= 0.92588 validation ap= 0.93536
# Epoch: 0117 training loss= 0.00057 time= 0.09196
# validation roc= 0.92563 validation ap= 0.93525
# Epoch: 0118 training loss= 0.00057 time= 0.08212
# validation roc= 0.92559 validation ap= 0.93514
# Epoch: 0119 training loss= 0.00057 time= 0.08128
# validation roc= 0.92575 validation ap= 0.93537
# Epoch: 0120 training loss= 0.00057 time= 0.09468
# validation roc= 0.92567 validation ap= 0.93531
# Epoch: 0121 training loss= 0.00057 time= 0.09053
# validation roc= 0.92566 validation ap= 0.93537
# Epoch: 0122 training loss= 0.00057 time= 0.10539
# validation roc= 0.92547 validation ap= 0.93521
# Epoch: 0123 training loss= 0.00057 time= 0.08519
# validation roc= 0.92549 validation ap= 0.93533
# Epoch: 0124 training loss= 0.00057 time= 0.07926
# validation roc= 0.92546 validation ap= 0.93532
# Epoch: 0125 training loss= 0.00057 time= 0.08378
# validation roc= 0.92543 validation ap= 0.93533
# Epoch: 0126 training loss= 0.00057 time= 0.09859
# validation roc= 0.92541 validation ap= 0.93537
# Epoch: 0127 training loss= 0.00057 time= 0.08424
# validation roc= 0.92569 validation ap= 0.93558
# Epoch: 0128 training loss= 0.00057 time= 0.08016
# validation roc= 0.92586 validation ap= 0.93576
# Epoch: 0129 training loss= 0.00057 time= 0.08161
# validation roc= 0.92602 validation ap= 0.93608
# Epoch: 0130 training loss= 0.00056 time= 0.08678
# validation roc= 0.92612 validation ap= 0.93627
# Epoch: 0131 training loss= 0.00056 time= 0.07979
# validation roc= 0.92637 validation ap= 0.93657
# Epoch: 0132 training loss= 0.00056 time= 0.08399
# validation roc= 0.92667 validation ap= 0.93692
# Epoch: 0133 training loss= 0.00056 time= 0.08399
# validation roc= 0.92670 validation ap= 0.93698
# Epoch: 0134 training loss= 0.00056 time= 0.08713
# validation roc= 0.92673 validation ap= 0.93715
# Epoch: 0135 training loss= 0.00056 time= 0.08784
# validation roc= 0.92679 validation ap= 0.93725
# Epoch: 0136 training loss= 0.00056 time= 0.08867
# validation roc= 0.92705 validation ap= 0.93764
# Epoch: 0137 training loss= 0.00056 time= 0.08461
# validation roc= 0.92722 validation ap= 0.93787
# Epoch: 0138 training loss= 0.00056 time= 0.07803
# validation roc= 0.92742 validation ap= 0.93818
# Epoch: 0139 training loss= 0.00056 time= 0.07963
# validation roc= 0.92732 validation ap= 0.93806
# Epoch: 0140 training loss= 0.00056 time= 0.08592
# validation roc= 0.92783 validation ap= 0.93876
# Epoch: 0141 training loss= 0.00056 time= 0.07883
# validation roc= 0.92716 validation ap= 0.93808
# Epoch: 0142 training loss= 0.00056 time= 0.08805
# validation roc= 0.92818 validation ap= 0.93971
# Epoch: 0143 training loss= 0.00056 time= 0.08059
# validation roc= 0.92661 validation ap= 0.93742
# Epoch: 0144 training loss= 0.00056 time= 0.08359
# validation roc= 0.92839 validation ap= 0.94047
# Epoch: 0145 training loss= 0.00056 time= 0.08260
# validation roc= 0.92670 validation ap= 0.93767
# Epoch: 0146 training loss= 0.00056 time= 0.18127
# validation roc= 0.92750 validation ap= 0.93960
# Epoch: 0147 training loss= 0.00056 time= 0.08332
# validation roc= 0.92864 validation ap= 0.94028
# Epoch: 0148 training loss= 0.00056 time= 0.08587
# validation roc= 0.92663 validation ap= 0.93834
# Epoch: 0149 training loss= 0.00056 time= 0.08372
# validation roc= 0.92789 validation ap= 0.93995
# Epoch: 0150 training loss= 0.00056 time= 0.23936
# validation roc= 0.92799 validation ap= 0.93987
# Epoch: 0151 training loss= 0.00056 time= 0.12177
# validation roc= 0.92724 validation ap= 0.93916
# Epoch: 0152 training loss= 0.00056 time= 0.12819
# validation roc= 0.92789 validation ap= 0.93990
# Epoch: 0153 training loss= 0.00056 time= 0.12637
# validation roc= 0.92779 validation ap= 0.93982
# Epoch: 0154 training loss= 0.00055 time= 0.12179
# validation roc= 0.92748 validation ap= 0.93950
# Epoch: 0155 training loss= 0.00055 time= 0.13078
# validation roc= 0.92779 validation ap= 0.94023
# Epoch: 0156 training loss= 0.00055 time= 0.12648
# validation roc= 0.92767 validation ap= 0.93970
# Epoch: 0157 training loss= 0.00055 time= 0.16184
# validation roc= 0.92764 validation ap= 0.93995
# Epoch: 0158 training loss= 0.00055 time= 0.10077
# validation roc= 0.92805 validation ap= 0.94059
# Epoch: 0159 training loss= 0.00055 time= 0.08767
# validation roc= 0.92751 validation ap= 0.93963
# Epoch: 0160 training loss= 0.00055 time= 0.09267
# validation roc= 0.92836 validation ap= 0.94084
# Epoch: 0161 training loss= 0.00055 time= 0.11503
# validation roc= 0.92809 validation ap= 0.94054
# Epoch: 0162 training loss= 0.00055 time= 0.12341
# validation roc= 0.92757 validation ap= 0.93994
# Epoch: 0163 training loss= 0.00055 time= 0.09477
# validation roc= 0.92849 validation ap= 0.94096
# Epoch: 0164 training loss= 0.00055 time= 0.11172
# validation roc= 0.92781 validation ap= 0.94046
# Epoch: 0165 training loss= 0.00055 time= 0.13389
# validation roc= 0.92787 validation ap= 0.94043
# Epoch: 0166 training loss= 0.00055 time= 0.11661
# validation roc= 0.92871 validation ap= 0.94129
# Epoch: 0167 training loss= 0.00055 time= 0.11473
# validation roc= 0.92758 validation ap= 0.94042
# Epoch: 0168 training loss= 0.00055 time= 0.09358
# validation roc= 0.92823 validation ap= 0.94082
# Epoch: 0169 training loss= 0.00055 time= 0.11787
# validation roc= 0.92815 validation ap= 0.94095
# Epoch: 0170 training loss= 0.00055 time= 0.11852
# validation roc= 0.92760 validation ap= 0.94042
# Epoch: 0171 training loss= 0.00055 time= 0.11707
# validation roc= 0.92845 validation ap= 0.94131
# Epoch: 0172 training loss= 0.00055 time= 0.12008
# validation roc= 0.92816 validation ap= 0.94086
# Epoch: 0173 training loss= 0.00055 time= 0.11983
# validation roc= 0.92797 validation ap= 0.94095
# Epoch: 0174 training loss= 0.00055 time= 0.12953
# validation roc= 0.92891 validation ap= 0.94130
# Epoch: 0175 training loss= 0.00055 time= 0.11952
# validation roc= 0.92776 validation ap= 0.94110
# Epoch: 0176 training loss= 0.00055 time= 0.13067
# validation roc= 0.92893 validation ap= 0.94113
# Epoch: 0177 training loss= 0.00055 time= 0.12788
# validation roc= 0.92803 validation ap= 0.94177
# Epoch: 0178 training loss= 0.00055 time= 0.12579
# validation roc= 0.92867 validation ap= 0.94048
# Epoch: 0179 training loss= 0.00055 time= 0.14117
# validation roc= 0.92828 validation ap= 0.94213
# Epoch: 0180 training loss= 0.00055 time= 0.11823
# validation roc= 0.92836 validation ap= 0.94030
# Epoch: 0181 training loss= 0.00055 time= 0.12953
# validation roc= 0.92852 validation ap= 0.94213
# Epoch: 0182 training loss= 0.00055 time= 0.11676
# validation roc= 0.92819 validation ap= 0.94106
# Epoch: 0183 training loss= 0.00055 time= 0.12502
# validation roc= 0.92848 validation ap= 0.94107
# Epoch: 0184 training loss= 0.00055 time= 0.13344
# validation roc= 0.92860 validation ap= 0.94234
# Epoch: 0185 training loss= 0.00055 time= 0.13412
# validation roc= 0.92847 validation ap= 0.94070
# Epoch: 0186 training loss= 0.00055 time= 0.14051
# validation roc= 0.92878 validation ap= 0.94216
# Epoch: 0187 training loss= 0.00055 time= 0.11531
# validation roc= 0.92848 validation ap= 0.94142
# Epoch: 0188 training loss= 0.00054 time= 0.13460
# validation roc= 0.92842 validation ap= 0.94103
# Epoch: 0189 training loss= 0.00054 time= 0.10424
# validation roc= 0.92874 validation ap= 0.94226
# Epoch: 0190 training loss= 0.00054 time= 0.13490
# validation roc= 0.92822 validation ap= 0.94083
# Epoch: 0191 training loss= 0.00054 time= 0.11018
# validation roc= 0.92870 validation ap= 0.94192
# Epoch: 0192 training loss= 0.00054 time= 0.10615
# validation roc= 0.92839 validation ap= 0.94146
# Epoch: 0193 training loss= 0.00054 time= 0.10016
# validation roc= 0.92820 validation ap= 0.94104
# Epoch: 0194 training loss= 0.00054 time= 0.09557
# validation roc= 0.92862 validation ap= 0.94208
# Epoch: 0195 training loss= 0.00054 time= 0.08390
# validation roc= 0.92803 validation ap= 0.94079
# Epoch: 0196 training loss= 0.00054 time= 0.08802
# validation roc= 0.92815 validation ap= 0.94146
# Epoch: 0197 training loss= 0.00054 time= 0.09838
# validation roc= 0.92829 validation ap= 0.94143
# Epoch: 0198 training loss= 0.00054 time= 0.08986
# validation roc= 0.92790 validation ap= 0.94083
# Epoch: 0199 training loss= 0.00054 time= 0.12470
# validation roc= 0.92797 validation ap= 0.94160
# Epoch: 0200 training loss= 0.00054 time= 0.09917
# validation roc= 0.92781 validation ap= 0.94064
# testing roc= 0.92955 testing ap= 0.94170
# Epoch: 0001 training loss= 0.00102 time= 1.07354
# validation roc= 0.69569 validation ap= 0.70637
# Epoch: 0002 training loss= 0.00099 time= 0.12844
# validation roc= 0.67921 validation ap= 0.70273
# Epoch: 0003 training loss= 0.00107 time= 0.12560
# validation roc= 0.75530 validation ap= 0.76282
# Epoch: 0004 training loss= 0.00095 time= 0.11880
# validation roc= 0.69869 validation ap= 0.71041
# Epoch: 0005 training loss= 0.00095 time= 0.19603
# validation roc= 0.67978 validation ap= 0.69831
# Epoch: 0006 training loss= 0.00095 time= 0.32516
# validation roc= 0.73394 validation ap= 0.74254
# Epoch: 0007 training loss= 0.00092 time= 0.10658
# validation roc= 0.78791 validation ap= 0.78558
# Epoch: 0008 training loss= 0.00090 time= 0.12098
# validation roc= 0.81457 validation ap= 0.79951
# Epoch: 0009 training loss= 0.00088 time= 0.12630
# validation roc= 0.83099 validation ap= 0.81013
# Epoch: 0010 training loss= 0.00085 time= 0.24929
# validation roc= 0.84156 validation ap= 0.81748
# Epoch: 0011 training loss= 0.00082 time= 0.11039
# validation roc= 0.84515 validation ap= 0.82116
# Epoch: 0012 training loss= 0.00080 time= 0.13679
# validation roc= 0.85113 validation ap= 0.82814
# Epoch: 0013 training loss= 0.00078 time= 0.11710
# validation roc= 0.85981 validation ap= 0.83924
# Epoch: 0014 training loss= 0.00077 time= 0.11804
# validation roc= 0.86349 validation ap= 0.84383
# Epoch: 0015 training loss= 0.00076 time= 0.15415
# validation roc= 0.86731 validation ap= 0.84850
# Epoch: 0016 training loss= 0.00075 time= 0.20584
# validation roc= 0.87370 validation ap= 0.85553
# Epoch: 0017 training loss= 0.00074 time= 0.19239
# validation roc= 0.88029 validation ap= 0.86290
# Epoch: 0018 training loss= 0.00074 time= 0.64049
# validation roc= 0.88654 validation ap= 0.87055
# Epoch: 0019 training loss= 0.00073 time= 0.12255
# validation roc= 0.89148 validation ap= 0.87632
# Epoch: 0020 training loss= 0.00072 time= 0.09750
# validation roc= 0.89524 validation ap= 0.88253
# Epoch: 0021 training loss= 0.00071 time= 0.12284
# validation roc= 0.89753 validation ap= 0.88624
# Epoch: 0022 training loss= 0.00071 time= 0.38208
# validation roc= 0.89740 validation ap= 0.88651
# Epoch: 0023 training loss= 0.00070 time= 0.13420
# validation roc= 0.89780 validation ap= 0.88609
# Epoch: 0024 training loss= 0.00070 time= 0.13308
# validation roc= 0.89894 validation ap= 0.88709
# Epoch: 0025 training loss= 0.00070 time= 0.15044
# validation roc= 0.89993 validation ap= 0.88732
# Epoch: 0026 training loss= 0.00069 time= 0.12379
# validation roc= 0.90042 validation ap= 0.88596
# Epoch: 0027 training loss= 0.00069 time= 0.13025
# validation roc= 0.90105 validation ap= 0.88572
# Epoch: 0028 training loss= 0.00069 time= 0.16241
# validation roc= 0.90204 validation ap= 0.88739
# Epoch: 0029 training loss= 0.00068 time= 0.26883
# validation roc= 0.90215 validation ap= 0.88856
# Epoch: 0030 training loss= 0.00068 time= 0.14216
# validation roc= 0.90201 validation ap= 0.88931
# Epoch: 0031 training loss= 0.00067 time= 0.15630
# validation roc= 0.90208 validation ap= 0.88959
# Epoch: 0032 training loss= 0.00067 time= 0.14411
# validation roc= 0.90264 validation ap= 0.89043
# Epoch: 0033 training loss= 0.00067 time= 0.12742
# validation roc= 0.90418 validation ap= 0.89199
# Epoch: 0034 training loss= 0.00067 time= 0.12578
# validation roc= 0.90555 validation ap= 0.89319
# Epoch: 0035 training loss= 0.00066 time= 0.10002
# validation roc= 0.90687 validation ap= 0.89474
# Epoch: 0036 training loss= 0.00066 time= 0.09122
# validation roc= 0.90775 validation ap= 0.89574
# Epoch: 0037 training loss= 0.00066 time= 0.12318
# validation roc= 0.90859 validation ap= 0.89650
# Epoch: 0038 training loss= 0.00066 time= 0.10382
# validation roc= 0.90938 validation ap= 0.89763
# Epoch: 0039 training loss= 0.00065 time= 0.09644
# validation roc= 0.91045 validation ap= 0.89900
# Epoch: 0040 training loss= 0.00065 time= 0.21368
# validation roc= 0.91149 validation ap= 0.90013
# Epoch: 0041 training loss= 0.00065 time= 0.10387
# validation roc= 0.91268 validation ap= 0.90260
# Epoch: 0042 training loss= 0.00065 time= 0.12668
# validation roc= 0.91331 validation ap= 0.90337
# Epoch: 0043 training loss= 0.00065 time= 0.43144
# validation roc= 0.91420 validation ap= 0.90516
# Epoch: 0044 training loss= 0.00064 time= 0.13179
# validation roc= 0.91502 validation ap= 0.90667
# Epoch: 0045 training loss= 0.00064 time= 0.13700
# validation roc= 0.91566 validation ap= 0.90788
# Epoch: 0046 training loss= 0.00064 time= 0.16581
# validation roc= 0.91664 validation ap= 0.90968
# Epoch: 0047 training loss= 0.00064 time= 0.13303
# validation roc= 0.91723 validation ap= 0.91072
# Epoch: 0048 training loss= 0.00064 time= 0.14012
# validation roc= 0.91790 validation ap= 0.91204
# Epoch: 0049 training loss= 0.00064 time= 0.11672
# validation roc= 0.91934 validation ap= 0.91411
# Epoch: 0050 training loss= 0.00063 time= 0.09602
# validation roc= 0.92090 validation ap= 0.91604
# Epoch: 0051 training loss= 0.00063 time= 0.10678
# validation roc= 0.92225 validation ap= 0.91724
# Epoch: 0052 training loss= 0.00063 time= 0.12885
# validation roc= 0.92346 validation ap= 0.91831
# Epoch: 0053 training loss= 0.00063 time= 0.09362
# validation roc= 0.92437 validation ap= 0.91910
# Epoch: 0054 training loss= 0.00063 time= 0.11862
# validation roc= 0.92553 validation ap= 0.92069
# Epoch: 0055 training loss= 0.00063 time= 0.11601
# validation roc= 0.92729 validation ap= 0.92329
# Epoch: 0056 training loss= 0.00063 time= 0.08932
# validation roc= 0.92873 validation ap= 0.92521
# Epoch: 0057 training loss= 0.00062 time= 0.11998
# validation roc= 0.93055 validation ap= 0.92798
# Epoch: 0058 training loss= 0.00062 time= 0.11305
# validation roc= 0.93214 validation ap= 0.93002
# Epoch: 0059 training loss= 0.00062 time= 0.09311
# validation roc= 0.93348 validation ap= 0.93174
# Epoch: 0060 training loss= 0.00062 time= 0.16138
# validation roc= 0.93507 validation ap= 0.93387
# Epoch: 0061 training loss= 0.00062 time= 0.12799
# validation roc= 0.93656 validation ap= 0.93570
# Epoch: 0062 training loss= 0.00062 time= 0.12020
# validation roc= 0.93815 validation ap= 0.93777
# Epoch: 0063 training loss= 0.00062 time= 0.11303
# validation roc= 0.93921 validation ap= 0.93919
# Epoch: 0064 training loss= 0.00061 time= 0.13344
# validation roc= 0.94045 validation ap= 0.94066
# Epoch: 0065 training loss= 0.00061 time= 0.09303
# validation roc= 0.94162 validation ap= 0.94172
# Epoch: 0066 training loss= 0.00061 time= 0.08875
# validation roc= 0.94232 validation ap= 0.94244
# Epoch: 0067 training loss= 0.00061 time= 0.24443
# validation roc= 0.94294 validation ap= 0.94297
# Epoch: 0068 training loss= 0.00061 time= 0.09526
# validation roc= 0.94339 validation ap= 0.94355
# Epoch: 0069 training loss= 0.00061 time= 0.11829
# validation roc= 0.94373 validation ap= 0.94407
# Epoch: 0070 training loss= 0.00061 time= 0.13315
# validation roc= 0.94401 validation ap= 0.94465
# Epoch: 0071 training loss= 0.00061 time= 0.08949
# validation roc= 0.94422 validation ap= 0.94504
# Epoch: 0072 training loss= 0.00060 time= 0.10702
# validation roc= 0.94425 validation ap= 0.94539
# Epoch: 0073 training loss= 0.00060 time= 0.13778
# validation roc= 0.94445 validation ap= 0.94581
# Epoch: 0074 training loss= 0.00060 time= 0.09796
# validation roc= 0.94485 validation ap= 0.94649
# Epoch: 0075 training loss= 0.00060 time= 0.12089
# validation roc= 0.94512 validation ap= 0.94702
# Epoch: 0076 training loss= 0.00060 time= 0.14171
# validation roc= 0.94561 validation ap= 0.94794
# Epoch: 0077 training loss= 0.00060 time= 0.13416
# validation roc= 0.94596 validation ap= 0.94860
# Epoch: 0078 training loss= 0.00060 time= 0.13952
# validation roc= 0.94561 validation ap= 0.94860
# Epoch: 0079 training loss= 0.00060 time= 0.16514
# validation roc= 0.94576 validation ap= 0.94905
# Epoch: 0080 training loss= 0.00060 time= 0.12404
# validation roc= 0.94603 validation ap= 0.94957
# Epoch: 0081 training loss= 0.00059 time= 0.11111
# validation roc= 0.94602 validation ap= 0.94980
# Epoch: 0082 training loss= 0.00059 time= 0.18215
# validation roc= 0.94574 validation ap= 0.94994
# Epoch: 0083 training loss= 0.00059 time= 0.12150
# validation roc= 0.94539 validation ap= 0.94995
# Epoch: 0084 training loss= 0.00059 time= 0.16439
# validation roc= 0.94521 validation ap= 0.94998
# Epoch: 0085 training loss= 0.00059 time= 0.17031
# validation roc= 0.94506 validation ap= 0.95004
# Epoch: 0086 training loss= 0.00059 time= 0.10303
# validation roc= 0.94486 validation ap= 0.95010
# Epoch: 0087 training loss= 0.00059 time= 0.11532
# validation roc= 0.94422 validation ap= 0.94972
# Epoch: 0088 training loss= 0.00059 time= 0.16361
# validation roc= 0.94399 validation ap= 0.94978
# Epoch: 0089 training loss= 0.00059 time= 0.12288
# validation roc= 0.94379 validation ap= 0.94978
# Epoch: 0090 training loss= 0.00059 time= 0.09692
# validation roc= 0.94369 validation ap= 0.94980
# Epoch: 0091 training loss= 0.00059 time= 0.12326
# validation roc= 0.94359 validation ap= 0.95003
# Epoch: 0092 training loss= 0.00059 time= 0.14633
# validation roc= 0.94349 validation ap= 0.95025
# ...
# Epoch: 0035 training loss= 0.00066 time= 0.11780
# validation roc= 0.89602 validation ap= 0.89053
# Epoch: 0036 training loss= 0.00066 time= 0.10842
# validation roc= 0.89575 validation ap= 0.88905
# Epoch: 0037 training loss= 0.00066 time= 0.16632
# validation roc= 0.89555 validation ap= 0.88811
# Epoch: 0038 training loss= 0.00065 time= 0.10897
# validation roc= 0.89634 validation ap= 0.88841
# Epoch: 0039 training loss= 0.00065 time= 0.13118
# validation roc= 0.89761 validation ap= 0.88938
# Epoch: 0040 training loss= 0.00065 time= 0.14168
# validation roc= 0.90007 validation ap= 0.89320
# Epoch: 0041 training loss= 0.00065 time= 0.13386
# validation roc= 0.90236 validation ap= 0.89645
# Epoch: 0042 training loss= 0.00065 time= 0.15424
# validation roc= 0.90405 validation ap= 0.89913
# Epoch: 0043 training loss= 0.00065 time= 0.12279
# validation roc= 0.90525 validation ap= 0.90093
# Epoch: 0044 training loss= 0.00064 time= 0.09530
# validation roc= 0.90578 validation ap= 0.90167
# Epoch: 0045 training loss= 0.00064 time= 0.09085
# validation roc= 0.90671 validation ap= 0.90266
# Epoch: 0046 training loss= 0.00064 time= 0.30267
# validation roc= 0.90742 validation ap= 0.90337
# Epoch: 0047 training loss= 0.00064 time= 0.09797
# validation roc= 0.90802 validation ap= 0.90381
# Epoch: 0048 training loss= 0.00064 time= 0.08605
# validation roc= 0.90818 validation ap= 0.90385
# Epoch: 0049 training loss= 0.00063 time= 0.18739
# validation roc= 0.90814 validation ap= 0.90367
# Epoch: 0050 training loss= 0.00063 time= 0.09371
# validation roc= 0.90801 validation ap= 0.90357
# Epoch: 0051 training loss= 0.00063 time= 0.09525
# validation roc= 0.90796 validation ap= 0.90343
# Epoch: 0052 training loss= 0.00063 time= 0.15662
# validation roc= 0.90799 validation ap= 0.90333
# Epoch: 0053 training loss= 0.00063 time= 0.09487
# validation roc= 0.90802 validation ap= 0.90335
# Epoch: 0054 training loss= 0.00063 time= 0.11529
# validation roc= 0.90820 validation ap= 0.90353
# Epoch: 0055 training loss= 0.00063 time= 0.17274
# validation roc= 0.90844 validation ap= 0.90359
# Epoch: 0056 training loss= 0.00062 time= 0.09468
# validation roc= 0.90906 validation ap= 0.90374
# Epoch: 0057 training loss= 0.00062 time= 0.10692
# validation roc= 0.90948 validation ap= 0.90371
# Epoch: 0058 training loss= 0.00062 time= 0.15578
# validation roc= 0.90974 validation ap= 0.90367
# Epoch: 0059 training loss= 0.00062 time= 0.10073
# validation roc= 0.91010 validation ap= 0.90436
# Epoch: 0060 training loss= 0.00062 time= 0.10253
# validation roc= 0.91044 validation ap= 0.90515
# Epoch: 0061 training loss= 0.00062 time= 0.17897
# validation roc= 0.91102 validation ap= 0.90564
# Epoch: 0062 training loss= 0.00062 time= 0.08929
# validation roc= 0.91187 validation ap= 0.90649
# Epoch: 0063 training loss= 0.00061 time= 0.09809
# validation roc= 0.91248 validation ap= 0.90701
# Epoch: 0064 training loss= 0.00061 time= 0.15871
# validation roc= 0.91289 validation ap= 0.90790
# Epoch: 0065 training loss= 0.00061 time= 0.13321
# validation roc= 0.91285 validation ap= 0.90826
# Epoch: 0066 training loss= 0.00061 time= 0.12493
# validation roc= 0.91327 validation ap= 0.90869
# Epoch: 0067 training loss= 0.00061 time= 0.19639
# validation roc= 0.91386 validation ap= 0.90928
# Epoch: 0068 training loss= 0.00061 time= 0.09500
# validation roc= 0.91418 validation ap= 0.90943
# Epoch: 0069 training loss= 0.00061 time= 0.11595
# validation roc= 0.91446 validation ap= 0.91010
# Epoch: 0070 training loss= 0.00060 time= 0.17494
# validation roc= 0.91453 validation ap= 0.91027
# Epoch: 0071 training loss= 0.00060 time= 0.10930
# validation roc= 0.91447 validation ap= 0.91049
# Epoch: 0072 training loss= 0.00060 time= 0.11786
# validation roc= 0.91446 validation ap= 0.91021
# Epoch: 0073 training loss= 0.00060 time= 0.15783
# validation roc= 0.91464 validation ap= 0.91058
# Epoch: 0074 training loss= 0.00060 time= 0.14117
# validation roc= 0.91509 validation ap= 0.91100
# Epoch: 0075 training loss= 0.00060 time= 0.16887
# validation roc= 0.91540 validation ap= 0.91100
# Epoch: 0076 training loss= 0.00060 time= 0.11773
# validation roc= 0.91538 validation ap= 0.91078
# Epoch: 0077 training loss= 0.00060 time= 0.12303
# validation roc= 0.91542 validation ap= 0.91046
# Epoch: 0078 training loss= 0.00060 time= 0.19446
# validation roc= 0.91564 validation ap= 0.91094
# Epoch: 0079 training loss= 0.00059 time= 0.12815
# validation roc= 0.91580 validation ap= 0.91156
# Epoch: 0080 training loss= 0.00059 time= 0.12389
# validation roc= 0.91597 validation ap= 0.91194
# Epoch: 0081 training loss= 0.00059 time= 0.14698
# validation roc= 0.91610 validation ap= 0.91242
# Epoch: 0082 training loss= 0.00059 time= 0.13109
# validation roc= 0.91631 validation ap= 0.91249
# Epoch: 0083 training loss= 0.00059 time= 0.11138
# validation roc= 0.91661 validation ap= 0.91320
# Epoch: 0084 training loss= 0.00059 time= 0.11836
# validation roc= 0.91710 validation ap= 0.91390
# Epoch: 0085 training loss= 0.00059 time= 0.12417
# validation roc= 0.91759 validation ap= 0.91493
# Epoch: 0086 training loss= 0.00059 time= 0.11217
# validation roc= 0.91778 validation ap= 0.91553
# Epoch: 0087 training loss= 0.00059 time= 0.09344
# validation roc= 0.91781 validation ap= 0.91570
# Epoch: 0088 training loss= 0.00059 time= 0.15510
# validation roc= 0.91787 validation ap= 0.91591
# Epoch: 0089 training loss= 0.00059 time= 0.09227
# validation roc= 0.91814 validation ap= 0.91641
# Epoch: 0090 training loss= 0.00059 time= 0.09195
# validation roc= 0.91848 validation ap= 0.91701
# Epoch: 0091 training loss= 0.00058 time= 0.10909
# validation roc= 0.91888 validation ap= 0.91782
# Epoch: 0092 training loss= 0.00058 time= 0.10032
# validation roc= 0.91900 validation ap= 0.91788
# Epoch: 0093 training loss= 0.00058 time= 0.08757
# validation roc= 0.91914 validation ap= 0.91792
# Epoch: 0094 training loss= 0.00058 time= 0.09137
# validation roc= 0.91952 validation ap= 0.91849
# Epoch: 0095 training loss= 0.00058 time= 0.12126
# validation roc= 0.91994 validation ap= 0.91950
# Epoch: 0096 training loss= 0.00058 time= 0.09494
# validation roc= 0.92022 validation ap= 0.92013
# Epoch: 0097 training loss= 0.00058 time= 0.11970
# validation roc= 0.92047 validation ap= 0.92040
# Epoch: 0098 training loss= 0.00058 time= 0.15494
# validation roc= 0.92073 validation ap= 0.92056
# Epoch: 0099 training loss= 0.00058 time= 0.09031
# validation roc= 0.92102 validation ap= 0.92114
# Epoch: 0100 training loss= 0.00058 time= 0.12556
# validation roc= 0.92129 validation ap= 0.92130
# Epoch: 0101 training loss= 0.00058 time= 0.13492
# validation roc= 0.92168 validation ap= 0.92189
# Epoch: 0102 training loss= 0.00058 time= 0.10089
# validation roc= 0.92192 validation ap= 0.92217
# Epoch: 0103 training loss= 0.00058 time= 0.12011
# validation roc= 0.92216 validation ap= 0.92236
# Epoch: 0104 training loss= 0.00058 time= 0.13721
# validation roc= 0.92231 validation ap= 0.92260
# Epoch: 0105 training loss= 0.00058 time= 0.10065
# validation roc= 0.92260 validation ap= 0.92314
# Epoch: 0106 training loss= 0.00057 time= 0.09608
# validation roc= 0.92296 validation ap= 0.92335
# Epoch: 0107 training loss= 0.00057 time= 0.09258
# validation roc= 0.92303 validation ap= 0.92336
# Epoch: 0108 training loss= 0.00057 time= 0.11943
# validation roc= 0.92319 validation ap= 0.92348
# Epoch: 0109 training loss= 0.00057 time= 0.08652
# validation roc= 0.92307 validation ap= 0.92339
# Epoch: 0110 training loss= 0.00057 time= 0.09364
# validation roc= 0.92288 validation ap= 0.92336
# Epoch: 0111 training loss= 0.00057 time= 0.15417
# validation roc= 0.92314 validation ap= 0.92357
# Epoch: 0112 training loss= 0.00057 time= 0.09616
# validation roc= 0.92361 validation ap= 0.92404
# Epoch: 0113 training loss= 0.00057 time= 0.11783
# validation roc= 0.92361 validation ap= 0.92408
# Epoch: 0114 training loss= 0.00057 time= 0.16214
# validation roc= 0.92349 validation ap= 0.92406
# Epoch: 0115 training loss= 0.00057 time= 0.10223
# validation roc= 0.92362 validation ap= 0.92429
# Epoch: 0116 training loss= 0.00057 time= 0.13852
# validation roc= 0.92369 validation ap= 0.92445
# Epoch: 0117 training loss= 0.00057 time= 0.12235
# validation roc= 0.92364 validation ap= 0.92454
# Epoch: 0118 training loss= 0.00057 time= 0.11064
# validation roc= 0.92364 validation ap= 0.92466
# Epoch: 0119 training loss= 0.00057 time= 0.10074
# validation roc= 0.92369 validation ap= 0.92475
# Epoch: 0120 training loss= 0.00057 time= 0.13095
# validation roc= 0.92382 validation ap= 0.92515
# Epoch: 0121 training loss= 0.00057 time= 0.10779
# validation roc= 0.92419 validation ap= 0.92553
# Epoch: 0122 training loss= 0.00057 time= 0.11891
# validation roc= 0.92394 validation ap= 0.92566
# Epoch: 0123 training loss= 0.00057 time= 0.11374
# validation roc= 0.92382 validation ap= 0.92569
# Epoch: 0124 training loss= 0.00056 time= 0.11125
# validation roc= 0.92375 validation ap= 0.92582
# Epoch: 0125 training loss= 0.00056 time= 0.10912
# validation roc= 0.92364 validation ap= 0.92577
# Epoch: 0126 training loss= 0.00056 time= 0.11000
# validation roc= 0.92356 validation ap= 0.92569
# Epoch: 0127 training loss= 0.00056 time= 0.10110
# validation roc= 0.92346 validation ap= 0.92562
# Epoch: 0128 training loss= 0.00056 time= 0.09422
# validation roc= 0.92330 validation ap= 0.92534
# Epoch: 0129 training loss= 0.00056 time= 0.10407
# validation roc= 0.92336 validation ap= 0.92552
# Epoch: 0130 training loss= 0.00056 time= 0.14303
# validation roc= 0.92323 validation ap= 0.92543
# Epoch: 0131 training loss= 0.00056 time= 0.09856
# validation roc= 0.92296 validation ap= 0.92519
# Epoch: 0132 training loss= 0.00056 time= 0.08646
# validation roc= 0.92297 validation ap= 0.92521
# Epoch: 0133 training loss= 0.00056 time= 0.12909
# validation roc= 0.92300 validation ap= 0.92530
# Epoch: 0134 training loss= 0.00056 time= 0.08332
# validation roc= 0.92299 validation ap= 0.92526
# Epoch: 0135 training loss= 0.00056 time= 0.09107
# validation roc= 0.92284 validation ap= 0.92504
# Epoch: 0136 training loss= 0.00056 time= 0.12416
# validation roc= 0.92288 validation ap= 0.92516
# Epoch: 0137 training loss= 0.00056 time= 0.09161
# validation roc= 0.92296 validation ap= 0.92519
# Epoch: 0138 training loss= 0.00056 time= 0.12595
# validation roc= 0.92280 validation ap= 0.92494
# Epoch: 0139 training loss= 0.00056 time= 0.14020
# validation roc= 0.92273 validation ap= 0.92492
# Epoch: 0140 training loss= 0.00056 time= 0.11107
# validation roc= 0.92252 validation ap= 0.92485
# Epoch: 0141 training loss= 0.00056 time= 0.10877
# validation roc= 0.92280 validation ap= 0.92512
# Epoch: 0142 training loss= 0.00056 time= 0.15883
# validation roc= 0.92244 validation ap= 0.92497
# Epoch: 0143 training loss= 0.00056 time= 0.12514
# validation roc= 0.92280 validation ap= 0.92514
# Epoch: 0144 training loss= 0.00056 time= 0.13526
# validation roc= 0.92238 validation ap= 0.92530
# Epoch: 0145 training loss= 0.00056 time= 0.17545
# validation roc= 0.92327 validation ap= 0.92541
# Epoch: 0146 training loss= 0.00056 time= 0.12397
# validation roc= 0.92148 validation ap= 0.92519
# Epoch: 0147 training loss= 0.00056 time= 0.12963
# validation roc= 0.92413 validation ap= 0.92579
# Epoch: 0148 training loss= 0.00056 time= 0.18972
# validation roc= 0.92093 validation ap= 0.92501
# Epoch: 0149 training loss= 0.00056 time= 0.11293
# validation roc= 0.92345 validation ap= 0.92575
# Epoch: 0150 training loss= 0.00055 time= 0.12731
# validation roc= 0.92326 validation ap= 0.92637
# Epoch: 0151 training loss= 0.00055 time= 0.13794
# validation roc= 0.92119 validation ap= 0.92485
# Epoch: 0152 training loss= 0.00055 time= 0.12008
# validation roc= 0.92332 validation ap= 0.92573
# Epoch: 0153 training loss= 0.00055 time= 0.10805
# validation roc= 0.92218 validation ap= 0.92572
# Epoch: 0154 training loss= 0.00055 time= 0.13697
# validation roc= 0.92158 validation ap= 0.92506
# Epoch: 0155 training loss= 0.00055 time= 0.13806
# validation roc= 0.92365 validation ap= 0.92671
# Epoch: 0156 training loss= 0.00055 time= 0.12259
# validation roc= 0.92184 validation ap= 0.92554
# Epoch: 0157 training loss= 0.00055 time= 0.13492
# validation roc= 0.92232 validation ap= 0.92567
# Epoch: 0158 training loss= 0.00055 time= 0.17812
# validation roc= 0.92340 validation ap= 0.92673
# Epoch: 0159 training loss= 0.00055 time= 0.11306
# validation roc= 0.92148 validation ap= 0.92539
# Epoch: 0160 training loss= 0.00055 time= 0.12753
# validation roc= 0.92268 validation ap= 0.92609
# Epoch: 0161 training loss= 0.00055 time= 0.14371
# validation roc= 0.92249 validation ap= 0.92597
# Epoch: 0162 training loss= 0.00055 time= 0.10263
# validation roc= 0.92179 validation ap= 0.92560
# Epoch: 0163 training loss= 0.00055 time= 0.10512
# validation roc= 0.92249 validation ap= 0.92635
# Epoch: 0164 training loss= 0.00055 time= 0.13661
# validation roc= 0.92270 validation ap= 0.92676
# Epoch: 0165 training loss= 0.00055 time= 0.12394
# validation roc= 0.92202 validation ap= 0.92635
# Epoch: 0166 training loss= 0.00055 time= 0.11149
# validation roc= 0.92258 validation ap= 0.92673
# Epoch: 0167 training loss= 0.00055 time= 0.15366
# validation roc= 0.92231 validation ap= 0.92658
# Epoch: 0168 training loss= 0.00055 time= 0.10600
# validation roc= 0.92219 validation ap= 0.92661
# Epoch: 0169 training loss= 0.00055 time= 0.10908
# validation roc= 0.92278 validation ap= 0.92705
# Epoch: 0170 training loss= 0.00055 time= 0.18756
# validation roc= 0.92219 validation ap= 0.92679
# Epoch: 0171 training loss= 0.00055 time= 0.12798
# validation roc= 0.92244 validation ap= 0.92691
# Epoch: 0172 training loss= 0.00055 time= 0.11595
# validation roc= 0.92252 validation ap= 0.92682
# Epoch: 0173 training loss= 0.00055 time= 0.13894
# validation roc= 0.92187 validation ap= 0.92676
# Epoch: 0174 training loss= 0.00055 time= 0.11980
# validation roc= 0.92270 validation ap= 0.92713
# Epoch: 0175 training loss= 0.00055 time= 0.12325
# validation roc= 0.92249 validation ap= 0.92717
# Epoch: 0176 training loss= 0.00055 time= 0.11726
# validation roc= 0.92176 validation ap= 0.92687
# Epoch: 0177 training loss= 0.00055 time= 0.14519
# validation roc= 0.92275 validation ap= 0.92733
# Epoch: 0178 training loss= 0.00055 time= 0.13146
# validation roc= 0.92168 validation ap= 0.92686
# Epoch: 0179 training loss= 0.00055 time= 0.16349
# validation roc= 0.92186 validation ap= 0.92702
# Epoch: 0180 training loss= 0.00055 time= 0.10744
# validation roc= 0.92236 validation ap= 0.92706
# Epoch: 0181 training loss= 0.00055 time= 0.12702
# validation roc= 0.92163 validation ap= 0.92696
# Epoch: 0182 training loss= 0.00054 time= 0.10046
# validation roc= 0.92190 validation ap= 0.92707
# Epoch: 0183 training loss= 0.00054 time= 0.12112
# validation roc= 0.92228 validation ap= 0.92727
# Epoch: 0184 training loss= 0.00054 time= 0.08812
# validation roc= 0.92128 validation ap= 0.92691
# Epoch: 0185 training loss= 0.00054 time= 0.10567
# validation roc= 0.92226 validation ap= 0.92724
# Epoch: 0186 training loss= 0.00054 time= 0.17811
# validation roc= 0.92166 validation ap= 0.92712
# Epoch: 0187 training loss= 0.00054 time= 0.10345
# validation roc= 0.92148 validation ap= 0.92727
# Epoch: 0188 training loss= 0.00054 time= 0.12931
# validation roc= 0.92242 validation ap= 0.92753
# Epoch: 0189 training loss= 0.00054 time= 0.14492
# validation roc= 0.92119 validation ap= 0.92719
# Epoch: 0190 training loss= 0.00054 time= 0.12136
# validation roc= 0.92216 validation ap= 0.92774
# Epoch: 0191 training loss= 0.00054 time= 0.11582
# validation roc= 0.92128 validation ap= 0.92700
# Epoch: 0192 training loss= 0.00054 time= 0.17193
# validation roc= 0.92154 validation ap= 0.92738
# Epoch: 0193 training loss= 0.00054 time= 0.12884
# validation roc= 0.92125 validation ap= 0.92702
# Epoch: 0194 training loss= 0.00054 time= 0.12185
# validation roc= 0.92164 validation ap= 0.92747
# Epoch: 0195 training loss= 0.00054 time= 0.17924
# validation roc= 0.92063 validation ap= 0.92687
# Epoch: 0196 training loss= 0.00054 time= 0.11550
# validation roc= 0.92229 validation ap= 0.92793
# Epoch: 0197 training loss= 0.00054 time= 0.11552
# validation roc= 0.91985 validation ap= 0.92634
# Epoch: 0198 training loss= 0.00054 time= 0.18624
# validation roc= 0.92205 validation ap= 0.92797
# Epoch: 0199 training loss= 0.00054 time= 0.12178
# validation roc= 0.91962 validation ap= 0.92624
# Epoch: 0200 training loss= 0.00054 time= 0.13334
# validation roc= 0.92138 validation ap= 0.92760
# testing roc= 0.94495 testing ap= 0.95320

# %% [markdown]
# # Results

# %%
time_10run=results_output_path+"layers_"+str(layers_no)+"_time_10run.csv"
roc_10run=results_output_path+"layers_"+str(layers_no)+"_roc_10run.csv"
ap_10run=results_output_path+"layers_"+str(layers_no)+"_ap_10run.csv"

mean_time_read=np.array(pd.read_csv(time_10run,header=None))
mean_roc_read=np.array(pd.read_csv(roc_10run,header=None))
mean_ap_read=np.array(pd.read_csv(ap_10run,header=None))

p_used_number=10
time_test=mean_time_read[:,-1][0:p_used_number]
roc_test=mean_roc_read[:,-1][0:p_used_number]
ap_test=mean_ap_read[:,-1][0:p_used_number]

print("Time: ", time_test)
print("\n")
print("AUC: ", roc_test)
print("\n")
print("AP: ", ap_test)
# Out:
# Time:  [38.53893185 38.44051862 43.4342792  48.2143929  45.21522689 48.29295611
#  47.10885215 46.83126068 47.29770684 48.93942809]
#
#
# AUC:  [0.93639483 0.92955003 0.92542731 0.92657231 0.94429102 0.93397161
#  0.93161319 0.95207919 0.92989209 0.94494993]
#
#
# AP:  [0.94364659 0.94169656 0.93457458 0.93983425 0.9516889  0.94891568
#  0.94376792 0.95687906 0.93136761 0.95320478]

# %%
print("Averaged AUC: ", str(np.mean(roc_test))+'±'+str(np.std(roc_test)))
print("\n")
print("Averaged AP: ",  str(np.mean(ap_test))+'±'+str(np.std(ap_test)))
# Out:
# Averaged AUC:  0.93547414926061±0.008412512345024612
#
#
# Averaged AP:  0.9445575923323297±0.007759034167711865
