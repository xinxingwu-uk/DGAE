# %% [markdown]
# # Import libraries

# %%
import numpy as np
import random as rn
import os
from keras import backend as K
import  tensorflow.compat.v1  as tf
tf.disable_v2_behavior() 
import tensorflow as tf

#--------------------------------------------------------------------------------------------------------------------
# Reproducible
seed=0
os.environ['PYTHONHASHSEED'] = str(seed)

np.random.seed(seed)
rn.seed(seed)
session_conf =tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
tf.compat.v1.set_random_seed(seed)
#--------------------------------------------------------------------------------------------------------------------

import scipy.sparse as sp
import time
import pandas as pd
import sys

from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

sys.path.append(r"../../")

from dgae_alpha.evaluation import get_roc_score
from dgae_alpha.input_data import load_data, load_label
from dgae_alpha.model import *
from dgae_alpha.optimizer import *
from dgae_alpha.preprocessing import *
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.8/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %% [markdown]
# # Parameters setting

# %%
layers_no=36
data_path="../../Datasets/"
path_now="./log/"

dataset='cora'
model_name='DGAE_alpha_feature'

dropout=0.0
epochs=200
features_used=True
learning_rate=0.01
nb_run=1
prop_val=5
prop_test=10
validation=True
verbose=True

# %% [markdown]
# # Load data

# %%
adj_init, features_init = load_data(dataset,data_path)
num_adj=adj_init.shape[1]

# %% [markdown]
# # Training and testing

# %%
loss_coeff_adj=0.001
loss_coeff_AE=0.05
results_output_path = path_now+model_name+"/"
mkdir(results_output_path)

for seed_i in np.arange(nb_run):
    
    seed=seed_i
    lost_list=[]
    roc_list=[]
    ap_list=[]
    mean_time=[]
    
    adj, val_edges, val_edges_false, test_edges, test_edges_false =mask_test_edges(adj_init, seed,prop_test, prop_val)
                
    t_start = time.time()

    if features_used:
        features = features_init
    
    num_nodes = adj.shape[0]

    if not features_used:
        features = sp.identity(adj.shape[0])

    features = sparse_to_tuple(features)
    num_features = features[2][1]
    features_nonzero = features[1].shape[0]
        
    placeholders = {
        'features': tf.sparse_placeholder(tf.float32),
        'adj': tf.sparse_placeholder(tf.float32),
        'adj_orig': tf.sparse_placeholder(tf.float32),
        'dropout': tf.placeholder_with_default(0., shape = ())
    }

#--------------------------------------------------------------------------------------------------------------------
# Create model
    if model_name=='DGAE_alpha_feature':
        model = DGAE_alpha_feature(placeholders, layers_no,num_features, features_nonzero)
    elif model_name=='DGAE_alpha_no_feature':
        model=DGAE_alpha_no_feature(placeholders, layers_no,num_features, num_adj,features_nonzero)
    else:
        raise ValueError('Undefined model!')

    pos_weight = float(adj.shape[0] * adj.shape[0] - adj.sum()) / adj.sum()
    norm = adj.shape[0] * adj.shape[0] / float((adj.shape[0] * adj.shape[0]- adj.sum()) * 2)
    
    with tf.name_scope('optimizer'):
        if model_name in ('DGAE_alpha_feature'):
            opt =OptimizerAE_FeatureReconstrution(preds_adj = model.reconstructions,\
                                                  preds_Features=model.feature_reconstruction,\
                                                  labels_adj = tf.reshape(tf.sparse_tensor_to_dense(placeholders['adj_orig'],\
                                                                                                    validate_indices = False), [-1]),\
                                                  labels_Features=placeholders['features'],\
                                                  labels_adj_rec=placeholders['adj'],\
                                                  loss_coeff_adj=loss_coeff_adj,\
                                                  loss_coeff_AE=loss_coeff_AE,\
                                                  pos_weight = pos_weight,\
                                                  norm = norm)
                
        elif model_name in ('DGAE_alpha_no_feature'):
            opt =OptimizerAE_AdjReconstrution(preds_adj = model.reconstructions,\
                                              preds_adj_rec=model.adj_reconstruction,\
                                              labels_adj = tf.reshape(tf.sparse_tensor_to_dense(placeholders['adj_orig'],
                                                                                                validate_indices = False), [-1]),\
                                              labels_Features=placeholders['features'],\
                                              labels_adj_rec=placeholders['adj'],\
                                              loss_coeff_adj=loss_coeff_adj,\
                                              loss_coeff_AE=loss_coeff_AE,\
                                              pos_weight = pos_weight,\
                                              norm = norm)

    adj_norm = preprocess_graph(adj)
    adj_label = sparse_to_tuple(adj + sp.eye(adj.shape[0]))

    sess = tf.Session()
    sess.run(tf.global_variables_initializer())
    
    for epoch in range(epochs):
        t = time.time()
        feed_dict = construct_feed_dict(adj_norm, adj_label, features,placeholders)
        feed_dict.update({placeholders['dropout']: dropout})
        outs = sess.run([opt.opt_op, opt.cost, opt.accuracy],feed_dict = feed_dict)
        avg_cost = outs[1]
        if verbose:
            lost_list.append(avg_cost)
            print("Epoch:", '%04d' % (epoch + 1), "training loss=", "{:.5f}".format(avg_cost),"time=", "{:.5f}".format(time.time() - t))
                    
            if validation:
                feed_dict.update({placeholders['dropout']: 0})
                emb = sess.run(model.z_mean, feed_dict = feed_dict)
                feed_dict.update({placeholders['dropout']: dropout})
                val_roc, val_ap = get_roc_score(val_edges, val_edges_false, emb)
                roc_list.append(val_roc)
                ap_list.append(val_ap)
                print("validation roc=", "{:.5f}".format(val_roc), "validation ap=", "{:.5f}".format(val_ap))

    emb = sess.run(model.z_mean, feed_dict = feed_dict)   
    mean_time.append(time.time() - t_start)
    
    roc_score, ap_score = get_roc_score(test_edges, test_edges_false, emb)
    print("testing roc=", "{:.5f}".format(roc_score), "testing ap=", "{:.5f}".format(ap_score))
    
    roc_list.append(roc_score)
    ap_list.append(ap_score)
    
    mean_time_=np.array(mean_time)
    write_to_csv(mean_time_.reshape(1,len(mean_time_)),results_output_path+"layers_"+str(layers_no)+"_time.csv")

    roc_list_=np.array(roc_list)
    write_to_csv(roc_list_.reshape(1,len(roc_list_)),results_output_path+"layers_"+str(layers_no)+"_roc.csv")

    ap_list_=np.array(ap_list)
    write_to_csv(ap_list_.reshape(1,len(ap_list_)),results_output_path+"layers_"+str(layers_no)+"_ap.csv")
# Out:
# Successful!
# WARNING:tensorflow:From /usr/local/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:201: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:201: calling weighted_cross_entropy_with_logits (from tensorflow.python.ops.nn_impl) with targets is deprecated and will be removed in a future version.
# Instructions for updating:
# targets is deprecated, use labels instead
# Epoch: 0001 training loss= 0.00102 time= 7.08553
# validation roc= 0.71097 validation ap= 0.75518
# Epoch: 0002 training loss= 0.00099 time= 0.48950
# validation roc= 0.69696 validation ap= 0.74583
# Epoch: 0003 training loss= 0.00107 time= 0.64540
# validation roc= 0.77036 validation ap= 0.80247
# Epoch: 0004 training loss= 0.00095 time= 0.53368
# validation roc= 0.70010 validation ap= 0.72469
# Epoch: 0005 training loss= 0.00095 time= 0.41945
# validation roc= 0.67387 validation ap= 0.70662
# Epoch: 0006 training loss= 0.00095 time= 0.38921
# validation roc= 0.71837 validation ap= 0.73927
# Epoch: 0007 training loss= 0.00093 time= 0.68906
# validation roc= 0.77204 validation ap= 0.77691
# Epoch: 0008 training loss= 0.00090 time= 0.43996
# validation roc= 0.79719 validation ap= 0.79091
# Epoch: 0009 training loss= 0.00088 time= 0.36599
# validation roc= 0.81707 validation ap= 0.80641
# Epoch: 0010 training loss= 0.00085 time= 0.33339
# validation roc= 0.83400 validation ap= 0.82341
# Epoch: 0011 training loss= 0.00082 time= 0.49966
# validation roc= 0.84113 validation ap= 0.83130
# Epoch: 0012 training loss= 0.00080 time= 0.71219
# validation roc= 0.84557 validation ap= 0.83685
# Epoch: 0013 training loss= 0.00079 time= 0.40586
# validation roc= 0.85255 validation ap= 0.84357
# Epoch: 0014 training loss= 0.00077 time= 0.47767
# validation roc= 0.85507 validation ap= 0.84530
# Epoch: 0015 training loss= 0.00075 time= 0.50185
# validation roc= 0.85773 validation ap= 0.84602
# Epoch: 0016 training loss= 0.00075 time= 0.46524
# validation roc= 0.86099 validation ap= 0.84888
# Epoch: 0017 training loss= 0.00074 time= 0.39446
# validation roc= 0.86297 validation ap= 0.85308
# Epoch: 0018 training loss= 0.00074 time= 0.37375
# validation roc= 0.86546 validation ap= 0.85798
# Epoch: 0019 training loss= 0.00073 time= 0.39928
# validation roc= 0.86763 validation ap= 0.86216
# Epoch: 0020 training loss= 0.00072 time= 0.43277
# validation roc= 0.87142 validation ap= 0.86717
# Epoch: 0021 training loss= 0.00071 time= 0.39836
# validation roc= 0.87612 validation ap= 0.87193
# Epoch: 0022 training loss= 0.00071 time= 0.40712
# validation roc= 0.87904 validation ap= 0.87306
# Epoch: 0023 training loss= 0.00070 time= 0.49299
# validation roc= 0.88052 validation ap= 0.87199
# Epoch: 0024 training loss= 0.00070 time= 2.56102
# validation roc= 0.88159 validation ap= 0.87044
# Epoch: 0025 training loss= 0.00070 time= 0.47150
# validation roc= 0.88278 validation ap= 0.87091
# Epoch: 0026 training loss= 0.00069 time= 0.56110
# validation roc= 0.88326 validation ap= 0.87140
# Epoch: 0027 training loss= 0.00069 time= 0.61662
# validation roc= 0.88469 validation ap= 0.87481
# Epoch: 0028 training loss= 0.00069 time= 0.55142
# validation roc= 0.88728 validation ap= 0.87995
# Epoch: 0029 training loss= 0.00068 time= 0.42523
# validation roc= 0.89047 validation ap= 0.88519
# Epoch: 0030 training loss= 0.00068 time= 0.40602
# validation roc= 0.89283 validation ap= 0.88922
# Epoch: 0031 training loss= 0.00067 time= 0.50916
# validation roc= 0.89497 validation ap= 0.89238
# Epoch: 0032 training loss= 0.00067 time= 0.57835
# validation roc= 0.89719 validation ap= 0.89457
# Epoch: 0033 training loss= 0.00067 time= 0.37613
# validation roc= 0.89935 validation ap= 0.89636
# Epoch: 0034 training loss= 0.00066 time= 0.38470
# validation roc= 0.90150 validation ap= 0.89834
# Epoch: 0035 training loss= 0.00066 time= 0.49232
# validation roc= 0.90410 validation ap= 0.90066
# Epoch: 0036 training loss= 0.00066 time= 1.73497
# validation roc= 0.90679 validation ap= 0.90248
# Epoch: 0037 training loss= 0.00066 time= 1.61228
# validation roc= 0.90873 validation ap= 0.90379
# Epoch: 0038 training loss= 0.00065 time= 0.39986
# validation roc= 0.90980 validation ap= 0.90445
# Epoch: 0039 training loss= 0.00065 time= 0.63363
# validation roc= 0.91078 validation ap= 0.90573
# Epoch: 0040 training loss= 0.00065 time= 0.51623
# validation roc= 0.91213 validation ap= 0.90774
# Epoch: 0041 training loss= 0.00065 time= 0.45344
# validation roc= 0.91324 validation ap= 0.90912
# Epoch: 0042 training loss= 0.00065 time= 0.40861
# validation roc= 0.91411 validation ap= 0.91033
# Epoch: 0043 training loss= 0.00064 time= 0.41818
# validation roc= 0.91483 validation ap= 0.91115
# Epoch: 0044 training loss= 0.00064 time= 0.45749
# validation roc= 0.91557 validation ap= 0.91202
# Epoch: 0045 training loss= 0.00064 time= 0.59209
# validation roc= 0.91622 validation ap= 0.91324
# Epoch: 0046 training loss= 0.00064 time= 0.37438
# validation roc= 0.91662 validation ap= 0.91398
# Epoch: 0047 training loss= 0.00064 time= 0.43390
# validation roc= 0.91709 validation ap= 0.91516
# Epoch: 0048 training loss= 0.00064 time= 1.25220
# validation roc= 0.91694 validation ap= 0.91545
# Epoch: 0049 training loss= 0.00063 time= 0.45779
# validation roc= 0.91722 validation ap= 0.91636
# Epoch: 0050 training loss= 0.00063 time= 0.63607
# validation roc= 0.91755 validation ap= 0.91699
# Epoch: 0051 training loss= 0.00063 time= 0.49182
# validation roc= 0.91795 validation ap= 0.91739
# Epoch: 0052 training loss= 0.00063 time= 0.50596
# validation roc= 0.91850 validation ap= 0.91793
# Epoch: 0053 training loss= 0.00063 time= 0.44738
# validation roc= 0.91875 validation ap= 0.91811
# Epoch: 0054 training loss= 0.00063 time= 0.42643
# validation roc= 0.91953 validation ap= 0.91854
# Epoch: 0055 training loss= 0.00062 time= 0.46232
# validation roc= 0.92086 validation ap= 0.91994
# Epoch: 0056 training loss= 0.00062 time= 0.64087
# validation roc= 0.92194 validation ap= 0.92100
# Epoch: 0057 training loss= 0.00062 time= 0.54043
# validation roc= 0.92231 validation ap= 0.92093
# Epoch: 0058 training loss= 0.00062 time= 0.33873
# validation roc= 0.92270 validation ap= 0.92117
# Epoch: 0059 training loss= 0.00062 time= 0.37409
# validation roc= 0.92286 validation ap= 0.92129
# Epoch: 0060 training loss= 0.00062 time= 0.51493
# validation roc= 0.92390 validation ap= 0.92256
# Epoch: 0061 training loss= 0.00062 time= 1.00750
# validation roc= 0.92495 validation ap= 0.92344
# Epoch: 0062 training loss= 0.00061 time= 0.54304
# validation roc= 0.92559 validation ap= 0.92448
# Epoch: 0063 training loss= 0.00061 time= 0.36407
# validation roc= 0.92620 validation ap= 0.92552
# Epoch: 0064 training loss= 0.00061 time= 0.58843
# validation roc= 0.92605 validation ap= 0.92567
# Epoch: 0065 training loss= 0.00061 time= 0.50671
# validation roc= 0.92627 validation ap= 0.92628
# Epoch: 0066 training loss= 0.00061 time= 0.50202
# validation roc= 0.92682 validation ap= 0.92684
# Epoch: 0067 training loss= 0.00061 time= 0.32447
# validation roc= 0.92793 validation ap= 0.92783
# Epoch: 0068 training loss= 0.00061 time= 0.39831
# validation roc= 0.92842 validation ap= 0.92858
# Epoch: 0069 training loss= 0.00061 time= 0.50909
# validation roc= 0.92841 validation ap= 0.92868
# Epoch: 0070 training loss= 0.00061 time= 0.52812
# validation roc= 0.92813 validation ap= 0.92880
# Epoch: 0071 training loss= 0.00061 time= 0.42728
# validation roc= 0.92810 validation ap= 0.92871
# Epoch: 0072 training loss= 0.00060 time= 0.37792
# validation roc= 0.92815 validation ap= 0.92868
# Epoch: 0073 training loss= 0.00060 time= 0.37109
# validation roc= 0.92822 validation ap= 0.92880
# Epoch: 0074 training loss= 0.00060 time= 0.47695
# validation roc= 0.92822 validation ap= 0.92882
# Epoch: 0075 training loss= 0.00060 time= 0.66469
# validation roc= 0.92793 validation ap= 0.92864
# Epoch: 0076 training loss= 0.00060 time= 0.42028
# validation roc= 0.92787 validation ap= 0.92858
# Epoch: 0077 training loss= 0.00060 time= 0.68715
# validation roc= 0.92787 validation ap= 0.92878
# Epoch: 0078 training loss= 0.00060 time= 0.55905
# validation roc= 0.92764 validation ap= 0.92891
# Epoch: 0079 training loss= 0.00060 time= 0.42584
# validation roc= 0.92776 validation ap= 0.92923
# Epoch: 0080 training loss= 0.00060 time= 0.35826
# validation roc= 0.92767 validation ap= 0.92917
# Epoch: 0081 training loss= 0.00060 time= 0.36600
# validation roc= 0.92776 validation ap= 0.92950
# Epoch: 0082 training loss= 0.00059 time= 0.49205
# validation roc= 0.92758 validation ap= 0.92940
# Epoch: 0083 training loss= 0.00059 time= 0.52508
# validation roc= 0.92744 validation ap= 0.92937
# Epoch: 0084 training loss= 0.00059 time= 0.52185
# validation roc= 0.92740 validation ap= 0.92966
# Epoch: 0085 training loss= 0.00059 time= 0.40198
# validation roc= 0.92734 validation ap= 0.92962
# Epoch: 0086 training loss= 0.00059 time= 0.38028
# validation roc= 0.92713 validation ap= 0.92947
# Epoch: 0087 training loss= 0.00059 time= 0.45275
# validation roc= 0.92715 validation ap= 0.92951
# Epoch: 0088 training loss= 0.00059 time= 0.96228
# validation roc= 0.92693 validation ap= 0.92941
# Epoch: 0089 training loss= 0.00059 time= 0.36331
# validation roc= 0.92660 validation ap= 0.92915
# Epoch: 0090 training loss= 0.00059 time= 0.34678
# validation roc= 0.92634 validation ap= 0.92894
# Epoch: 0091 training loss= 0.00059 time= 0.56276
# validation roc= 0.92599 validation ap= 0.92860
# Epoch: 0092 training loss= 0.00059 time= 0.52582
# validation roc= 0.92562 validation ap= 0.92853
# Epoch: 0093 training loss= 0.00058 time= 0.37982
# validation roc= 0.92547 validation ap= 0.92854
# Epoch: 0094 training loss= 0.00058 time= 0.33062
# validation roc= 0.92536 validation ap= 0.92858
# Epoch: 0095 training loss= 0.00058 time= 0.31973
# validation roc= 0.92536 validation ap= 0.92869
# Epoch: 0096 training loss= 0.00058 time= 0.51903
# validation roc= 0.92533 validation ap= 0.92868
# Epoch: 0097 training loss= 0.00058 time= 0.39909
# validation roc= 0.92531 validation ap= 0.92882
# Epoch: 0098 training loss= 0.00058 time= 0.31026
# validation roc= 0.92553 validation ap= 0.92913
# Epoch: 0099 training loss= 0.00058 time= 0.35610
# validation roc= 0.92539 validation ap= 0.92894
# Epoch: 0100 training loss= 0.00058 time= 0.39880
# validation roc= 0.92533 validation ap= 0.92891
# Epoch: 0101 training loss= 0.00058 time= 0.47836
# validation roc= 0.92549 validation ap= 0.92928
# Epoch: 0102 training loss= 0.00058 time= 0.36270
# validation roc= 0.92557 validation ap= 0.92933
# Epoch: 0103 training loss= 0.00058 time= 0.51965
# validation roc= 0.92589 validation ap= 0.92971
# Epoch: 0104 training loss= 0.00058 time= 0.46793
# validation roc= 0.92646 validation ap= 0.93034
# Epoch: 0105 training loss= 0.00058 time= 0.35152
# validation roc= 0.92648 validation ap= 0.93025
# Epoch: 0106 training loss= 0.00058 time= 0.29085
# validation roc= 0.92689 validation ap= 0.93071
# Epoch: 0107 training loss= 0.00058 time= 0.28714
# validation roc= 0.92702 validation ap= 0.93070
# Epoch: 0108 training loss= 0.00058 time= 0.31833
# validation roc= 0.92721 validation ap= 0.93093
# Epoch: 0109 training loss= 0.00057 time= 0.52970
# validation roc= 0.92738 validation ap= 0.93096
# Epoch: 0110 training loss= 0.00057 time= 0.44120
# validation roc= 0.92755 validation ap= 0.93096
# Epoch: 0111 training loss= 0.00057 time= 0.27728
# validation roc= 0.92771 validation ap= 0.93106
# Epoch: 0112 training loss= 0.00057 time= 0.29685
# validation roc= 0.92763 validation ap= 0.93083
# Epoch: 0113 training loss= 0.00057 time= 0.61755
# validation roc= 0.92797 validation ap= 0.93110
# Epoch: 0114 training loss= 0.00057 time= 0.44488
# validation roc= 0.92816 validation ap= 0.93125
# Epoch: 0115 training loss= 0.00057 time= 0.30806
# validation roc= 0.92835 validation ap= 0.93131
# Epoch: 0116 training loss= 0.00057 time= 0.52752
# validation roc= 0.92839 validation ap= 0.93121
# Epoch: 0117 training loss= 0.00057 time= 0.43346
# validation roc= 0.92855 validation ap= 0.93136
# Epoch: 0118 training loss= 0.00057 time= 0.32010
# validation roc= 0.92864 validation ap= 0.93146
# Epoch: 0119 training loss= 0.00057 time= 0.28062
# validation roc= 0.92888 validation ap= 0.93163
# Epoch: 0120 training loss= 0.00057 time= 0.28051
# validation roc= 0.92896 validation ap= 0.93160
# Epoch: 0121 training loss= 0.00057 time= 0.35046
# validation roc= 0.92910 validation ap= 0.93171
# Epoch: 0122 training loss= 0.00057 time= 0.29626
# validation roc= 0.92929 validation ap= 0.93187
# Epoch: 0123 training loss= 0.00057 time= 0.43418
# validation roc= 0.92946 validation ap= 0.93193
# Epoch: 0124 training loss= 0.00057 time= 0.28449
# validation roc= 0.92962 validation ap= 0.93197
# Epoch: 0125 training loss= 0.00057 time= 0.33691
# validation roc= 0.92984 validation ap= 0.93230
# Epoch: 0126 training loss= 0.00057 time= 0.24587
# validation roc= 0.93014 validation ap= 0.93257
# Epoch: 0127 training loss= 0.00057 time= 0.23254
# validation roc= 0.93024 validation ap= 0.93278
# Epoch: 0128 training loss= 0.00056 time= 0.25547
# validation roc= 0.93063 validation ap= 0.93322
# Epoch: 0129 training loss= 0.00056 time= 0.22694
# validation roc= 0.93092 validation ap= 0.93344
# Epoch: 0130 training loss= 0.00056 time= 0.35506
# validation roc= 0.93133 validation ap= 0.93386
# Epoch: 0131 training loss= 0.00056 time= 0.32606
# validation roc= 0.93149 validation ap= 0.93416
# Epoch: 0132 training loss= 0.00056 time= 0.23342
# validation roc= 0.93165 validation ap= 0.93436
# Epoch: 0133 training loss= 0.00056 time= 0.26234
# validation roc= 0.93208 validation ap= 0.93494
# Epoch: 0134 training loss= 0.00056 time= 0.34127
# validation roc= 0.93234 validation ap= 0.93521
# Epoch: 0135 training loss= 0.00056 time= 0.30057
# validation roc= 0.93286 validation ap= 0.93587
# Epoch: 0136 training loss= 0.00056 time= 0.27382
# validation roc= 0.93315 validation ap= 0.93623
# Epoch: 0137 training loss= 0.00056 time= 0.28277
# validation roc= 0.93328 validation ap= 0.93638
# Epoch: 0138 training loss= 0.00056 time= 0.28961
# validation roc= 0.93358 validation ap= 0.93678
# Epoch: 0139 training loss= 0.00056 time= 0.21497
# validation roc= 0.93370 validation ap= 0.93714
# Epoch: 0140 training loss= 0.00056 time= 0.27530
# validation roc= 0.93399 validation ap= 0.93761
# Epoch: 0141 training loss= 0.00056 time= 0.20605
# validation roc= 0.93419 validation ap= 0.93779
# Epoch: 0142 training loss= 0.00056 time= 0.22132
# validation roc= 0.93423 validation ap= 0.93793
# Epoch: 0143 training loss= 0.00056 time= 0.54391
# validation roc= 0.93448 validation ap= 0.93838
# Epoch: 0144 training loss= 0.00056 time= 0.30149
# validation roc= 0.93419 validation ap= 0.93824
# Epoch: 0145 training loss= 0.00056 time= 0.32151
# validation roc= 0.93491 validation ap= 0.93904
# Epoch: 0146 training loss= 0.00056 time= 0.41656
# validation roc= 0.93402 validation ap= 0.93782
# Epoch: 0147 training loss= 0.00056 time= 0.25047
# validation roc= 0.93552 validation ap= 0.94009
# Epoch: 0148 training loss= 0.00056 time= 0.22815
# validation roc= 0.93500 validation ap= 0.93907
# Epoch: 0149 training loss= 0.00056 time= 0.27737
# validation roc= 0.93491 validation ap= 0.93935
# Epoch: 0150 training loss= 0.00056 time= 0.21537
# validation roc= 0.93538 validation ap= 0.94015
# Epoch: 0151 training loss= 0.00056 time= 0.22559
# validation roc= 0.93514 validation ap= 0.93967
# Epoch: 0152 training loss= 0.00055 time= 0.22658
# validation roc= 0.93546 validation ap= 0.94051
# Epoch: 0153 training loss= 0.00055 time= 0.33853
# validation roc= 0.93526 validation ap= 0.94044
# Epoch: 0154 training loss= 0.00055 time= 0.60228
# validation roc= 0.93504 validation ap= 0.93985
# Epoch: 0155 training loss= 0.00055 time= 0.35766
# validation roc= 0.93578 validation ap= 0.94117
# Epoch: 0156 training loss= 0.00055 time= 0.21956
# validation roc= 0.93555 validation ap= 0.94092
# Epoch: 0157 training loss= 0.00055 time= 0.29920
# validation roc= 0.93516 validation ap= 0.94026
# Epoch: 0158 training loss= 0.00055 time= 0.34797
# validation roc= 0.93574 validation ap= 0.94141
# Epoch: 0159 training loss= 0.00055 time= 0.25840
# validation roc= 0.93582 validation ap= 0.94167
# Epoch: 0160 training loss= 0.00055 time= 0.47301
# validation roc= 0.93548 validation ap= 0.94102
# Epoch: 0161 training loss= 0.00055 time= 0.23514
# validation roc= 0.93577 validation ap= 0.94158
# Epoch: 0162 training loss= 0.00055 time= 0.23526
# validation roc= 0.93594 validation ap= 0.94181
# Epoch: 0163 training loss= 0.00055 time= 0.27996
# validation roc= 0.93571 validation ap= 0.94140
# Epoch: 0164 training loss= 0.00055 time= 0.30569
# validation roc= 0.93595 validation ap= 0.94175
# Epoch: 0165 training loss= 0.00055 time= 0.27468
# validation roc= 0.93582 validation ap= 0.94167
# Epoch: 0166 training loss= 0.00055 time= 0.27551
# validation roc= 0.93572 validation ap= 0.94161
# Epoch: 0167 training loss= 0.00055 time= 0.28043
# validation roc= 0.93584 validation ap= 0.94179
# Epoch: 0168 training loss= 0.00055 time= 0.33352
# validation roc= 0.93616 validation ap= 0.94187
# Epoch: 0169 training loss= 0.00055 time= 0.29588
# validation roc= 0.93584 validation ap= 0.94186
# Epoch: 0170 training loss= 0.00055 time= 0.30707
# validation roc= 0.93595 validation ap= 0.94201
# Epoch: 0171 training loss= 0.00055 time= 0.26273
# validation roc= 0.93626 validation ap= 0.94206
# Epoch: 0172 training loss= 0.00055 time= 0.25616
# validation roc= 0.93629 validation ap= 0.94233
# Epoch: 0173 training loss= 0.00055 time= 0.23145
# validation roc= 0.93619 validation ap= 0.94201
# Epoch: 0174 training loss= 0.00055 time= 0.24552
# validation roc= 0.93620 validation ap= 0.94210
# Epoch: 0175 training loss= 0.00055 time= 0.24874
# validation roc= 0.93617 validation ap= 0.94218
# Epoch: 0176 training loss= 0.00055 time= 0.26423
# validation roc= 0.93614 validation ap= 0.94211
# Epoch: 0177 training loss= 0.00055 time= 0.39915
# validation roc= 0.93624 validation ap= 0.94240
# Epoch: 0178 training loss= 0.00055 time= 0.55485
# validation roc= 0.93600 validation ap= 0.94204
# Epoch: 0179 training loss= 0.00055 time= 0.57332
# validation roc= 0.93584 validation ap= 0.94195
# Epoch: 0180 training loss= 0.00055 time= 0.74885
# validation roc= 0.93590 validation ap= 0.94209
# Epoch: 0181 training loss= 0.00054 time= 0.40034
# validation roc= 0.93578 validation ap= 0.94187
# Epoch: 0182 training loss= 0.00054 time= 0.27757
# validation roc= 0.93558 validation ap= 0.94172
# Epoch: 0183 training loss= 0.00054 time= 0.25858
# validation roc= 0.93590 validation ap= 0.94198
# Epoch: 0184 training loss= 0.00054 time= 0.27186
# validation roc= 0.93527 validation ap= 0.94135
# Epoch: 0185 training loss= 0.00054 time= 0.29111
# validation roc= 0.93574 validation ap= 0.94211
# Epoch: 0186 training loss= 0.00054 time= 0.23256
# validation roc= 0.93516 validation ap= 0.94093
# Epoch: 0187 training loss= 0.00054 time= 0.24529
# validation roc= 0.93546 validation ap= 0.94183
# Epoch: 0188 training loss= 0.00055 time= 0.39326
# validation roc= 0.93512 validation ap= 0.94054
# Epoch: 0189 training loss= 0.00055 time= 0.27602
# validation roc= 0.93499 validation ap= 0.94151
# Epoch: 0190 training loss= 0.00054 time= 0.26592
# validation roc= 0.93533 validation ap= 0.94117
# Epoch: 0191 training loss= 0.00054 time= 0.21738
# validation roc= 0.93480 validation ap= 0.94092
# Epoch: 0192 training loss= 0.00054 time= 0.29517
# validation roc= 0.93501 validation ap= 0.94123
# Epoch: 0193 training loss= 0.00054 time= 0.31082
# validation roc= 0.93510 validation ap= 0.94088
# Epoch: 0194 training loss= 0.00054 time= 0.37896
# validation roc= 0.93488 validation ap= 0.94118
# Epoch: 0195 training loss= 0.00054 time= 0.29243
# validation roc= 0.93530 validation ap= 0.94135
# Epoch: 0196 training loss= 0.00054 time= 0.23036
# validation roc= 0.93481 validation ap= 0.94076
# Epoch: 0197 training loss= 0.00054 time= 0.23078
# validation roc= 0.93468 validation ap= 0.94081
# Epoch: 0198 training loss= 0.00054 time= 0.35091
# validation roc= 0.93465 validation ap= 0.94099
# Epoch: 0199 training loss= 0.00054 time= 0.40949
# validation roc= 0.93449 validation ap= 0.94060
# Epoch: 0200 training loss= 0.00054 time= 0.97453
# validation roc= 0.93462 validation ap= 0.94092
# testing roc= 0.93616 testing ap= 0.94338

# %% [markdown]
# # Visulization

# %%
emb=emb
labels=load_label(dataset,data_path)

X_embedded = TSNE(n_components=2, init='pca', random_state=seed).fit_transform(emb)

cs=['orange','blue','darkcyan','fuchsia','chocolate','dodgerblue','aqua','green','red','purple']
markers=['o','+','v','2','s','X','d','>','*','<']

fig, ax = plt.subplots(1,figsize=(8,6))
for i in np.arange(X_embedded.shape[0]):#X_embedded.shape[0]
    scatter = ax.scatter(X_embedded[i,0],X_embedded[i,1],label=labels[i],marker=markers[labels[i]],color=cs[labels[i]], s=10, alpha = 1)
plt.xticks([])
plt.yticks([])
plt.xlabel("")
plt.ylabel("")
plt.axis('off')
plt.show()
