# %% [markdown]
# # Import libraries

# %%
import numpy as np
import random as rn
import os
from keras import backend as K
import  tensorflow.compat.v1  as tf
tf.disable_v2_behavior() 
import tensorflow as tf

#--------------------------------------------------------------------------------------------------------------------
# Reproducible
seed=0
os.environ['PYTHONHASHSEED'] = str(seed)

np.random.seed(seed)
rn.seed(seed)
session_conf =tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
tf.compat.v1.set_random_seed(seed)
#--------------------------------------------------------------------------------------------------------------------

import scipy.sparse as sp
import time
import pandas as pd
import sys

from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

sys.path.append(r"../../")

from dgae_alpha.evaluation import get_roc_score
from dgae_alpha.input_data import load_data, load_label
from dgae_alpha.model import *
from dgae_alpha.optimizer import *
from dgae_alpha.preprocessing import *
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.8/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %% [markdown]
# # Parameters setting

# %%
layers_no=36
data_path="../../Datasets/"
path_now="./log/"

dataset='citeseer'
model_name='DGAE_alpha_feature'

dropout=0.0
epochs=200
features_used=True
learning_rate=0.01
nb_run=1
prop_val=5
prop_test=10
validation=True
verbose=True

# %% [markdown]
# # Load data

# %%
adj_init, features_init = load_data(dataset,data_path)
num_adj=adj_init.shape[1]

# %% [markdown]
# # Training and testing

# %%
loss_coeff_adj=0.001
loss_coeff_AE=0.1
results_output_path = path_now+model_name+"/"
mkdir(results_output_path)

for seed_i in np.arange(nb_run):
    
    seed=seed_i
    lost_list=[]
    roc_list=[]
    ap_list=[]
    mean_time=[]
    
    adj, val_edges, val_edges_false, test_edges, test_edges_false =mask_test_edges(adj_init, seed,prop_test, prop_val)
                
    t_start = time.time()

    if features_used:
        features = features_init
    
    num_nodes = adj.shape[0]

    if not features_used:
        features = sp.identity(adj.shape[0])

    features = sparse_to_tuple(features)
    num_features = features[2][1]
    features_nonzero = features[1].shape[0]
        
    placeholders = {
        'features': tf.sparse_placeholder(tf.float32),
        'adj': tf.sparse_placeholder(tf.float32),
        'adj_orig': tf.sparse_placeholder(tf.float32),
        'dropout': tf.placeholder_with_default(0., shape = ())
    }

#--------------------------------------------------------------------------------------------------------------------
# Create model
    if model_name=='DGAE_alpha_feature':
        model = DGAE_alpha_feature(placeholders, layers_no,num_features, features_nonzero)
    elif model_name=='DGAE_alpha_no_feature':
        model=DGAE_alpha_no_feature(placeholders, layers_no,num_features, num_adj,features_nonzero)
    else:
        raise ValueError('Undefined model!')

    pos_weight = float(adj.shape[0] * adj.shape[0] - adj.sum()) / adj.sum()
    norm = adj.shape[0] * adj.shape[0] / float((adj.shape[0] * adj.shape[0]- adj.sum()) * 2)
    
    with tf.name_scope('optimizer'):
        if model_name in ('DGAE_alpha_feature'):
            opt =OptimizerAE_FeatureReconstrution(preds_adj = model.reconstructions,\
                                                  preds_Features=model.feature_reconstruction,\
                                                  labels_adj = tf.reshape(tf.sparse_tensor_to_dense(placeholders['adj_orig'],\
                                                                                                    validate_indices = False), [-1]),\
                                                  labels_Features=placeholders['features'],\
                                                  labels_adj_rec=placeholders['adj'],\
                                                  loss_coeff_adj=loss_coeff_adj,\
                                                  loss_coeff_AE=loss_coeff_AE,\
                                                  pos_weight = pos_weight,\
                                                  norm = norm)
                
        elif model_name in ('DGAE_alpha_no_feature'):
            opt =OptimizerAE_AdjReconstrution(preds_adj = model.reconstructions,\
                                              preds_adj_rec=model.adj_reconstruction,\
                                              labels_adj = tf.reshape(tf.sparse_tensor_to_dense(placeholders['adj_orig'],
                                                                                                validate_indices = False), [-1]),\
                                              labels_Features=placeholders['features'],\
                                              labels_adj_rec=placeholders['adj'],\
                                              loss_coeff_adj=loss_coeff_adj,\
                                              loss_coeff_AE=loss_coeff_AE,\
                                              pos_weight = pos_weight,\
                                              norm = norm)

    adj_norm = preprocess_graph(adj)
    adj_label = sparse_to_tuple(adj + sp.eye(adj.shape[0]))

    sess = tf.Session()
    sess.run(tf.global_variables_initializer())
    
    for epoch in range(epochs):
        t = time.time()
        feed_dict = construct_feed_dict(adj_norm, adj_label, features,placeholders)
        feed_dict.update({placeholders['dropout']: dropout})
        outs = sess.run([opt.opt_op, opt.cost, opt.accuracy],feed_dict = feed_dict)
        avg_cost = outs[1]
        if verbose:
            lost_list.append(avg_cost)
            print("Epoch:", '%04d' % (epoch + 1), "training loss=", "{:.5f}".format(avg_cost),"time=", "{:.5f}".format(time.time() - t))
                    
            if validation:
                feed_dict.update({placeholders['dropout']: 0})
                emb = sess.run(model.z_mean, feed_dict = feed_dict)
                feed_dict.update({placeholders['dropout']: dropout})
                val_roc, val_ap = get_roc_score(val_edges, val_edges_false, emb)
                roc_list.append(val_roc)
                ap_list.append(val_ap)
                print("validation roc=", "{:.5f}".format(val_roc), "validation ap=", "{:.5f}".format(val_ap))

    emb = sess.run(model.z_mean, feed_dict = feed_dict)   
    mean_time.append(time.time() - t_start)
    
    roc_score, ap_score = get_roc_score(test_edges, test_edges_false, emb)
    print("testing roc=", "{:.5f}".format(roc_score), "testing ap=", "{:.5f}".format(ap_score))
    
    roc_list.append(roc_score)
    ap_list.append(ap_score)
    
    mean_time_=np.array(mean_time)
    write_to_csv(mean_time_.reshape(1,len(mean_time_)),results_output_path+"layers_"+str(layers_no)+"_time.csv")

    roc_list_=np.array(roc_list)
    write_to_csv(roc_list_.reshape(1,len(roc_list_)),results_output_path+"layers_"+str(layers_no)+"_roc.csv")

    ap_list_=np.array(ap_list)
    write_to_csv(ap_list_.reshape(1,len(ap_list_)),results_output_path+"layers_"+str(layers_no)+"_ap.csv")
# Out:
# Failure
# WARNING:tensorflow:From /usr/local/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:201: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:201: calling weighted_cross_entropy_with_logits (from tensorflow.python.ops.nn_impl) with targets is deprecated and will be removed in a future version.
# Instructions for updating:
# targets is deprecated, use labels instead
# Epoch: 0001 training loss= 0.00125 time= 3.43645
# validation roc= 0.64769 validation ap= 0.68269
# Epoch: 0002 training loss= 0.00125 time= 0.53730
# validation roc= 0.72122 validation ap= 0.70837
# Epoch: 0003 training loss= 0.00121 time= 0.53279
# validation roc= 0.63056 validation ap= 0.63175
# Epoch: 0004 training loss= 0.00120 time= 0.49367
# validation roc= 0.70787 validation ap= 0.72008
# Epoch: 0005 training loss= 0.00116 time= 0.48637
# validation roc= 0.79330 validation ap= 0.81099
# Epoch: 0006 training loss= 0.00110 time= 0.49235
# validation roc= 0.82274 validation ap= 0.83362
# Epoch: 0007 training loss= 0.00105 time= 0.48744
# validation roc= 0.83314 validation ap= 0.83527
# Epoch: 0008 training loss= 0.00101 time= 0.48857
# validation roc= 0.83918 validation ap= 0.83453
# Epoch: 0009 training loss= 0.00100 time= 0.44564
# validation roc= 0.84801 validation ap= 0.84215
# Epoch: 0010 training loss= 0.00099 time= 0.45952
# validation roc= 0.85715 validation ap= 0.85184
# Epoch: 0011 training loss= 0.00097 time= 0.46453
# validation roc= 0.86780 validation ap= 0.86283
# Epoch: 0012 training loss= 0.00095 time= 0.47453
# validation roc= 0.87747 validation ap= 0.87329
# Epoch: 0013 training loss= 0.00093 time= 0.43394
# validation roc= 0.88377 validation ap= 0.88086
# Epoch: 0014 training loss= 0.00092 time= 0.43957
# validation roc= 0.88661 validation ap= 0.88427
# Epoch: 0015 training loss= 0.00092 time= 0.44178
# validation roc= 0.88888 validation ap= 0.88532
# Epoch: 0016 training loss= 0.00091 time= 0.47559
# validation roc= 0.89053 validation ap= 0.88604
# Epoch: 0017 training loss= 0.00091 time= 0.42876
# validation roc= 0.89377 validation ap= 0.88944
# Epoch: 0018 training loss= 0.00091 time= 0.43120
# validation roc= 0.89786 validation ap= 0.89564
# Epoch: 0019 training loss= 0.00090 time= 0.44309
# validation roc= 0.89878 validation ap= 0.89868
# Epoch: 0020 training loss= 0.00089 time= 0.39639
# validation roc= 0.89736 validation ap= 0.89957
# Epoch: 0021 training loss= 0.00088 time= 0.43629
# validation roc= 0.89532 validation ap= 0.89849
# Epoch: 0022 training loss= 0.00088 time= 0.42688
# validation roc= 0.89361 validation ap= 0.89692
# Epoch: 0023 training loss= 0.00088 time= 0.43115
# validation roc= 0.89321 validation ap= 0.89586
# Epoch: 0024 training loss= 0.00087 time= 0.42375
# validation roc= 0.89365 validation ap= 0.89477
# Epoch: 0025 training loss= 0.00087 time= 0.45342
# validation roc= 0.89486 validation ap= 0.89492
# Epoch: 0026 training loss= 0.00087 time= 0.42418
# validation roc= 0.89629 validation ap= 0.89574
# Epoch: 0027 training loss= 0.00086 time= 0.45584
# validation roc= 0.89808 validation ap= 0.89768
# Epoch: 0028 training loss= 0.00086 time= 0.44948
# validation roc= 0.90008 validation ap= 0.90001
# Epoch: 0029 training loss= 0.00085 time= 0.42921
# validation roc= 0.90206 validation ap= 0.90210
# Epoch: 0030 training loss= 0.00085 time= 0.45974
# validation roc= 0.90402 validation ap= 0.90542
# Epoch: 0031 training loss= 0.00085 time= 0.45280
# validation roc= 0.90557 validation ap= 0.90768
# Epoch: 0032 training loss= 0.00084 time= 0.41732
# validation roc= 0.90731 validation ap= 0.90940
# Epoch: 0033 training loss= 0.00084 time= 0.43859
# validation roc= 0.91011 validation ap= 0.91227
# Epoch: 0034 training loss= 0.00084 time= 0.43462
# validation roc= 0.91174 validation ap= 0.91341
# Epoch: 0035 training loss= 0.00083 time= 0.42595
# validation roc= 0.91319 validation ap= 0.91470
# Epoch: 0036 training loss= 0.00083 time= 0.40356
# validation roc= 0.91548 validation ap= 0.91695
# Epoch: 0037 training loss= 0.00083 time= 0.39753
# validation roc= 0.91706 validation ap= 0.91855
# Epoch: 0038 training loss= 0.00083 time= 0.43483
# validation roc= 0.91838 validation ap= 0.91968
# Epoch: 0039 training loss= 0.00082 time= 0.40889
# validation roc= 0.91900 validation ap= 0.92060
# Epoch: 0040 training loss= 0.00082 time= 0.47089
# validation roc= 0.91958 validation ap= 0.92107
# Epoch: 0041 training loss= 0.00082 time= 0.41809
# validation roc= 0.92053 validation ap= 0.92210
# Epoch: 0042 training loss= 0.00082 time= 0.42239
# validation roc= 0.92113 validation ap= 0.92297
# Epoch: 0043 training loss= 0.00082 time= 0.42805
# validation roc= 0.92197 validation ap= 0.92415
# Epoch: 0044 training loss= 0.00081 time= 0.40748
# validation roc= 0.92313 validation ap= 0.92566
# Epoch: 0045 training loss= 0.00081 time= 0.40493
# validation roc= 0.92381 validation ap= 0.92658
# Epoch: 0046 training loss= 0.00081 time= 0.39706
# validation roc= 0.92433 validation ap= 0.92748
# Epoch: 0047 training loss= 0.00081 time= 0.36168
# validation roc= 0.92422 validation ap= 0.92786
# Epoch: 0048 training loss= 0.00081 time= 0.41926
# validation roc= 0.92364 validation ap= 0.92801
# Epoch: 0049 training loss= 0.00080 time= 0.40845
# validation roc= 0.92408 validation ap= 0.92929
# Epoch: 0050 training loss= 0.00080 time= 0.42382
# validation roc= 0.92466 validation ap= 0.92995
# Epoch: 0051 training loss= 0.00080 time= 0.41065
# validation roc= 0.92451 validation ap= 0.92999
# Epoch: 0052 training loss= 0.00080 time= 0.38865
# validation roc= 0.92466 validation ap= 0.93014
# Epoch: 0053 training loss= 0.00080 time= 0.44543
# validation roc= 0.92462 validation ap= 0.93003
# Epoch: 0054 training loss= 0.00080 time= 0.44788
# validation roc= 0.92513 validation ap= 0.93043
# Epoch: 0055 training loss= 0.00080 time= 0.42561
# validation roc= 0.92563 validation ap= 0.93080
# Epoch: 0056 training loss= 0.00079 time= 0.38553
# validation roc= 0.92672 validation ap= 0.93189
# Epoch: 0057 training loss= 0.00079 time= 0.45304
# validation roc= 0.92715 validation ap= 0.93254
# Epoch: 0058 training loss= 0.00079 time= 0.43896
# validation roc= 0.92765 validation ap= 0.93293
# Epoch: 0059 training loss= 0.00079 time= 0.43724
# validation roc= 0.92769 validation ap= 0.93273
# Epoch: 0060 training loss= 0.00079 time= 0.42023
# validation roc= 0.92816 validation ap= 0.93326
# Epoch: 0061 training loss= 0.00079 time= 0.40179
# validation roc= 0.92876 validation ap= 0.93389
# Epoch: 0062 training loss= 0.00079 time= 0.40817
# validation roc= 0.92889 validation ap= 0.93391
# Epoch: 0063 training loss= 0.00079 time= 0.38462
# validation roc= 0.92891 validation ap= 0.93361
# Epoch: 0064 training loss= 0.00078 time= 0.36403
# validation roc= 0.92917 validation ap= 0.93407
# Epoch: 0065 training loss= 0.00078 time= 0.35024
# validation roc= 0.92946 validation ap= 0.93446
# Epoch: 0066 training loss= 0.00078 time= 0.36862
# validation roc= 0.92967 validation ap= 0.93480
# Epoch: 0067 training loss= 0.00078 time= 0.36415
# validation roc= 0.92975 validation ap= 0.93490
# Epoch: 0068 training loss= 0.00078 time= 0.36848
# validation roc= 0.93004 validation ap= 0.93515
# Epoch: 0069 training loss= 0.00078 time= 0.45219
# validation roc= 0.93010 validation ap= 0.93504
# Epoch: 0070 training loss= 0.00078 time= 0.43013
# validation roc= 0.93023 validation ap= 0.93523
# Epoch: 0071 training loss= 0.00078 time= 0.36978
# validation roc= 0.92986 validation ap= 0.93515
# Epoch: 0072 training loss= 0.00078 time= 0.37155
# validation roc= 0.92946 validation ap= 0.93481
# Epoch: 0073 training loss= 0.00078 time= 0.38678
# validation roc= 0.92952 validation ap= 0.93509
# Epoch: 0074 training loss= 0.00077 time= 0.39517
# validation roc= 0.92985 validation ap= 0.93553
# Epoch: 0075 training loss= 0.00077 time= 0.47637
# validation roc= 0.93019 validation ap= 0.93622
# Epoch: 0076 training loss= 0.00077 time= 0.46402
# validation roc= 0.93027 validation ap= 0.93681
# Epoch: 0077 training loss= 0.00077 time= 0.42455
# validation roc= 0.93023 validation ap= 0.93726
# Epoch: 0078 training loss= 0.00077 time= 0.34587
# validation roc= 0.93051 validation ap= 0.93761
# Epoch: 0079 training loss= 0.00077 time= 0.43559
# validation roc= 0.93066 validation ap= 0.93813
# Epoch: 0080 training loss= 0.00077 time= 0.39612
# validation roc= 0.93031 validation ap= 0.93801
# Epoch: 0081 training loss= 0.00077 time= 0.36238
# validation roc= 0.92990 validation ap= 0.93772
# Epoch: 0082 training loss= 0.00077 time= 0.35793
# validation roc= 0.92983 validation ap= 0.93784
# Epoch: 0083 training loss= 0.00077 time= 0.43996
# validation roc= 0.92963 validation ap= 0.93775
# Epoch: 0084 training loss= 0.00076 time= 0.40583
# validation roc= 0.92952 validation ap= 0.93770
# Epoch: 0085 training loss= 0.00076 time= 0.40428
# validation roc= 0.92934 validation ap= 0.93765
# Epoch: 0086 training loss= 0.00076 time= 0.39637
# validation roc= 0.92888 validation ap= 0.93749
# Epoch: 0087 training loss= 0.00076 time= 0.37712
# validation roc= 0.92847 validation ap= 0.93692
# Epoch: 0088 training loss= 0.00076 time= 0.36736
# validation roc= 0.92804 validation ap= 0.93643
# Epoch: 0089 training loss= 0.00076 time= 0.40225
# validation roc= 0.92777 validation ap= 0.93623
# Epoch: 0090 training loss= 0.00076 time= 0.46352
# validation roc= 0.92740 validation ap= 0.93576
# Epoch: 0091 training loss= 0.00076 time= 0.38279
# validation roc= 0.92730 validation ap= 0.93578
# Epoch: 0092 training loss= 0.00076 time= 0.39495
# validation roc= 0.92701 validation ap= 0.93556
# Epoch: 0093 training loss= 0.00076 time= 0.39033
# validation roc= 0.92659 validation ap= 0.93515
# Epoch: 0094 training loss= 0.00076 time= 0.40651
# validation roc= 0.92631 validation ap= 0.93486
# Epoch: 0095 training loss= 0.00076 time= 0.37851
# validation roc= 0.92627 validation ap= 0.93467
# Epoch: 0096 training loss= 0.00075 time= 0.39661
# validation roc= 0.92606 validation ap= 0.93441
# Epoch: 0097 training loss= 0.00075 time= 0.36838
# validation roc= 0.92631 validation ap= 0.93445
# Epoch: 0098 training loss= 0.00075 time= 0.35578
# validation roc= 0.92662 validation ap= 0.93460
# Epoch: 0099 training loss= 0.00075 time= 0.35895
# validation roc= 0.92674 validation ap= 0.93476
# Epoch: 0100 training loss= 0.00075 time= 0.40649
# validation roc= 0.92703 validation ap= 0.93485
# Epoch: 0101 training loss= 0.00075 time= 0.40293
# validation roc= 0.92715 validation ap= 0.93488
# Epoch: 0102 training loss= 0.00075 time= 0.34406
# validation roc= 0.92709 validation ap= 0.93486
# Epoch: 0103 training loss= 0.00075 time= 0.41196
# validation roc= 0.92736 validation ap= 0.93521
# Epoch: 0104 training loss= 0.00075 time= 0.40279
# validation roc= 0.92759 validation ap= 0.93573
# Epoch: 0105 training loss= 0.00075 time= 0.39117
# validation roc= 0.92756 validation ap= 0.93582
# Epoch: 0106 training loss= 0.00075 time= 0.36370
# validation roc= 0.92773 validation ap= 0.93610
# Epoch: 0107 training loss= 0.00075 time= 0.46780
# validation roc= 0.92767 validation ap= 0.93613
# Epoch: 0108 training loss= 0.00075 time= 0.39226
# validation roc= 0.92777 validation ap= 0.93648
# Epoch: 0109 training loss= 0.00075 time= 0.39956
# validation roc= 0.92765 validation ap= 0.93674
# Epoch: 0110 training loss= 0.00074 time= 0.36191
# validation roc= 0.92775 validation ap= 0.93681
# Epoch: 0111 training loss= 0.00074 time= 0.41054
# validation roc= 0.92767 validation ap= 0.93684
# Epoch: 0112 training loss= 0.00074 time= 0.38687
# validation roc= 0.92759 validation ap= 0.93693
# Epoch: 0113 training loss= 0.00074 time= 0.40670
# validation roc= 0.92785 validation ap= 0.93756
# Epoch: 0114 training loss= 0.00074 time= 0.36413
# validation roc= 0.92796 validation ap= 0.93802
# Epoch: 0115 training loss= 0.00074 time= 0.42385
# validation roc= 0.92806 validation ap= 0.93831
# Epoch: 0116 training loss= 0.00074 time= 0.40820
# validation roc= 0.92789 validation ap= 0.93823
# Epoch: 0117 training loss= 0.00074 time= 0.38763
# validation roc= 0.92779 validation ap= 0.93830
# Epoch: 0118 training loss= 0.00074 time= 0.41772
# validation roc= 0.92781 validation ap= 0.93852
# Epoch: 0119 training loss= 0.00074 time= 0.39411
# validation roc= 0.92806 validation ap= 0.93878
# Epoch: 0120 training loss= 0.00074 time= 0.38216
# validation roc= 0.92789 validation ap= 0.93867
# Epoch: 0121 training loss= 0.00074 time= 0.38594
# validation roc= 0.92783 validation ap= 0.93870
# Epoch: 0122 training loss= 0.00074 time= 0.42329
# validation roc= 0.92773 validation ap= 0.93873
# Epoch: 0123 training loss= 0.00074 time= 0.40108
# validation roc= 0.92794 validation ap= 0.93891
# Epoch: 0124 training loss= 0.00074 time= 0.37920
# validation roc= 0.92752 validation ap= 0.93855
# Epoch: 0125 training loss= 0.00074 time= 0.41405
# validation roc= 0.92752 validation ap= 0.93844
# Epoch: 0126 training loss= 0.00074 time= 0.41594
# validation roc= 0.92738 validation ap= 0.93844
# Epoch: 0127 training loss= 0.00074 time= 0.38612
# validation roc= 0.92728 validation ap= 0.93863
# Epoch: 0128 training loss= 0.00074 time= 0.40014
# validation roc= 0.92756 validation ap= 0.93846
# Epoch: 0129 training loss= 0.00073 time= 0.36944
# validation roc= 0.92802 validation ap= 0.93927
# Epoch: 0130 training loss= 0.00073 time= 0.44695
# validation roc= 0.92711 validation ap= 0.93799
# Epoch: 0131 training loss= 0.00073 time= 0.42113
# validation roc= 0.92790 validation ap= 0.93912
# Epoch: 0132 training loss= 0.00073 time= 0.39324
# validation roc= 0.92765 validation ap= 0.93852
# Epoch: 0133 training loss= 0.00073 time= 0.39867
# validation roc= 0.92761 validation ap= 0.93891
# Epoch: 0134 training loss= 0.00073 time= 0.45408
# validation roc= 0.92781 validation ap= 0.93883
# Epoch: 0135 training loss= 0.00073 time= 0.39763
# validation roc= 0.92787 validation ap= 0.93843
# Epoch: 0136 training loss= 0.00073 time= 0.42145
# validation roc= 0.92732 validation ap= 0.93865
# Epoch: 0137 training loss= 0.00073 time= 0.35793
# validation roc= 0.92752 validation ap= 0.93836
# Epoch: 0138 training loss= 0.00073 time= 0.41092
# validation roc= 0.92769 validation ap= 0.93835
# Epoch: 0139 training loss= 0.00073 time= 0.40173
# validation roc= 0.92707 validation ap= 0.93846
# Epoch: 0140 training loss= 0.00073 time= 0.39480
# validation roc= 0.92715 validation ap= 0.93805
# Epoch: 0141 training loss= 0.00073 time= 0.39739
# validation roc= 0.92715 validation ap= 0.93775
# Epoch: 0142 training loss= 0.00073 time= 0.42549
# validation roc= 0.92672 validation ap= 0.93789
# Epoch: 0143 training loss= 0.00073 time= 0.39673
# validation roc= 0.92672 validation ap= 0.93750
# Epoch: 0144 training loss= 0.00073 time= 0.41762
# validation roc= 0.92678 validation ap= 0.93741
# Epoch: 0145 training loss= 0.00072 time= 0.37533
# validation roc= 0.92662 validation ap= 0.93753
# Epoch: 0146 training loss= 0.00072 time= 0.38729
# validation roc= 0.92604 validation ap= 0.93662
# Epoch: 0147 training loss= 0.00072 time= 0.36995
# validation roc= 0.92701 validation ap= 0.93765
# Epoch: 0148 training loss= 0.00072 time= 0.38774
# validation roc= 0.92639 validation ap= 0.93709
# Epoch: 0149 training loss= 0.00072 time= 0.41104
# validation roc= 0.92684 validation ap= 0.93763
# Epoch: 0150 training loss= 0.00072 time= 0.40007
# validation roc= 0.92614 validation ap= 0.93688
# Epoch: 0151 training loss= 0.00072 time= 0.40300
# validation roc= 0.92717 validation ap= 0.93802
# Epoch: 0152 training loss= 0.00072 time= 0.40120
# validation roc= 0.92558 validation ap= 0.93639
# Epoch: 0153 training loss= 0.00072 time= 0.40210
# validation roc= 0.92794 validation ap= 0.93861
# Epoch: 0154 training loss= 0.00072 time= 0.44669
# validation roc= 0.92497 validation ap= 0.93604
# Epoch: 0155 training loss= 0.00072 time= 0.40095
# validation roc= 0.92765 validation ap= 0.93854
# Epoch: 0156 training loss= 0.00072 time= 0.47536
# validation roc= 0.92643 validation ap= 0.93731
# Epoch: 0157 training loss= 0.00072 time= 0.44392
# validation roc= 0.92629 validation ap= 0.93752
# Epoch: 0158 training loss= 0.00072 time= 0.43668
# validation roc= 0.92726 validation ap= 0.93814
# Epoch: 0159 training loss= 0.00072 time= 0.47259
# validation roc= 0.92571 validation ap= 0.93672
# Epoch: 0160 training loss= 0.00072 time= 0.35681
# validation roc= 0.92726 validation ap= 0.93850
# Epoch: 0161 training loss= 0.00072 time= 0.34764
# validation roc= 0.92666 validation ap= 0.93766
# Epoch: 0162 training loss= 0.00072 time= 0.39501
# validation roc= 0.92610 validation ap= 0.93734
# Epoch: 0163 training loss= 0.00072 time= 0.43340
# validation roc= 0.92744 validation ap= 0.93838
# Epoch: 0164 training loss= 0.00072 time= 0.36721
# validation roc= 0.92643 validation ap= 0.93753
# Epoch: 0165 training loss= 0.00072 time= 0.41332
# validation roc= 0.92659 validation ap= 0.93777
# Epoch: 0166 training loss= 0.00072 time= 0.41184
# validation roc= 0.92703 validation ap= 0.93815
# Epoch: 0167 training loss= 0.00071 time= 0.36728
# validation roc= 0.92585 validation ap= 0.93717
# Epoch: 0168 training loss= 0.00071 time= 0.35222
# validation roc= 0.92711 validation ap= 0.93820
# Epoch: 0169 training loss= 0.00071 time= 0.40490
# validation roc= 0.92666 validation ap= 0.93813
# Epoch: 0170 training loss= 0.00071 time= 0.41615
# validation roc= 0.92618 validation ap= 0.93740
# Epoch: 0171 training loss= 0.00071 time= 0.41596
# validation roc= 0.92724 validation ap= 0.93889
# Epoch: 0172 training loss= 0.00071 time= 0.42003
# validation roc= 0.92627 validation ap= 0.93791
# Epoch: 0173 training loss= 0.00071 time= 0.38654
# validation roc= 0.92684 validation ap= 0.93861
# Epoch: 0174 training loss= 0.00071 time= 0.40079
# validation roc= 0.92707 validation ap= 0.93888
# Epoch: 0175 training loss= 0.00071 time= 0.39475
# validation roc= 0.92666 validation ap= 0.93860
# Epoch: 0176 training loss= 0.00071 time= 0.33999
# validation roc= 0.92701 validation ap= 0.93882
# Epoch: 0177 training loss= 0.00071 time= 0.41337
# validation roc= 0.92649 validation ap= 0.93886
# Epoch: 0178 training loss= 0.00071 time= 0.41077
# validation roc= 0.92659 validation ap= 0.93833
# Epoch: 0179 training loss= 0.00071 time= 0.37231
# validation roc= 0.92686 validation ap= 0.93955
# Epoch: 0180 training loss= 0.00071 time= 0.42039
# validation roc= 0.92645 validation ap= 0.93820
# Epoch: 0181 training loss= 0.00071 time= 0.36480
# validation roc= 0.92693 validation ap= 0.93986
# Epoch: 0182 training loss= 0.00071 time= 0.36449
# validation roc= 0.92666 validation ap= 0.93835
# Epoch: 0183 training loss= 0.00071 time= 0.39914
# validation roc= 0.92691 validation ap= 0.93997
# Epoch: 0184 training loss= 0.00071 time= 0.44566
# validation roc= 0.92672 validation ap= 0.93875
# Epoch: 0185 training loss= 0.00071 time= 0.41330
# validation roc= 0.92730 validation ap= 0.93981
# Epoch: 0186 training loss= 0.00071 time= 0.35482
# validation roc= 0.92688 validation ap= 0.93936
# Epoch: 0187 training loss= 0.00071 time= 0.34207
# validation roc= 0.92670 validation ap= 0.93882
# Epoch: 0188 training loss= 0.00071 time= 0.37336
# validation roc= 0.92756 validation ap= 0.94043
# Epoch: 0189 training loss= 0.00071 time= 0.40705
# validation roc= 0.92678 validation ap= 0.93883
# Epoch: 0190 training loss= 0.00071 time= 0.36102
# validation roc= 0.92703 validation ap= 0.93934
# Epoch: 0191 training loss= 0.00071 time= 0.40485
# validation roc= 0.92744 validation ap= 0.94005
# Epoch: 0192 training loss= 0.00071 time= 0.35180
# validation roc= 0.92660 validation ap= 0.93876
# Epoch: 0193 training loss= 0.00071 time= 0.40429
# validation roc= 0.92738 validation ap= 0.93984
# Epoch: 0194 training loss= 0.00071 time= 0.41240
# validation roc= 0.92697 validation ap= 0.93947
# Epoch: 0195 training loss= 0.00071 time= 0.46473
# validation roc= 0.92680 validation ap= 0.93874
# Epoch: 0196 training loss= 0.00071 time= 0.42793
# validation roc= 0.92688 validation ap= 0.93978
# Epoch: 0197 training loss= 0.00071 time= 0.36727
# validation roc= 0.92659 validation ap= 0.93861
# Epoch: 0198 training loss= 0.00070 time= 0.36814
# validation roc= 0.92680 validation ap= 0.93923
# Epoch: 0199 training loss= 0.00070 time= 0.44721
# validation roc= 0.92660 validation ap= 0.93885
# Epoch: 0200 training loss= 0.00070 time= 0.38180
# validation roc= 0.92662 validation ap= 0.93890
# testing roc= 0.94715 testing ap= 0.95158

# %% [markdown]
# # Visulization

# %%
emb=emb
labels=load_label(dataset,data_path)

X_embedded = TSNE(n_components=2, init='pca', random_state=seed).fit_transform(emb)

cs=['orange','blue','darkcyan','fuchsia','chocolate','dodgerblue','aqua','green','red','purple']
markers=['o','+','v','2','s','X','d','>','*','<']

fig, ax = plt.subplots(1,figsize=(8,6))
for i in np.arange(X_embedded.shape[0]):#X_embedded.shape[0]
    scatter = ax.scatter(X_embedded[i,0],X_embedded[i,1],label=labels[i],marker=markers[labels[i]],color=cs[labels[i]], s=10, alpha = 1)
plt.xticks([])
plt.yticks([])
plt.xlabel("")
plt.ylabel("")
plt.axis('off')
plt.show()
