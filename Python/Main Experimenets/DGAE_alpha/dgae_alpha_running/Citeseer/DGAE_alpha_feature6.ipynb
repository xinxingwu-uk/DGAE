# %% [markdown]
# # Import libraries

# %%
import numpy as np
import random as rn
import os
from keras import backend as K
import  tensorflow.compat.v1  as tf
tf.disable_v2_behavior() 
import tensorflow as tf

#--------------------------------------------------------------------------------------------------------------------
# Reproducible
seed=0
os.environ['PYTHONHASHSEED'] = str(seed)

np.random.seed(seed)
rn.seed(seed)
session_conf =tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
tf.compat.v1.set_random_seed(seed)
#--------------------------------------------------------------------------------------------------------------------

import scipy.sparse as sp
import time
import pandas as pd
import sys

from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

sys.path.append(r"../../")

from dgae_alpha.evaluation import get_roc_score
from dgae_alpha.input_data import load_data, load_label
from dgae_alpha.model import *
from dgae_alpha.optimizer import *
from dgae_alpha.preprocessing import *
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.8/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %% [markdown]
# # Parameters setting

# %%
layers_no=6
data_path="../../Datasets/"
path_now="./log/"

dataset='citeseer'
model_name='DGAE_alpha_feature'

dropout=0.0
epochs=200
features_used=True
learning_rate=0.01
nb_run=1
prop_val=5
prop_test=10
validation=True
verbose=True

# %% [markdown]
# # Load data

# %%
adj_init, features_init = load_data(dataset,data_path)
num_adj=adj_init.shape[1]

# %% [markdown]
# # Training and testing

# %%
loss_coeff_adj=0.001
loss_coeff_AE=0.1
results_output_path = path_now+model_name+"/"
mkdir(results_output_path)

for seed_i in np.arange(nb_run):
    
    seed=seed_i
    lost_list=[]
    roc_list=[]
    ap_list=[]
    mean_time=[]
    
    adj, val_edges, val_edges_false, test_edges, test_edges_false =mask_test_edges(adj_init, seed,prop_test, prop_val)
                
    t_start = time.time()

    if features_used:
        features = features_init
    
    num_nodes = adj.shape[0]

    if not features_used:
        features = sp.identity(adj.shape[0])

    features = sparse_to_tuple(features)
    num_features = features[2][1]
    features_nonzero = features[1].shape[0]
        
    placeholders = {
        'features': tf.sparse_placeholder(tf.float32),
        'adj': tf.sparse_placeholder(tf.float32),
        'adj_orig': tf.sparse_placeholder(tf.float32),
        'dropout': tf.placeholder_with_default(0., shape = ())
    }

#--------------------------------------------------------------------------------------------------------------------
# Create model
    if model_name=='DGAE_alpha_feature':
        model = DGAE_alpha_feature(placeholders, layers_no,num_features, features_nonzero)
    elif model_name=='DGAE_alpha_no_feature':
        model=DGAE_alpha_no_feature(placeholders, layers_no,num_features, num_adj,features_nonzero)
    else:
        raise ValueError('Undefined model!')

    pos_weight = float(adj.shape[0] * adj.shape[0] - adj.sum()) / adj.sum()
    norm = adj.shape[0] * adj.shape[0] / float((adj.shape[0] * adj.shape[0]- adj.sum()) * 2)
    
    with tf.name_scope('optimizer'):
        if model_name in ('DGAE_alpha_feature'):
            opt =OptimizerAE_FeatureReconstrution(preds_adj = model.reconstructions,\
                                                  preds_Features=model.feature_reconstruction,\
                                                  labels_adj = tf.reshape(tf.sparse_tensor_to_dense(placeholders['adj_orig'],\
                                                                                                    validate_indices = False), [-1]),\
                                                  labels_Features=placeholders['features'],\
                                                  labels_adj_rec=placeholders['adj'],\
                                                  loss_coeff_adj=loss_coeff_adj,\
                                                  loss_coeff_AE=loss_coeff_AE,\
                                                  pos_weight = pos_weight,\
                                                  norm = norm)
                
        elif model_name in ('DGAE_alpha_no_feature'):
            opt =OptimizerAE_AdjReconstrution(preds_adj = model.reconstructions,\
                                              preds_adj_rec=model.adj_reconstruction,\
                                              labels_adj = tf.reshape(tf.sparse_tensor_to_dense(placeholders['adj_orig'],
                                                                                                validate_indices = False), [-1]),\
                                              labels_Features=placeholders['features'],\
                                              labels_adj_rec=placeholders['adj'],\
                                              loss_coeff_adj=loss_coeff_adj,\
                                              loss_coeff_AE=loss_coeff_AE,\
                                              pos_weight = pos_weight,\
                                              norm = norm)

    adj_norm = preprocess_graph(adj)
    adj_label = sparse_to_tuple(adj + sp.eye(adj.shape[0]))

    sess = tf.Session()
    sess.run(tf.global_variables_initializer())
    
    for epoch in range(epochs):
        t = time.time()
        feed_dict = construct_feed_dict(adj_norm, adj_label, features,placeholders)
        feed_dict.update({placeholders['dropout']: dropout})
        outs = sess.run([opt.opt_op, opt.cost, opt.accuracy],feed_dict = feed_dict)
        avg_cost = outs[1]
        if verbose:
            lost_list.append(avg_cost)
            print("Epoch:", '%04d' % (epoch + 1), "training loss=", "{:.5f}".format(avg_cost),"time=", "{:.5f}".format(time.time() - t))
                    
            if validation:
                feed_dict.update({placeholders['dropout']: 0})
                emb = sess.run(model.z_mean, feed_dict = feed_dict)
                feed_dict.update({placeholders['dropout']: dropout})
                val_roc, val_ap = get_roc_score(val_edges, val_edges_false, emb)
                roc_list.append(val_roc)
                ap_list.append(val_ap)
                print("validation roc=", "{:.5f}".format(val_roc), "validation ap=", "{:.5f}".format(val_ap))

    emb = sess.run(model.z_mean, feed_dict = feed_dict)   
    mean_time.append(time.time() - t_start)
    
    roc_score, ap_score = get_roc_score(test_edges, test_edges_false, emb)
    print("testing roc=", "{:.5f}".format(roc_score), "testing ap=", "{:.5f}".format(ap_score))
    
    roc_list.append(roc_score)
    ap_list.append(ap_score)
    
    mean_time_=np.array(mean_time)
    write_to_csv(mean_time_.reshape(1,len(mean_time_)),results_output_path+"layers_"+str(layers_no)+"_time.csv")

    roc_list_=np.array(roc_list)
    write_to_csv(roc_list_.reshape(1,len(roc_list_)),results_output_path+"layers_"+str(layers_no)+"_roc.csv")

    ap_list_=np.array(ap_list)
    write_to_csv(ap_list_.reshape(1,len(ap_list_)),results_output_path+"layers_"+str(layers_no)+"_ap.csv")
# Out:
# Successful!
# WARNING:tensorflow:From /usr/local/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:201: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:201: calling weighted_cross_entropy_with_logits (from tensorflow.python.ops.nn_impl) with targets is deprecated and will be removed in a future version.
# Instructions for updating:
# targets is deprecated, use labels instead
# Epoch: 0001 training loss= 0.00125 time= 0.98124
# validation roc= 0.64769 validation ap= 0.68269
# Epoch: 0002 training loss= 0.00125 time= 0.74242
# validation roc= 0.72122 validation ap= 0.70837
# Epoch: 0003 training loss= 0.00121 time= 0.33463
# validation roc= 0.63056 validation ap= 0.63175
# Epoch: 0004 training loss= 0.00120 time= 0.32753
# validation roc= 0.70787 validation ap= 0.72008
# Epoch: 0005 training loss= 0.00116 time= 0.38083
# validation roc= 0.79330 validation ap= 0.81099
# Epoch: 0006 training loss= 0.00110 time= 0.83642
# validation roc= 0.82274 validation ap= 0.83362
# Epoch: 0007 training loss= 0.00105 time= 0.47894
# validation roc= 0.83314 validation ap= 0.83527
# Epoch: 0008 training loss= 0.00101 time= 0.64260
# validation roc= 0.83918 validation ap= 0.83453
# Epoch: 0009 training loss= 0.00100 time= 0.54154
# validation roc= 0.84801 validation ap= 0.84215
# Epoch: 0010 training loss= 0.00099 time= 0.51003
# validation roc= 0.85715 validation ap= 0.85184
# Epoch: 0011 training loss= 0.00097 time= 0.35999
# validation roc= 0.86780 validation ap= 0.86283
# Epoch: 0012 training loss= 0.00095 time= 0.65762
# validation roc= 0.87747 validation ap= 0.87329
# Epoch: 0013 training loss= 0.00093 time= 0.57729
# validation roc= 0.88377 validation ap= 0.88086
# Epoch: 0014 training loss= 0.00092 time= 0.34278
# validation roc= 0.88661 validation ap= 0.88427
# Epoch: 0015 training loss= 0.00092 time= 0.31059
# validation roc= 0.88888 validation ap= 0.88532
# Epoch: 0016 training loss= 0.00091 time= 0.37760
# validation roc= 0.89053 validation ap= 0.88604
# Epoch: 0017 training loss= 0.00091 time= 0.65824
# validation roc= 0.89377 validation ap= 0.88944
# Epoch: 0018 training loss= 0.00091 time= 0.48710
# validation roc= 0.89786 validation ap= 0.89564
# Epoch: 0019 training loss= 0.00090 time= 0.63537
# validation roc= 0.89878 validation ap= 0.89868
# Epoch: 0020 training loss= 0.00089 time= 0.49435
# validation roc= 0.89736 validation ap= 0.89957
# Epoch: 0021 training loss= 0.00088 time= 0.43596
# validation roc= 0.89532 validation ap= 0.89849
# Epoch: 0022 training loss= 0.00088 time= 0.45566
# validation roc= 0.89361 validation ap= 0.89692
# Epoch: 0023 training loss= 0.00088 time= 0.36511
# validation roc= 0.89321 validation ap= 0.89586
# Epoch: 0024 training loss= 0.00087 time= 0.59868
# validation roc= 0.89365 validation ap= 0.89477
# Epoch: 0025 training loss= 0.00087 time= 0.67637
# validation roc= 0.89486 validation ap= 0.89492
# Epoch: 0026 training loss= 0.00087 time= 0.34695
# validation roc= 0.89629 validation ap= 0.89574
# Epoch: 0027 training loss= 0.00086 time= 0.34470
# validation roc= 0.89808 validation ap= 0.89768
# Epoch: 0028 training loss= 0.00086 time= 0.34102
# validation roc= 0.90008 validation ap= 0.90001
# Epoch: 0029 training loss= 0.00085 time= 0.71927
# validation roc= 0.90206 validation ap= 0.90210
# Epoch: 0030 training loss= 0.00085 time= 0.48966
# validation roc= 0.90402 validation ap= 0.90542
# Epoch: 0031 training loss= 0.00085 time= 0.71778
# validation roc= 0.90557 validation ap= 0.90768
# Epoch: 0032 training loss= 0.00084 time= 0.52471
# validation roc= 0.90731 validation ap= 0.90940
# Epoch: 0033 training loss= 0.00084 time= 0.52040
# validation roc= 0.91011 validation ap= 0.91227
# Epoch: 0034 training loss= 0.00084 time= 0.42107
# validation roc= 0.91174 validation ap= 0.91341
# Epoch: 0035 training loss= 0.00083 time= 0.40190
# validation roc= 0.91319 validation ap= 0.91470
# Epoch: 0036 training loss= 0.00083 time= 0.72848
# validation roc= 0.91548 validation ap= 0.91695
# Epoch: 0037 training loss= 0.00083 time= 0.53280
# validation roc= 0.91706 validation ap= 0.91855
# Epoch: 0038 training loss= 0.00083 time= 0.31964
# validation roc= 0.91838 validation ap= 0.91968
# Epoch: 0039 training loss= 0.00082 time= 0.33622
# validation roc= 0.91900 validation ap= 0.92060
# Epoch: 0040 training loss= 0.00082 time= 0.59876
# validation roc= 0.91958 validation ap= 0.92107
# Epoch: 0041 training loss= 0.00082 time= 0.48849
# validation roc= 0.92053 validation ap= 0.92210
# Epoch: 0042 training loss= 0.00082 time= 0.41354
# validation roc= 0.92113 validation ap= 0.92297
# Epoch: 0043 training loss= 0.00082 time= 0.55623
# validation roc= 0.92197 validation ap= 0.92415
# Epoch: 0044 training loss= 0.00081 time= 0.54099
# validation roc= 0.92313 validation ap= 0.92566
# Epoch: 0045 training loss= 0.00081 time= 0.45248
# validation roc= 0.92381 validation ap= 0.92658
# Epoch: 0046 training loss= 0.00081 time= 0.44551
# validation roc= 0.92433 validation ap= 0.92748
# Epoch: 0047 training loss= 0.00081 time= 0.40529
# validation roc= 0.92422 validation ap= 0.92786
# Epoch: 0048 training loss= 0.00081 time= 0.79098
# validation roc= 0.92364 validation ap= 0.92801
# Epoch: 0049 training loss= 0.00080 time= 0.53658
# validation roc= 0.92408 validation ap= 0.92929
# Epoch: 0050 training loss= 0.00080 time= 0.31875
# validation roc= 0.92466 validation ap= 0.92995
# Epoch: 0051 training loss= 0.00080 time= 0.31854
# validation roc= 0.92451 validation ap= 0.92999
# Epoch: 0052 training loss= 0.00080 time= 0.65979
# validation roc= 0.92466 validation ap= 0.93014
# Epoch: 0053 training loss= 0.00080 time= 0.39655
# validation roc= 0.92462 validation ap= 0.93003
# Epoch: 0054 training loss= 0.00080 time= 0.48299
# validation roc= 0.92513 validation ap= 0.93043
# Epoch: 0055 training loss= 0.00080 time= 0.52285
# validation roc= 0.92563 validation ap= 0.93080
# Epoch: 0056 training loss= 0.00079 time= 0.53429
# validation roc= 0.92672 validation ap= 0.93189
# Epoch: 0057 training loss= 0.00079 time= 0.43176
# validation roc= 0.92715 validation ap= 0.93254
# Epoch: 0058 training loss= 0.00079 time= 0.41260
# validation roc= 0.92765 validation ap= 0.93293
# Epoch: 0059 training loss= 0.00079 time= 0.38814
# validation roc= 0.92769 validation ap= 0.93273
# Epoch: 0060 training loss= 0.00079 time= 0.93254
# validation roc= 0.92816 validation ap= 0.93326
# Epoch: 0061 training loss= 0.00079 time= 0.45917
# validation roc= 0.92876 validation ap= 0.93389
# Epoch: 0062 training loss= 0.00079 time= 0.33478
# validation roc= 0.92889 validation ap= 0.93391
# Epoch: 0063 training loss= 0.00079 time= 0.31729
# validation roc= 0.92891 validation ap= 0.93361
# Epoch: 0064 training loss= 0.00078 time= 0.67991
# validation roc= 0.92917 validation ap= 0.93407
# Epoch: 0065 training loss= 0.00078 time= 0.46885
# validation roc= 0.92946 validation ap= 0.93446
# Epoch: 0066 training loss= 0.00078 time= 0.65690
# validation roc= 0.92967 validation ap= 0.93480
# Epoch: 0067 training loss= 0.00078 time= 0.57882
# validation roc= 0.92975 validation ap= 0.93490
# Epoch: 0068 training loss= 0.00078 time= 0.49898
# validation roc= 0.93004 validation ap= 0.93515
# Epoch: 0069 training loss= 0.00078 time= 0.41125
# validation roc= 0.93010 validation ap= 0.93504
# Epoch: 0070 training loss= 0.00078 time= 0.38276
# validation roc= 0.93023 validation ap= 0.93523
# Epoch: 0071 training loss= 0.00078 time= 0.89886
# validation roc= 0.92986 validation ap= 0.93515
# Epoch: 0072 training loss= 0.00078 time= 0.55973
# validation roc= 0.92946 validation ap= 0.93481
# Epoch: 0073 training loss= 0.00078 time= 0.32062
# validation roc= 0.92952 validation ap= 0.93509
# Epoch: 0074 training loss= 0.00077 time= 0.33074
# validation roc= 0.92985 validation ap= 0.93553
# Epoch: 0075 training loss= 0.00077 time= 0.48598
# validation roc= 0.93019 validation ap= 0.93622
# Epoch: 0076 training loss= 0.00077 time= 0.57632
# validation roc= 0.93027 validation ap= 0.93681
# Epoch: 0077 training loss= 0.00077 time= 0.47166
# validation roc= 0.93023 validation ap= 0.93726
# Epoch: 0078 training loss= 0.00077 time= 0.56379
# validation roc= 0.93051 validation ap= 0.93761
# Epoch: 0079 training loss= 0.00077 time= 0.55734
# validation roc= 0.93066 validation ap= 0.93813
# Epoch: 0080 training loss= 0.00077 time= 0.42784
# validation roc= 0.93031 validation ap= 0.93801
# Epoch: 0081 training loss= 0.00077 time= 0.40041
# validation roc= 0.92990 validation ap= 0.93772
# Epoch: 0082 training loss= 0.00077 time= 0.47213
# validation roc= 0.92983 validation ap= 0.93784
# Epoch: 0083 training loss= 0.00077 time= 0.90705
# validation roc= 0.92963 validation ap= 0.93775
# Epoch: 0084 training loss= 0.00076 time= 0.45126
# validation roc= 0.92952 validation ap= 0.93770
# Epoch: 0085 training loss= 0.00076 time= 0.32908
# validation roc= 0.92934 validation ap= 0.93765
# Epoch: 0086 training loss= 0.00076 time= 0.38191
# validation roc= 0.92888 validation ap= 0.93749
# Epoch: 0087 training loss= 0.00076 time= 0.33072
# validation roc= 0.92847 validation ap= 0.93692
# Epoch: 0088 training loss= 0.00076 time= 0.60821
# validation roc= 0.92804 validation ap= 0.93643
# Epoch: 0089 training loss= 0.00076 time= 0.47829
# validation roc= 0.92777 validation ap= 0.93623
# Epoch: 0090 training loss= 0.00076 time= 0.49944
# validation roc= 0.92740 validation ap= 0.93576
# Epoch: 0091 training loss= 0.00076 time= 0.54593
# validation roc= 0.92730 validation ap= 0.93578
# Epoch: 0092 training loss= 0.00076 time= 0.65335
# validation roc= 0.92701 validation ap= 0.93556
# Epoch: 0093 training loss= 0.00076 time= 0.44448
# validation roc= 0.92659 validation ap= 0.93515
# Epoch: 0094 training loss= 0.00076 time= 0.44160
# validation roc= 0.92631 validation ap= 0.93486
# Epoch: 0095 training loss= 0.00076 time= 0.50578
# validation roc= 0.92627 validation ap= 0.93467
# Epoch: 0096 training loss= 0.00075 time= 0.84486
# validation roc= 0.92606 validation ap= 0.93441
# Epoch: 0097 training loss= 0.00075 time= 0.51274
# validation roc= 0.92631 validation ap= 0.93445
# Epoch: 0098 training loss= 0.00075 time= 0.37178
# validation roc= 0.92662 validation ap= 0.93460
# Epoch: 0099 training loss= 0.00075 time= 0.36682
# validation roc= 0.92674 validation ap= 0.93476
# Epoch: 0100 training loss= 0.00075 time= 0.47387
# validation roc= 0.92703 validation ap= 0.93485
# Epoch: 0101 training loss= 0.00075 time= 1.58075
# validation roc= 0.92715 validation ap= 0.93488
# Epoch: 0102 training loss= 0.00075 time= 0.52770
# validation roc= 0.92709 validation ap= 0.93486
# Epoch: 0103 training loss= 0.00075 time= 0.58155
# validation roc= 0.92736 validation ap= 0.93521
# Epoch: 0104 training loss= 0.00075 time= 0.67347
# validation roc= 0.92759 validation ap= 0.93573
# Epoch: 0105 training loss= 0.00075 time= 0.48478
# validation roc= 0.92756 validation ap= 0.93582
# Epoch: 0106 training loss= 0.00075 time= 0.40180
# validation roc= 0.92773 validation ap= 0.93610
# Epoch: 0107 training loss= 0.00075 time= 0.56335
# validation roc= 0.92767 validation ap= 0.93613
# Epoch: 0108 training loss= 0.00075 time= 0.71683
# validation roc= 0.92777 validation ap= 0.93648
# Epoch: 0109 training loss= 0.00075 time= 0.65099
# validation roc= 0.92765 validation ap= 0.93674
# Epoch: 0110 training loss= 0.00074 time= 0.42293
# validation roc= 0.92775 validation ap= 0.93681
# Epoch: 0111 training loss= 0.00074 time= 0.40662
# validation roc= 0.92767 validation ap= 0.93684
# Epoch: 0112 training loss= 0.00074 time= 0.63534
# validation roc= 0.92759 validation ap= 0.93693
# Epoch: 0113 training loss= 0.00074 time= 2.57376
# validation roc= 0.92785 validation ap= 0.93756
# Epoch: 0114 training loss= 0.00074 time= 0.50754
# validation roc= 0.92796 validation ap= 0.93802
# Epoch: 0115 training loss= 0.00074 time= 0.80200
# validation roc= 0.92806 validation ap= 0.93831
# Epoch: 0116 training loss= 0.00074 time= 0.76406
# validation roc= 0.92789 validation ap= 0.93823
# Epoch: 0117 training loss= 0.00074 time= 0.55856
# validation roc= 0.92779 validation ap= 0.93830
# Epoch: 0118 training loss= 0.00074 time= 0.55710
# validation roc= 0.92781 validation ap= 0.93852
# Epoch: 0119 training loss= 0.00074 time= 0.47853
# validation roc= 0.92806 validation ap= 0.93878
# Epoch: 0120 training loss= 0.00074 time= 0.92289
# validation roc= 0.92789 validation ap= 0.93867
# Epoch: 0121 training loss= 0.00074 time= 0.73145
# validation roc= 0.92783 validation ap= 0.93870
# Epoch: 0122 training loss= 0.00074 time= 0.42512
# validation roc= 0.92773 validation ap= 0.93873
# Epoch: 0123 training loss= 0.00074 time= 0.43408
# validation roc= 0.92794 validation ap= 0.93891
# Epoch: 0124 training loss= 0.00074 time= 0.55859
# validation roc= 0.92752 validation ap= 0.93855
# Epoch: 0125 training loss= 0.00074 time= 3.93109
# validation roc= 0.92752 validation ap= 0.93844
# Epoch: 0126 training loss= 0.00074 time= 0.51432
# validation roc= 0.92738 validation ap= 0.93844
# Epoch: 0127 training loss= 0.00074 time= 0.79971
# validation roc= 0.92728 validation ap= 0.93863
# Epoch: 0128 training loss= 0.00074 time= 0.65318
# validation roc= 0.92756 validation ap= 0.93846
# Epoch: 0129 training loss= 0.00073 time= 0.60709
# validation roc= 0.92802 validation ap= 0.93927
# Epoch: 0130 training loss= 0.00073 time= 0.51416
# validation roc= 0.92711 validation ap= 0.93799
# Epoch: 0131 training loss= 0.00073 time= 0.51638
# validation roc= 0.92790 validation ap= 0.93912
# Epoch: 0132 training loss= 0.00073 time= 0.77284
# validation roc= 0.92765 validation ap= 0.93852
# Epoch: 0133 training loss= 0.00073 time= 0.72742
# validation roc= 0.92761 validation ap= 0.93891
# Epoch: 0134 training loss= 0.00073 time= 0.55272
# validation roc= 0.92781 validation ap= 0.93883
# Epoch: 0135 training loss= 0.00073 time= 0.41441
# validation roc= 0.92785 validation ap= 0.93842
# Epoch: 0136 training loss= 0.00073 time= 0.65569
# validation roc= 0.92732 validation ap= 0.93865
# Epoch: 0137 training loss= 0.00073 time= 1.32016
# validation roc= 0.92752 validation ap= 0.93836
# Epoch: 0138 training loss= 0.00073 time= 0.66873
# validation roc= 0.92767 validation ap= 0.93834
# Epoch: 0139 training loss= 0.00073 time= 0.76695
# validation roc= 0.92707 validation ap= 0.93846
# Epoch: 0140 training loss= 0.00073 time= 0.72882
# validation roc= 0.92713 validation ap= 0.93802
# Epoch: 0141 training loss= 0.00073 time= 0.59131
# validation roc= 0.92715 validation ap= 0.93775
# Epoch: 0142 training loss= 0.00073 time= 0.52437
# validation roc= 0.92672 validation ap= 0.93789
# Epoch: 0143 training loss= 0.00073 time= 0.52008
# validation roc= 0.92674 validation ap= 0.93751
# Epoch: 0144 training loss= 0.00073 time= 0.94529
# validation roc= 0.92678 validation ap= 0.93741
# Epoch: 0145 training loss= 0.00072 time= 0.66091
# validation roc= 0.92662 validation ap= 0.93753
# Epoch: 0146 training loss= 0.00072 time= 0.48640
# validation roc= 0.92604 validation ap= 0.93662
# Epoch: 0147 training loss= 0.00072 time= 0.39506
# validation roc= 0.92699 validation ap= 0.93763
# Epoch: 0148 training loss= 0.00072 time= 0.39962
# validation roc= 0.92637 validation ap= 0.93707
# Epoch: 0149 training loss= 0.00072 time= 2.31919
# validation roc= 0.92680 validation ap= 0.93757
# Epoch: 0150 training loss= 0.00072 time= 0.47650
# validation roc= 0.92610 validation ap= 0.93685
# Epoch: 0151 training loss= 0.00072 time= 0.83982
# validation roc= 0.92709 validation ap= 0.93798
# Epoch: 0152 training loss= 0.00072 time= 0.74119
# validation roc= 0.92561 validation ap= 0.93641
# Epoch: 0153 training loss= 0.00072 time= 0.64983
# validation roc= 0.92792 validation ap= 0.93858
# Epoch: 0154 training loss= 0.00072 time= 0.54183
# validation roc= 0.92494 validation ap= 0.93601
# Epoch: 0155 training loss= 0.00072 time= 0.49281
# validation roc= 0.92765 validation ap= 0.93845
# Epoch: 0156 training loss= 0.00072 time= 0.78725
# validation roc= 0.92639 validation ap= 0.93726
# Epoch: 0157 training loss= 0.00072 time= 0.74864
# validation roc= 0.92635 validation ap= 0.93757
# Epoch: 0158 training loss= 0.00072 time= 0.49055
# validation roc= 0.92723 validation ap= 0.93810
# Epoch: 0159 training loss= 0.00072 time= 0.41435
# validation roc= 0.92567 validation ap= 0.93668
# Epoch: 0160 training loss= 0.00072 time= 0.43282
# validation roc= 0.92730 validation ap= 0.93851
# Epoch: 0161 training loss= 0.00072 time= 1.11538
# validation roc= 0.92668 validation ap= 0.93768
# Epoch: 0162 training loss= 0.00072 time= 0.60796
# validation roc= 0.92610 validation ap= 0.93734
# Epoch: 0163 training loss= 0.00072 time= 0.63189
# validation roc= 0.92744 validation ap= 0.93835
# Epoch: 0164 training loss= 0.00072 time= 0.60438
# validation roc= 0.92647 validation ap= 0.93754
# Epoch: 0165 training loss= 0.00072 time= 0.66731
# validation roc= 0.92666 validation ap= 0.93784
# Epoch: 0166 training loss= 0.00072 time= 0.56667
# validation roc= 0.92713 validation ap= 0.93824
# Epoch: 0167 training loss= 0.00071 time= 0.51268
# validation roc= 0.92585 validation ap= 0.93717
# Epoch: 0168 training loss= 0.00071 time= 0.43106
# validation roc= 0.92701 validation ap= 0.93802
# Epoch: 0169 training loss= 0.00071 time= 1.13003
# validation roc= 0.92666 validation ap= 0.93814
# Epoch: 0170 training loss= 0.00071 time= 0.61744
# validation roc= 0.92602 validation ap= 0.93722
# Epoch: 0171 training loss= 0.00071 time= 0.44828
# validation roc= 0.92726 validation ap= 0.93888
# Epoch: 0172 training loss= 0.00071 time= 0.43374
# validation roc= 0.92629 validation ap= 0.93793
# Epoch: 0173 training loss= 0.00071 time= 0.58938
# validation roc= 0.92691 validation ap= 0.93856
# Epoch: 0174 training loss= 0.00071 time= 1.57328
# validation roc= 0.92699 validation ap= 0.93877
# Epoch: 0175 training loss= 0.00071 time= 0.54033
# validation roc= 0.92666 validation ap= 0.93858
# Epoch: 0176 training loss= 0.00071 time= 0.86548
# validation roc= 0.92717 validation ap= 0.93905
# Epoch: 0177 training loss= 0.00071 time= 0.72252
# validation roc= 0.92649 validation ap= 0.93882
# Epoch: 0178 training loss= 0.00071 time= 0.63124
# validation roc= 0.92664 validation ap= 0.93840
# Epoch: 0179 training loss= 0.00071 time= 0.47227
# validation roc= 0.92703 validation ap= 0.93954
# Epoch: 0180 training loss= 0.00071 time= 0.40383
# validation roc= 0.92660 validation ap= 0.93857
# Epoch: 0181 training loss= 0.00071 time= 0.68606
# validation roc= 0.92695 validation ap= 0.93973
# Epoch: 0182 training loss= 0.00071 time= 0.64740
# validation roc= 0.92659 validation ap= 0.93837
# Epoch: 0183 training loss= 0.00071 time= 0.41965
# validation roc= 0.92664 validation ap= 0.93989
# Epoch: 0184 training loss= 0.00071 time= 0.35989
# validation roc= 0.92651 validation ap= 0.93816
# Epoch: 0185 training loss= 0.00071 time= 0.35626
# validation roc= 0.92703 validation ap= 0.94005
# Epoch: 0186 training loss= 0.00071 time= 0.82642
# validation roc= 0.92699 validation ap= 0.93916
# Epoch: 0187 training loss= 0.00071 time= 0.48432
# validation roc= 0.92672 validation ap= 0.93902
# Epoch: 0188 training loss= 0.00071 time= 0.60210
# validation roc= 0.92754 validation ap= 0.94033
# Epoch: 0189 training loss= 0.00071 time= 0.50972
# validation roc= 0.92674 validation ap= 0.93878
# Epoch: 0190 training loss= 0.00071 time= 0.53147
# validation roc= 0.92726 validation ap= 0.93980
# Epoch: 0191 training loss= 0.00071 time= 0.46850
# validation roc= 0.92750 validation ap= 0.93976
# Epoch: 0192 training loss= 0.00071 time= 0.44849
# validation roc= 0.92668 validation ap= 0.93875
# Epoch: 0193 training loss= 0.00071 time= 0.56937
# validation roc= 0.92763 validation ap= 0.94013
# Epoch: 0194 training loss= 0.00071 time= 0.73746
# validation roc= 0.92721 validation ap= 0.93947
# Epoch: 0195 training loss= 0.00071 time= 0.58647
# validation roc= 0.92703 validation ap= 0.93902
# Epoch: 0196 training loss= 0.00071 time= 0.34232
# validation roc= 0.92697 validation ap= 0.93964
# Epoch: 0197 training loss= 0.00071 time= 0.34542
# validation roc= 0.92664 validation ap= 0.93881
# Epoch: 0198 training loss= 0.00070 time= 1.28203
# validation roc= 0.92674 validation ap= 0.93879
# Epoch: 0199 training loss= 0.00070 time= 0.41811
# validation roc= 0.92664 validation ap= 0.93930
# Epoch: 0200 training loss= 0.00070 time= 0.56687
# validation roc= 0.92666 validation ap= 0.93846
# testing roc= 0.94745 testing ap= 0.95183

# %% [markdown]
# # Visulization

# %%
emb=emb
labels=load_label(dataset,data_path)

X_embedded = TSNE(n_components=2, init='pca', random_state=seed).fit_transform(emb)

cs=['orange','blue','darkcyan','fuchsia','chocolate','dodgerblue','aqua','green','red','purple']
markers=['o','+','v','2','s','X','d','>','*','<']

fig, ax = plt.subplots(1,figsize=(8,6))
for i in np.arange(X_embedded.shape[0]):#X_embedded.shape[0]
    scatter = ax.scatter(X_embedded[i,0],X_embedded[i,1],label=labels[i],marker=markers[labels[i]],color=cs[labels[i]], s=10, alpha = 1)
plt.xticks([])
plt.yticks([])
plt.xlabel("")
plt.ylabel("")
plt.axis('off')
plt.show()
