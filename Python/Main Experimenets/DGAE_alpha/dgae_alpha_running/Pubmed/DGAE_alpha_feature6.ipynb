# %% [markdown]
# # Import libraries

# %%
import numpy as np
import random as rn
import os
from keras import backend as K
import  tensorflow.compat.v1  as tf
tf.disable_v2_behavior() 
import tensorflow as tf

#--------------------------------------------------------------------------------------------------------------------
# Reproducible
seed=0
os.environ['PYTHONHASHSEED'] = str(seed)

np.random.seed(seed)
rn.seed(seed)
session_conf =tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
tf.compat.v1.set_random_seed(seed)
#--------------------------------------------------------------------------------------------------------------------

import scipy.sparse as sp
import time
import pandas as pd
import sys

from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

sys.path.append(r"../../")

from dgae_alpha.evaluation import get_roc_score
from dgae_alpha.input_data import load_data, load_label
from dgae_alpha.model import *
from dgae_alpha.optimizer import *
from dgae_alpha.preprocessing import *
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.8/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %% [markdown]
# # Parameters setting

# %%
layers_no=6
data_path="../../Datasets/"
path_now="./log/"

dataset='pubmed'
model_name='DGAE_alpha_feature'

dropout=0.0
epochs=200
features_used=True
learning_rate=0.01
nb_run=1
prop_val=5
prop_test=10
validation=True
verbose=True

# %% [markdown]
# # Load data

# %%
adj_init, features_init = load_data(dataset,data_path)
num_adj=adj_init.shape[1]

# %% [markdown]
# # Training and testing

# %%
loss_coeff_adj=0.001
loss_coeff_AE=0.5
results_output_path = path_now+model_name+"/"
mkdir(results_output_path)

for seed_i in np.arange(nb_run):
    
    seed=seed_i
    lost_list=[]
    roc_list=[]
    ap_list=[]
    mean_time=[]
    
    adj, val_edges, val_edges_false, test_edges, test_edges_false =mask_test_edges(adj_init, seed,prop_test, prop_val)
                
    t_start = time.time()

    if features_used:
        features = features_init
    
    num_nodes = adj.shape[0]

    if not features_used:
        features = sp.identity(adj.shape[0])

    features = sparse_to_tuple(features)
    num_features = features[2][1]
    features_nonzero = features[1].shape[0]
        
    placeholders = {
        'features': tf.sparse_placeholder(tf.float32),
        'adj': tf.sparse_placeholder(tf.float32),
        'adj_orig': tf.sparse_placeholder(tf.float32),
        'dropout': tf.placeholder_with_default(0., shape = ())
    }

#--------------------------------------------------------------------------------------------------------------------
# Create model
    if model_name=='DGAE_alpha_feature':
        model = DGAE_alpha_feature(placeholders, layers_no,num_features, features_nonzero)
    elif model_name=='DGAE_alpha_no_feature':
        model=DGAE_alpha_no_feature(placeholders, layers_no,num_features, num_adj,features_nonzero)
    else:
        raise ValueError('Undefined model!')

    pos_weight = float(adj.shape[0] * adj.shape[0] - adj.sum()) / adj.sum()
    norm = adj.shape[0] * adj.shape[0] / float((adj.shape[0] * adj.shape[0]- adj.sum()) * 2)
    
    with tf.name_scope('optimizer'):
        if model_name in ('DGAE_alpha_feature'):
            opt =OptimizerAE_FeatureReconstrution(preds_adj = model.reconstructions,\
                                                  preds_Features=model.feature_reconstruction,\
                                                  labels_adj = tf.reshape(tf.sparse_tensor_to_dense(placeholders['adj_orig'],\
                                                                                                    validate_indices = False), [-1]),\
                                                  labels_Features=placeholders['features'],\
                                                  labels_adj_rec=placeholders['adj'],\
                                                  loss_coeff_adj=loss_coeff_adj,\
                                                  loss_coeff_AE=loss_coeff_AE,\
                                                  pos_weight = pos_weight,\
                                                  norm = norm)
                
        elif model_name in ('DGAE_alpha_no_feature'):
            opt =OptimizerAE_AdjReconstrution(preds_adj = model.reconstructions,\
                                              preds_adj_rec=model.adj_reconstruction,\
                                              labels_adj = tf.reshape(tf.sparse_tensor_to_dense(placeholders['adj_orig'],
                                                                                                validate_indices = False), [-1]),\
                                              labels_Features=placeholders['features'],\
                                              labels_adj_rec=placeholders['adj'],\
                                              loss_coeff_adj=loss_coeff_adj,\
                                              loss_coeff_AE=loss_coeff_AE,\
                                              pos_weight = pos_weight,\
                                              norm = norm)

    adj_norm = preprocess_graph(adj)
    adj_label = sparse_to_tuple(adj + sp.eye(adj.shape[0]))

    sess = tf.Session()
    sess.run(tf.global_variables_initializer())
    
    for epoch in range(epochs):
        t = time.time()
        feed_dict = construct_feed_dict(adj_norm, adj_label, features,placeholders)
        feed_dict.update({placeholders['dropout']: dropout})
        outs = sess.run([opt.opt_op, opt.cost, opt.accuracy],feed_dict = feed_dict)
        avg_cost = outs[1]
        if verbose:
            lost_list.append(avg_cost)
            print("Epoch:", '%04d' % (epoch + 1), "training loss=", "{:.5f}".format(avg_cost),"time=", "{:.5f}".format(time.time() - t))
                    
            if validation:
                feed_dict.update({placeholders['dropout']: 0})
                emb = sess.run(model.z_mean, feed_dict = feed_dict)
                feed_dict.update({placeholders['dropout']: dropout})
                val_roc, val_ap = get_roc_score(val_edges, val_edges_false, emb)
                roc_list.append(val_roc)
                ap_list.append(val_ap)
                print("validation roc=", "{:.5f}".format(val_roc), "validation ap=", "{:.5f}".format(val_ap))

    emb = sess.run(model.z_mean, feed_dict = feed_dict)   
    mean_time.append(time.time() - t_start)
    
    roc_score, ap_score = get_roc_score(test_edges, test_edges_false, emb)
    print("testing roc=", "{:.5f}".format(roc_score), "testing ap=", "{:.5f}".format(ap_score))
    
    roc_list.append(roc_score)
    ap_list.append(ap_score)
    
    mean_time_=np.array(mean_time)
    write_to_csv(mean_time_.reshape(1,len(mean_time_)),results_output_path+"layers_"+str(layers_no)+"_time.csv")

    roc_list_=np.array(roc_list)
    write_to_csv(roc_list_.reshape(1,len(roc_list_)),results_output_path+"layers_"+str(layers_no)+"_roc.csv")

    ap_list_=np.array(ap_list)
    write_to_csv(ap_list_.reshape(1,len(ap_list_)),results_output_path+"layers_"+str(layers_no)+"_ap.csv")
# Out:
# Successful!
# WARNING:tensorflow:From /usr/local/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:201: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:201: calling weighted_cross_entropy_with_logits (from tensorflow.python.ops.nn_impl) with targets is deprecated and will be removed in a future version.
# Instructions for updating:
# targets is deprecated, use labels instead
# Epoch: 0001 training loss= 0.00085 time= 7.42408
# validation roc= 0.83663 validation ap= 0.82586
# Epoch: 0002 training loss= 0.00085 time= 5.37096
# validation roc= 0.83818 validation ap= 0.83221
# Epoch: 0003 training loss= 0.00085 time= 5.44864
# validation roc= 0.83832 validation ap= 0.83700
# Epoch: 0004 training loss= 0.00085 time= 5.29183
# validation roc= 0.83641 validation ap= 0.83869
# Epoch: 0005 training loss= 0.00085 time= 5.43913
# validation roc= 0.83304 validation ap= 0.83762
# Epoch: 0006 training loss= 0.00085 time= 5.36824
# validation roc= 0.82863 validation ap= 0.83463
# Epoch: 0007 training loss= 0.00085 time= 5.39200
# validation roc= 0.82370 validation ap= 0.83063
# Epoch: 0008 training loss= 0.00084 time= 5.38309
# validation roc= 0.81807 validation ap= 0.82594
# Epoch: 0009 training loss= 0.00084 time= 5.40971
# validation roc= 0.81264 validation ap= 0.82156
# Epoch: 0010 training loss= 0.00084 time= 5.41387
# validation roc= 0.80847 validation ap= 0.81828
# Epoch: 0011 training loss= 0.00083 time= 5.48813
# validation roc= 0.80638 validation ap= 0.81688
# Epoch: 0012 training loss= 0.00082 time= 6.57198
# validation roc= 0.80674 validation ap= 0.81755
# Epoch: 0013 training loss= 0.00081 time= 6.43284
# validation roc= 0.80948 validation ap= 0.82011
# Epoch: 0014 training loss= 0.00079 time= 6.56493
# validation roc= 0.81387 validation ap= 0.82376
# Epoch: 0015 training loss= 0.00078 time= 6.49347
# validation roc= 0.81891 validation ap= 0.82796
# Epoch: 0016 training loss= 0.00077 time= 6.57988
# validation roc= 0.82231 validation ap= 0.83083
# Epoch: 0017 training loss= 0.00077 time= 6.38465
# validation roc= 0.82061 validation ap= 0.82984
# Epoch: 0018 training loss= 0.00078 time= 6.54250
# validation roc= 0.81475 validation ap= 0.82564
# Epoch: 0019 training loss= 0.00078 time= 7.20817
# validation roc= 0.80691 validation ap= 0.81993
# Epoch: 0020 training loss= 0.00077 time= 8.00131
# validation roc= 0.79987 validation ap= 0.81460
# Epoch: 0021 training loss= 0.00076 time= 9.98529
# validation roc= 0.79721 validation ap= 0.81237
# Epoch: 0022 training loss= 0.00076 time= 11.51424
# validation roc= 0.80198 validation ap= 0.81541
# Epoch: 0023 training loss= 0.00076 time= 8.82663
# validation roc= 0.81449 validation ap= 0.82424
# Epoch: 0024 training loss= 0.00076 time= 9.84496
# validation roc= 0.83231 validation ap= 0.83755
# Epoch: 0025 training loss= 0.00075 time= 8.95552
# validation roc= 0.85130 validation ap= 0.85261
# Epoch: 0026 training loss= 0.00075 time= 9.22054
# validation roc= 0.86856 validation ap= 0.86728
# Epoch: 0027 training loss= 0.00074 time= 7.29095
# validation roc= 0.88327 validation ap= 0.88048
# Epoch: 0028 training loss= 0.00074 time= 7.45826
# validation roc= 0.89576 validation ap= 0.89207
# Epoch: 0029 training loss= 0.00073 time= 9.81118
# validation roc= 0.90601 validation ap= 0.90196
# Epoch: 0030 training loss= 0.00072 time= 11.97522
# validation roc= 0.91362 validation ap= 0.90974
# Epoch: 0031 training loss= 0.00071 time= 13.32169
# validation roc= 0.91853 validation ap= 0.91527
# Epoch: 0032 training loss= 0.00071 time= 12.10761
# validation roc= 0.92002 validation ap= 0.91767
# Epoch: 0033 training loss= 0.00070 time= 12.55123
# validation roc= 0.91775 validation ap= 0.91654
# Epoch: 0034 training loss= 0.00069 time= 16.29714
# validation roc= 0.91187 validation ap= 0.91187
# Epoch: 0035 training loss= 0.00068 time= 15.14328
# validation roc= 0.90309 validation ap= 0.90458
# Epoch: 0036 training loss= 0.00066 time= 16.29618
# validation roc= 0.89351 validation ap= 0.89641
# Epoch: 0037 training loss= 0.00065 time= 17.80455
# validation roc= 0.88494 validation ap= 0.88888
# Epoch: 0038 training loss= 0.00065 time= 17.06337
# validation roc= 0.87839 validation ap= 0.88300
# Epoch: 0039 training loss= 0.00064 time= 15.90767
# validation roc= 0.87418 validation ap= 0.87942
# Epoch: 0040 training loss= 0.00064 time= 15.53763
# validation roc= 0.87252 validation ap= 0.87827
# Epoch: 0041 training loss= 0.00064 time= 16.72956
# validation roc= 0.87293 validation ap= 0.87926
# Epoch: 0042 training loss= 0.00064 time= 15.46515
# validation roc= 0.87532 validation ap= 0.88220
# Epoch: 0043 training loss= 0.00063 time= 15.68725
# validation roc= 0.87963 validation ap= 0.88690
# Epoch: 0044 training loss= 0.00062 time= 16.53070
# validation roc= 0.88582 validation ap= 0.89321
# Epoch: 0045 training loss= 0.00062 time= 15.65150
# validation roc= 0.89357 validation ap= 0.90095
# Epoch: 0046 training loss= 0.00061 time= 18.03047
# validation roc= 0.90207 validation ap= 0.90929
# Epoch: 0047 training loss= 0.00060 time= 17.12114
# validation roc= 0.90993 validation ap= 0.91697
# Epoch: 0048 training loss= 0.00060 time= 16.44609
# validation roc= 0.91553 validation ap= 0.92224
# Epoch: 0049 training loss= 0.00059 time= 17.33242
# validation roc= 0.91795 validation ap= 0.92411
# Epoch: 0050 training loss= 0.00058 time= 15.31456
# validation roc= 0.91701 validation ap= 0.92289
# Epoch: 0051 training loss= 0.00058 time= 12.69901
# validation roc= 0.91342 validation ap= 0.91940
# Epoch: 0052 training loss= 0.00058 time= 10.35441
# validation roc= 0.90888 validation ap= 0.91542
# Epoch: 0053 training loss= 0.00058 time= 10.63748
# validation roc= 0.90673 validation ap= 0.91360
# Epoch: 0054 training loss= 0.00058 time= 10.23767
# validation roc= 0.90787 validation ap= 0.91503
# Epoch: 0055 training loss= 0.00058 time= 9.45878
# validation roc= 0.91113 validation ap= 0.91852
# Epoch: 0056 training loss= 0.00057 time= 10.23409
# validation roc= 0.91493 validation ap= 0.92244
# Epoch: 0057 training loss= 0.00057 time= 9.22927
# validation roc= 0.91811 validation ap= 0.92564
# Epoch: 0058 training loss= 0.00057 time= 9.49313
# validation roc= 0.92019 validation ap= 0.92771
# Epoch: 0059 training loss= 0.00057 time= 8.94993
# validation roc= 0.92118 validation ap= 0.92877
# Epoch: 0060 training loss= 0.00057 time= 5.90042
# validation roc= 0.92147 validation ap= 0.92911
# Epoch: 0061 training loss= 0.00057 time= 5.88864
# validation roc= 0.92129 validation ap= 0.92897
# Epoch: 0062 training loss= 0.00057 time= 5.94229
# validation roc= 0.92111 validation ap= 0.92883
# Epoch: 0063 training loss= 0.00057 time= 5.95874
# validation roc= 0.92106 validation ap= 0.92883
# Epoch: 0064 training loss= 0.00057 time= 5.78877
# validation roc= 0.92125 validation ap= 0.92911
# Epoch: 0065 training loss= 0.00056 time= 5.87790
# validation roc= 0.92146 validation ap= 0.92948
# Epoch: 0066 training loss= 0.00056 time= 5.72981
# validation roc= 0.92168 validation ap= 0.92988
# Epoch: 0067 training loss= 0.00056 time= 6.01220
# validation roc= 0.92181 validation ap= 0.93015
# Epoch: 0068 training loss= 0.00056 time= 5.85599
# validation roc= 0.92184 validation ap= 0.93018
# Epoch: 0069 training loss= 0.00056 time= 5.90839
# validation roc= 0.92187 validation ap= 0.92996
# Epoch: 0070 training loss= 0.00056 time= 5.75564
# validation roc= 0.92206 validation ap= 0.92984
# Epoch: 0071 training loss= 0.00056 time= 5.96547
# validation roc= 0.92249 validation ap= 0.92995
# Epoch: 0072 training loss= 0.00056 time= 6.09046
# validation roc= 0.92328 validation ap= 0.93048
# Epoch: 0073 training loss= 0.00056 time= 5.97732
# validation roc= 0.92439 validation ap= 0.93149
# Epoch: 0074 training loss= 0.00056 time= 5.87585
# validation roc= 0.92569 validation ap= 0.93280
# Epoch: 0075 training loss= 0.00055 time= 5.86244
# validation roc= 0.92703 validation ap= 0.93421
# Epoch: 0076 training loss= 0.00055 time= 5.75072
# validation roc= 0.92835 validation ap= 0.93561
# Epoch: 0077 training loss= 0.00055 time= 5.91246
# validation roc= 0.92949 validation ap= 0.93675
# Epoch: 0078 training loss= 0.00055 time= 5.87949
# validation roc= 0.93066 validation ap= 0.93783
# Epoch: 0079 training loss= 0.00055 time= 5.76126
# validation roc= 0.93185 validation ap= 0.93884
# Epoch: 0080 training loss= 0.00055 time= 5.82609
# validation roc= 0.93323 validation ap= 0.93997
# Epoch: 0081 training loss= 0.00055 time= 5.83970
# validation roc= 0.93485 validation ap= 0.94128
# Epoch: 0082 training loss= 0.00054 time= 5.72929
# validation roc= 0.93672 validation ap= 0.94284
# Epoch: 0083 training loss= 0.00054 time= 5.87179
# validation roc= 0.93872 validation ap= 0.94455
# Epoch: 0084 training loss= 0.00054 time= 5.87711
# validation roc= 0.94078 validation ap= 0.94635
# Epoch: 0085 training loss= 0.00054 time= 5.82668
# validation roc= 0.94270 validation ap= 0.94808
# Epoch: 0086 training loss= 0.00053 time= 5.95972
# validation roc= 0.94425 validation ap= 0.94945
# Epoch: 0087 training loss= 0.00053 time= 5.82580
# validation roc= 0.94526 validation ap= 0.95027
# Epoch: 0088 training loss= 0.00053 time= 5.73756
# validation roc= 0.94565 validation ap= 0.95037
# Epoch: 0089 training loss= 0.00053 time= 5.94203
# validation roc= 0.94539 validation ap= 0.94970
# Epoch: 0090 training loss= 0.00053 time= 5.85377
# validation roc= 0.94476 validation ap= 0.94875
# Epoch: 0091 training loss= 0.00053 time= 5.93890
# validation roc= 0.94402 validation ap= 0.94785
# Epoch: 0092 training loss= 0.00053 time= 5.99260
# validation roc= 0.94357 validation ap= 0.94730
# Epoch: 0093 training loss= 0.00053 time= 5.87387
# validation roc= 0.94368 validation ap= 0.94731
# Epoch: 0094 training loss= 0.00053 time= 5.88162
# validation roc= 0.94438 validation ap= 0.94797
# Epoch: 0095 training loss= 0.00053 time= 5.97959
# validation roc= 0.94558 validation ap= 0.94921
# Epoch: 0096 training loss= 0.00052 time= 5.91819
# validation roc= 0.94713 validation ap= 0.95083
# Epoch: 0097 training loss= 0.00052 time= 5.79609
# validation roc= 0.94873 validation ap= 0.95250
# Epoch: 0098 training loss= 0.00052 time= 5.78402
# validation roc= 0.95019 validation ap= 0.95397
# Epoch: 0099 training loss= 0.00052 time= 5.80535
# validation roc= 0.95137 validation ap= 0.95511
# Epoch: 0100 training loss= 0.00052 time= 5.96784
# validation roc= 0.95231 validation ap= 0.95596
# Epoch: 0101 training loss= 0.00052 time= 5.86336
# validation roc= 0.95303 validation ap= 0.95655
# Epoch: 0102 training loss= 0.00052 time= 5.90014
# validation roc= 0.95356 validation ap= 0.95694
# Epoch: 0103 training loss= 0.00052 time= 5.84378
# validation roc= 0.95400 validation ap= 0.95723
# Epoch: 0104 training loss= 0.00052 time= 5.74621
# validation roc= 0.95445 validation ap= 0.95755
# Epoch: 0105 training loss= 0.00051 time= 5.74302
# validation roc= 0.95491 validation ap= 0.95787
# Epoch: 0106 training loss= 0.00051 time= 5.90194
# validation roc= 0.95538 validation ap= 0.95820
# Epoch: 0107 training loss= 0.00051 time= 5.77075
# validation roc= 0.95579 validation ap= 0.95845
# Epoch: 0108 training loss= 0.00051 time= 5.69214
# validation roc= 0.95613 validation ap= 0.95869
# Epoch: 0109 training loss= 0.00051 time= 5.94901
# validation roc= 0.95633 validation ap= 0.95887
# Epoch: 0110 training loss= 0.00051 time= 5.86387
# validation roc= 0.95637 validation ap= 0.95895
# Epoch: 0111 training loss= 0.00051 time= 5.90891
# validation roc= 0.95624 validation ap= 0.95890
# Epoch: 0112 training loss= 0.00051 time= 5.79826
# validation roc= 0.95601 validation ap= 0.95873
# Epoch: 0113 training loss= 0.00051 time= 5.71041
# validation roc= 0.95576 validation ap= 0.95853
# Epoch: 0114 training loss= 0.00051 time= 5.83925
# validation roc= 0.95546 validation ap= 0.95826
# Epoch: 0115 training loss= 0.00051 time= 5.83670
# validation roc= 0.95525 validation ap= 0.95808
# Epoch: 0116 training loss= 0.00051 time= 5.86518
# validation roc= 0.95522 validation ap= 0.95803
# Epoch: 0117 training loss= 0.00051 time= 5.91193
# validation roc= 0.95538 validation ap= 0.95815
# Epoch: 0118 training loss= 0.00051 time= 5.79637
# validation roc= 0.95574 validation ap= 0.95848
# Epoch: 0119 training loss= 0.00051 time= 5.85358
# validation roc= 0.95630 validation ap= 0.95900
# Epoch: 0120 training loss= 0.00050 time= 5.81048
# validation roc= 0.95695 validation ap= 0.95960
# Epoch: 0121 training loss= 0.00050 time= 5.75337
# validation roc= 0.95760 validation ap= 0.96018
# Epoch: 0122 training loss= 0.00050 time= 5.77708
# validation roc= 0.95821 validation ap= 0.96071
# Epoch: 0123 training loss= 0.00050 time= 5.93785
# validation roc= 0.95869 validation ap= 0.96112
# Epoch: 0124 training loss= 0.00050 time= 6.04382
# validation roc= 0.95910 validation ap= 0.96148
# Epoch: 0125 training loss= 0.00050 time= 5.82192
# validation roc= 0.95939 validation ap= 0.96172
# Epoch: 0126 training loss= 0.00050 time= 5.79370
# validation roc= 0.95962 validation ap= 0.96190
# Epoch: 0127 training loss= 0.00050 time= 5.75490
# validation roc= 0.95981 validation ap= 0.96203
# Epoch: 0128 training loss= 0.00050 time= 5.95926
# validation roc= 0.95996 validation ap= 0.96214
# Epoch: 0129 training loss= 0.00050 time= 5.98174
# validation roc= 0.96010 validation ap= 0.96225
# Epoch: 0130 training loss= 0.00050 time= 5.82775
# validation roc= 0.96020 validation ap= 0.96237
# Epoch: 0131 training loss= 0.00050 time= 5.89718
# validation roc= 0.96029 validation ap= 0.96247
# Epoch: 0132 training loss= 0.00050 time= 5.98658
# validation roc= 0.96035 validation ap= 0.96253
# Epoch: 0133 training loss= 0.00050 time= 5.76877
# validation roc= 0.96038 validation ap= 0.96260
# Epoch: 0134 training loss= 0.00050 time= 5.85790
# validation roc= 0.96041 validation ap= 0.96264
# Epoch: 0135 training loss= 0.00050 time= 5.97616
# validation roc= 0.96040 validation ap= 0.96267
# Epoch: 0136 training loss= 0.00050 time= 5.76248
# validation roc= 0.96040 validation ap= 0.96270
# Epoch: 0137 training loss= 0.00050 time= 5.96073
# validation roc= 0.96041 validation ap= 0.96274
# Epoch: 0138 training loss= 0.00050 time= 5.78380
# validation roc= 0.96042 validation ap= 0.96277
# Epoch: 0139 training loss= 0.00050 time= 5.66044
# validation roc= 0.96047 validation ap= 0.96283
# Epoch: 0140 training loss= 0.00050 time= 5.78241
# validation roc= 0.96053 validation ap= 0.96290
# Epoch: 0141 training loss= 0.00050 time= 5.95381
# validation roc= 0.96065 validation ap= 0.96302
# Epoch: 0142 training loss= 0.00050 time= 5.75706
# validation roc= 0.96082 validation ap= 0.96316
# Epoch: 0143 training loss= 0.00050 time= 5.86080
# validation roc= 0.96104 validation ap= 0.96335
# Epoch: 0144 training loss= 0.00049 time= 5.90469
# validation roc= 0.96130 validation ap= 0.96357
# Epoch: 0145 training loss= 0.00049 time= 5.51884
# validation roc= 0.96158 validation ap= 0.96382
# Epoch: 0146 training loss= 0.00049 time= 5.77336
# validation roc= 0.96185 validation ap= 0.96405
# Epoch: 0147 training loss= 0.00049 time= 5.98197
# validation roc= 0.96209 validation ap= 0.96428
# Epoch: 0148 training loss= 0.00049 time= 5.96952
# validation roc= 0.96233 validation ap= 0.96449
# Epoch: 0149 training loss= 0.00049 time= 5.92453
# validation roc= 0.96253 validation ap= 0.96467
# Epoch: 0150 training loss= 0.00049 time= 5.98661
# validation roc= 0.96266 validation ap= 0.96479
# Epoch: 0151 training loss= 0.00049 time= 5.73517
# validation roc= 0.96271 validation ap= 0.96481
# Epoch: 0152 training loss= 0.00049 time= 5.85803
# validation roc= 0.96270 validation ap= 0.96479
# Epoch: 0153 training loss= 0.00049 time= 5.82184
# validation roc= 0.96263 validation ap= 0.96471
# Epoch: 0154 training loss= 0.00049 time= 5.65189
# validation roc= 0.96248 validation ap= 0.96457
# Epoch: 0155 training loss= 0.00049 time= 5.93325
# validation roc= 0.96238 validation ap= 0.96445
# Epoch: 0156 training loss= 0.00049 time= 5.88151
# validation roc= 0.96228 validation ap= 0.96434
# Epoch: 0157 training loss= 0.00049 time= 5.79979
# validation roc= 0.96225 validation ap= 0.96429
# Epoch: 0158 training loss= 0.00049 time= 5.78862
# validation roc= 0.96231 validation ap= 0.96434
# Epoch: 0159 training loss= 0.00049 time= 5.82874
# validation roc= 0.96246 validation ap= 0.96448
# Epoch: 0160 training loss= 0.00049 time= 5.88536
# validation roc= 0.96269 validation ap= 0.96473
# Epoch: 0161 training loss= 0.00049 time= 6.10013
# validation roc= 0.96299 validation ap= 0.96503
# Epoch: 0162 training loss= 0.00049 time= 5.93983
# validation roc= 0.96326 validation ap= 0.96529
# Epoch: 0163 training loss= 0.00049 time= 6.52738
# validation roc= 0.96347 validation ap= 0.96548
# Epoch: 0164 training loss= 0.00049 time= 5.87993
# validation roc= 0.96366 validation ap= 0.96565
# Epoch: 0165 training loss= 0.00049 time= 5.89944
# validation roc= 0.96379 validation ap= 0.96576
# Epoch: 0166 training loss= 0.00049 time= 5.89833
# validation roc= 0.96391 validation ap= 0.96587
# Epoch: 0167 training loss= 0.00048 time= 5.88653
# validation roc= 0.96400 validation ap= 0.96595
# Epoch: 0168 training loss= 0.00048 time= 5.80571
# validation roc= 0.96411 validation ap= 0.96606
# Epoch: 0169 training loss= 0.00048 time= 5.91681
# validation roc= 0.96424 validation ap= 0.96620
# Epoch: 0170 training loss= 0.00048 time= 5.90146
# validation roc= 0.96442 validation ap= 0.96640
# Epoch: 0171 training loss= 0.00048 time= 5.96279
# validation roc= 0.96462 validation ap= 0.96658
# Epoch: 0172 training loss= 0.00048 time= 5.92521
# validation roc= 0.96483 validation ap= 0.96679
# Epoch: 0173 training loss= 0.00048 time= 6.00862
# validation roc= 0.96499 validation ap= 0.96696
# Epoch: 0174 training loss= 0.00048 time= 5.78531
# validation roc= 0.96512 validation ap= 0.96710
# Epoch: 0175 training loss= 0.00048 time= 5.81758
# validation roc= 0.96520 validation ap= 0.96717
# Epoch: 0176 training loss= 0.00048 time= 5.77546
# validation roc= 0.96528 validation ap= 0.96725
# Epoch: 0177 training loss= 0.00048 time= 5.80437
# validation roc= 0.96539 validation ap= 0.96737
# Epoch: 0178 training loss= 0.00048 time= 5.94029
# validation roc= 0.96549 validation ap= 0.96748
# Epoch: 0179 training loss= 0.00048 time= 5.87552
# validation roc= 0.96559 validation ap= 0.96757
# Epoch: 0180 training loss= 0.00048 time= 5.80837
# validation roc= 0.96568 validation ap= 0.96766
# Epoch: 0181 training loss= 0.00048 time= 5.86295
# validation roc= 0.96573 validation ap= 0.96770
# Epoch: 0182 training loss= 0.00048 time= 5.93597
# validation roc= 0.96576 validation ap= 0.96773
# Epoch: 0183 training loss= 0.00048 time= 5.97137
# validation roc= 0.96566 validation ap= 0.96764
# Epoch: 0184 training loss= 0.00048 time= 5.95027
# validation roc= 0.96557 validation ap= 0.96759
# Epoch: 0185 training loss= 0.00048 time= 6.01326
# validation roc= 0.96514 validation ap= 0.96730
# Epoch: 0186 training loss= 0.00048 time= 5.89171
# validation roc= 0.96536 validation ap= 0.96749
# Epoch: 0187 training loss= 0.00048 time= 5.96601
# validation roc= 0.96257 validation ap= 0.96527
# Epoch: 0188 training loss= 0.00048 time= 5.89838
# validation roc= 0.96497 validation ap= 0.96706
# Epoch: 0189 training loss= 0.00048 time= 5.91019
# validation roc= 0.96476 validation ap= 0.96717
# Epoch: 0190 training loss= 0.00047 time= 5.99280
# validation roc= 0.96322 validation ap= 0.96602
# Epoch: 0191 training loss= 0.00048 time= 6.00395
# validation roc= 0.96516 validation ap= 0.96792
# Epoch: 0192 training loss= 0.00047 time= 5.96243
# validation roc= 0.96575 validation ap= 0.96821
# Epoch: 0193 training loss= 0.00048 time= 5.90452
# validation roc= 0.96570 validation ap= 0.96827
# Epoch: 0194 training loss= 0.00047 time= 5.79480
# validation roc= 0.96464 validation ap= 0.96746
# Epoch: 0195 training loss= 0.00047 time= 5.76046
# validation roc= 0.96476 validation ap= 0.96771
# Epoch: 0196 training loss= 0.00047 time= 5.93054
# validation roc= 0.96514 validation ap= 0.96822
# Epoch: 0197 training loss= 0.00047 time= 6.03560
# validation roc= 0.96496 validation ap= 0.96812
# Epoch: 0198 training loss= 0.00047 time= 5.78292
# validation roc= 0.96471 validation ap= 0.96791
# Epoch: 0199 training loss= 0.00047 time= 5.89508
# validation roc= 0.96447 validation ap= 0.96756
# Epoch: 0200 training loss= 0.00047 time= 5.83198
# validation roc= 0.96447 validation ap= 0.96757
# testing roc= 0.96243 testing ap= 0.96587

# %% [markdown]
# # Visulization

# %%
emb=emb
labels=load_label(dataset,data_path)

X_embedded = TSNE(n_components=2, init='pca', random_state=seed).fit_transform(emb)

cs=['orange','blue','darkcyan','fuchsia','chocolate','dodgerblue','aqua','green','red','purple']
markers=['o','+','v','2','s','X','d','>','*','<']

fig, ax = plt.subplots(1,figsize=(8,6))
for i in np.arange(X_embedded.shape[0]):#X_embedded.shape[0]
    scatter = ax.scatter(X_embedded[i,0],X_embedded[i,1],label=labels[i],marker=markers[labels[i]],color=cs[labels[i]], s=10, alpha = 1)
plt.xticks([])
plt.yticks([])
plt.xlabel("")
plt.ylabel("")
plt.axis('off')
plt.show()
