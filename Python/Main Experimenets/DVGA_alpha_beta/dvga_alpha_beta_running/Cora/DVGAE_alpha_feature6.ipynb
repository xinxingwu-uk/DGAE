# %% [markdown]
# # Import libraries

# %%
import numpy as np
import random as rn
import os
from keras import backend as K
import  tensorflow.compat.v1  as tf
tf.disable_v2_behavior() 
import tensorflow as tf

#--------------------------------------------------------------------------------------------------------------------
# Reproducible
seed=0
os.environ['PYTHONHASHSEED'] = str(seed)

np.random.seed(seed)
rn.seed(seed)
session_conf =tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
tf.compat.v1.set_random_seed(seed)
#--------------------------------------------------------------------------------------------------------------------

import scipy.sparse as sp
import time
import pandas as pd
import sys

from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

sys.path.append(r"../../")

from dvgae_alpha_beta.evaluation import get_roc_score
from dvgae_alpha_beta.input_data import load_data, load_label
from dvgae_alpha_beta.model import *
from dvgae_alpha_beta.optimizer import *
from dvgae_alpha_beta.preprocessing import *
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.8/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %% [markdown]
# # Parameters setting

# %%
layers_no=6
data_path="../../Datasets/"
path_now="./log/"

dataset='cora'
model_name='DVGAE_alpha_beta_feature'

dropout=0.0
epochs=200
features_used=True
learning_rate=0.01
nb_run=1
prop_val=5
prop_test=10
validation=True
verbose=True

# %% [markdown]
# # Load data

# %%
adj_init, features_init = load_data(dataset,data_path)
num_adj=adj_init.shape[1]

# %% [markdown]
# # Training and testing

# %%
loss_coeff_adj=0.001
loss_coeff_AE=0.1
results_output_path = path_now+model_name+"/"
mkdir(results_output_path)

for seed_i in np.arange(nb_run):
    
    seed=seed_i
    lost_list=[]
    roc_list=[]
    ap_list=[]
    mean_time=[]
    
    adj, val_edges, val_edges_false, test_edges, test_edges_false =mask_test_edges(adj_init, seed,prop_test, prop_val)
                
    t_start = time.time()

    if features_used:
        features = features_init
    
    num_nodes = adj.shape[0]

    if not features_used:
        features = sp.identity(adj.shape[0])

    features = sparse_to_tuple(features)
    num_features = features[2][1]
    features_nonzero = features[1].shape[0]
        
    placeholders = {
        'features': tf.sparse_placeholder(tf.float32),
        'adj': tf.sparse_placeholder(tf.float32),
        'adj_orig': tf.sparse_placeholder(tf.float32),
        'dropout': tf.placeholder_with_default(0., shape = ())
    }

#--------------------------------------------------------------------------------------------------------------------
# Create model
    if model_name=='DVGAE_alpha_beta_feature':
        model = DVGAE_alpha_beta_feature(placeholders, layers_no,num_features, num_nodes,features_nonzero)
    elif model_name=='DVGAE_alpha_beta_no_feature':
        model=DVGAE_alpha_beta_no_feature(placeholders, layers_no,num_features, num_adj,num_nodes,features_nonzero)
    else:
        raise ValueError('Undefined model!')

    pos_weight = float(adj.shape[0] * adj.shape[0] - adj.sum()) / adj.sum()
    norm = adj.shape[0] * adj.shape[0] / float((adj.shape[0] * adj.shape[0]- adj.sum()) * 2)
    
    with tf.name_scope('optimizer'):
        if model_name in ('DVGAE_alpha_beta_feature'):
            opt =OptimizerVAE_FeatureReconstrution(preds_adj = model.reconstructions,\
                                                   preds_Features=model.feature_reconstruction,\
                                                   labels_adj = tf.reshape(tf.sparse_tensor_to_dense(placeholders['adj_orig'],\
                                                                                                     validate_indices = False), [-1]),\
                                                   labels_Features=placeholders['features'],\
                                                   labels_adj_rec=placeholders['adj'],\
                                                   loss_coeff_adj=loss_coeff_adj,\
                                                   loss_coeff_AE=loss_coeff_AE,\
                                                   model = model,\
                                                   num_nodes = num_nodes,\
                                                   pos_weight = pos_weight,\
                                                   norm = norm)
                
        elif model_name in ('DVGAE_alpha_beta_no_feature'):
            opt =OptimizerVAE_AdjReconstrution(preds_adj = model.reconstructions,\
                                               preds_adj_rec=model.adj_reconstruction,\
                                               labels_adj = tf.reshape(tf.sparse_tensor_to_dense(placeholders['adj_orig'],
                                                                                                 validate_indices = False), [-1]),\
                                               labels_Features=placeholders['features'],\
                                               labels_adj_rec=placeholders['adj'],\
                                               loss_coeff_adj=loss_coeff_adj,\
                                               loss_coeff_AE=loss_coeff_AE,\
                                               model = model,\
                                               num_nodes = num_nodes,\
                                               pos_weight = pos_weight,\
                                               norm = norm)

    adj_norm = preprocess_graph(adj)
    adj_label = sparse_to_tuple(adj + sp.eye(adj.shape[0]))

    sess = tf.Session()
    sess.run(tf.global_variables_initializer())
    
    for epoch in range(epochs):
        t = time.time()
        feed_dict = construct_feed_dict(adj_norm, adj_label, features,placeholders)
        feed_dict.update({placeholders['dropout']: dropout})
        outs = sess.run([opt.opt_op, opt.cost, opt.accuracy],feed_dict = feed_dict)
        avg_cost = outs[1]
        if verbose:
            lost_list.append(avg_cost)
            print("Epoch:", '%04d' % (epoch + 1), "training loss=", "{:.5f}".format(avg_cost),"time=", "{:.5f}".format(time.time() - t))
                    
            if validation:
                feed_dict.update({placeholders['dropout']: 0})
                emb = sess.run(model.z_mean, feed_dict = feed_dict)
                feed_dict.update({placeholders['dropout']: dropout})
                val_roc, val_ap = get_roc_score(val_edges, val_edges_false, emb)
                roc_list.append(val_roc)
                ap_list.append(val_ap)
                print("validation roc=", "{:.5f}".format(val_roc), "validation ap=", "{:.5f}".format(val_ap))

    emb = sess.run(model.z_mean, feed_dict = feed_dict)   
    mean_time.append(time.time() - t_start)
    
    roc_score, ap_score = get_roc_score(test_edges, test_edges_false, emb)
    print("testing roc=", "{:.5f}".format(roc_score), "testing ap=", "{:.5f}".format(ap_score))
    
    roc_list.append(roc_score)
    ap_list.append(ap_score)
    
    mean_time_=np.array(mean_time)
    write_to_csv(mean_time_.reshape(1,len(mean_time_)),results_output_path+"layers_"+str(layers_no)+"_time.csv")

    roc_list_=np.array(roc_list)
    write_to_csv(roc_list_.reshape(1,len(roc_list_)),results_output_path+"layers_"+str(layers_no)+"_roc.csv")

    ap_list_=np.array(ap_list)
    write_to_csv(ap_list_.reshape(1,len(ap_list_)),results_output_path+"layers_"+str(layers_no)+"_ap.csv")
# Out:
# Failure
# WARNING:tensorflow:From /usr/local/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:201: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:201: calling weighted_cross_entropy_with_logits (from tensorflow.python.ops.nn_impl) with targets is deprecated and will be removed in a future version.
# Instructions for updating:
# targets is deprecated, use labels instead
# Epoch: 0001 training loss= 0.00220 time= 1.19707
# validation roc= 0.70109 validation ap= 0.74532
# Epoch: 0002 training loss= 0.00200 time= 0.22118
# validation roc= 0.68972 validation ap= 0.74078
# Epoch: 0003 training loss= 0.00187 time= 0.18371
# validation roc= 0.68724 validation ap= 0.74232
# Epoch: 0004 training loss= 0.00168 time= 0.11554
# validation roc= 0.69060 validation ap= 0.74616
# Epoch: 0005 training loss= 0.00155 time= 0.17556
# validation roc= 0.69391 validation ap= 0.74933
# Epoch: 0006 training loss= 0.00143 time= 0.09116
# validation roc= 0.69671 validation ap= 0.75024
# Epoch: 0007 training loss= 0.00134 time= 0.17242
# validation roc= 0.70308 validation ap= 0.75336
# Epoch: 0008 training loss= 0.00125 time= 0.16437
# validation roc= 0.71778 validation ap= 0.76394
# Epoch: 0009 training loss= 0.00119 time= 0.13208
# validation roc= 0.74121 validation ap= 0.77711
# Epoch: 0010 training loss= 0.00117 time= 0.13115
# validation roc= 0.75706 validation ap= 0.78219
# Epoch: 0011 training loss= 0.00116 time= 0.12689
# validation roc= 0.75751 validation ap= 0.78221
# Epoch: 0012 training loss= 0.00115 time= 0.13531
# validation roc= 0.75735 validation ap= 0.78406
# Epoch: 0013 training loss= 0.00114 time= 0.10292
# validation roc= 0.76335 validation ap= 0.78956
# Epoch: 0014 training loss= 0.00114 time= 0.12901
# validation roc= 0.77869 validation ap= 0.80112
# Epoch: 0015 training loss= 0.00113 time= 0.12174
# validation roc= 0.79737 validation ap= 0.81545
# Epoch: 0016 training loss= 0.00111 time= 0.10988
# validation roc= 0.81198 validation ap= 0.82522
# Epoch: 0017 training loss= 0.00109 time= 0.09586
# validation roc= 0.81694 validation ap= 0.82968
# Epoch: 0018 training loss= 0.00108 time= 0.09260
# validation roc= 0.81201 validation ap= 0.82748
# Epoch: 0019 training loss= 0.00106 time= 0.09377
# validation roc= 0.80717 validation ap= 0.82319
# Epoch: 0020 training loss= 0.00104 time= 0.11184
# validation roc= 0.80675 validation ap= 0.82238
# Epoch: 0021 training loss= 0.00102 time= 0.08817
# validation roc= 0.81048 validation ap= 0.82641
# Epoch: 0022 training loss= 0.00099 time= 0.09566
# validation roc= 0.81302 validation ap= 0.82676
# Epoch: 0023 training loss= 0.00097 time= 0.11494
# validation roc= 0.81612 validation ap= 0.82318
# Epoch: 0024 training loss= 0.00097 time= 0.09962
# validation roc= 0.81866 validation ap= 0.82374
# Epoch: 0025 training loss= 0.00097 time= 0.09185
# validation roc= 0.82339 validation ap= 0.82838
# Epoch: 0026 training loss= 0.00097 time= 0.09545
# validation roc= 0.82859 validation ap= 0.83402
# Epoch: 0027 training loss= 0.00096 time= 0.08753
# validation roc= 0.83429 validation ap= 0.83926
# Epoch: 0028 training loss= 0.00096 time= 0.10575
# validation roc= 0.84111 validation ap= 0.84541
# Epoch: 0029 training loss= 0.00094 time= 0.10064
# validation roc= 0.84849 validation ap= 0.85175
# Epoch: 0030 training loss= 0.00093 time= 0.08647
# validation roc= 0.85666 validation ap= 0.85936
# Epoch: 0031 training loss= 0.00092 time= 0.08458
# validation roc= 0.86527 validation ap= 0.86717
# Epoch: 0032 training loss= 0.00091 time= 0.09888
# validation roc= 0.87437 validation ap= 0.87473
# Epoch: 0033 training loss= 0.00091 time= 0.09676
# validation roc= 0.88032 validation ap= 0.87868
# Epoch: 0034 training loss= 0.00091 time= 0.08607
# validation roc= 0.88334 validation ap= 0.88009
# Epoch: 0035 training loss= 0.00091 time= 0.08157
# validation roc= 0.88454 validation ap= 0.88025
# Epoch: 0036 training loss= 0.00090 time= 0.08575
# validation roc= 0.88589 validation ap= 0.88125
# Epoch: 0037 training loss= 0.00090 time= 0.10017
# validation roc= 0.88874 validation ap= 0.88455
# Epoch: 0038 training loss= 0.00089 time= 0.09604
# validation roc= 0.89173 validation ap= 0.88815
# Epoch: 0039 training loss= 0.00089 time= 0.09118
# validation roc= 0.89436 validation ap= 0.89102
# Epoch: 0040 training loss= 0.00088 time= 0.09252
# validation roc= 0.89544 validation ap= 0.89274
# Epoch: 0041 training loss= 0.00088 time= 0.08685
# validation roc= 0.89573 validation ap= 0.89416
# Epoch: 0042 training loss= 0.00088 time= 0.09067
# validation roc= 0.89453 validation ap= 0.89342
# Epoch: 0043 training loss= 0.00088 time= 0.10319
# validation roc= 0.89417 validation ap= 0.89365
# Epoch: 0044 training loss= 0.00087 time= 0.09438
# validation roc= 0.89478 validation ap= 0.89442
# Epoch: 0045 training loss= 0.00087 time= 0.10041
# validation roc= 0.89546 validation ap= 0.89567
# Epoch: 0046 training loss= 0.00087 time= 0.10017
# validation roc= 0.89490 validation ap= 0.89587
# Epoch: 0047 training loss= 0.00086 time= 0.10352
# validation roc= 0.89436 validation ap= 0.89611
# Epoch: 0048 training loss= 0.00086 time= 0.08762
# validation roc= 0.89325 validation ap= 0.89578
# Epoch: 0049 training loss= 0.00086 time= 0.09818
# validation roc= 0.89265 validation ap= 0.89589
# Epoch: 0050 training loss= 0.00086 time= 0.10807
# validation roc= 0.89277 validation ap= 0.89629
# Epoch: 0051 training loss= 0.00086 time= 0.10234
# validation roc= 0.89355 validation ap= 0.89746
# Epoch: 0052 training loss= 0.00086 time= 0.10144
# validation roc= 0.89372 validation ap= 0.89779
# Epoch: 0053 training loss= 0.00085 time= 0.09572
# validation roc= 0.89462 validation ap= 0.89925
# Epoch: 0054 training loss= 0.00085 time= 0.09945
# validation roc= 0.89507 validation ap= 0.90005
# Epoch: 0055 training loss= 0.00085 time= 0.10151
# validation roc= 0.89592 validation ap= 0.90144
# Epoch: 0056 training loss= 0.00085 time= 0.08493
# validation roc= 0.89728 validation ap= 0.90290
# Epoch: 0057 training loss= 0.00085 time= 0.09528
# validation roc= 0.89942 validation ap= 0.90477
# Epoch: 0058 training loss= 0.00084 time= 0.08392
# validation roc= 0.90069 validation ap= 0.90583
# Epoch: 0059 training loss= 0.00084 time= 0.09771
# validation roc= 0.90121 validation ap= 0.90644
# Epoch: 0060 training loss= 0.00084 time= 0.10077
# validation roc= 0.90237 validation ap= 0.90767
# Epoch: 0061 training loss= 0.00084 time= 0.11779
# validation roc= 0.90367 validation ap= 0.90838
# Epoch: 0062 training loss= 0.00084 time= 0.09247
# validation roc= 0.90455 validation ap= 0.90895
# Epoch: 0063 training loss= 0.00083 time= 0.09573
# validation roc= 0.90517 validation ap= 0.90960
# Epoch: 0064 training loss= 0.00083 time= 0.09503
# validation roc= 0.90590 validation ap= 0.91016
# Epoch: 0065 training loss= 0.00083 time= 0.09367
# validation roc= 0.90689 validation ap= 0.91124
# Epoch: 0066 training loss= 0.00083 time= 0.11148
# validation roc= 0.90772 validation ap= 0.91181
# Epoch: 0067 training loss= 0.00083 time= 0.09609
# validation roc= 0.90822 validation ap= 0.91222
# Epoch: 0068 training loss= 0.00082 time= 0.08649
# validation roc= 0.90778 validation ap= 0.91186
# Epoch: 0069 training loss= 0.00082 time= 0.09526
# validation roc= 0.90788 validation ap= 0.91187
# Epoch: 0070 training loss= 0.00082 time= 0.09630
# validation roc= 0.90795 validation ap= 0.91191
# Epoch: 0071 training loss= 0.00082 time= 0.09213
# validation roc= 0.90879 validation ap= 0.91269
# Epoch: 0072 training loss= 0.00082 time= 0.10078
# validation roc= 0.90942 validation ap= 0.91316
# Epoch: 0073 training loss= 0.00082 time= 0.08425
# validation roc= 0.90995 validation ap= 0.91359
# Epoch: 0074 training loss= 0.00082 time= 0.08849
# validation roc= 0.91122 validation ap= 0.91506
# Epoch: 0075 training loss= 0.00081 time= 0.08629
# validation roc= 0.91181 validation ap= 0.91557
# Epoch: 0076 training loss= 0.00081 time= 0.08671
# validation roc= 0.91190 validation ap= 0.91593
# Epoch: 0077 training loss= 0.00081 time= 0.09536
# validation roc= 0.91207 validation ap= 0.91629
# Epoch: 0078 training loss= 0.00081 time= 0.10399
# validation roc= 0.91287 validation ap= 0.91731
# Epoch: 0079 training loss= 0.00081 time= 0.10199
# validation roc= 0.91396 validation ap= 0.91866
# Epoch: 0080 training loss= 0.00081 time= 0.09304
# validation roc= 0.91339 validation ap= 0.91844
# Epoch: 0081 training loss= 0.00081 time= 0.08387
# validation roc= 0.91327 validation ap= 0.91855
# Epoch: 0082 training loss= 0.00080 time= 0.09065
# validation roc= 0.91421 validation ap= 0.91955
# Epoch: 0083 training loss= 0.00080 time= 0.09965
# validation roc= 0.91554 validation ap= 0.92062
# Epoch: 0084 training loss= 0.00080 time= 0.09079
# validation roc= 0.91605 validation ap= 0.92098
# Epoch: 0085 training loss= 0.00080 time= 0.08726
# validation roc= 0.91596 validation ap= 0.92114
# Epoch: 0086 training loss= 0.00080 time= 0.08908
# validation roc= 0.91644 validation ap= 0.92224
# Epoch: 0087 training loss= 0.00080 time= 0.09584
# validation roc= 0.91723 validation ap= 0.92304
# Epoch: 0088 training loss= 0.00080 time= 0.09099
# validation roc= 0.91767 validation ap= 0.92367
# Epoch: 0089 training loss= 0.00080 time= 0.08923
# validation roc= 0.91874 validation ap= 0.92505
# Epoch: 0090 training loss= 0.00080 time= 0.08761
# validation roc= 0.91858 validation ap= 0.92508
# Epoch: 0091 training loss= 0.00079 time= 0.09722
# validation roc= 0.91901 validation ap= 0.92568
# Epoch: 0092 training loss= 0.00079 time= 0.10104
# validation roc= 0.91918 validation ap= 0.92608
# Epoch: 0093 training loss= 0.00079 time= 0.10519
# validation roc= 0.91988 validation ap= 0.92683
# Epoch: 0094 training loss= 0.00079 time= 0.10143
# validation roc= 0.92031 validation ap= 0.92752
# Epoch: 0095 training loss= 0.00079 time= 0.08386
# validation roc= 0.92024 validation ap= 0.92797
# Epoch: 0096 training loss= 0.00079 time= 0.11511
# validation roc= 0.92050 validation ap= 0.92827
# Epoch: 0097 training loss= 0.00079 time= 0.10060
# validation roc= 0.92173 validation ap= 0.92971
# Epoch: 0098 training loss= 0.00079 time= 0.09928
# validation roc= 0.92312 validation ap= 0.93102
# Epoch: 0099 training loss= 0.00079 time= 0.08734
# validation roc= 0.92354 validation ap= 0.93127
# Epoch: 0100 training loss= 0.00079 time= 0.09633
# validation roc= 0.92381 validation ap= 0.93198
# Epoch: 0101 training loss= 0.00079 time= 0.09075
# validation roc= 0.92432 validation ap= 0.93267
# Epoch: 0102 training loss= 0.00079 time= 0.11084
# validation roc= 0.92507 validation ap= 0.93312
# Epoch: 0103 training loss= 0.00078 time= 0.08881
# validation roc= 0.92650 validation ap= 0.93465
# Epoch: 0104 training loss= 0.00078 time= 0.10567
# validation roc= 0.92712 validation ap= 0.93539
# Epoch: 0105 training loss= 0.00078 time= 0.08855
# validation roc= 0.92683 validation ap= 0.93533
# Epoch: 0106 training loss= 0.00078 time= 0.08917
# validation roc= 0.92823 validation ap= 0.93661
# Epoch: 0107 training loss= 0.00078 time= 0.09672
# validation roc= 0.92980 validation ap= 0.93789
# Epoch: 0108 training loss= 0.00078 time= 0.08550
# validation roc= 0.92965 validation ap= 0.93782
# Epoch: 0109 training loss= 0.00078 time= 0.09231
# validation roc= 0.93008 validation ap= 0.93844
# Epoch: 0110 training loss= 0.00078 time= 0.08391
# validation roc= 0.93110 validation ap= 0.93916
# Epoch: 0111 training loss= 0.00078 time= 0.08948
# validation roc= 0.93170 validation ap= 0.93960
# Epoch: 0112 training loss= 0.00078 time= 0.09731
# validation roc= 0.93206 validation ap= 0.94003
# Epoch: 0113 training loss= 0.00078 time= 0.09756
# validation roc= 0.93279 validation ap= 0.94080
# Epoch: 0114 training loss= 0.00078 time= 0.08858
# validation roc= 0.93266 validation ap= 0.94072
# Epoch: 0115 training loss= 0.00078 time= 0.08272
# validation roc= 0.93282 validation ap= 0.94090
# Epoch: 0116 training loss= 0.00078 time= 0.09098
# validation roc= 0.93370 validation ap= 0.94177
# Epoch: 0117 training loss= 0.00077 time= 0.09522
# validation roc= 0.93364 validation ap= 0.94148
# Epoch: 0118 training loss= 0.00077 time= 0.08304
# validation roc= 0.93389 validation ap= 0.94213
# Epoch: 0119 training loss= 0.00077 time= 0.10917
# validation roc= 0.93335 validation ap= 0.94153
# Epoch: 0120 training loss= 0.00077 time= 0.11011
# validation roc= 0.93477 validation ap= 0.94255
# Epoch: 0121 training loss= 0.00077 time= 0.09385
# validation roc= 0.93409 validation ap= 0.94213
# Epoch: 0122 training loss= 0.00077 time= 0.09907
# validation roc= 0.93412 validation ap= 0.94219
# Epoch: 0123 training loss= 0.00077 time= 0.08544
# validation roc= 0.93436 validation ap= 0.94241
# Epoch: 0124 training loss= 0.00077 time= 0.09025
# validation roc= 0.93387 validation ap= 0.94203
# Epoch: 0125 training loss= 0.00077 time= 0.10473
# validation roc= 0.93400 validation ap= 0.94193
# Epoch: 0126 training loss= 0.00077 time= 0.11390
# validation roc= 0.93496 validation ap= 0.94266
# Epoch: 0127 training loss= 0.00077 time= 0.08912
# validation roc= 0.93347 validation ap= 0.94173
# Epoch: 0128 training loss= 0.00077 time= 0.08583
# validation roc= 0.93448 validation ap= 0.94250
# Epoch: 0129 training loss= 0.00077 time= 0.08290
# validation roc= 0.93433 validation ap= 0.94234
# Epoch: 0130 training loss= 0.00077 time= 0.12988
# validation roc= 0.93380 validation ap= 0.94201
# Epoch: 0131 training loss= 0.00077 time= 0.10196
# validation roc= 0.93493 validation ap= 0.94286
# Epoch: 0132 training loss= 0.00077 time= 0.08263
# validation roc= 0.93392 validation ap= 0.94210
# Epoch: 0133 training loss= 0.00077 time= 0.08720
# validation roc= 0.93444 validation ap= 0.94211
# Epoch: 0134 training loss= 0.00077 time= 0.09369
# validation roc= 0.93390 validation ap= 0.94226
# Epoch: 0135 training loss= 0.00076 time= 0.09161
# validation roc= 0.93535 validation ap= 0.94331
# Epoch: 0136 training loss= 0.00076 time= 0.10521
# validation roc= 0.93406 validation ap= 0.94257
# Epoch: 0137 training loss= 0.00076 time= 0.08665
# validation roc= 0.93474 validation ap= 0.94255
# Epoch: 0138 training loss= 0.00076 time= 0.11234
# validation roc= 0.93477 validation ap= 0.94305
# Epoch: 0139 training loss= 0.00076 time= 0.08956
# validation roc= 0.93428 validation ap= 0.94280
# Epoch: 0140 training loss= 0.00076 time= 0.09994
# validation roc= 0.93532 validation ap= 0.94304
# Epoch: 0141 training loss= 0.00076 time= 0.09081
# validation roc= 0.93503 validation ap= 0.94364
# Epoch: 0142 training loss= 0.00076 time= 0.09692
# validation roc= 0.93433 validation ap= 0.94297
# Epoch: 0143 training loss= 0.00076 time= 0.08550
# validation roc= 0.93577 validation ap= 0.94373
# Epoch: 0144 training loss= 0.00076 time= 0.09159
# validation roc= 0.93538 validation ap= 0.94391
# Epoch: 0145 training loss= 0.00076 time= 0.08461
# validation roc= 0.93549 validation ap= 0.94394
# Epoch: 0146 training loss= 0.00076 time= 0.08869
# validation roc= 0.93533 validation ap= 0.94334
# Epoch: 0147 training loss= 0.00076 time= 0.10744
# validation roc= 0.93536 validation ap= 0.94410
# Epoch: 0148 training loss= 0.00076 time= 0.09424
# validation roc= 0.93577 validation ap= 0.94410
# Epoch: 0149 training loss= 0.00076 time= 0.10632
# validation roc= 0.93595 validation ap= 0.94395
# Epoch: 0150 training loss= 0.00076 time= 0.11017
# validation roc= 0.93542 validation ap= 0.94426
# Epoch: 0151 training loss= 0.00076 time= 0.09175
# validation roc= 0.93640 validation ap= 0.94469
# Epoch: 0152 training loss= 0.00076 time= 0.10898
# validation roc= 0.93588 validation ap= 0.94394
# Epoch: 0153 training loss= 0.00076 time= 0.10011
# validation roc= 0.93540 validation ap= 0.94401
# Epoch: 0154 training loss= 0.00076 time= 0.09998
# validation roc= 0.93553 validation ap= 0.94415
# Epoch: 0155 training loss= 0.00076 time= 0.08836
# validation roc= 0.93590 validation ap= 0.94431
# Epoch: 0156 training loss= 0.00076 time= 0.11778
# validation roc= 0.93594 validation ap= 0.94417
# Epoch: 0157 training loss= 0.00076 time= 0.09901
# validation roc= 0.93616 validation ap= 0.94464
# Epoch: 0158 training loss= 0.00076 time= 0.16250
# validation roc= 0.93575 validation ap= 0.94437
# Epoch: 0159 training loss= 0.00076 time= 0.09117
# validation roc= 0.93629 validation ap= 0.94448
# Epoch: 0160 training loss= 0.00076 time= 0.09646
# validation roc= 0.93695 validation ap= 0.94520
# Epoch: 0161 training loss= 0.00076 time= 0.10255
# validation roc= 0.93636 validation ap= 0.94478
# Epoch: 0162 training loss= 0.00076 time= 0.10006
# validation roc= 0.93564 validation ap= 0.94424
# Epoch: 0163 training loss= 0.00076 time= 0.13453
# validation roc= 0.93650 validation ap= 0.94467
# Epoch: 0164 training loss= 0.00075 time= 0.08337
# validation roc= 0.93699 validation ap= 0.94530
# Epoch: 0165 training loss= 0.00075 time= 0.08462
# validation roc= 0.93617 validation ap= 0.94466
# Epoch: 0166 training loss= 0.00075 time= 0.11500
# validation roc= 0.93672 validation ap= 0.94514
# Epoch: 0167 training loss= 0.00075 time= 0.08965
# validation roc= 0.93701 validation ap= 0.94530
# Epoch: 0168 training loss= 0.00075 time= 0.08717
# validation roc= 0.93691 validation ap= 0.94521
# Epoch: 0169 training loss= 0.00075 time= 0.10907
# validation roc= 0.93659 validation ap= 0.94493
# Epoch: 0170 training loss= 0.00075 time= 0.08223
# validation roc= 0.93666 validation ap= 0.94514
# Epoch: 0171 training loss= 0.00075 time= 0.08439
# validation roc= 0.93645 validation ap= 0.94463
# Epoch: 0172 training loss= 0.00075 time= 0.11866
# validation roc= 0.93726 validation ap= 0.94583
# Epoch: 0173 training loss= 0.00075 time= 0.09390
# validation roc= 0.93694 validation ap= 0.94505
# Epoch: 0174 training loss= 0.00075 time= 0.08997
# validation roc= 0.93620 validation ap= 0.94454
# Epoch: 0175 training loss= 0.00075 time= 0.09793
# validation roc= 0.93702 validation ap= 0.94529
# Epoch: 0176 training loss= 0.00075 time= 0.08245
# validation roc= 0.93726 validation ap= 0.94530
# Epoch: 0177 training loss= 0.00075 time= 0.10580
# validation roc= 0.93658 validation ap= 0.94492
# Epoch: 0178 training loss= 0.00075 time= 0.09951
# validation roc= 0.93710 validation ap= 0.94537
# Epoch: 0179 training loss= 0.00075 time= 0.09497
# validation roc= 0.93733 validation ap= 0.94518
# Epoch: 0180 training loss= 0.00075 time= 0.08691
# validation roc= 0.93724 validation ap= 0.94545
# Epoch: 0181 training loss= 0.00075 time= 0.09008
# validation roc= 0.93727 validation ap= 0.94541
# Epoch: 0182 training loss= 0.00075 time= 0.12869
# validation roc= 0.93760 validation ap= 0.94550
# Epoch: 0183 training loss= 0.00075 time= 0.09153
# validation roc= 0.93765 validation ap= 0.94551
# Epoch: 0184 training loss= 0.00075 time= 0.08867
# validation roc= 0.93744 validation ap= 0.94536
# Epoch: 0185 training loss= 0.00075 time= 0.08352
# validation roc= 0.93808 validation ap= 0.94596
# Epoch: 0186 training loss= 0.00075 time= 0.08332
# validation roc= 0.93798 validation ap= 0.94591
# Epoch: 0187 training loss= 0.00075 time= 0.08858
# validation roc= 0.93713 validation ap= 0.94518
# Epoch: 0188 training loss= 0.00075 time= 0.08523
# validation roc= 0.93708 validation ap= 0.94506
# Epoch: 0189 training loss= 0.00075 time= 0.08244
# validation roc= 0.93837 validation ap= 0.94618
# Epoch: 0190 training loss= 0.00075 time= 0.11821
# validation roc= 0.93783 validation ap= 0.94568
# Epoch: 0191 training loss= 0.00075 time= 0.10647
# validation roc= 0.93685 validation ap= 0.94487
# Epoch: 0192 training loss= 0.00075 time= 0.09910
# validation roc= 0.93775 validation ap= 0.94560
# Epoch: 0193 training loss= 0.00075 time= 0.08537
# validation roc= 0.93840 validation ap= 0.94621
# Epoch: 0194 training loss= 0.00075 time= 0.09095
# validation roc= 0.93788 validation ap= 0.94555
# Epoch: 0195 training loss= 0.00075 time= 0.09765
# validation roc= 0.93744 validation ap= 0.94540
# Epoch: 0196 training loss= 0.00075 time= 0.09512
# validation roc= 0.93754 validation ap= 0.94556
# Epoch: 0197 training loss= 0.00075 time= 0.09615
# validation roc= 0.93752 validation ap= 0.94535
# Epoch: 0198 training loss= 0.00075 time= 0.10336
# validation roc= 0.93831 validation ap= 0.94598
# Epoch: 0199 training loss= 0.00075 time= 0.09021
# validation roc= 0.93769 validation ap= 0.94593
# Epoch: 0200 training loss= 0.00075 time= 0.09162
# validation roc= 0.93734 validation ap= 0.94533
# testing roc= 0.92466 testing ap= 0.93638

# %% [markdown]
# # Visulization

# %%
emb=emb
labels=load_label(dataset,data_path)

X_embedded = TSNE(n_components=2, init='pca', random_state=seed).fit_transform(emb)

cs=['orange','blue','darkcyan','fuchsia','chocolate','dodgerblue','aqua','green','red','purple']
markers=['o','+','v','2','s','X','d','>','*','<']

fig, ax = plt.subplots(1,figsize=(8,6))
for i in np.arange(X_embedded.shape[0]):
    scatter = ax.scatter(X_embedded[i,0],X_embedded[i,1],label=labels[i],marker=markers[labels[i]],color=cs[labels[i]], s=10, alpha = 1)
plt.xticks([])
plt.yticks([])
plt.xlabel("")
plt.ylabel("")
plt.axis('off')
plt.show()
