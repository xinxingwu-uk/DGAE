# %% [markdown]
# # Import libraries

# %%
import numpy as np
import random as rn
import os
from keras import backend as K
import  tensorflow.compat.v1  as tf
tf.disable_v2_behavior() 
import tensorflow as tf

#--------------------------------------------------------------------------------------------------------------------
# Reproducible
seed=0
os.environ['PYTHONHASHSEED'] = str(seed)

np.random.seed(seed)
rn.seed(seed)
session_conf =tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
tf.compat.v1.set_random_seed(seed)
#--------------------------------------------------------------------------------------------------------------------

import scipy.sparse as sp
import time
import pandas as pd
import sys

from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

sys.path.append(r"../../")

from dvgae_alpha_beta.evaluation import get_roc_score
from dvgae_alpha_beta.input_data import load_data, load_label
from dvgae_alpha_beta.model import *
from dvgae_alpha_beta.optimizer import *
from dvgae_alpha_beta.preprocessing import *
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.8/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %% [markdown]
# # Parameters setting

# %%
layers_no=6
data_path="../../Datasets/"
path_now="./log/"

dataset='pubmed'
model_name='DVGAE_alpha_beta_feature'

dropout=0.0
epochs=200
features_used=True
learning_rate=0.01
nb_run=1
prop_val=5
prop_test=10
validation=True
verbose=True

# %% [markdown]
# # Load data

# %%
adj_init, features_init = load_data(dataset,data_path)
num_adj=adj_init.shape[1]

# %% [markdown]
# # Training and testing

# %%
loss_coeff_adj=0.005
loss_coeff_AE=2.0
results_output_path = path_now+model_name+"/"
mkdir(results_output_path)

for seed_i in np.arange(nb_run):
    
    seed=seed_i
    lost_list=[]
    roc_list=[]
    ap_list=[]
    mean_time=[]
    
    adj, val_edges, val_edges_false, test_edges, test_edges_false =mask_test_edges(adj_init, seed,prop_test, prop_val)
                
    t_start = time.time()

    if features_used:
        features = features_init
    
    num_nodes = adj.shape[0]

    if not features_used:
        features = sp.identity(adj.shape[0])

    features = sparse_to_tuple(features)
    num_features = features[2][1]
    features_nonzero = features[1].shape[0]
        
    placeholders = {
        'features': tf.sparse_placeholder(tf.float32),
        'adj': tf.sparse_placeholder(tf.float32),
        'adj_orig': tf.sparse_placeholder(tf.float32),
        'dropout': tf.placeholder_with_default(0., shape = ())
    }

#--------------------------------------------------------------------------------------------------------------------
# Create model
    if model_name=='DVGAE_alpha_beta_feature':
        model = DVGAE_alpha_beta_feature(placeholders, layers_no,num_features, num_nodes,features_nonzero)
    elif model_name=='DVGAE_alpha_beta_no_feature':
        model=DVGAE_alpha_beta_no_feature(placeholders, layers_no,num_features, num_adj,num_nodes,features_nonzero)
    else:
        raise ValueError('Undefined model!')

    pos_weight = float(adj.shape[0] * adj.shape[0] - adj.sum()) / adj.sum()
    norm = adj.shape[0] * adj.shape[0] / float((adj.shape[0] * adj.shape[0]- adj.sum()) * 2)
    
    with tf.name_scope('optimizer'):
        if model_name in ('DVGAE_alpha_beta_feature'):
            opt =OptimizerVAE_FeatureReconstrution(preds_adj = model.reconstructions,\
                                                   preds_Features=model.feature_reconstruction,\
                                                   labels_adj = tf.reshape(tf.sparse_tensor_to_dense(placeholders['adj_orig'],\
                                                                                                     validate_indices = False), [-1]),\
                                                   labels_Features=placeholders['features'],\
                                                   labels_adj_rec=placeholders['adj'],\
                                                   loss_coeff_adj=loss_coeff_adj,\
                                                   loss_coeff_AE=loss_coeff_AE,\
                                                   model = model,\
                                                   num_nodes = num_nodes,\
                                                   pos_weight = pos_weight,\
                                                   norm = norm)
                
        elif model_name in ('DVGAE_alpha_beta_no_feature'):
            opt =OptimizerVAE_AdjReconstrution(preds_adj = model.reconstructions,\
                                               preds_adj_rec=model.adj_reconstruction,\
                                               labels_adj = tf.reshape(tf.sparse_tensor_to_dense(placeholders['adj_orig'],
                                                                                                 validate_indices = False), [-1]),\
                                               labels_Features=placeholders['features'],\
                                               labels_adj_rec=placeholders['adj'],\
                                               loss_coeff_adj=loss_coeff_adj,\
                                               loss_coeff_AE=loss_coeff_AE,\
                                               model = model,\
                                               num_nodes = num_nodes,\
                                               pos_weight = pos_weight,\
                                               norm = norm)

    adj_norm = preprocess_graph(adj)
    adj_label = sparse_to_tuple(adj + sp.eye(adj.shape[0]))

    sess = tf.Session()
    sess.run(tf.global_variables_initializer())
    
    for epoch in range(epochs):
        t = time.time()
        feed_dict = construct_feed_dict(adj_norm, adj_label, features,placeholders)
        feed_dict.update({placeholders['dropout']: dropout})
        outs = sess.run([opt.opt_op, opt.cost, opt.accuracy],feed_dict = feed_dict)
        avg_cost = outs[1]
        if verbose:
            lost_list.append(avg_cost)
            print("Epoch:", '%04d' % (epoch + 1), "training loss=", "{:.5f}".format(avg_cost),"time=", "{:.5f}".format(time.time() - t))
                    
            if validation:
                feed_dict.update({placeholders['dropout']: 0})
                emb = sess.run(model.z_mean, feed_dict = feed_dict)
                feed_dict.update({placeholders['dropout']: dropout})
                val_roc, val_ap = get_roc_score(val_edges, val_edges_false, emb)
                roc_list.append(val_roc)
                ap_list.append(val_ap)
                print("validation roc=", "{:.5f}".format(val_roc), "validation ap=", "{:.5f}".format(val_ap))

    emb = sess.run(model.z_mean, feed_dict = feed_dict)   
    mean_time.append(time.time() - t_start)
    
    roc_score, ap_score = get_roc_score(test_edges, test_edges_false, emb)
    print("testing roc=", "{:.5f}".format(roc_score), "testing ap=", "{:.5f}".format(ap_score))
    
    roc_list.append(roc_score)
    ap_list.append(ap_score)
    
    mean_time_=np.array(mean_time)
    write_to_csv(mean_time_.reshape(1,len(mean_time_)),results_output_path+"layers_"+str(layers_no)+"_time.csv")

    roc_list_=np.array(roc_list)
    write_to_csv(roc_list_.reshape(1,len(roc_list_)),results_output_path+"layers_"+str(layers_no)+"_roc.csv")

    ap_list_=np.array(ap_list)
    write_to_csv(ap_list_.reshape(1,len(ap_list_)),results_output_path+"layers_"+str(layers_no)+"_ap.csv")
# Out:
# Successful!
# WARNING:tensorflow:From /usr/local/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:201: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:201: calling weighted_cross_entropy_with_logits (from tensorflow.python.ops.nn_impl) with targets is deprecated and will be removed in a future version.
# Instructions for updating:
# targets is deprecated, use labels instead
# Epoch: 0001 training loss= 0.00891 time= 40.37059
# validation roc= 0.85484 validation ap= 0.85031
# Epoch: 0002 training loss= 0.00871 time= 13.97996
# validation roc= 0.87214 validation ap= 0.86439
# Epoch: 0003 training loss= 0.00861 time= 10.58795
# validation roc= 0.87915 validation ap= 0.86844
# Epoch: 0004 training loss= 0.00825 time= 7.92039
# validation roc= 0.88203 validation ap= 0.86978
# Epoch: 0005 training loss= 0.00789 time= 8.03492
# validation roc= 0.88319 validation ap= 0.87024
# Epoch: 0006 training loss= 0.00743 time= 8.04977
# validation roc= 0.88379 validation ap= 0.87055
# Epoch: 0007 training loss= 0.00698 time= 8.00127
# validation roc= 0.88419 validation ap= 0.87095
# Epoch: 0008 training loss= 0.00661 time= 7.98840
# validation roc= 0.88452 validation ap= 0.87142
# Epoch: 0009 training loss= 0.00621 time= 10.27115
# validation roc= 0.88481 validation ap= 0.87198
# Epoch: 0010 training loss= 0.00582 time= 11.65890
# validation roc= 0.88502 validation ap= 0.87255
# Epoch: 0011 training loss= 0.00550 time= 11.71499
# validation roc= 0.88516 validation ap= 0.87302
# Epoch: 0012 training loss= 0.00516 time= 10.35835
# validation roc= 0.88525 validation ap= 0.87342
# Epoch: 0013 training loss= 0.00486 time= 7.06523
# validation roc= 0.88540 validation ap= 0.87378
# Epoch: 0014 training loss= 0.00455 time= 6.48020
# validation roc= 0.88563 validation ap= 0.87405
# Epoch: 0015 training loss= 0.00429 time= 6.63113
# validation roc= 0.88590 validation ap= 0.87429
# Epoch: 0016 training loss= 0.00409 time= 6.57064
# validation roc= 0.88627 validation ap= 0.87458
# Epoch: 0017 training loss= 0.00394 time= 6.67381
# validation roc= 0.88658 validation ap= 0.87486
# Epoch: 0018 training loss= 0.00384 time= 6.46197
# validation roc= 0.88688 validation ap= 0.87507
# Epoch: 0019 training loss= 0.00379 time= 6.63912
# validation roc= 0.88718 validation ap= 0.87536
# Epoch: 0020 training loss= 0.00375 time= 6.56870
# validation roc= 0.88751 validation ap= 0.87573
# Epoch: 0021 training loss= 0.00372 time= 6.51426
# validation roc= 0.88782 validation ap= 0.87606
# Epoch: 0022 training loss= 0.00370 time= 6.48999
# validation roc= 0.88802 validation ap= 0.87632
# Epoch: 0023 training loss= 0.00370 time= 6.44882
# validation roc= 0.88819 validation ap= 0.87678
# Epoch: 0024 training loss= 0.00371 time= 6.49666
# validation roc= 0.88810 validation ap= 0.87721
# Epoch: 0025 training loss= 0.00371 time= 6.53009
# validation roc= 0.88761 validation ap= 0.87751
# Epoch: 0026 training loss= 0.00371 time= 6.58988
# validation roc= 0.88681 validation ap= 0.87765
# Epoch: 0027 training loss= 0.00369 time= 6.43025
# validation roc= 0.88540 validation ap= 0.87743
# Epoch: 0028 training loss= 0.00369 time= 6.55933
# validation roc= 0.88315 validation ap= 0.87646
# Epoch: 0029 training loss= 0.00369 time= 6.45859
# validation roc= 0.87972 validation ap= 0.87431
# Epoch: 0030 training loss= 0.00369 time= 6.52811
# validation roc= 0.87554 validation ap= 0.87136
# Epoch: 0031 training loss= 0.00369 time= 6.56847
# validation roc= 0.87117 validation ap= 0.86809
# Epoch: 0032 training loss= 0.00369 time= 6.53954
# validation roc= 0.86703 validation ap= 0.86498
# Epoch: 0033 training loss= 0.00369 time= 6.64328
# validation roc= 0.86276 validation ap= 0.86183
# Epoch: 0034 training loss= 0.00368 time= 6.67878
# validation roc= 0.85838 validation ap= 0.85858
# Epoch: 0035 training loss= 0.00367 time= 6.65879
# validation roc= 0.85439 validation ap= 0.85554
# Epoch: 0036 training loss= 0.00367 time= 6.73713
# validation roc= 0.85147 validation ap= 0.85332
# Epoch: 0037 training loss= 0.00367 time= 6.39689
# validation roc= 0.85013 validation ap= 0.85228
# Epoch: 0038 training loss= 0.00366 time= 6.47542
# validation roc= 0.85040 validation ap= 0.85253
# Epoch: 0039 training loss= 0.00365 time= 6.49437
# validation roc= 0.85238 validation ap= 0.85415
# Epoch: 0040 training loss= 0.00364 time= 6.47475
# validation roc= 0.85676 validation ap= 0.85773
# Epoch: 0041 training loss= 0.00363 time= 6.58642
# validation roc= 0.86410 validation ap= 0.86369
# Epoch: 0042 training loss= 0.00362 time= 6.55989
# validation roc= 0.87526 validation ap= 0.87287
# Epoch: 0043 training loss= 0.00360 time= 6.49777
# validation roc= 0.89022 validation ap= 0.88553
# Epoch: 0044 training loss= 0.00358 time= 6.33849
# validation roc= 0.90621 validation ap= 0.89958
# Epoch: 0045 training loss= 0.00356 time= 6.60337
# validation roc= 0.91901 validation ap= 0.91128
# Epoch: 0046 training loss= 0.00353 time= 6.57102
# validation roc= 0.92610 validation ap= 0.91816
# Epoch: 0047 training loss= 0.00350 time= 6.61265
# validation roc= 0.92729 validation ap= 0.91988
# Epoch: 0048 training loss= 0.00347 time= 6.56154
# validation roc= 0.92431 validation ap= 0.91789
# Epoch: 0049 training loss= 0.00343 time= 6.48792
# validation roc= 0.91895 validation ap= 0.91371
# Epoch: 0050 training loss= 0.00340 time= 6.51527
# validation roc= 0.91206 validation ap= 0.90808
# Epoch: 0051 training loss= 0.00335 time= 6.45375
# validation roc= 0.90426 validation ap= 0.90154
# Epoch: 0052 training loss= 0.00331 time= 6.51465
# validation roc= 0.89615 validation ap= 0.89494
# Epoch: 0053 training loss= 0.00327 time= 6.53833
# validation roc= 0.88797 validation ap= 0.88874
# Epoch: 0054 training loss= 0.00323 time= 6.58049
# validation roc= 0.88045 validation ap= 0.88374
# Epoch: 0055 training loss= 0.00320 time= 6.56263
# validation roc= 0.87382 validation ap= 0.87983
# Epoch: 0056 training loss= 0.00317 time= 6.52636
# validation roc= 0.86867 validation ap= 0.87668
# Epoch: 0057 training loss= 0.00316 time= 6.21751
# validation roc= 0.86521 validation ap= 0.87422
# Epoch: 0058 training loss= 0.00316 time= 6.42277
# validation roc= 0.86312 validation ap= 0.87219
# Epoch: 0059 training loss= 0.00316 time= 6.57428
# validation roc= 0.86209 validation ap= 0.87074
# Epoch: 0060 training loss= 0.00316 time= 6.56207
# validation roc= 0.86220 validation ap= 0.87054
# Epoch: 0061 training loss= 0.00315 time= 6.64406
# validation roc= 0.86358 validation ap= 0.87220
# Epoch: 0062 training loss= 0.00314 time= 6.58729
# validation roc= 0.86595 validation ap= 0.87505
# Epoch: 0063 training loss= 0.00312 time= 6.46669
# validation roc= 0.86906 validation ap= 0.87857
# Epoch: 0064 training loss= 0.00311 time= 6.42695
# validation roc= 0.87287 validation ap= 0.88239
# Epoch: 0065 training loss= 0.00309 time= 6.59324
# validation roc= 0.87741 validation ap= 0.88656
# Epoch: 0066 training loss= 0.00307 time= 6.56512
# validation roc= 0.88241 validation ap= 0.89093
# Epoch: 0067 training loss= 0.00305 time= 6.55226
# validation roc= 0.88750 validation ap= 0.89559
# Epoch: 0068 training loss= 0.00304 time= 6.57718
# validation roc= 0.89230 validation ap= 0.90024
# Epoch: 0069 training loss= 0.00302 time= 6.33165
# validation roc= 0.89684 validation ap= 0.90470
# Epoch: 0070 training loss= 0.00301 time= 6.50216
# validation roc= 0.90139 validation ap= 0.90901
# Epoch: 0071 training loss= 0.00299 time= 6.41514
# validation roc= 0.90561 validation ap= 0.91272
# Epoch: 0072 training loss= 0.00297 time= 6.44348
# validation roc= 0.90924 validation ap= 0.91564
# Epoch: 0073 training loss= 0.00295 time= 6.48215
# validation roc= 0.91192 validation ap= 0.91763
# Epoch: 0074 training loss= 0.00293 time= 6.48728
# validation roc= 0.91332 validation ap= 0.91861
# Epoch: 0075 training loss= 0.00291 time= 6.55267
# validation roc= 0.91369 validation ap= 0.91891
# Epoch: 0076 training loss= 0.00290 time= 6.51289
# validation roc= 0.91340 validation ap= 0.91886
# Epoch: 0077 training loss= 0.00289 time= 6.60375
# validation roc= 0.91280 validation ap= 0.91853
# Epoch: 0078 training loss= 0.00288 time= 6.51983
# validation roc= 0.91191 validation ap= 0.91786
# Epoch: 0079 training loss= 0.00288 time= 6.54001
# validation roc= 0.91101 validation ap= 0.91712
# Epoch: 0080 training loss= 0.00289 time= 6.54531
# validation roc= 0.91017 validation ap= 0.91641
# Epoch: 0081 training loss= 0.00289 time= 6.17346
# validation roc= 0.90951 validation ap= 0.91583
# Epoch: 0082 training loss= 0.00289 time= 6.40528
# validation roc= 0.90952 validation ap= 0.91589
# Epoch: 0083 training loss= 0.00289 time= 6.53958
# validation roc= 0.91029 validation ap= 0.91672
# Epoch: 0084 training loss= 0.00288 time= 6.55865
# validation roc= 0.91151 validation ap= 0.91791
# Epoch: 0085 training loss= 0.00287 time= 6.50829
# validation roc= 0.91303 validation ap= 0.91941
# Epoch: 0086 training loss= 0.00286 time= 6.58315
# validation roc= 0.91447 validation ap= 0.92085
# Epoch: 0087 training loss= 0.00285 time= 6.50741
# validation roc= 0.91547 validation ap= 0.92188
# Epoch: 0088 training loss= 0.00285 time= 6.31365
# validation roc= 0.91602 validation ap= 0.92251
# Epoch: 0089 training loss= 0.00284 time= 6.54175
# validation roc= 0.91630 validation ap= 0.92281
# Epoch: 0090 training loss= 0.00284 time= 6.38630
# validation roc= 0.91663 validation ap= 0.92317
# Epoch: 0091 training loss= 0.00284 time= 6.16913
# validation roc= 0.91721 validation ap= 0.92375
# Epoch: 0092 training loss= 0.00284 time= 6.61716
# validation roc= 0.91786 validation ap= 0.92442
# Epoch: 0093 training loss= 0.00284 time= 6.54868
# validation roc= 0.91845 validation ap= 0.92503
# Epoch: 0094 training loss= 0.00284 time= 6.59950
# validation roc= 0.91873 validation ap= 0.92533
# Epoch: 0095 training loss= 0.00283 time= 6.58844
# validation roc= 0.91871 validation ap= 0.92535
# Epoch: 0096 training loss= 0.00283 time= 6.64483
# validation roc= 0.91846 validation ap= 0.92513
# Epoch: 0097 training loss= 0.00283 time= 6.64882
# validation roc= 0.91834 validation ap= 0.92506
# Epoch: 0098 training loss= 0.00282 time= 6.43386
# validation roc= 0.91853 validation ap= 0.92530
# Epoch: 0099 training loss= 0.00282 time= 6.59511
# validation roc= 0.91881 validation ap= 0.92563
# Epoch: 0100 training loss= 0.00282 time= 6.52139
# validation roc= 0.91907 validation ap= 0.92593
# Epoch: 0101 training loss= 0.00282 time= 6.52569
# validation roc= 0.91915 validation ap= 0.92608
# Epoch: 0102 training loss= 0.00282 time= 6.63496
# validation roc= 0.91895 validation ap= 0.92596
# Epoch: 0103 training loss= 0.00282 time= 6.45042
# validation roc= 0.91870 validation ap= 0.92581
# Epoch: 0104 training loss= 0.00281 time= 6.53530
# validation roc= 0.91862 validation ap= 0.92581
# Epoch: 0105 training loss= 0.00281 time= 6.60623
# validation roc= 0.91895 validation ap= 0.92613
# Epoch: 0106 training loss= 0.00281 time= 6.63209
# validation roc= 0.91905 validation ap= 0.92630
# Epoch: 0107 training loss= 0.00281 time= 6.43587
# validation roc= 0.91890 validation ap= 0.92626
# Epoch: 0108 training loss= 0.00280 time= 6.55627
# validation roc= 0.91882 validation ap= 0.92626
# Epoch: 0109 training loss= 0.00280 time= 6.52915
# validation roc= 0.91893 validation ap= 0.92642
# Epoch: 0110 training loss= 0.00280 time= 6.56154
# validation roc= 0.91928 validation ap= 0.92672
# Epoch: 0111 training loss= 0.00280 time= 6.52990
# validation roc= 0.91960 validation ap= 0.92700
# Epoch: 0112 training loss= 0.00280 time= 6.58334
# validation roc= 0.91984 validation ap= 0.92727
# Epoch: 0113 training loss= 0.00280 time= 6.57034
# validation roc= 0.91999 validation ap= 0.92740
# Epoch: 0114 training loss= 0.00279 time= 6.52758
# validation roc= 0.92036 validation ap= 0.92773
# Epoch: 0115 training loss= 0.00279 time= 6.68811
# validation roc= 0.92071 validation ap= 0.92808
# Epoch: 0116 training loss= 0.00279 time= 6.63702
# validation roc= 0.92100 validation ap= 0.92835
# Epoch: 0117 training loss= 0.00279 time= 6.27876
# validation roc= 0.92110 validation ap= 0.92849
# Epoch: 0118 training loss= 0.00279 time= 6.58912
# validation roc= 0.92143 validation ap= 0.92878
# Epoch: 0119 training loss= 0.00279 time= 6.39849
# validation roc= 0.92185 validation ap= 0.92917
# Epoch: 0120 training loss= 0.00279 time= 6.44384
# validation roc= 0.92217 validation ap= 0.92946
# Epoch: 0121 training loss= 0.00278 time= 6.50549
# validation roc= 0.92239 validation ap= 0.92966
# Epoch: 0122 training loss= 0.00278 time= 6.48293
# validation roc= 0.92273 validation ap= 0.92996
# Epoch: 0123 training loss= 0.00278 time= 6.50297
# validation roc= 0.92314 validation ap= 0.93033
# Epoch: 0124 training loss= 0.00278 time= 6.60717
# validation roc= 0.92348 validation ap= 0.93065
# Epoch: 0125 training loss= 0.00278 time= 6.60419
# validation roc= 0.92380 validation ap= 0.93093
# Epoch: 0126 training loss= 0.00278 time= 6.53469
# validation roc= 0.92400 validation ap= 0.93112
# Epoch: 0127 training loss= 0.00277 time= 6.56363
# validation roc= 0.92425 validation ap= 0.93137
# Epoch: 0128 training loss= 0.00277 time= 6.43076
# validation roc= 0.92462 validation ap= 0.93167
# Epoch: 0129 training loss= 0.00277 time= 6.54918
# validation roc= 0.92513 validation ap= 0.93210
# Epoch: 0130 training loss= 0.00277 time= 6.46516
# validation roc= 0.92567 validation ap= 0.93254
# Epoch: 0131 training loss= 0.00277 time= 6.63737
# validation roc= 0.92610 validation ap= 0.93293
# Epoch: 0132 training loss= 0.00276 time= 6.59892
# validation roc= 0.92645 validation ap= 0.93324
# Epoch: 0133 training loss= 0.00276 time= 6.57197
# validation roc= 0.92701 validation ap= 0.93372
# Epoch: 0134 training loss= 0.00276 time= 6.41078
# validation roc= 0.92768 validation ap= 0.93426
# Epoch: 0135 training loss= 0.00276 time= 6.65676
# validation roc= 0.92831 validation ap= 0.93480
# Epoch: 0136 training loss= 0.00275 time= 6.57424
# validation roc= 0.92908 validation ap= 0.93546
# Epoch: 0137 training loss= 0.00275 time= 6.61844
# validation roc= 0.92985 validation ap= 0.93611
# Epoch: 0138 training loss= 0.00275 time= 6.47758
# validation roc= 0.93058 validation ap= 0.93674
# Epoch: 0139 training loss= 0.00274 time= 6.50418
# validation roc= 0.93128 validation ap= 0.93733
# Epoch: 0140 training loss= 0.00274 time= 6.48218
# validation roc= 0.93230 validation ap= 0.93822
# Epoch: 0141 training loss= 0.00273 time= 6.46277
# validation roc= 0.93355 validation ap= 0.93931
# Epoch: 0142 training loss= 0.00273 time= 6.57491
# validation roc= 0.93465 validation ap= 0.94032
# Epoch: 0143 training loss= 0.00272 time= 6.51570
# validation roc= 0.93559 validation ap= 0.94115
# Epoch: 0144 training loss= 0.00272 time= 6.52433
# validation roc= 0.93688 validation ap= 0.94227
# Epoch: 0145 training loss= 0.00271 time= 6.43422
# validation roc= 0.93834 validation ap= 0.94356
# Epoch: 0146 training loss= 0.00270 time= 6.57880
# validation roc= 0.93960 validation ap= 0.94469
# Epoch: 0147 training loss= 0.00270 time= 6.48582
# validation roc= 0.94094 validation ap= 0.94586
# Epoch: 0148 training loss= 0.00269 time= 6.99037
# validation roc= 0.94261 validation ap= 0.94732
# Epoch: 0149 training loss= 0.00268 time= 6.56338
# validation roc= 0.94413 validation ap= 0.94864
# Epoch: 0150 training loss= 0.00267 time= 6.51464
# validation roc= 0.94557 validation ap= 0.94990
# Epoch: 0151 training loss= 0.00266 time= 6.65569
# validation roc= 0.94686 validation ap= 0.95104
# Epoch: 0152 training loss= 0.00265 time= 6.60422
# validation roc= 0.94793 validation ap= 0.95187
# Epoch: 0153 training loss= 0.00265 time= 6.51297
# validation roc= 0.94846 validation ap= 0.95215
# Epoch: 0154 training loss= 0.00264 time= 6.58206
# validation roc= 0.94898 validation ap= 0.95249
# Epoch: 0155 training loss= 0.00264 time= 6.48650
# validation roc= 0.94867 validation ap= 0.95202
# Epoch: 0156 training loss= 0.00264 time= 6.63082
# validation roc= 0.94900 validation ap= 0.95226
# Epoch: 0157 training loss= 0.00264 time= 6.45296
# validation roc= 0.94932 validation ap= 0.95248
# Epoch: 0158 training loss= 0.00264 time= 6.62748
# validation roc= 0.94960 validation ap= 0.95268
# Epoch: 0159 training loss= 0.00263 time= 6.58458
# validation roc= 0.95058 validation ap= 0.95360
# Epoch: 0160 training loss= 0.00263 time= 6.25383
# validation roc= 0.95164 validation ap= 0.95459
# Epoch: 0161 training loss= 0.00262 time= 6.42140
# validation roc= 0.95250 validation ap= 0.95541
# Epoch: 0162 training loss= 0.00261 time= 6.55676
# validation roc= 0.95333 validation ap= 0.95624
# Epoch: 0163 training loss= 0.00261 time= 6.61361
# validation roc= 0.95391 validation ap= 0.95684
# Epoch: 0164 training loss= 0.00260 time= 6.62857
# validation roc= 0.95445 validation ap= 0.95733
# Epoch: 0165 training loss= 0.00260 time= 6.55427
# validation roc= 0.95504 validation ap= 0.95790
# Epoch: 0166 training loss= 0.00260 time= 6.55602
# validation roc= 0.95526 validation ap= 0.95806
# Epoch: 0167 training loss= 0.00259 time= 6.59629
# validation roc= 0.95551 validation ap= 0.95822
# Epoch: 0168 training loss= 0.00259 time= 6.57600
# validation roc= 0.95553 validation ap= 0.95822
# Epoch: 0169 training loss= 0.00258 time= 6.61271
# validation roc= 0.95560 validation ap= 0.95823
# Epoch: 0170 training loss= 0.00258 time= 6.58764
# validation roc= 0.95547 validation ap= 0.95804
# Epoch: 0171 training loss= 0.00258 time= 6.52798
# validation roc= 0.95545 validation ap= 0.95790
# Epoch: 0172 training loss= 0.00258 time= 6.63035
# validation roc= 0.95548 validation ap= 0.95785
# Epoch: 0173 training loss= 0.00258 time= 6.30290
# validation roc= 0.95531 validation ap= 0.95766
# Epoch: 0174 training loss= 0.00258 time= 6.71741
# validation roc= 0.95522 validation ap= 0.95755
# Epoch: 0175 training loss= 0.00257 time= 6.59342
# validation roc= 0.95563 validation ap= 0.95793
# Epoch: 0176 training loss= 0.00257 time= 6.61197
# validation roc= 0.95565 validation ap= 0.95794
# Epoch: 0177 training loss= 0.00257 time= 6.51896
# validation roc= 0.95592 validation ap= 0.95820
# Epoch: 0178 training loss= 0.00257 time= 6.62020
# validation roc= 0.95652 validation ap= 0.95876
# Epoch: 0179 training loss= 0.00257 time= 6.45246
# validation roc= 0.95670 validation ap= 0.95892
# Epoch: 0180 training loss= 0.00256 time= 6.56034
# validation roc= 0.95698 validation ap= 0.95921
# Epoch: 0181 training loss= 0.00256 time= 6.54974
# validation roc= 0.95738 validation ap= 0.95959
# Epoch: 0182 training loss= 0.00256 time= 6.54819
# validation roc= 0.95773 validation ap= 0.95988
# Epoch: 0183 training loss= 0.00256 time= 6.54514
# validation roc= 0.95795 validation ap= 0.96008
# Epoch: 0184 training loss= 0.00255 time= 6.54953
# validation roc= 0.95822 validation ap= 0.96036
# Epoch: 0185 training loss= 0.00255 time= 6.43241
# validation roc= 0.95835 validation ap= 0.96048
# Epoch: 0186 training loss= 0.00255 time= 6.56822
# validation roc= 0.95849 validation ap= 0.96061
# Epoch: 0187 training loss= 0.00255 time= 6.50822
# validation roc= 0.95881 validation ap= 0.96091
# Epoch: 0188 training loss= 0.00255 time= 6.58785
# validation roc= 0.95881 validation ap= 0.96090
# Epoch: 0189 training loss= 0.00255 time= 6.52976
# validation roc= 0.95892 validation ap= 0.96097
# Epoch: 0190 training loss= 0.00254 time= 6.59210
# validation roc= 0.95917 validation ap= 0.96120
# Epoch: 0191 training loss= 0.00254 time= 6.52406
# validation roc= 0.95898 validation ap= 0.96112
# Epoch: 0192 training loss= 0.00254 time= 6.60195
# validation roc= 0.95913 validation ap= 0.96125
# Epoch: 0193 training loss= 0.00254 time= 6.59315
# validation roc= 0.95946 validation ap= 0.96149
# Epoch: 0194 training loss= 0.00254 time= 6.59518
# validation roc= 0.95934 validation ap= 0.96144
# Epoch: 0195 training loss= 0.00254 time= 6.54746
# validation roc= 0.95950 validation ap= 0.96157
# Epoch: 0196 training loss= 0.00253 time= 6.59974
# validation roc= 0.95986 validation ap= 0.96187
# Epoch: 0197 training loss= 0.00253 time= 6.61254
# validation roc= 0.95967 validation ap= 0.96172
# Epoch: 0198 training loss= 0.00253 time= 6.55189
# validation roc= 0.95987 validation ap= 0.96189
# Epoch: 0199 training loss= 0.00253 time= 6.53853
# validation roc= 0.96010 validation ap= 0.96206
# Epoch: 0200 training loss= 0.00253 time= 6.62627
# validation roc= 0.95995 validation ap= 0.96197
# testing roc= 0.95869 testing ap= 0.95955

# %% [markdown]
# # Visulization

# %%
emb=emb
labels=load_label(dataset,data_path)

X_embedded = TSNE(n_components=2, init='pca', random_state=seed).fit_transform(emb)

cs=['orange','blue','darkcyan','fuchsia','chocolate','dodgerblue','aqua','green','red','purple']
markers=['o','+','v','2','s','X','d','>','*','<']

fig, ax = plt.subplots(1,figsize=(8,6))
for i in np.arange(X_embedded.shape[0]):
    scatter = ax.scatter(X_embedded[i,0],X_embedded[i,1],label=labels[i],marker=markers[labels[i]],color=cs[labels[i]], s=10, alpha = 1)
plt.xticks([])
plt.yticks([])
plt.xlabel("")
plt.ylabel("")
plt.axis('off')
plt.show()
