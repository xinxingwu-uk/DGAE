# %% [markdown]
# # Import libraries

# %%
import numpy as np
import random as rn
import os
from keras import backend as K
import  tensorflow.compat.v1  as tf
tf.disable_v2_behavior() 
import tensorflow as tf

#--------------------------------------------------------------------------------------------------------------------
# Reproducible
seed=0
os.environ['PYTHONHASHSEED'] = str(seed)

np.random.seed(seed)
rn.seed(seed)
session_conf =tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
tf.compat.v1.set_random_seed(seed)
#--------------------------------------------------------------------------------------------------------------------

import scipy.sparse as sp
import time
import pandas as pd
import sys

from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

sys.path.append(r"../../")

from dgae_alpha_beta.evaluation import get_roc_score
from dgae_alpha_beta.input_data import load_data, load_label
from dgae_alpha_beta.model import *
from dgae_alpha_beta.optimizer import *
from dgae_alpha_beta.preprocessing import *
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.8/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %% [markdown]
# # Parameters setting

# %%
layers_no=6
data_path="../../Datasets/"
path_now="./log/"

dataset='pubmed'
model_name='DGAE_alpha_beta_feature'

dropout=0.0
epochs=200
features_used=True
learning_rate=0.01
nb_run=1
prop_val=5
prop_test=10
validation=True
verbose=True

# %% [markdown]
# # Load data

# %%
adj_init, features_init = load_data(dataset,data_path)
num_adj=adj_init.shape[1]

# %% [markdown]
# # Training and testing

# %%
loss_coeff_adj=0.001
loss_coeff_AE=2.0
results_output_path = path_now+model_name+"/"
mkdir(results_output_path)

for seed_i in np.arange(nb_run):
    
    seed=seed_i
    lost_list=[]
    roc_list=[]
    ap_list=[]
    mean_time=[]
    
    adj, val_edges, val_edges_false, test_edges, test_edges_false =mask_test_edges(adj_init, seed,prop_test, prop_val)
                
    t_start = time.time()

    if features_used:
        features = features_init
    
    num_nodes = adj.shape[0]

    if not features_used:
        features = sp.identity(adj.shape[0])

    features = sparse_to_tuple(features)
    num_features = features[2][1]
    features_nonzero = features[1].shape[0]
        
    placeholders = {
        'features': tf.sparse_placeholder(tf.float32),
        'adj': tf.sparse_placeholder(tf.float32),
        'adj_orig': tf.sparse_placeholder(tf.float32),
        'dropout': tf.placeholder_with_default(0., shape = ())
    }

#--------------------------------------------------------------------------------------------------------------------
# Create model
    if model_name=='DGAE_alpha_beta_feature':
        model = DGAE_alpha_beta_feature(placeholders, layers_no,num_features, features_nonzero)
    elif model_name=='DGAE_alpha_beta_no_feature':
        model=DGAE_alpha_beta_no_feature(placeholders, layers_no,num_features, num_adj,features_nonzero)
    elif model_name == 'deep_gcn_ae':
        model = DeepGCNModelAE(placeholders, layers_no,num_features, features_nonzero)
    elif model_name == 'linear_ae':
        model = LinearModelAE(placeholders, num_features, features_nonzero)
    elif model_name == 'gcn_ae':
        model = GCNModelAE(placeholders, num_features, features_nonzero)
    else:
        raise ValueError('Undefined model!')

    pos_weight = float(adj.shape[0] * adj.shape[0] - adj.sum()) / adj.sum()
    norm = adj.shape[0] * adj.shape[0] / float((adj.shape[0] * adj.shape[0]- adj.sum()) * 2)
    
    with tf.name_scope('optimizer'):
        if model_name in ('DGAE_alpha_beta_feature'):
            opt =OptimizerAE_FeatureReconstrution(preds_adj = model.reconstructions,\
                                                  preds_Features=model.feature_reconstruction,\
                                                  labels_adj = tf.reshape(tf.sparse_tensor_to_dense(placeholders['adj_orig'],\
                                                                                                    validate_indices = False), [-1]),\
                                                  labels_Features=placeholders['features'],\
                                                  labels_adj_rec=placeholders['adj'],\
                                                  loss_coeff_adj=loss_coeff_adj,\
                                                  loss_coeff_AE=loss_coeff_AE,\
                                                  pos_weight = pos_weight,\
                                                  norm = norm)
                
        elif model_name in ('DGAE_alpha_beta_no_feature'):
            opt =OptimizerAE_AdjReconstrution(preds_adj = model.reconstructions,\
                                              preds_adj_rec=model.adj_reconstruction,\
                                              labels_adj = tf.reshape(tf.sparse_tensor_to_dense(placeholders['adj_orig'],
                                                                                                validate_indices = False), [-1]),\
                                              labels_Features=placeholders['features'],\
                                              labels_adj_rec=placeholders['adj'],\
                                              loss_coeff_adj=loss_coeff_adj,\
                                              loss_coeff_AE=loss_coeff_AE,\
                                              pos_weight = pos_weight,\
                                              norm = norm)
            
        elif model_name in ('gcn_ae', 'linear_ae', 'deep_gcn_ae'):
            opt = OptimizerAE(preds = model.reconstructions,\
                              labels = tf.reshape(tf.sparse_tensor_to_dense(placeholders['adj_orig'],\
                                                                            validate_indices = False), [-1]),
                              pos_weight = pos_weight,
                              norm = norm)

    adj_norm = preprocess_graph(adj)
    adj_label = sparse_to_tuple(adj + sp.eye(adj.shape[0]))

    sess = tf.Session()
    sess.run(tf.global_variables_initializer())
    
    for epoch in range(epochs):
        t = time.time()
        feed_dict = construct_feed_dict(adj_norm, adj_label, features,placeholders)
        feed_dict.update({placeholders['dropout']: dropout})
        outs = sess.run([opt.opt_op, opt.cost, opt.accuracy],feed_dict = feed_dict)
        avg_cost = outs[1]
        if verbose:
            lost_list.append(avg_cost)
            print("Epoch:", '%04d' % (epoch + 1), "training loss=", "{:.5f}".format(avg_cost),"time=", "{:.5f}".format(time.time() - t))
                    
            if validation:
                feed_dict.update({placeholders['dropout']: 0})
                emb = sess.run(model.z_mean, feed_dict = feed_dict)
                feed_dict.update({placeholders['dropout']: dropout})
                val_roc, val_ap = get_roc_score(val_edges, val_edges_false, emb)
                roc_list.append(val_roc)
                ap_list.append(val_ap)
                print("validation roc=", "{:.5f}".format(val_roc), "validation ap=", "{:.5f}".format(val_ap))

    emb = sess.run(model.z_mean, feed_dict = feed_dict)   
    mean_time.append(time.time() - t_start)
    
    roc_score, ap_score = get_roc_score(test_edges, test_edges_false, emb)
    print("testing roc=", "{:.5f}".format(roc_score), "testing ap=", "{:.5f}".format(ap_score))
    
    roc_list.append(roc_score)
    ap_list.append(ap_score)
    
    mean_time_=np.array(mean_time)
    write_to_csv(mean_time_.reshape(1,len(mean_time_)),results_output_path+"layers_"+str(layers_no)+"_time.csv")

    roc_list_=np.array(roc_list)
    write_to_csv(roc_list_.reshape(1,len(roc_list_)),results_output_path+"layers_"+str(layers_no)+"_roc.csv")

    ap_list_=np.array(ap_list)
    write_to_csv(ap_list_.reshape(1,len(ap_list_)),results_output_path+"layers_"+str(layers_no)+"_ap.csv")
# Out:
# Successful!
# WARNING:tensorflow:From /usr/local/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:201: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:201: calling weighted_cross_entropy_with_logits (from tensorflow.python.ops.nn_impl) with targets is deprecated and will be removed in a future version.
# Instructions for updating:
# targets is deprecated, use labels instead
# Epoch: 0001 training loss= 0.00105 time= 12.52269
# validation roc= 0.83685 validation ap= 0.82732
# Epoch: 0002 training loss= 0.00105 time= 5.73552
# validation roc= 0.84167 validation ap= 0.83913
# Epoch: 0003 training loss= 0.00104 time= 5.88073
# validation roc= 0.84580 validation ap= 0.84806
# Epoch: 0091 training loss= 0.00059 time= 5.70016
# validation roc= 0.96077 validation ap= 0.96208
# Epoch: 0092 training loss= 0.00059 time= 5.56727
# validation roc= 0.96096 validation ap= 0.96221
# Epoch: 0093 training loss= 0.00059 time= 5.73717
# validation roc= 0.96105 validation ap= 0.96226
# Epoch: 0094 training loss= 0.00059 time= 5.78733
# validation roc= 0.96103 validation ap= 0.96222
# Epoch: 0095 training loss= 0.00059 time= 5.66097
# validation roc= 0.96102 validation ap= 0.96221
# Epoch: 0096 training loss= 0.00059 time= 5.83631
# validation roc= 0.96099 validation ap= 0.96217
# Epoch: 0097 training loss= 0.00058 time= 5.90438
# validation roc= 0.96097 validation ap= 0.96212
# Epoch: 0098 training loss= 0.00058 time= 5.80359
# validation roc= 0.96098 validation ap= 0.96214
# Epoch: 0099 training loss= 0.00058 time= 5.73007
# validation roc= 0.96106 validation ap= 0.96221
# Epoch: 0100 training loss= 0.00058 time= 5.65686
# validation roc= 0.96117 validation ap= 0.96228
# Epoch: 0101 training loss= 0.00058 time= 5.72603
# validation roc= 0.96131 validation ap= 0.96239
# Epoch: 0102 training loss= 0.00058 time= 5.75087
# validation roc= 0.96144 validation ap= 0.96247
# Epoch: 0103 training loss= 0.00058 time= 5.60292
# validation roc= 0.96157 validation ap= 0.96255
# Epoch: 0104 training loss= 0.00058 time= 6.00042
# validation roc= 0.96171 validation ap= 0.96264
# Epoch: 0105 training loss= 0.00058 time= 5.49945
# validation roc= 0.96186 validation ap= 0.96272
# Epoch: 0106 training loss= 0.00058 time= 5.74494
# validation roc= 0.96199 validation ap= 0.96280
# Epoch: 0107 training loss= 0.00058 time= 5.62124
# validation roc= 0.96209 validation ap= 0.96285
# Epoch: 0108 training loss= 0.00058 time= 5.63349
# validation roc= 0.96221 validation ap= 0.96294
# Epoch: 0109 training loss= 0.00058 time= 5.64811
# validation roc= 0.96233 validation ap= 0.96306
# Epoch: 0110 training loss= 0.00058 time= 5.51722
# validation roc= 0.96249 validation ap= 0.96319
# Epoch: 0111 training loss= 0.00058 time= 5.70691
# validation roc= 0.96265 validation ap= 0.96334
# Epoch: 0112 training loss= 0.00058 time= 5.67800
# validation roc= 0.96276 validation ap= 0.96345
# Epoch: 0113 training loss= 0.00058 time= 5.64414
# validation roc= 0.96281 validation ap= 0.96353
# Epoch: 0114 training loss= 0.00058 time= 5.60528
# validation roc= 0.96289 validation ap= 0.96360
# Epoch: 0115 training loss= 0.00057 time= 5.66689
# validation roc= 0.96296 validation ap= 0.96368
# Epoch: 0116 training loss= 0.00057 time= 5.82704
# validation roc= 0.96296 validation ap= 0.96372
# Epoch: 0117 training loss= 0.00057 time= 5.70759
# validation roc= 0.96299 validation ap= 0.96376
# Epoch: 0118 training loss= 0.00057 time= 5.90362
# validation roc= 0.96302 validation ap= 0.96377
# Epoch: 0119 training loss= 0.00057 time= 5.77037
# validation roc= 0.96301 validation ap= 0.96376
# Epoch: 0120 training loss= 0.00057 time= 5.78167
# validation roc= 0.96296 validation ap= 0.96374
# Epoch: 0121 training loss= 0.00057 time= 5.72842
# validation roc= 0.96292 validation ap= 0.96369
# Epoch: 0122 training loss= 0.00057 time= 5.85604
# validation roc= 0.96280 validation ap= 0.96355
# Epoch: 0123 training loss= 0.00057 time= 5.64966
# validation roc= 0.96263 validation ap= 0.96341
# Epoch: 0124 training loss= 0.00057 time= 5.66358
# validation roc= 0.96236 validation ap= 0.96317
# Epoch: 0125 training loss= 0.00057 time= 5.83278
# validation roc= 0.96198 validation ap= 0.96283
# Epoch: 0126 training loss= 0.00057 time= 5.68807
# validation roc= 0.96153 validation ap= 0.96236
# Epoch: 0127 training loss= 0.00057 time= 5.78003
# validation roc= 0.96107 validation ap= 0.96192
# Epoch: 0128 training loss= 0.00057 time= 5.89692
# validation roc= 0.96059 validation ap= 0.96148
# Epoch: 0129 training loss= 0.00057 time= 5.71879
# validation roc= 0.96015 validation ap= 0.96106
# Epoch: 0130 training loss= 0.00056 time= 5.63006
# validation roc= 0.95990 validation ap= 0.96083
# Epoch: 0131 training loss= 0.00056 time= 5.66571
# validation roc= 0.95989 validation ap= 0.96083
# Epoch: 0132 training loss= 0.00056 time= 5.70018
# validation roc= 0.96015 validation ap= 0.96109
# Epoch: 0133 training loss= 0.00056 time= 5.55936
# validation roc= 0.96056 validation ap= 0.96150
# Epoch: 0134 training loss= 0.00056 time= 5.67900
# validation roc= 0.96111 validation ap= 0.96205
# Epoch: 0135 training loss= 0.00056 time= 5.64764
# validation roc= 0.96173 validation ap= 0.96269
# Epoch: 0136 training loss= 0.00056 time= 5.76080
# validation roc= 0.96229 validation ap= 0.96331
# Epoch: 0137 training loss= 0.00056 time= 5.80259
# validation roc= 0.96280 validation ap= 0.96382
# Epoch: 0138 training loss= 0.00056 time= 16.72060
# validation roc= 0.96319 validation ap= 0.96424
# Epoch: 0139 training loss= 0.00056 time= 10.41718
# validation roc= 0.96352 validation ap= 0.96460
# Epoch: 0140 training loss= 0.00056 time= 8.20825
# validation roc= 0.96373 validation ap= 0.96485
# Epoch: 0141 training loss= 0.00056 time= 6.73076
# validation roc= 0.96382 validation ap= 0.96494
# Epoch: 0142 training loss= 0.00056 time= 6.68675
# validation roc= 0.96379 validation ap= 0.96492
# Epoch: 0143 training loss= 0.00056 time= 10.60167
# validation roc= 0.96371 validation ap= 0.96484
# Epoch: 0144 training loss= 0.00056 time= 9.84918
# validation roc= 0.96349 validation ap= 0.96461
# Epoch: 0145 training loss= 0.00056 time= 5.82515
# validation roc= 0.96337 validation ap= 0.96449
# Epoch: 0146 training loss= 0.00055 time= 5.83386
# validation roc= 0.96288 validation ap= 0.96409
# Epoch: 0147 training loss= 0.00055 time= 5.81573
# validation roc= 0.96340 validation ap= 0.96457
# Epoch: 0148 training loss= 0.00055 time= 5.78809
# validation roc= 0.96140 validation ap= 0.96299
# Epoch: 0149 training loss= 0.00056 time= 5.78438
# validation roc= 0.96425 validation ap= 0.96540
# Epoch: 0150 training loss= 0.00056 time= 5.92753
# validation roc= 0.96102 validation ap= 0.96276
# Epoch: 0151 training loss= 0.00056 time= 5.83057
# validation roc= 0.96329 validation ap= 0.96499
# Epoch: 0152 training loss= 0.00055 time= 5.92149
# validation roc= 0.96499 validation ap= 0.96642
# Epoch: 0153 training loss= 0.00056 time= 6.64051
# validation roc= 0.96313 validation ap= 0.96513
# Epoch: 0154 training loss= 0.00055 time= 13.56916
# validation roc= 0.96256 validation ap= 0.96483
# Epoch: 0155 training loss= 0.00055 time= 9.49653
# validation roc= 0.96474 validation ap= 0.96661
# Epoch: 0156 training loss= 0.00055 time= 9.49781
# validation roc= 0.96481 validation ap= 0.96674
# Epoch: 0157 training loss= 0.00055 time= 10.00491
# validation roc= 0.96306 validation ap= 0.96558
# Epoch: 0158 training loss= 0.00055 time= 6.39916
# validation roc= 0.96329 validation ap= 0.96583
# Epoch: 0159 training loss= 0.00055 time= 6.57973
# validation roc= 0.96449 validation ap= 0.96677
# Epoch: 0160 training loss= 0.00055 time= 9.80856
# validation roc= 0.96416 validation ap= 0.96666
# Epoch: 0161 training loss= 0.00055 time= 6.09303
# validation roc= 0.96312 validation ap= 0.96596
# Epoch: 0162 training loss= 0.00055 time= 8.08248
# validation roc= 0.96357 validation ap= 0.96628
# Epoch: 0163 training loss= 0.00055 time= 6.18639
# validation roc= 0.96423 validation ap= 0.96684
# Epoch: 0164 training loss= 0.00055 time= 9.37785
# validation roc= 0.96371 validation ap= 0.96652
# Epoch: 0165 training loss= 0.00055 time= 9.67263
# validation roc= 0.96327 validation ap= 0.96622
# Epoch: 0166 training loss= 0.00055 time= 9.74220
# validation roc= 0.96385 validation ap= 0.96677
# Epoch: 0167 training loss= 0.00055 time= 9.84872
# validation roc= 0.96395 validation ap= 0.96695
# Epoch: 0168 training loss= 0.00055 time= 5.78930
# validation roc= 0.96336 validation ap= 0.96653
# Epoch: 0169 training loss= 0.00054 time= 5.91711
# validation roc= 0.96361 validation ap= 0.96682
# Epoch: 0170 training loss= 0.00054 time= 5.91137
# validation roc= 0.96409 validation ap= 0.96736
# Epoch: 0171 training loss= 0.00054 time= 5.84041
# validation roc= 0.96382 validation ap= 0.96726
# Epoch: 0172 training loss= 0.00054 time= 5.82339
# validation roc= 0.96382 validation ap= 0.96731
# Epoch: 0173 training loss= 0.00054 time= 5.74886
# validation roc= 0.96432 validation ap= 0.96787
# Epoch: 0174 training loss= 0.00054 time= 5.89865
# validation roc= 0.96436 validation ap= 0.96806
# Epoch: 0175 training loss= 0.00054 time= 6.01845
# validation roc= 0.96424 validation ap= 0.96801
# Epoch: 0176 training loss= 0.00054 time= 5.75694
# validation roc= 0.96445 validation ap= 0.96825
# Epoch: 0177 training loss= 0.00054 time= 5.81294
# validation roc= 0.96472 validation ap= 0.96860
# Epoch: 0178 training loss= 0.00054 time= 5.74834
# validation roc= 0.96446 validation ap= 0.96845
# Epoch: 0179 training loss= 0.00054 time= 5.77596
# validation roc= 0.96459 validation ap= 0.96860
# Epoch: 0180 training loss= 0.00054 time= 5.96183
# validation roc= 0.96458 validation ap= 0.96867
# Epoch: 0181 training loss= 0.00054 time= 5.90006
# validation roc= 0.96462 validation ap= 0.96875
# Epoch: 0182 training loss= 0.00054 time= 5.93319
# validation roc= 0.96416 validation ap= 0.96840
# Epoch: 0183 training loss= 0.00054 time= 5.79892
# validation roc= 0.96457 validation ap= 0.96864
# Epoch: 0184 training loss= 0.00054 time= 5.87545
# validation roc= 0.96369 validation ap= 0.96813
# Epoch: 0185 training loss= 0.00054 time= 6.13515
# validation roc= 0.96451 validation ap= 0.96850
# Epoch: 0186 training loss= 0.00054 time= 5.85300
# validation roc= 0.96390 validation ap= 0.96822
# Epoch: 0187 training loss= 0.00054 time= 5.85368
# validation roc= 0.96439 validation ap= 0.96863
# Epoch: 0188 training loss= 0.00054 time= 5.96511
# validation roc= 0.96473 validation ap= 0.96869
# Epoch: 0189 training loss= 0.00054 time= 5.61672
# validation roc= 0.96417 validation ap= 0.96838
# Epoch: 0190 training loss= 0.00054 time= 5.62312
# validation roc= 0.96474 validation ap= 0.96886
# Epoch: 0191 training loss= 0.00054 time= 5.72043
# validation roc= 0.96489 validation ap= 0.96881
# Epoch: 0192 training loss= 0.00054 time= 5.57213
# validation roc= 0.96454 validation ap= 0.96876
# Epoch: 0193 training loss= 0.00054 time= 5.58905
# validation roc= 0.96478 validation ap= 0.96898
# Epoch: 0194 training loss= 0.00054 time= 5.71947
# validation roc= 0.96471 validation ap= 0.96877
# Epoch: 0195 training loss= 0.00054 time= 6.42014
# validation roc= 0.96472 validation ap= 0.96911
# Epoch: 0196 training loss= 0.00054 time= 5.67943
# validation roc= 0.96463 validation ap= 0.96898
# Epoch: 0197 training loss= 0.00054 time= 5.44592
# validation roc= 0.96489 validation ap= 0.96910
# Epoch: 0198 training loss= 0.00054 time= 5.66197
# validation roc= 0.96487 validation ap= 0.96933
# Epoch: 0199 training loss= 0.00053 time= 5.67228
# validation roc= 0.96459 validation ap= 0.96900
# Epoch: 0200 training loss= 0.00053 time= 5.72713
# validation roc= 0.96515 validation ap= 0.96941
# testing roc= 0.96405 testing ap= 0.96802

# %% [markdown]
# # Visulization

# %%
emb=emb
labels=load_label(dataset,data_path)

X_embedded = TSNE(n_components=2, init='pca', random_state=seed).fit_transform(emb)

cs=['orange','blue','darkcyan','fuchsia','chocolate','dodgerblue','aqua','green','red','purple']
markers=['o','+','v','2','s','X','d','>','*','<']

fig, ax = plt.subplots(1,figsize=(8,6))
for i in np.arange(X_embedded.shape[0]):
    scatter = ax.scatter(X_embedded[i,0],X_embedded[i,1],label=labels[i],marker=markers[labels[i]],color=cs[labels[i]], s=10, alpha = 1)
plt.xticks([])
plt.yticks([])
plt.xlabel("")
plt.ylabel("")
plt.axis('off')
plt.show()
