# %% [markdown]
# # Import libraries

# %%
import numpy as np
import random as rn
import os
from keras import backend as K
import  tensorflow.compat.v1  as tf
tf.disable_v2_behavior() 
import tensorflow as tf

#--------------------------------------------------------------------------------------------------------------------
# Reproducible
seed=0
os.environ['PYTHONHASHSEED'] = str(seed)

np.random.seed(seed)
rn.seed(seed)
session_conf =tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
tf.compat.v1.set_random_seed(seed)
#--------------------------------------------------------------------------------------------------------------------

import scipy.sparse as sp
import time
import pandas as pd
import sys

from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

sys.path.append(r"../../")

from dgae_alpha_beta.evaluation import get_roc_score
from dgae_alpha_beta.input_data import load_data, load_label
from dgae_alpha_beta.model import *
from dgae_alpha_beta.optimizer import *
from dgae_alpha_beta.preprocessing import *
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.8/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %% [markdown]
# # Parameters setting

# %%
layers_no=2
data_path="../../Datasets/"
path_now="./log/"

dataset='cora'
model_name='gcn_ae'

dropout=0.0
epochs=200
features_used=True
learning_rate=0.01
nb_run=1
prop_val=5
prop_test=10
validation=True
verbose=True

# %% [markdown]
# # Load data

# %%
adj_init, features_init = load_data(dataset,data_path)
num_adj=adj_init.shape[1]

# %% [markdown]
# # Training and testing

# %%
#loss_coeff_adj=0.001
#loss_coeff_AE=0.05
results_output_path = path_now+model_name+"/"
mkdir(results_output_path)

for seed_i in np.arange(nb_run):
    
    seed=seed_i
    lost_list=[]
    roc_list=[]
    ap_list=[]
    mean_time=[]
    
    adj, val_edges, val_edges_false, test_edges, test_edges_false =mask_test_edges(adj_init, seed,prop_test, prop_val)
                
    t_start = time.time()

    if features_used:
        features = features_init
    
    num_nodes = adj.shape[0]

    if not features_used:
        features = sp.identity(adj.shape[0])

    features = sparse_to_tuple(features)
    num_features = features[2][1]
    features_nonzero = features[1].shape[0]
        
    placeholders = {
        'features': tf.sparse_placeholder(tf.float32),
        'adj': tf.sparse_placeholder(tf.float32),
        'adj_orig': tf.sparse_placeholder(tf.float32),
        'dropout': tf.placeholder_with_default(0., shape = ())
    }

#--------------------------------------------------------------------------------------------------------------------
# Create model
    if model_name=='DGAE_alpha_beta_feature':
        model = DGAE_alpha_beta_feature(placeholders, layers_no,num_features, features_nonzero)
    elif model_name=='DGAE_alpha_beta_no_feature':
        model=DGAE_alpha_beta_no_feature(placeholders, layers_no,num_features, num_adj,features_nonzero)
    elif model_name == 'deep_gcn_ae':
        model = DeepGCNModelAE(placeholders, layers_no,num_features, features_nonzero)
    elif model_name == 'linear_ae':
        model = LinearModelAE(placeholders, num_features, features_nonzero)
    elif model_name == 'gcn_ae':
        model = GCNModelAE(placeholders, num_features, features_nonzero)
    else:
        raise ValueError('Undefined model!')

    pos_weight = float(adj.shape[0] * adj.shape[0] - adj.sum()) / adj.sum()
    norm = adj.shape[0] * adj.shape[0] / float((adj.shape[0] * adj.shape[0]- adj.sum()) * 2)
    
    with tf.name_scope('optimizer'):
        if model_name in ('DGAE_alpha_beta_feature'):
            opt =OptimizerAE_FeatureReconstrution(preds_adj = model.reconstructions,\
                                                  preds_Features=model.feature_reconstruction,\
                                                  labels_adj = tf.reshape(tf.sparse_tensor_to_dense(placeholders['adj_orig'],\
                                                                                                    validate_indices = False), [-1]),\
                                                  labels_Features=placeholders['features'],\
                                                  labels_adj_rec=placeholders['adj'],\
                                                  loss_coeff_adj=loss_coeff_adj,\
                                                  loss_coeff_AE=loss_coeff_AE,\
                                                  pos_weight = pos_weight,\
                                                  norm = norm)
                
        elif model_name in ('DGAE_alpha_beta_no_feature'):
            opt =OptimizerAE_AdjReconstrution(preds_adj = model.reconstructions,\
                                              preds_adj_rec=model.adj_reconstruction,\
                                              labels_adj = tf.reshape(tf.sparse_tensor_to_dense(placeholders['adj_orig'],
                                                                                                validate_indices = False), [-1]),\
                                              labels_Features=placeholders['features'],\
                                              labels_adj_rec=placeholders['adj'],\
                                              loss_coeff_adj=loss_coeff_adj,\
                                              loss_coeff_AE=loss_coeff_AE,\
                                              pos_weight = pos_weight,\
                                              norm = norm)
            
        elif model_name in ('gcn_ae', 'linear_ae', 'deep_gcn_ae'):
            opt = OptimizerAE(preds = model.reconstructions,\
                              labels = tf.reshape(tf.sparse_tensor_to_dense(placeholders['adj_orig'],\
                                                                            validate_indices = False), [-1]),
                              pos_weight = pos_weight,
                              norm = norm)

    adj_norm = preprocess_graph(adj)
    adj_label = sparse_to_tuple(adj + sp.eye(adj.shape[0]))

    sess = tf.Session()
    sess.run(tf.global_variables_initializer())
    
    for epoch in range(epochs):
        t = time.time()
        feed_dict = construct_feed_dict(adj_norm, adj_label, features,placeholders)
        feed_dict.update({placeholders['dropout']: dropout})
        outs = sess.run([opt.opt_op, opt.cost, opt.accuracy],feed_dict = feed_dict)
        avg_cost = outs[1]
        if verbose:
            lost_list.append(avg_cost)
            print("Epoch:", '%04d' % (epoch + 1), "training loss=", "{:.5f}".format(avg_cost),"time=", "{:.5f}".format(time.time() - t))
                    
            if validation:
                feed_dict.update({placeholders['dropout']: 0})
                emb = sess.run(model.z_mean, feed_dict = feed_dict)
                feed_dict.update({placeholders['dropout']: dropout})
                val_roc, val_ap = get_roc_score(val_edges, val_edges_false, emb)
                roc_list.append(val_roc)
                ap_list.append(val_ap)
                print("validation roc=", "{:.5f}".format(val_roc), "validation ap=", "{:.5f}".format(val_ap))

    emb = sess.run(model.z_mean, feed_dict = feed_dict)   
    mean_time.append(time.time() - t_start)
    
    roc_score, ap_score = get_roc_score(test_edges, test_edges_false, emb)
    print("testing roc=", "{:.5f}".format(roc_score), "testing ap=", "{:.5f}".format(ap_score))
    
    roc_list.append(roc_score)
    ap_list.append(ap_score)
    
    mean_time_=np.array(mean_time)
    write_to_csv(mean_time_.reshape(1,len(mean_time_)),results_output_path+"layers_"+str(layers_no)+"_time.csv")

    roc_list_=np.array(roc_list)
    write_to_csv(roc_list_.reshape(1,len(roc_list_)),results_output_path+"layers_"+str(layers_no)+"_roc.csv")

    ap_list_=np.array(ap_list)
    write_to_csv(ap_list_.reshape(1,len(ap_list_)),results_output_path+"layers_"+str(layers_no)+"_ap.csv")
# Out:
# Successful!
# WARNING:tensorflow:From /usr/local/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:201: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:201: calling weighted_cross_entropy_with_logits (from tensorflow.python.ops.nn_impl) with targets is deprecated and will be removed in a future version.
# Instructions for updating:
# targets is deprecated, use labels instead
# Epoch: 0001 training loss= 0.78500 time= 0.23739
# validation roc= 0.69045 validation ap= 0.74539
# Epoch: 0002 training loss= 0.81033 time= 0.23111
# validation roc= 0.77866 validation ap= 0.78402
# Epoch: 0003 training loss= 0.73698 time= 0.28894
# validation roc= 0.70388 validation ap= 0.71991
# Epoch: 0004 training loss= 0.72921 time= 0.11444
# validation roc= 0.72557 validation ap= 0.73991
# Epoch: 0005 training loss= 0.72293 time= 0.14752
# validation roc= 0.76819 validation ap= 0.77151
# Epoch: 0006 training loss= 0.69534 time= 0.07440
# validation roc= 0.79073 validation ap= 0.78646
# Epoch: 0007 training loss= 0.67159 time= 0.10985
# validation roc= 0.80350 validation ap= 0.79484
# Epoch: 0008 training loss= 0.64573 time= 0.10238
# validation roc= 0.81713 validation ap= 0.80631
# Epoch: 0009 training loss= 0.61775 time= 0.10301
# validation roc= 0.82896 validation ap= 0.81817
# Epoch: 0010 training loss= 0.59550 time= 0.15129
# validation roc= 0.83971 validation ap= 0.83161
# Epoch: 0011 training loss= 0.58536 time= 0.17822
# validation roc= 0.84802 validation ap= 0.84265
# Epoch: 0012 training loss= 0.58021 time= 0.06005
# validation roc= 0.85157 validation ap= 0.84722
# Epoch: 0013 training loss= 0.56820 time= 0.15365
# validation roc= 0.84980 validation ap= 0.84372
# Epoch: 0014 training loss= 0.55601 time= 0.07524
# validation roc= 0.84455 validation ap= 0.83747
# Epoch: 0015 training loss= 0.55241 time= 0.12173
# validation roc= 0.84344 validation ap= 0.83759
# Epoch: 0016 training loss= 0.54801 time= 0.06690
# validation roc= 0.84836 validation ap= 0.84501
# Epoch: 0017 training loss= 0.54106 time= 0.11255
# validation roc= 0.85293 validation ap= 0.85012
# Epoch: 0018 training loss= 0.53549 time= 0.09815
# validation roc= 0.85845 validation ap= 0.85536
# Epoch: 0019 training loss= 0.52995 time= 0.12777
# validation roc= 0.86359 validation ap= 0.86040
# Epoch: 0020 training loss= 0.52386 time= 0.05744
# validation roc= 0.86714 validation ap= 0.86270
# Epoch: 0021 training loss= 0.51982 time= 0.14153
# validation roc= 0.86897 validation ap= 0.86275
# Epoch: 0022 training loss= 0.51774 time= 0.07873
# validation roc= 0.87085 validation ap= 0.86399
# Epoch: 0023 training loss= 0.51493 time= 0.07139
# validation roc= 0.87239 validation ap= 0.86605
# Epoch: 0024 training loss= 0.51021 time= 0.12842
# validation roc= 0.87499 validation ap= 0.87076
# Epoch: 0025 training loss= 0.50450 time= 0.06853
# validation roc= 0.87701 validation ap= 0.87487
# Epoch: 0026 training loss= 0.49930 time= 0.06911
# validation roc= 0.87766 validation ap= 0.87684
# Epoch: 0027 training loss= 0.49556 time= 0.07241
# validation roc= 0.87746 validation ap= 0.87690
# Epoch: 0028 training loss= 0.49318 time= 0.09726
# validation roc= 0.87731 validation ap= 0.87654
# Epoch: 0029 training loss= 0.49123 time= 0.09471
# validation roc= 0.87912 validation ap= 0.87813
# Epoch: 0030 training loss= 0.48907 time= 0.06880
# validation roc= 0.88106 validation ap= 0.87921
# Epoch: 0031 training loss= 0.48676 time= 0.11478
# validation roc= 0.88414 validation ap= 0.88192
# Epoch: 0032 training loss= 0.48484 time= 0.20755
# validation roc= 0.88693 validation ap= 0.88433
# Epoch: 0033 training loss= 0.48356 time= 0.11817
# validation roc= 0.89079 validation ap= 0.88798
# Epoch: 0034 training loss= 0.48240 time= 0.17904
# validation roc= 0.89354 validation ap= 0.89045
# Epoch: 0035 training loss= 0.48079 time= 0.08770
# validation roc= 0.89484 validation ap= 0.89193
# Epoch: 0036 training loss= 0.47872 time= 0.11836
# validation roc= 0.89623 validation ap= 0.89361
# Epoch: 0037 training loss= 0.47643 time= 0.10252
# validation roc= 0.89725 validation ap= 0.89542
# Epoch: 0038 training loss= 0.47422 time= 0.11319
# validation roc= 0.89757 validation ap= 0.89626
# Epoch: 0039 training loss= 0.47235 time= 0.10847
# validation roc= 0.89809 validation ap= 0.89716
# Epoch: 0040 training loss= 0.47089 time= 0.05688
# validation roc= 0.89915 validation ap= 0.89822
# Epoch: 0041 training loss= 0.46959 time= 0.07114
# validation roc= 0.90079 validation ap= 0.89971
# Epoch: 0042 training loss= 0.46817 time= 0.09314
# validation roc= 0.90328 validation ap= 0.90213
# Epoch: 0043 training loss= 0.46663 time= 0.05699
# validation roc= 0.90554 validation ap= 0.90473
# Epoch: 0044 training loss= 0.46528 time= 0.06810
# validation roc= 0.90678 validation ap= 0.90589
# Epoch: 0045 training loss= 0.46420 time= 0.05241
# validation roc= 0.90773 validation ap= 0.90735
# Epoch: 0046 training loss= 0.46304 time= 0.05014
# validation roc= 0.90818 validation ap= 0.90796
# Epoch: 0047 training loss= 0.46165 time= 0.06277
# validation roc= 0.90783 validation ap= 0.90779
# Epoch: 0048 training loss= 0.46030 time= 0.06314
# validation roc= 0.90730 validation ap= 0.90742
# Epoch: 0049 training loss= 0.45913 time= 0.05733
# validation roc= 0.90710 validation ap= 0.90713
# Epoch: 0050 training loss= 0.45804 time= 0.05719
# validation roc= 0.90714 validation ap= 0.90695
# Epoch: 0051 training loss= 0.45684 time= 0.05541
# validation roc= 0.90742 validation ap= 0.90740
# Epoch: 0052 training loss= 0.45554 time= 0.14643
# validation roc= 0.90843 validation ap= 0.90828
# Epoch: 0053 training loss= 0.45430 time= 0.15778
# validation roc= 0.90953 validation ap= 0.90953
# Epoch: 0054 training loss= 0.45325 time= 0.13495
# validation roc= 0.91041 validation ap= 0.91017
# Epoch: 0055 training loss= 0.45231 time= 0.10688
# validation roc= 0.91122 validation ap= 0.91067
# Epoch: 0056 training loss= 0.45137 time= 0.20883
# validation roc= 0.91174 validation ap= 0.91104
# Epoch: 0057 training loss= 0.45044 time= 0.08639
# validation roc= 0.91206 validation ap= 0.91144
# Epoch: 0058 training loss= 0.44959 time= 0.06222
# validation roc= 0.91236 validation ap= 0.91157
# Epoch: 0059 training loss= 0.44883 time= 0.09280
# validation roc= 0.91298 validation ap= 0.91227
# Epoch: 0060 training loss= 0.44805 time= 0.05926
# validation roc= 0.91392 validation ap= 0.91290
# Epoch: 0061 training loss= 0.44721 time= 0.07140
# validation roc= 0.91541 validation ap= 0.91398
# Epoch: 0062 training loss= 0.44642 time= 0.16476
# validation roc= 0.91655 validation ap= 0.91494
# Epoch: 0063 training loss= 0.44569 time= 0.18553
# validation roc= 0.91733 validation ap= 0.91557
# Epoch: 0064 training loss= 0.44499 time= 0.08647
# validation roc= 0.91787 validation ap= 0.91608
# Epoch: 0065 training loss= 0.44429 time= 0.14070
# validation roc= 0.91803 validation ap= 0.91608
# Epoch: 0066 training loss= 0.44360 time= 0.09817
# validation roc= 0.91830 validation ap= 0.91613
# Epoch: 0067 training loss= 0.44290 time= 0.11796
# validation roc= 0.91917 validation ap= 0.91683
# Epoch: 0068 training loss= 0.44216 time= 0.06858
# validation roc= 0.92030 validation ap= 0.91791
# Epoch: 0069 training loss= 0.44141 time= 0.09756
# validation roc= 0.92129 validation ap= 0.91873
# Epoch: 0070 training loss= 0.44069 time= 0.05733
# validation roc= 0.92215 validation ap= 0.91946
# Epoch: 0071 training loss= 0.44002 time= 0.11265
# validation roc= 0.92261 validation ap= 0.91970
# Epoch: 0072 training loss= 0.43935 time= 0.06626
# validation roc= 0.92294 validation ap= 0.92023
# Epoch: 0073 training loss= 0.43866 time= 0.12589
# validation roc= 0.92313 validation ap= 0.92045
# Epoch: 0074 training loss= 0.43800 time= 0.05724
# validation roc= 0.92323 validation ap= 0.92039
# Epoch: 0075 training loss= 0.43737 time= 0.05469
# validation roc= 0.92340 validation ap= 0.92054
# Epoch: 0076 training loss= 0.43677 time= 0.05875
# validation roc= 0.92384 validation ap= 0.92091
# Epoch: 0077 training loss= 0.43619 time= 0.10357
# validation roc= 0.92390 validation ap= 0.92091
# Epoch: 0078 training loss= 0.43565 time= 0.07450
# validation roc= 0.92397 validation ap= 0.92112
# Epoch: 0079 training loss= 0.43512 time= 0.10343
# validation roc= 0.92381 validation ap= 0.92104
# Epoch: 0080 training loss= 0.43458 time= 0.07067
# validation roc= 0.92375 validation ap= 0.92111
# Epoch: 0081 training loss= 0.43406 time= 0.05663
# validation roc= 0.92368 validation ap= 0.92129
# Epoch: 0082 training loss= 0.43357 time= 0.06977
# validation roc= 0.92393 validation ap= 0.92198
# Epoch: 0083 training loss= 0.43309 time= 0.06180
# validation roc= 0.92410 validation ap= 0.92257
# Epoch: 0084 training loss= 0.43260 time= 0.10866
# validation roc= 0.92385 validation ap= 0.92268
# Epoch: 0085 training loss= 0.43211 time= 0.14983
# validation roc= 0.92390 validation ap= 0.92293
# Epoch: 0086 training loss= 0.43165 time= 0.13250
# validation roc= 0.92401 validation ap= 0.92333
# Epoch: 0087 training loss= 0.43119 time= 0.14366
# validation roc= 0.92445 validation ap= 0.92411
# Epoch: 0088 training loss= 0.43072 time= 0.14949
# validation roc= 0.92498 validation ap= 0.92522
# Epoch: 0089 training loss= 0.43026 time= 0.12871
# validation roc= 0.92539 validation ap= 0.92586
# Epoch: 0090 training loss= 0.42982 time= 0.11044
# validation roc= 0.92546 validation ap= 0.92603
# Epoch: 0091 training loss= 0.42938 time= 0.07543
# validation roc= 0.92578 validation ap= 0.92660
# Epoch: 0092 training loss= 0.42894 time= 0.11471
# validation roc= 0.92582 validation ap= 0.92682
# Epoch: 0093 training loss= 0.42852 time= 0.05823
# validation roc= 0.92601 validation ap= 0.92712
# Epoch: 0094 training loss= 0.42810 time= 0.05538
# validation roc= 0.92604 validation ap= 0.92694
# Epoch: 0095 training loss= 0.42770 time= 0.05234
# validation roc= 0.92599 validation ap= 0.92685
# Epoch: 0096 training loss= 0.42730 time= 0.06976
# validation roc= 0.92585 validation ap= 0.92679
# Epoch: 0097 training loss= 0.42692 time= 0.05543
# validation roc= 0.92596 validation ap= 0.92712
# Epoch: 0098 training loss= 0.42654 time= 0.06469
# validation roc= 0.92612 validation ap= 0.92735
# Epoch: 0099 training loss= 0.42618 time= 0.06008
# validation roc= 0.92592 validation ap= 0.92735
# Epoch: 0100 training loss= 0.42582 time= 0.05663
# validation roc= 0.92565 validation ap= 0.92736
# Epoch: 0101 training loss= 0.42546 time= 0.05408
# validation roc= 0.92560 validation ap= 0.92746
# Epoch: 0102 training loss= 0.42511 time= 0.05514
# validation roc= 0.92521 validation ap= 0.92736
# Epoch: 0103 training loss= 0.42476 time= 0.05345
# validation roc= 0.92505 validation ap= 0.92746
# Epoch: 0104 training loss= 0.42443 time= 0.04923
# validation roc= 0.92510 validation ap= 0.92796
# Epoch: 0105 training loss= 0.42410 time= 0.06140
# validation roc= 0.92533 validation ap= 0.92846
# Epoch: 0106 training loss= 0.42378 time= 0.06661
# validation roc= 0.92537 validation ap= 0.92883
# Epoch: 0107 training loss= 0.42347 time= 0.06052
# validation roc= 0.92531 validation ap= 0.92898
# Epoch: 0108 training loss= 0.42316 time= 0.07740
# validation roc= 0.92507 validation ap= 0.92906
# Epoch: 0109 training loss= 0.42287 time= 0.11453
# validation roc= 0.92526 validation ap= 0.92949
# Epoch: 0110 training loss= 0.42259 time= 0.11428
# validation roc= 0.92502 validation ap= 0.92951
# Epoch: 0111 training loss= 0.42232 time= 0.18366
# validation roc= 0.92513 validation ap= 0.92983
# Epoch: 0112 training loss= 0.42205 time= 0.08366
# validation roc= 0.92526 validation ap= 0.93017
# Epoch: 0113 training loss= 0.42178 time= 0.06605
# validation roc= 0.92526 validation ap= 0.93034
# Epoch: 0114 training loss= 0.42152 time= 0.08733
# validation roc= 0.92552 validation ap= 0.93070
# Epoch: 0115 training loss= 0.42126 time= 0.04925
# validation roc= 0.92566 validation ap= 0.93095
# Epoch: 0116 training loss= 0.42100 time= 0.06089
# validation roc= 0.92576 validation ap= 0.93124
# Epoch: 0117 training loss= 0.42074 time= 0.08694
# validation roc= 0.92567 validation ap= 0.93128
# Epoch: 0118 training loss= 0.42048 time= 0.07774
# validation roc= 0.92594 validation ap= 0.93169
# Epoch: 0119 training loss= 0.42021 time= 0.08646
# validation roc= 0.92596 validation ap= 0.93189
# Epoch: 0120 training loss= 0.41995 time= 0.09944
# validation roc= 0.92592 validation ap= 0.93184
# Epoch: 0121 training loss= 0.41969 time= 0.09725
# validation roc= 0.92596 validation ap= 0.93190
# Epoch: 0122 training loss= 0.41943 time= 0.11603
# validation roc= 0.92608 validation ap= 0.93204
# Epoch: 0123 training loss= 0.41917 time= 0.07350
# validation roc= 0.92617 validation ap= 0.93207
# Epoch: 0124 training loss= 0.41891 time= 0.07976
# validation roc= 0.92633 validation ap= 0.93230
# Epoch: 0125 training loss= 0.41866 time= 0.05467
# validation roc= 0.92643 validation ap= 0.93254
# Epoch: 0126 training loss= 0.41841 time= 0.08613
# validation roc= 0.92666 validation ap= 0.93275
# Epoch: 0127 training loss= 0.41816 time= 0.13917
# validation roc= 0.92676 validation ap= 0.93283
# Epoch: 0128 training loss= 0.41792 time= 0.06374
# validation roc= 0.92669 validation ap= 0.93288
# Epoch: 0129 training loss= 0.41769 time= 0.10990
# validation roc= 0.92660 validation ap= 0.93288
# Epoch: 0130 training loss= 0.41746 time= 0.06140
# validation roc= 0.92670 validation ap= 0.93316
# Epoch: 0131 training loss= 0.41723 time= 0.13785
# validation roc= 0.92644 validation ap= 0.93300
# Epoch: 0132 training loss= 0.41702 time= 0.05150
# validation roc= 0.92643 validation ap= 0.93307
# Epoch: 0133 training loss= 0.41680 time= 0.05535
# validation roc= 0.92653 validation ap= 0.93332
# Epoch: 0134 training loss= 0.41660 time= 0.06282
# validation roc= 0.92648 validation ap= 0.93336
# Epoch: 0135 training loss= 0.41640 time= 0.08016
# validation roc= 0.92641 validation ap= 0.93336
# Epoch: 0136 training loss= 0.41620 time= 0.05621
# validation roc= 0.92634 validation ap= 0.93329
# Epoch: 0137 training loss= 0.41600 time= 0.07995
# validation roc= 0.92646 validation ap= 0.93350
# Epoch: 0138 training loss= 0.41581 time= 0.06983
# validation roc= 0.92622 validation ap= 0.93344
# Epoch: 0139 training loss= 0.41563 time= 0.05997
# validation roc= 0.92605 validation ap= 0.93331
# Epoch: 0140 training loss= 0.41544 time= 0.05855
# validation roc= 0.92596 validation ap= 0.93337
# Epoch: 0141 training loss= 0.41526 time= 0.06626
# validation roc= 0.92563 validation ap= 0.93320
# Epoch: 0142 training loss= 0.41507 time= 0.05515
# validation roc= 0.92589 validation ap= 0.93356
# Epoch: 0143 training loss= 0.41490 time= 0.05947
# validation roc= 0.92585 validation ap= 0.93365
# Epoch: 0144 training loss= 0.41472 time= 0.05246
# validation roc= 0.92566 validation ap= 0.93351
# Epoch: 0145 training loss= 0.41455 time= 0.05976
# validation roc= 0.92576 validation ap= 0.93362
# Epoch: 0146 training loss= 0.41438 time= 0.10822
# validation roc= 0.92580 validation ap= 0.93365
# Epoch: 0147 training loss= 0.41421 time= 0.11386
# validation roc= 0.92569 validation ap= 0.93361
# Epoch: 0148 training loss= 0.41405 time= 0.17240
# validation roc= 0.92572 validation ap= 0.93366
# Epoch: 0149 training loss= 0.41388 time= 0.13411
# validation roc= 0.92563 validation ap= 0.93359
# Epoch: 0150 training loss= 0.41373 time= 0.09078
# validation roc= 0.92540 validation ap= 0.93341
# Epoch: 0151 training loss= 0.41357 time= 0.08950
# validation roc= 0.92547 validation ap= 0.93351
# Epoch: 0152 training loss= 0.41342 time= 0.08744
# validation roc= 0.92546 validation ap= 0.93361
# Epoch: 0153 training loss= 0.41327 time= 0.06976
# validation roc= 0.92544 validation ap= 0.93373
# Epoch: 0154 training loss= 0.41312 time= 0.12549
# validation roc= 0.92544 validation ap= 0.93376
# Epoch: 0155 training loss= 0.41298 time= 0.09052
# validation roc= 0.92520 validation ap= 0.93363
# Epoch: 0156 training loss= 0.41283 time= 0.05007
# validation roc= 0.92510 validation ap= 0.93367
# Epoch: 0157 training loss= 0.41269 time= 0.06997
# validation roc= 0.92502 validation ap= 0.93379
# Epoch: 0158 training loss= 0.41255 time= 0.06381
# validation roc= 0.92511 validation ap= 0.93381
# Epoch: 0159 training loss= 0.41241 time= 0.06402
# validation roc= 0.92521 validation ap= 0.93399
# Epoch: 0160 training loss= 0.41227 time= 0.05694
# validation roc= 0.92511 validation ap= 0.93403
# Epoch: 0161 training loss= 0.41213 time= 0.05872
# validation roc= 0.92492 validation ap= 0.93389
# Epoch: 0162 training loss= 0.41200 time= 0.05757
# validation roc= 0.92508 validation ap= 0.93396
# Epoch: 0163 training loss= 0.41187 time= 0.05684
# validation roc= 0.92511 validation ap= 0.93406
# Epoch: 0164 training loss= 0.41174 time= 0.06421
# validation roc= 0.92515 validation ap= 0.93419
# Epoch: 0165 training loss= 0.41161 time= 0.05356
# validation roc= 0.92504 validation ap= 0.93419
# Epoch: 0166 training loss= 0.41149 time= 0.05813
# validation roc= 0.92500 validation ap= 0.93424
# Epoch: 0167 training loss= 0.41137 time= 0.06049
# validation roc= 0.92494 validation ap= 0.93420
# Epoch: 0168 training loss= 0.41125 time= 0.09068
# validation roc= 0.92502 validation ap= 0.93450
# Epoch: 0169 training loss= 0.41114 time= 0.04938
# validation roc= 0.92504 validation ap= 0.93460
# Epoch: 0170 training loss= 0.41103 time= 0.12231
# validation roc= 0.92500 validation ap= 0.93467
# Epoch: 0171 training loss= 0.41092 time= 0.17125
# validation roc= 0.92501 validation ap= 0.93473
# Epoch: 0172 training loss= 0.41082 time= 0.26473
# validation roc= 0.92502 validation ap= 0.93479
# Epoch: 0173 training loss= 0.41072 time= 0.05815
# validation roc= 0.92507 validation ap= 0.93506
# Epoch: 0174 training loss= 0.41062 time= 0.06717
# validation roc= 0.92507 validation ap= 0.93516
# Epoch: 0175 training loss= 0.41053 time= 0.09754
# validation roc= 0.92511 validation ap= 0.93527
# Epoch: 0176 training loss= 0.41043 time= 0.06956
# validation roc= 0.92524 validation ap= 0.93542
# Epoch: 0177 training loss= 0.41035 time= 0.05055
# validation roc= 0.92533 validation ap= 0.93551
# Epoch: 0178 training loss= 0.41026 time= 0.06704
# validation roc= 0.92537 validation ap= 0.93566
# Epoch: 0179 training loss= 0.41018 time= 0.05083
# validation roc= 0.92552 validation ap= 0.93593
# Epoch: 0180 training loss= 0.41010 time= 0.06651
# validation roc= 0.92541 validation ap= 0.93597
# Epoch: 0181 training loss= 0.41002 time= 0.07433
# validation roc= 0.92552 validation ap= 0.93614
# Epoch: 0182 training loss= 0.40995 time= 0.12581
# validation roc= 0.92547 validation ap= 0.93624
# Epoch: 0183 training loss= 0.40988 time= 0.17413
# validation roc= 0.92552 validation ap= 0.93626
# Epoch: 0184 training loss= 0.40981 time= 0.06664
# validation roc= 0.92537 validation ap= 0.93612
# Epoch: 0185 training loss= 0.40974 time= 0.13951
# validation roc= 0.92543 validation ap= 0.93622
# Epoch: 0186 training loss= 0.40967 time= 0.06255
# validation roc= 0.92530 validation ap= 0.93614
# Epoch: 0187 training loss= 0.40961 time= 0.11158
# validation roc= 0.92518 validation ap= 0.93611
# Epoch: 0188 training loss= 0.40954 time= 0.10575
# validation roc= 0.92517 validation ap= 0.93614
# Epoch: 0189 training loss= 0.40948 time= 0.12918
# validation roc= 0.92526 validation ap= 0.93621
# Epoch: 0190 training loss= 0.40942 time= 0.05919
# validation roc= 0.92534 validation ap= 0.93634
# Epoch: 0191 training loss= 0.40936 time= 0.13352
# validation roc= 0.92524 validation ap= 0.93630
# Epoch: 0192 training loss= 0.40929 time= 0.06140
# validation roc= 0.92528 validation ap= 0.93639
# Epoch: 0193 training loss= 0.40923 time= 0.12581
# validation roc= 0.92523 validation ap= 0.93641
# Epoch: 0194 training loss= 0.40917 time= 0.05380
# validation roc= 0.92526 validation ap= 0.93650
# Epoch: 0195 training loss= 0.40911 time= 0.04959
# validation roc= 0.92508 validation ap= 0.93636
# Epoch: 0196 training loss= 0.40905 time= 0.05089
# validation roc= 0.92518 validation ap= 0.93643
# Epoch: 0197 training loss= 0.40899 time= 0.07990
# validation roc= 0.92521 validation ap= 0.93643
# Epoch: 0198 training loss= 0.40893 time= 0.05245
# validation roc= 0.92511 validation ap= 0.93636
# Epoch: 0199 training loss= 0.40887 time= 0.06070
# validation roc= 0.92507 validation ap= 0.93634
# Epoch: 0200 training loss= 0.40881 time= 0.09314
# validation roc= 0.92501 validation ap= 0.93634
# testing roc= 0.91577 testing ap= 0.92548

# %% [markdown]
# # Visulization

# %%
emb=emb
labels=load_label(dataset,data_path)

X_embedded = TSNE(n_components=2, init='pca', random_state=seed).fit_transform(emb)

cs=['orange','blue','darkcyan','fuchsia','chocolate','dodgerblue','aqua','green','red','purple']
markers=['o','+','v','2','s','X','d','>','*','<']

fig, ax = plt.subplots(1,figsize=(8,6))
for i in np.arange(X_embedded.shape[0]):
    scatter = ax.scatter(X_embedded[i,0],X_embedded[i,1],label=labels[i],marker=markers[labels[i]],color=cs[labels[i]], s=10, alpha = 1)
plt.xticks([])
plt.yticks([])
plt.xlabel("")
plt.ylabel("")
plt.axis('off')
plt.show()
