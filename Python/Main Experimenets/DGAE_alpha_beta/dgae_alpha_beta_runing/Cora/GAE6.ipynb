# %% [markdown]
# # Import libraries

# %%
import numpy as np
import random as rn
import os
from keras import backend as K
import  tensorflow.compat.v1  as tf
tf.disable_v2_behavior() 
import tensorflow as tf

#--------------------------------------------------------------------------------------------------------------------
# Reproducible
seed=0
os.environ['PYTHONHASHSEED'] = str(seed)

np.random.seed(seed)
rn.seed(seed)
session_conf =tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
tf.compat.v1.set_random_seed(seed)
#--------------------------------------------------------------------------------------------------------------------

import scipy.sparse as sp
import time
import pandas as pd
import sys

from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

sys.path.append(r"../../")

from dgae_alpha_beta.evaluation import get_roc_score
from dgae_alpha_beta.input_data import load_data, load_label
from dgae_alpha_beta.model import *
from dgae_alpha_beta.optimizer import *
from dgae_alpha_beta.preprocessing import *
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.8/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %% [markdown]
# # Parameters setting

# %%
layers_no=6
data_path="../../Datasets/"
path_now="./log/"

dataset='cora'
model_name='deep_gcn_ae'

dropout=0.0
epochs=200
features_used=True
learning_rate=0.01
nb_run=1
prop_val=5
prop_test=10
validation=True
verbose=True

# %% [markdown]
# # Load data

# %%
adj_init, features_init = load_data(dataset,data_path)
num_adj=adj_init.shape[1]

# %% [markdown]
# # Training and testing

# %%
#loss_coeff_adj=0.001
#loss_coeff_AE=0.05
results_output_path = path_now+model_name+"/"
mkdir(results_output_path)

for seed_i in np.arange(nb_run):
    
    seed=seed_i
    lost_list=[]
    roc_list=[]
    ap_list=[]
    mean_time=[]
    
    adj, val_edges, val_edges_false, test_edges, test_edges_false =mask_test_edges(adj_init, seed,prop_test, prop_val)
                
    t_start = time.time()

    if features_used:
        features = features_init
    
    num_nodes = adj.shape[0]

    if not features_used:
        features = sp.identity(adj.shape[0])

    features = sparse_to_tuple(features)
    num_features = features[2][1]
    features_nonzero = features[1].shape[0]
        
    placeholders = {
        'features': tf.sparse_placeholder(tf.float32),
        'adj': tf.sparse_placeholder(tf.float32),
        'adj_orig': tf.sparse_placeholder(tf.float32),
        'dropout': tf.placeholder_with_default(0., shape = ())
    }

#--------------------------------------------------------------------------------------------------------------------
# Create model
    if model_name=='DGAE_alpha_beta_feature':
        model = DGAE_alpha_beta_feature(placeholders, layers_no,num_features, features_nonzero)
    elif model_name=='DGAE_alpha_beta_no_feature':
        model=DGAE_alpha_beta_no_feature(placeholders, layers_no,num_features, num_adj,features_nonzero)
    elif model_name == 'deep_gcn_ae':
        model = DeepGCNModelAE(placeholders, layers_no,num_features, features_nonzero)
    elif model_name == 'linear_ae':
        model = LinearModelAE(placeholders, num_features, features_nonzero)
    elif model_name == 'gcn_ae':
        model = GCNModelAE(placeholders, num_features, features_nonzero)
    else:
        raise ValueError('Undefined model!')

    pos_weight = float(adj.shape[0] * adj.shape[0] - adj.sum()) / adj.sum()
    norm = adj.shape[0] * adj.shape[0] / float((adj.shape[0] * adj.shape[0]- adj.sum()) * 2)
    
    with tf.name_scope('optimizer'):
        if model_name in ('DGAE_alpha_beta_feature'):
            opt =OptimizerAE_FeatureReconstrution(preds_adj = model.reconstructions,\
                                                  preds_Features=model.feature_reconstruction,\
                                                  labels_adj = tf.reshape(tf.sparse_tensor_to_dense(placeholders['adj_orig'],\
                                                                                                    validate_indices = False), [-1]),\
                                                  labels_Features=placeholders['features'],\
                                                  labels_adj_rec=placeholders['adj'],\
                                                  loss_coeff_adj=loss_coeff_adj,\
                                                  loss_coeff_AE=loss_coeff_AE,\
                                                  pos_weight = pos_weight,\
                                                  norm = norm)
                
        elif model_name in ('DGAE_alpha_beta_no_feature'):
            opt =OptimizerAE_AdjReconstrution(preds_adj = model.reconstructions,\
                                              preds_adj_rec=model.adj_reconstruction,\
                                              labels_adj = tf.reshape(tf.sparse_tensor_to_dense(placeholders['adj_orig'],
                                                                                                validate_indices = False), [-1]),\
                                              labels_Features=placeholders['features'],\
                                              labels_adj_rec=placeholders['adj'],\
                                              loss_coeff_adj=loss_coeff_adj,\
                                              loss_coeff_AE=loss_coeff_AE,\
                                              pos_weight = pos_weight,\
                                              norm = norm)
            
        elif model_name in ('gcn_ae', 'linear_ae', 'deep_gcn_ae'):
            opt = OptimizerAE(preds = model.reconstructions,\
                              labels = tf.reshape(tf.sparse_tensor_to_dense(placeholders['adj_orig'],\
                                                                            validate_indices = False), [-1]),
                              pos_weight = pos_weight,
                              norm = norm)

    adj_norm = preprocess_graph(adj)
    adj_label = sparse_to_tuple(adj + sp.eye(adj.shape[0]))

    sess = tf.Session()
    sess.run(tf.global_variables_initializer())
    
    for epoch in range(epochs):
        t = time.time()
        feed_dict = construct_feed_dict(adj_norm, adj_label, features,placeholders)
        feed_dict.update({placeholders['dropout']: dropout})
        outs = sess.run([opt.opt_op, opt.cost, opt.accuracy],feed_dict = feed_dict)
        avg_cost = outs[1]
        if verbose:
            lost_list.append(avg_cost)
            print("Epoch:", '%04d' % (epoch + 1), "training loss=", "{:.5f}".format(avg_cost),"time=", "{:.5f}".format(time.time() - t))
                    
            if validation:
                feed_dict.update({placeholders['dropout']: 0})
                emb = sess.run(model.z_mean, feed_dict = feed_dict)
                feed_dict.update({placeholders['dropout']: dropout})
                val_roc, val_ap = get_roc_score(val_edges, val_edges_false, emb)
                roc_list.append(val_roc)
                ap_list.append(val_ap)
                print("validation roc=", "{:.5f}".format(val_roc), "validation ap=", "{:.5f}".format(val_ap))

    emb = sess.run(model.z_mean, feed_dict = feed_dict)   
    mean_time.append(time.time() - t_start)
    
    roc_score, ap_score = get_roc_score(test_edges, test_edges_false, emb)
    print("testing roc=", "{:.5f}".format(roc_score), "testing ap=", "{:.5f}".format(ap_score))
    
    roc_list.append(roc_score)
    ap_list.append(ap_score)
    
    mean_time_=np.array(mean_time)
    write_to_csv(mean_time_.reshape(1,len(mean_time_)),results_output_path+"layers_"+str(layers_no)+"_time.csv")

    roc_list_=np.array(roc_list)
    write_to_csv(roc_list_.reshape(1,len(roc_list_)),results_output_path+"layers_"+str(layers_no)+"_roc.csv")

    ap_list_=np.array(ap_list)
    write_to_csv(ap_list_.reshape(1,len(ap_list_)),results_output_path+"layers_"+str(layers_no)+"_ap.csv")
# Out:
# Failure
# WARNING:tensorflow:From /usr/local/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:201: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:201: calling weighted_cross_entropy_with_logits (from tensorflow.python.ops.nn_impl) with targets is deprecated and will be removed in a future version.
# Instructions for updating:
# targets is deprecated, use labels instead
# Epoch: 0001 training loss= 0.79664 time= 0.63669
# validation roc= 0.66845 validation ap= 0.71780
# Epoch: 0002 training loss= 1.05892 time= 0.19595
# validation roc= 0.65394 validation ap= 0.69839
# Epoch: 0003 training loss= 0.78530 time= 0.11822
# validation roc= 0.67566 validation ap= 0.72360
# Epoch: 0004 training loss= 0.79153 time= 0.14707
# validation roc= 0.68179 validation ap= 0.73266
# Epoch: 0005 training loss= 0.78753 time= 0.09410
# validation roc= 0.68255 validation ap= 0.73507
# Epoch: 0006 training loss= 0.77894 time= 0.08272
# validation roc= 0.68273 validation ap= 0.73438
# Epoch: 0007 training loss= 0.76422 time= 0.09903
# validation roc= 0.68279 validation ap= 0.73457
# Epoch: 0008 training loss= 0.75030 time= 0.08887
# validation roc= 0.68351 validation ap= 0.73565
# Epoch: 0009 training loss= 0.77573 time= 0.08329
# validation roc= 0.68434 validation ap= 0.73688
# Epoch: 0010 training loss= 0.75053 time= 0.08376
# validation roc= 0.68567 validation ap= 0.73845
# Epoch: 0011 training loss= 0.75397 time= 0.08277
# validation roc= 0.68668 validation ap= 0.73938
# Epoch: 0012 training loss= 0.75977 time= 0.07385
# validation roc= 0.68717 validation ap= 0.74004
# Epoch: 0013 training loss= 0.76171 time= 0.15937
# validation roc= 0.68726 validation ap= 0.74016
# Epoch: 0014 training loss= 0.75945 time= 3.77433
# validation roc= 0.68772 validation ap= 0.74013
# Epoch: 0015 training loss= 0.75378 time= 5.62163
# validation roc= 0.68856 validation ap= 0.74043
# Epoch: 0016 training loss= 0.74776 time= 0.94314
# validation roc= 0.68894 validation ap= 0.74066
# Epoch: 0017 training loss= 0.75084 time= 0.24720
# validation roc= 0.68908 validation ap= 0.74070
# Epoch: 0018 training loss= 0.75432 time= 0.07585
# validation roc= 0.68973 validation ap= 0.74101
# Epoch: 0019 training loss= 0.74739 time= 0.08694
# validation roc= 0.68973 validation ap= 0.74087
# Epoch: 0020 training loss= 0.74605 time= 0.14534
# validation roc= 0.68980 validation ap= 0.74127
# Epoch: 0021 training loss= 0.74819 time= 0.08366
# validation roc= 0.68936 validation ap= 0.74055
# Epoch: 0022 training loss= 0.74897 time= 0.07695
# validation roc= 0.68922 validation ap= 0.74052
# Epoch: 0023 training loss= 0.74648 time= 0.25217
# validation roc= 0.68946 validation ap= 0.74069
# Epoch: 0024 training loss= 0.74325 time= 0.08620
# validation roc= 0.68930 validation ap= 0.74038
# Epoch: 0025 training loss= 0.74170 time= 0.08098
# validation roc= 0.68791 validation ap= 0.73905
# Epoch: 0026 training loss= 0.74150 time= 0.14749
# validation roc= 0.68620 validation ap= 0.73848
# Epoch: 0027 training loss= 0.73903 time= 0.11164
# validation roc= 0.68580 validation ap= 0.73901
# Epoch: 0028 training loss= 0.73726 time= 0.13195
# validation roc= 0.68402 validation ap= 0.73725
# Epoch: 0029 training loss= 0.73623 time= 0.16483
# validation roc= 0.68383 validation ap= 0.73714
# Epoch: 0030 training loss= 0.73236 time= 0.06963
# validation roc= 0.68379 validation ap= 0.73661
# Epoch: 0031 training loss= 0.73147 time= 0.15879
# validation roc= 0.68266 validation ap= 0.73553
# Epoch: 0032 training loss= 0.72723 time= 0.08133
# validation roc= 0.68422 validation ap= 0.73463
# Epoch: 0033 training loss= 0.72703 time= 0.12204
# validation roc= 0.68973 validation ap= 0.73656
# Epoch: 0034 training loss= 0.72212 time= 0.07857
# validation roc= 0.69838 validation ap= 0.73888
# Epoch: 0035 training loss= 0.71914 time= 0.10759
# validation roc= 0.71749 validation ap= 0.74313
# Epoch: 0036 training loss= 0.71606 time= 0.09161
# validation roc= 0.72144 validation ap= 0.74565
# Epoch: 0037 training loss= 0.70639 time= 0.07321
# validation roc= 0.73336 validation ap= 0.75033
# Epoch: 0038 training loss= 0.69562 time= 0.08257
# validation roc= 0.75360 validation ap= 0.76405
# Epoch: 0039 training loss= 0.68531 time= 0.12387
# validation roc= 0.75240 validation ap= 0.76964
# Epoch: 0040 training loss= 0.67126 time= 0.16203
# validation roc= 0.74131 validation ap= 0.75035
# Epoch: 0041 training loss= 0.64346 time= 0.26029
# validation roc= 0.72600 validation ap= 0.72454
# Epoch: 0042 training loss= 0.65786 time= 0.13708
# validation roc= 0.75725 validation ap= 0.77763
# Epoch: 0043 training loss= 0.64370 time= 0.13153
# validation roc= 0.75829 validation ap= 0.78008
# Epoch: 0044 training loss= 0.63274 time= 0.13794
# validation roc= 0.74749 validation ap= 0.76721
# Epoch: 0045 training loss= 0.62739 time= 0.09148
# validation roc= 0.73894 validation ap= 0.75576
# Epoch: 0046 training loss= 0.63400 time= 0.07225
# validation roc= 0.73967 validation ap= 0.75985
# Epoch: 0047 training loss= 0.62673 time= 0.08051
# validation roc= 0.74366 validation ap= 0.76806
# Epoch: 0048 training loss= 0.61554 time= 0.07761
# validation roc= 0.74432 validation ap= 0.77007
# Epoch: 0049 training loss= 0.61990 time= 0.06877
# validation roc= 0.73825 validation ap= 0.75985
# Epoch: 0050 training loss= 0.61768 time= 0.06622
# validation roc= 0.72713 validation ap= 0.74124
# Epoch: 0051 training loss= 0.61637 time= 0.08559
# validation roc= 0.73691 validation ap= 0.75844
# Epoch: 0052 training loss= 0.60960 time= 0.08084
# validation roc= 0.73644 validation ap= 0.76243
# Epoch: 0053 training loss= 0.61201 time= 0.09646
# validation roc= 0.73523 validation ap= 0.76122
# Epoch: 0054 training loss= 0.61207 time= 0.09091
# validation roc= 0.73640 validation ap= 0.76069
# Epoch: 0055 training loss= 0.60838 time= 0.08685
# validation roc= 0.73245 validation ap= 0.75300
# Epoch: 0056 training loss= 0.60712 time= 0.13647
# validation roc= 0.72995 validation ap= 0.75039
# Epoch: 0057 training loss= 0.60745 time= 0.11826
# validation roc= 0.73426 validation ap= 0.75732
# Epoch: 0058 training loss= 0.60718 time= 1.77669
# validation roc= 0.73530 validation ap= 0.76043
# Epoch: 0059 training loss= 0.60459 time= 2.14342
# validation roc= 0.73505 validation ap= 0.76021
# Epoch: 0060 training loss= 0.60394 time= 0.09083
# validation roc= 0.73477 validation ap= 0.76017
# Epoch: 0061 training loss= 0.60517 time= 0.08895
# validation roc= 0.73396 validation ap= 0.75913
# Epoch: 0062 training loss= 0.60328 time= 0.08805
# validation roc= 0.73378 validation ap= 0.75885
# Epoch: 0063 training loss= 0.60172 time= 0.08620
# validation roc= 0.73268 validation ap= 0.75776
# Epoch: 0064 training loss= 0.60252 time= 0.08572
# validation roc= 0.73046 validation ap= 0.75496
# Epoch: 0065 training loss= 0.60131 time= 0.14920
# validation roc= 0.73166 validation ap= 0.75555
# Epoch: 0066 training loss= 0.59983 time= 0.11721
# validation roc= 0.73508 validation ap= 0.75923
# Epoch: 0067 training loss= 0.59958 time= 0.10975
# validation roc= 0.73711 validation ap= 0.76061
# Epoch: 0068 training loss= 0.59907 time= 0.08868
# validation roc= 0.73744 validation ap= 0.76092
# Epoch: 0069 training loss= 0.59746 time= 0.09164
# validation roc= 0.73335 validation ap= 0.75595
# Epoch: 0070 training loss= 0.59636 time= 0.22432
# validation roc= 0.73106 validation ap= 0.75167
# Epoch: 0071 training loss= 0.59585 time= 0.14610
# validation roc= 0.73698 validation ap= 0.75859
# Epoch: 0072 training loss= 0.59292 time= 0.09234
# validation roc= 0.74071 validation ap= 0.76197
# Epoch: 0073 training loss= 0.59094 time= 0.07097
# validation roc= 0.74078 validation ap= 0.76018
# Epoch: 0074 training loss= 0.58818 time= 0.14301
# validation roc= 0.74450 validation ap= 0.76307
# Epoch: 0075 training loss= 0.58405 time= 0.10512
# validation roc= 0.75120 validation ap= 0.76931
# Epoch: 0076 training loss= 0.57935 time= 0.07881
# validation roc= 0.76213 validation ap= 0.77853
# Epoch: 0077 training loss= 0.57473 time= 0.09617
# validation roc= 0.75754 validation ap= 0.77525
# Epoch: 0078 training loss= 0.56883 time= 0.10192
# validation roc= 0.77519 validation ap= 0.78577
# Epoch: 0079 training loss= 0.56402 time= 0.08200
# validation roc= 0.75843 validation ap= 0.77529
# Epoch: 0080 training loss= 0.56347 time= 0.10482
# validation roc= 0.78300 validation ap= 0.78861
# Epoch: 0081 training loss= 0.55585 time= 0.07605
# validation roc= 0.77445 validation ap= 0.78624
# Epoch: 0082 training loss= 0.55273 time= 0.07727
# validation roc= 0.77754 validation ap= 0.78931
# Epoch: 0083 training loss= 0.55133 time= 0.13574
# validation roc= 0.78979 validation ap= 0.79731
# Epoch: 0084 training loss= 0.55022 time= 0.16413
# validation roc= 0.77714 validation ap= 0.79359
# Epoch: 0085 training loss= 0.54901 time= 0.14510
# validation roc= 0.79605 validation ap= 0.80744
# Epoch: 0086 training loss= 0.54249 time= 0.17457
# validation roc= 0.79849 validation ap= 0.81191
# Epoch: 0087 training loss= 0.53820 time= 0.10932
# validation roc= 0.79105 validation ap= 0.80961
# Epoch: 0088 training loss= 0.53639 time= 0.11923
# validation roc= 0.81164 validation ap= 0.82633
# Epoch: 0089 training loss= 0.53418 time= 0.16624
# validation roc= 0.79593 validation ap= 0.81792
# Epoch: 0090 training loss= 0.53291 time= 0.09418
# validation roc= 0.81594 validation ap= 0.83186
# Epoch: 0091 training loss= 0.52768 time= 0.09036
# validation roc= 0.81531 validation ap= 0.83259
# Epoch: 0092 training loss= 0.52501 time= 0.07498
# validation roc= 0.81373 validation ap= 0.83071
# Epoch: 0093 training loss= 0.52578 time= 0.07729
# validation roc= 0.82001 validation ap= 0.83439
# Epoch: 0094 training loss= 0.52398 time= 0.07924
# validation roc= 0.82067 validation ap= 0.83490
# Epoch: 0095 training loss= 0.52251 time= 0.07964
# validation roc= 0.81739 validation ap= 0.83171
# Epoch: 0096 training loss= 0.52149 time= 0.08974
# validation roc= 0.82144 validation ap= 0.83449
# Epoch: 0097 training loss= 0.51963 time= 0.07474
# validation roc= 0.82515 validation ap= 0.83644
# Epoch: 0098 training loss= 0.51876 time= 0.07659
# validation roc= 0.82319 validation ap= 0.83462
# Epoch: 0099 training loss= 0.51722 time= 0.25606
# validation roc= 0.82359 validation ap= 0.83348
# Epoch: 0100 training loss= 0.51536 time= 0.12717
# validation roc= 0.82783 validation ap= 0.83672
# Epoch: 0101 training loss= 0.51432 time= 1.59407
# validation roc= 0.82602 validation ap= 0.83455
# Epoch: 0102 training loss= 0.51250 time= 0.10396
# validation roc= 0.82567 validation ap= 0.83379
# Epoch: 0103 training loss= 0.51100 time= 0.08247
# validation roc= 0.82797 validation ap= 0.83534
# Epoch: 0104 training loss= 0.50948 time= 0.08291
# validation roc= 0.82760 validation ap= 0.83483
# Epoch: 0105 training loss= 0.50765 time= 0.22111
# validation roc= 0.82631 validation ap= 0.83412
# Epoch: 0106 training loss= 0.50667 time= 0.09473
# validation roc= 0.82865 validation ap= 0.83686
# Epoch: 0107 training loss= 0.50524 time= 0.08176
# validation roc= 0.82907 validation ap= 0.83770
# Epoch: 0108 training loss= 0.50429 time= 0.09094
# validation roc= 0.82852 validation ap= 0.83656
# Epoch: 0109 training loss= 0.50356 time= 0.07921
# validation roc= 0.83151 validation ap= 0.83992
# Epoch: 0110 training loss= 0.50262 time= 0.18296
# validation roc= 0.83261 validation ap= 0.84057
# Epoch: 0111 training loss= 0.50204 time= 0.11249
# validation roc= 0.83240 validation ap= 0.84009
# Epoch: 0112 training loss= 0.50150 time= 0.17876
# validation roc= 0.83416 validation ap= 0.84233
# Epoch: 0113 training loss= 0.50061 time= 0.10245
# validation roc= 0.83425 validation ap= 0.84286
# Epoch: 0114 training loss= 0.50004 time= 0.13515
# validation roc= 0.83215 validation ap= 0.84106
# Epoch: 0115 training loss= 0.49937 time= 0.14227
# validation roc= 0.83318 validation ap= 0.84221
# Epoch: 0116 training loss= 0.49837 time= 0.08587
# validation roc= 0.83412 validation ap= 0.84450
# Epoch: 0117 training loss= 0.49776 time= 0.09086
# validation roc= 0.83104 validation ap= 0.84084
# Epoch: 0118 training loss= 0.49690 time= 0.07996
# validation roc= 0.83179 validation ap= 0.84198
# Epoch: 0119 training loss= 0.49590 time= 0.10123
# validation roc= 0.83081 validation ap= 0.84177
# Epoch: 0120 training loss= 0.49500 time= 0.08891
# validation roc= 0.82901 validation ap= 0.84048
# Epoch: 0121 training loss= 0.49416 time= 0.08549
# validation roc= 0.83122 validation ap= 0.84170
# Epoch: 0122 training loss= 0.49329 time= 0.07322
# validation roc= 0.83042 validation ap= 0.84123
# Epoch: 0123 training loss= 0.49243 time= 0.09951
# validation roc= 0.83089 validation ap= 0.84009
# Epoch: 0124 training loss= 0.49138 time= 0.07572
# validation roc= 0.83095 validation ap= 0.83832
# Epoch: 0125 training loss= 0.49050 time= 0.10713
# validation roc= 0.83189 validation ap= 0.83896
# Epoch: 0126 training loss= 0.48936 time= 0.09337
# validation roc= 0.83289 validation ap= 0.83968
# Epoch: 0127 training loss= 0.48832 time= 0.14982
# validation roc= 0.83198 validation ap= 0.83961
# Epoch: 0128 training loss= 0.48737 time= 0.15431
# validation roc= 0.83358 validation ap= 0.84093
# Epoch: 0129 training loss= 0.48674 time= 0.12072
# validation roc= 0.83253 validation ap= 0.83877
# Epoch: 0130 training loss= 0.48636 time= 0.12267
# validation roc= 0.83393 validation ap= 0.84026
# Epoch: 0131 training loss= 0.48621 time= 0.15694
# validation roc= 0.83329 validation ap= 0.83905
# Epoch: 0132 training loss= 0.48619 time= 0.09241
# validation roc= 0.83237 validation ap= 0.83974
# Epoch: 0133 training loss= 0.48537 time= 0.08871
# validation roc= 0.83105 validation ap= 0.83936
# Epoch: 0134 training loss= 0.48455 time= 0.07015
# validation roc= 0.83167 validation ap= 0.83945
# Epoch: 0135 training loss= 0.48409 time= 0.07949
# validation roc= 0.82910 validation ap= 0.83986
# Epoch: 0136 training loss= 0.48391 time= 0.07324
# validation roc= 0.82732 validation ap= 0.83856
# Epoch: 0137 training loss= 0.48355 time= 0.07280
# validation roc= 0.82965 validation ap= 0.83784
# Epoch: 0138 training loss= 0.48307 time= 0.08217
# validation roc= 0.82702 validation ap= 0.83804
# Epoch: 0139 training loss= 0.48260 time= 0.07775
# validation roc= 0.82968 validation ap= 0.83924
# Epoch: 0140 training loss= 0.48197 time= 0.07643
# validation roc= 0.82894 validation ap= 0.83902
# Epoch: 0141 training loss= 0.48152 time= 0.10557
# validation roc= 0.83131 validation ap= 0.84343
# Epoch: 0142 training loss= 0.48163 time= 0.07921
# validation roc= 0.82645 validation ap= 0.83809
# Epoch: 0143 training loss= 0.48204 time= 0.11177
# validation roc= 0.83478 validation ap= 0.84674
# Epoch: 0144 training loss= 0.48175 time= 0.14195
# validation roc= 0.82342 validation ap= 0.83755
# Epoch: 0145 training loss= 0.48151 time= 0.13102
# validation roc= 0.83219 validation ap= 0.84401
# Epoch: 0146 training loss= 0.48079 time= 0.19558
# validation roc= 0.82962 validation ap= 0.84581
# Epoch: 0147 training loss= 0.47878 time= 0.06611
# validation roc= 0.82732 validation ap= 0.84195
# Epoch: 0148 training loss= 0.47878 time= 0.08758
# validation roc= 0.83348 validation ap= 0.84625
# Epoch: 0149 training loss= 0.47874 time= 0.12031
# validation roc= 0.82884 validation ap= 0.84589
# Epoch: 0150 training loss= 0.47735 time= 0.08558
# validation roc= 0.82812 validation ap= 0.84353
# Epoch: 0151 training loss= 0.47674 time= 0.16062
# validation roc= 0.83310 validation ap= 0.84554
# Epoch: 0152 training loss= 0.47610 time= 0.10699
# validation roc= 0.82751 validation ap= 0.84289
# Epoch: 0153 training loss= 0.47613 time= 0.12473
# validation roc= 0.82773 validation ap= 0.84352
# Epoch: 0154 training loss= 0.47436 time= 0.08197
# validation roc= 0.82810 validation ap= 0.84236
# Epoch: 0155 training loss= 0.47431 time= 0.12694
# validation roc= 0.82336 validation ap= 0.83982
# Epoch: 0156 training loss= 0.47396 time= 0.19075
# validation roc= 0.82559 validation ap= 0.84167
# Epoch: 0157 training loss= 0.47281 time= 0.14277
# validation roc= 0.82476 validation ap= 0.84098
# Epoch: 0158 training loss= 0.47243 time= 0.09760
# validation roc= 0.82154 validation ap= 0.83943
# Epoch: 0159 training loss= 0.47212 time= 0.07413
# validation roc= 0.82420 validation ap= 0.83865
# Epoch: 0160 training loss= 0.47146 time= 0.14868
# validation roc= 0.82278 validation ap= 0.84013
# Epoch: 0161 training loss= 0.47081 time= 0.08433
# validation roc= 0.81996 validation ap= 0.84017
# Epoch: 0162 training loss= 0.47064 time= 0.10330
# validation roc= 0.82262 validation ap= 0.83876
# Epoch: 0163 training loss= 0.47051 time= 0.07758
# validation roc= 0.81829 validation ap= 0.83855
# Epoch: 0164 training loss= 0.47005 time= 0.08453
# validation roc= 0.81931 validation ap= 0.84022
# Epoch: 0165 training loss= 0.46970 time= 0.08453
# validation roc= 0.82099 validation ap= 0.84077
# Epoch: 0166 training loss= 0.46965 time= 0.08643
# validation roc= 0.81687 validation ap= 0.83808
# Epoch: 0167 training loss= 0.46965 time= 0.09792
# validation roc= 0.81996 validation ap= 0.83962
# Epoch: 0168 training loss= 0.46925 time= 0.09527
# validation roc= 0.81992 validation ap= 0.84112
# Epoch: 0169 training loss= 0.46886 time= 0.11182
# validation roc= 0.82001 validation ap= 0.84147
# Epoch: 0170 training loss= 0.46879 time= 0.13704
# validation roc= 0.82191 validation ap= 0.84260
# Epoch: 0171 training loss= 0.46852 time= 0.20448
# validation roc= 0.81894 validation ap= 0.84155
# Epoch: 0172 training loss= 0.46821 time= 0.20978
# validation roc= 0.82030 validation ap= 0.84153
# Epoch: 0173 training loss= 0.46790 time= 0.07484
# validation roc= 0.81863 validation ap= 0.84070
# Epoch: 0174 training loss= 0.46766 time= 0.14364
# validation roc= 0.81652 validation ap= 0.84075
# Epoch: 0175 training loss= 0.46754 time= 0.08567
# validation roc= 0.81866 validation ap= 0.84125
# Epoch: 0176 training loss= 0.46746 time= 0.07662
# validation roc= 0.81680 validation ap= 0.84143
# Epoch: 0177 training loss= 0.46713 time= 0.07715
# validation roc= 0.81787 validation ap= 0.84147
# Epoch: 0178 training loss= 0.46686 time= 0.07623
# validation roc= 0.81872 validation ap= 0.84184
# Epoch: 0179 training loss= 0.46668 time= 0.07172
# validation roc= 0.81863 validation ap= 0.84181
# Epoch: 0180 training loss= 0.46649 time= 0.07817
# validation roc= 0.81962 validation ap= 0.84244
# Epoch: 0181 training loss= 0.46630 time= 0.07237
# validation roc= 0.81839 validation ap= 0.84163
# Epoch: 0182 training loss= 0.46613 time= 0.07351
# validation roc= 0.82152 validation ap= 0.84277
# Epoch: 0183 training loss= 0.46596 time= 0.07311
# validation roc= 0.81979 validation ap= 0.84283
# Epoch: 0184 training loss= 0.46574 time= 0.06531
# validation roc= 0.82314 validation ap= 0.84598
# Epoch: 0185 training loss= 0.46551 time= 0.08675
# validation roc= 0.82017 validation ap= 0.84444
# Epoch: 0186 training loss= 0.46533 time= 0.11729
# validation roc= 0.82410 validation ap= 0.84601
# Epoch: 0187 training loss= 0.46552 time= 0.12447
# validation roc= 0.81941 validation ap= 0.84515
# Epoch: 0188 training loss= 0.46608 time= 0.22961
# validation roc= 0.82839 validation ap= 0.84867
# Epoch: 0189 training loss= 0.46692 time= 0.07364
# validation roc= 0.82206 validation ap= 0.84743
# Epoch: 0190 training loss= 0.46593 time= 0.07920
# validation roc= 0.82515 validation ap= 0.84857
# Epoch: 0191 training loss= 0.46414 time= 0.08107
# validation roc= 0.82773 validation ap= 0.84971
# Epoch: 0192 training loss= 0.46502 time= 0.07993
# validation roc= 0.82554 validation ap= 0.85025
# Epoch: 0193 training loss= 0.46494 time= 0.13515
# validation roc= 0.82884 validation ap= 0.85005
# Epoch: 0194 training loss= 0.46358 time= 0.06873
# validation roc= 0.83101 validation ap= 0.85348
# Epoch: 0195 training loss= 0.46395 time= 0.06979
# validation roc= 0.82468 validation ap= 0.84996
# Epoch: 0196 training loss= 0.46368 time= 0.13419
# validation roc= 0.82739 validation ap= 0.84861
# Epoch: 0197 training loss= 0.46257 time= 0.09185
# validation roc= 0.83117 validation ap= 0.85257
# Epoch: 0198 training loss= 0.46189 time= 0.06564
# validation roc= 0.83004 validation ap= 0.85367
# Epoch: 0199 training loss= 0.46127 time= 0.14944
# validation roc= 0.83003 validation ap= 0.84781
# Epoch: 0200 training loss= 0.46137 time= 0.13570
# validation roc= 0.83290 validation ap= 0.85606
# testing roc= 0.82900 testing ap= 0.85905

# %% [markdown]
# # Visulization

# %%
emb=emb
labels=load_label(dataset,data_path)

X_embedded = TSNE(n_components=2, init='pca', random_state=seed).fit_transform(emb)

cs=['orange','blue','darkcyan','fuchsia','chocolate','dodgerblue','aqua','green','red','purple']
markers=['o','+','v','2','s','X','d','>','*','<']

fig, ax = plt.subplots(1,figsize=(8,6))
for i in np.arange(X_embedded.shape[0]):
    scatter = ax.scatter(X_embedded[i,0],X_embedded[i,1],label=labels[i],marker=markers[labels[i]],color=cs[labels[i]], s=10, alpha = 1)
plt.xticks([])
plt.yticks([])
plt.xlabel("")
plt.ylabel("")
plt.axis('off')
plt.show()
