# %% [markdown]
# # Import libraries

# %%
import numpy as np
import random as rn
import os
from keras import backend as K
import  tensorflow.compat.v1  as tf
tf.disable_v2_behavior() 
import tensorflow as tf

#--------------------------------------------------------------------------------------------------------------------
# Reproducible
seed=0
os.environ['PYTHONHASHSEED'] = str(seed)

np.random.seed(seed)
rn.seed(seed)
session_conf =tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
tf.compat.v1.set_random_seed(seed)
#--------------------------------------------------------------------------------------------------------------------

import scipy.sparse as sp
import time
import pandas as pd
import sys

from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

sys.path.append(r"../../")

from dgae_alpha_beta.evaluation import get_roc_score
from dgae_alpha_beta.input_data import load_data, load_label
from dgae_alpha_beta.model import *
from dgae_alpha_beta.optimizer import *
from dgae_alpha_beta.preprocessing import *
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.8/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %% [markdown]
# # Parameters setting

# %%
layers_no=6
data_path="../../Datasets/"
path_now="./log/"

dataset='cora'
model_name='DGAE_alpha_beta_feature'

dropout=0.0
epochs=200
features_used=True
learning_rate=0.01
nb_run=10
prop_val=5
prop_test=10
validation=True
verbose=True

# %% [markdown]
# # Load data

# %%
adj_init, features_init = load_data(dataset,data_path)
num_adj=adj_init.shape[1]

# %% [markdown]
# # Training and testing

# %%
loss_coeff_adj=0.001
loss_coeff_AE=0.05
results_output_path = path_now+model_name+"/"
mkdir(results_output_path)

for seed_i in np.arange(nb_run):
    
    seed=seed_i
    lost_list=[]
    roc_list=[]
    ap_list=[]
    mean_time=[]
    
    adj, val_edges, val_edges_false, test_edges, test_edges_false =mask_test_edges(adj_init, seed,prop_test, prop_val)
                
    t_start = time.time()

    if features_used:
        features = features_init
    
    num_nodes = adj.shape[0]

    if not features_used:
        features = sp.identity(adj.shape[0])

    features = sparse_to_tuple(features)
    num_features = features[2][1]
    features_nonzero = features[1].shape[0]
        
    placeholders = {
        'features': tf.sparse_placeholder(tf.float32),
        'adj': tf.sparse_placeholder(tf.float32),
        'adj_orig': tf.sparse_placeholder(tf.float32),
        'dropout': tf.placeholder_with_default(0., shape = ())
    }

#--------------------------------------------------------------------------------------------------------------------
# Create model
    if model_name=='DGAE_alpha_beta_feature':
        model = DGAE_alpha_beta_feature(placeholders, layers_no,num_features, features_nonzero)
    elif model_name=='DGAE_alpha_beta_no_feature':
        model=DGAE_alpha_beta_no_feature(placeholders, layers_no,num_features, num_adj,features_nonzero)
    elif model_name == 'deep_gcn_ae':
        model = DeepGCNModelAE(placeholders, layers_no,num_features, features_nonzero)
    elif model_name == 'linear_ae':
        model = LinearModelAE(placeholders, num_features, features_nonzero)
    elif model_name == 'gcn_ae':
        model = GCNModelAE(placeholders, num_features, features_nonzero)
    else:
        raise ValueError('Undefined model!')

    pos_weight = float(adj.shape[0] * adj.shape[0] - adj.sum()) / adj.sum()
    norm = adj.shape[0] * adj.shape[0] / float((adj.shape[0] * adj.shape[0]- adj.sum()) * 2)
    
    with tf.name_scope('optimizer'):
        if model_name in ('DGAE_alpha_beta_feature'):
            opt =OptimizerAE_FeatureReconstrution(preds_adj = model.reconstructions,\
                                                  preds_Features=model.feature_reconstruction,\
                                                  labels_adj = tf.reshape(tf.sparse_tensor_to_dense(placeholders['adj_orig'],\
                                                                                                    validate_indices = False), [-1]),\
                                                  labels_Features=placeholders['features'],\
                                                  labels_adj_rec=placeholders['adj'],\
                                                  loss_coeff_adj=loss_coeff_adj,\
                                                  loss_coeff_AE=loss_coeff_AE,\
                                                  pos_weight = pos_weight,\
                                                  norm = norm)
                
        elif model_name in ('DGAE_alpha_beta_no_feature'):
            opt =OptimizerAE_AdjReconstrution(preds_adj = model.reconstructions,\
                                              preds_adj_rec=model.adj_reconstruction,\
                                              labels_adj = tf.reshape(tf.sparse_tensor_to_dense(placeholders['adj_orig'],
                                                                                                validate_indices = False), [-1]),\
                                              labels_Features=placeholders['features'],\
                                              labels_adj_rec=placeholders['adj'],\
                                              loss_coeff_adj=loss_coeff_adj,\
                                              loss_coeff_AE=loss_coeff_AE,\
                                              pos_weight = pos_weight,\
                                              norm = norm)
            
        elif model_name in ('gcn_ae', 'linear_ae', 'deep_gcn_ae'):
            opt = OptimizerAE(preds = model.reconstructions,\
                              labels = tf.reshape(tf.sparse_tensor_to_dense(placeholders['adj_orig'],\
                                                                            validate_indices = False), [-1]),
                              pos_weight = pos_weight,
                              norm = norm)

    adj_norm = preprocess_graph(adj)
    adj_label = sparse_to_tuple(adj + sp.eye(adj.shape[0]))

    sess = tf.Session()
    sess.run(tf.global_variables_initializer())
    
    for epoch in range(epochs):
        t = time.time()
        feed_dict = construct_feed_dict(adj_norm, adj_label, features,placeholders)
        feed_dict.update({placeholders['dropout']: dropout})
        outs = sess.run([opt.opt_op, opt.cost, opt.accuracy],feed_dict = feed_dict)
        avg_cost = outs[1]
        if verbose:
            lost_list.append(avg_cost)
            print("Epoch:", '%04d' % (epoch + 1), "training loss=", "{:.5f}".format(avg_cost),"time=", "{:.5f}".format(time.time() - t))
                    
            if validation:
                feed_dict.update({placeholders['dropout']: 0})
                emb = sess.run(model.z_mean, feed_dict = feed_dict)
                feed_dict.update({placeholders['dropout']: dropout})
                val_roc, val_ap = get_roc_score(val_edges, val_edges_false, emb)
                roc_list.append(val_roc)
                ap_list.append(val_ap)
                print("validation roc=", "{:.5f}".format(val_roc), "validation ap=", "{:.5f}".format(val_ap))

    emb = sess.run(model.z_mean, feed_dict = feed_dict)   
    mean_time.append(time.time() - t_start)
    
    roc_score, ap_score = get_roc_score(test_edges, test_edges_false, emb)
    print("testing roc=", "{:.5f}".format(roc_score), "testing ap=", "{:.5f}".format(ap_score))
    
    roc_list.append(roc_score)
    ap_list.append(ap_score)
    
    mean_time_=np.array(mean_time)
    write_to_csv(mean_time_.reshape(1,len(mean_time_)),results_output_path+"layers_"+str(layers_no)+"_time_10run.csv")

    roc_list_=np.array(roc_list)
    write_to_csv(roc_list_.reshape(1,len(roc_list_)),results_output_path+"layers_"+str(layers_no)+"_roc_10run.csv")

    ap_list_=np.array(ap_list)
    write_to_csv(ap_list_.reshape(1,len(ap_list_)),results_output_path+"layers_"+str(layers_no)+"_ap_10run.csv")
# Out:
# Failure
# WARNING:tensorflow:From /usr/local/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:201: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:201: calling weighted_cross_entropy_with_logits (from tensorflow.python.ops.nn_impl) with targets is deprecated and will be removed in a future version.
# Instructions for updating:
# targets is deprecated, use labels instead
# Epoch: 0001 training loss= 0.00102 time= 0.74606
# validation roc= 0.71091 validation ap= 0.75485
# Epoch: 0002 training loss= 0.00099 time= 0.14361
# validation roc= 0.69619 validation ap= 0.74522
# Epoch: 0003 training loss= 0.00107 time= 0.11891
# validation roc= 0.76834 validation ap= 0.80099
# Epoch: 0004 training loss= 0.00095 time= 0.10142
# validation roc= 0.69904 validation ap= 0.72473
# Epoch: 0005 training loss= 0.00095 time= 0.11494
# validation roc= 0.67076 validation ap= 0.70573
# Epoch: 0006 training loss= 0.00095 time= 0.09532
# validation roc= 0.71383 validation ap= 0.73717
# Epoch: 0007 training loss= 0.00093 time= 0.10586
# validation roc= 0.76925 validation ap= 0.77553
# Epoch: 0008 training loss= 0.00091 time= 0.10332
# validation roc= 0.79526 validation ap= 0.78963
# Epoch: 0009 training loss= 0.00088 time= 0.10721
# validation roc= 0.81484 validation ap= 0.80429
# Epoch: 0010 training loss= 0.00085 time= 0.09368
# validation roc= 0.83140 validation ap= 0.82105
# Epoch: 0011 training loss= 0.00082 time= 0.09945
# validation roc= 0.83909 validation ap= 0.82962
# Epoch: 0012 training loss= 0.00080 time= 0.12050
# validation roc= 0.84353 validation ap= 0.83411
# Epoch: 0013 training loss= 0.00079 time= 0.09557
# validation roc= 0.85038 validation ap= 0.84184
# Epoch: 0014 training loss= 0.00077 time= 0.08976
# validation roc= 0.85384 validation ap= 0.84430
# Epoch: 0015 training loss= 0.00076 time= 0.10209
# validation roc= 0.85702 validation ap= 0.84579
# Epoch: 0016 training loss= 0.00075 time= 0.10331
# validation roc= 0.86066 validation ap= 0.84825
# Epoch: 0017 training loss= 0.00074 time= 0.10151
# validation roc= 0.86303 validation ap= 0.85257
# Epoch: 0018 training loss= 0.00074 time= 0.08897
# validation roc= 0.86477 validation ap= 0.85704
# Epoch: 0019 training loss= 0.00073 time= 0.10137
# validation roc= 0.86704 validation ap= 0.86124
# Epoch: 0020 training loss= 0.00072 time= 0.09723
# validation roc= 0.87053 validation ap= 0.86596
# Epoch: 0021 training loss= 0.00071 time= 0.08756
# validation roc= 0.87486 validation ap= 0.87083
# Epoch: 0022 training loss= 0.00071 time= 0.10111
# validation roc= 0.87817 validation ap= 0.87276
# Epoch: 0023 training loss= 0.00070 time= 0.10372
# validation roc= 0.87986 validation ap= 0.87161
# Epoch: 0024 training loss= 0.00070 time= 0.11645
# validation roc= 0.88110 validation ap= 0.87003
# Epoch: 0025 training loss= 0.00070 time= 0.10722
# validation roc= 0.88236 validation ap= 0.86997
# Epoch: 0026 training loss= 0.00069 time= 0.10066
# validation roc= 0.88300 validation ap= 0.87062
# Epoch: 0027 training loss= 0.00069 time= 0.10523
# validation roc= 0.88444 validation ap= 0.87343
# Epoch: 0028 training loss= 0.00069 time= 0.10774
# validation roc= 0.88639 validation ap= 0.87810
# Epoch: 0029 training loss= 0.00068 time= 0.10310
# validation roc= 0.88982 validation ap= 0.88341
# Epoch: 0030 training loss= 0.00068 time= 0.09733
# validation roc= 0.89228 validation ap= 0.88814
# Epoch: 0031 training loss= 0.00068 time= 0.10559
# validation roc= 0.89481 validation ap= 0.89140
# Epoch: 0032 training loss= 0.00067 time= 0.08709
# validation roc= 0.89653 validation ap= 0.89362
# Epoch: 0033 training loss= 0.00067 time= 0.09876
# validation roc= 0.89849 validation ap= 0.89540
# Epoch: 0034 training loss= 0.00067 time= 0.09158
# validation roc= 0.90052 validation ap= 0.89721
# Epoch: 0035 training loss= 0.00066 time= 0.11057
# validation roc= 0.90334 validation ap= 0.89968
# Epoch: 0036 training loss= 0.00066 time= 0.10485
# validation roc= 0.90581 validation ap= 0.90146
# Epoch: 0037 training loss= 0.00066 time= 0.10788
# validation roc= 0.90809 validation ap= 0.90294
# Epoch: 0038 training loss= 0.00066 time= 0.09943
# validation roc= 0.90937 validation ap= 0.90383
# Epoch: 0039 training loss= 0.00065 time= 0.10163
# validation roc= 0.91088 validation ap= 0.90546
# Epoch: 0040 training loss= 0.00065 time= 0.09663
# validation roc= 0.91185 validation ap= 0.90725
# Epoch: 0041 training loss= 0.00065 time= 0.08525
# validation roc= 0.91321 validation ap= 0.90903
# Epoch: 0042 training loss= 0.00065 time= 0.09478
# validation roc= 0.91402 validation ap= 0.91008
# Epoch: 0043 training loss= 0.00065 time= 0.09315
# validation roc= 0.91483 validation ap= 0.91111
# Epoch: 0044 training loss= 0.00064 time= 0.10803
# validation roc= 0.91560 validation ap= 0.91196
# Epoch: 0045 training loss= 0.00064 time= 0.09772
# validation roc= 0.91636 validation ap= 0.91321
# Epoch: 0046 training loss= 0.00064 time= 0.11648
# validation roc= 0.91660 validation ap= 0.91397
# Epoch: 0047 training loss= 0.00064 time= 0.09928
# validation roc= 0.91732 validation ap= 0.91547
# Epoch: 0048 training loss= 0.00064 time= 0.11501
# validation roc= 0.91716 validation ap= 0.91566
# Epoch: 0049 training loss= 0.00063 time= 0.10921
# validation roc= 0.91774 validation ap= 0.91723
# Epoch: 0050 training loss= 0.00063 time= 0.09278
# validation roc= 0.91785 validation ap= 0.91754
# Epoch: 0051 training loss= 0.00063 time= 0.09468
# validation roc= 0.91826 validation ap= 0.91805
# Epoch: 0052 training loss= 0.00063 time= 0.08506
# validation roc= 0.91902 validation ap= 0.91875
# Epoch: 0053 training loss= 0.00063 time= 0.09596
# validation roc= 0.91960 validation ap= 0.91925
# Epoch: 0054 training loss= 0.00063 time= 0.09420
# validation roc= 0.92054 validation ap= 0.92013
# Epoch: 0055 training loss= 0.00063 time= 0.08567
# validation roc= 0.92164 validation ap= 0.92108
# Epoch: 0056 training loss= 0.00062 time= 0.09504
# validation roc= 0.92232 validation ap= 0.92163
# Epoch: 0057 training loss= 0.00062 time= 0.12265
# validation roc= 0.92309 validation ap= 0.92219
# Epoch: 0058 training loss= 0.00062 time= 0.10907
# validation roc= 0.92372 validation ap= 0.92255
# Epoch: 0059 training loss= 0.00062 time= 0.08452
# validation roc= 0.92390 validation ap= 0.92268
# Epoch: 0060 training loss= 0.00062 time= 0.10828
# validation roc= 0.92479 validation ap= 0.92374
# Epoch: 0061 training loss= 0.00062 time= 0.09139
# validation roc= 0.92592 validation ap= 0.92482
# Epoch: 0062 training loss= 0.00062 time= 0.11034
# validation roc= 0.92663 validation ap= 0.92587
# Epoch: 0063 training loss= 0.00061 time= 0.10590
# validation roc= 0.92711 validation ap= 0.92666
# Epoch: 0064 training loss= 0.00061 time= 0.09945
# validation roc= 0.92703 validation ap= 0.92694
# Epoch: 0065 training loss= 0.00061 time= 0.09882
# validation roc= 0.92727 validation ap= 0.92752
# Epoch: 0066 training loss= 0.00061 time= 0.09188
# validation roc= 0.92783 validation ap= 0.92819
# Epoch: 0067 training loss= 0.00061 time= 0.09167
# validation roc= 0.92847 validation ap= 0.92883
# Epoch: 0068 training loss= 0.00061 time= 0.13900
# validation roc= 0.92896 validation ap= 0.92934
# Epoch: 0069 training loss= 0.00061 time= 0.08124
# validation roc= 0.92890 validation ap= 0.92964
# Epoch: 0070 training loss= 0.00061 time= 0.09345
# validation roc= 0.92875 validation ap= 0.92973
# Epoch: 0071 training loss= 0.00061 time= 0.09816
# validation roc= 0.92842 validation ap= 0.92936
# Epoch: 0072 training loss= 0.00060 time= 0.09487
# validation roc= 0.92873 validation ap= 0.92945
# Epoch: 0073 training loss= 0.00060 time= 0.09644
# validation roc= 0.92875 validation ap= 0.92945
# Epoch: 0074 training loss= 0.00060 time= 0.10906
# validation roc= 0.92839 validation ap= 0.92905
# Epoch: 0075 training loss= 0.00060 time= 0.11204
# validation roc= 0.92816 validation ap= 0.92896
# Epoch: 0076 training loss= 0.00060 time= 0.09269
# validation roc= 0.92822 validation ap= 0.92909
# Epoch: 0077 training loss= 0.00060 time= 0.10518
# validation roc= 0.92822 validation ap= 0.92919
# Epoch: 0078 training loss= 0.00060 time= 0.09211
# validation roc= 0.92828 validation ap= 0.92966
# Epoch: 0079 training loss= 0.00060 time= 0.08561
# validation roc= 0.92806 validation ap= 0.92970
# Epoch: 0080 training loss= 0.00060 time= 0.08641
# validation roc= 0.92828 validation ap= 0.93001
# Epoch: 0081 training loss= 0.00060 time= 0.08900
# validation roc= 0.92823 validation ap= 0.92999
# Epoch: 0082 training loss= 0.00059 time= 0.09027
# validation roc= 0.92825 validation ap= 0.93006
# Epoch: 0083 training loss= 0.00059 time= 0.09440
# validation roc= 0.92823 validation ap= 0.93021
# Epoch: 0084 training loss= 0.00059 time= 0.09922
# validation roc= 0.92812 validation ap= 0.93048
# Epoch: 0085 training loss= 0.00059 time= 0.09764
# validation roc= 0.92818 validation ap= 0.93067
# Epoch: 0086 training loss= 0.00059 time= 0.09464
# validation roc= 0.92805 validation ap= 0.93062
# Epoch: 0087 training loss= 0.00059 time= 0.09961
# validation roc= 0.92779 validation ap= 0.93069
# Epoch: 0088 training loss= 0.00059 time= 0.08221
# validation roc= 0.92753 validation ap= 0.93043
# Epoch: 0089 training loss= 0.00059 time= 0.09304
# validation roc= 0.92731 validation ap= 0.93022
# Epoch: 0090 training loss= 0.00059 time= 0.08509
# validation roc= 0.92744 validation ap= 0.93034
# Epoch: 0091 training loss= 0.00059 time= 0.08786
# validation roc= 0.92724 validation ap= 0.93028
# Epoch: 0092 training loss= 0.00059 time= 0.08151
# validation roc= 0.92703 validation ap= 0.93016
# Epoch: 0093 training loss= 0.00058 time= 0.09601
# validation roc= 0.92666 validation ap= 0.92987
# Epoch: 0094 training loss= 0.00058 time= 0.09202
# validation roc= 0.92643 validation ap= 0.92963
# Epoch: 0095 training loss= 0.00058 time= 0.09596
# validation roc= 0.92601 validation ap= 0.92949
# Epoch: 0096 training loss= 0.00058 time= 0.08434
# validation roc= 0.92565 validation ap= 0.92930
# Epoch: 0097 training loss= 0.00058 time= 0.09388
# validation roc= 0.92562 validation ap= 0.92937
# Epoch: 0098 training loss= 0.00058 time= 0.09440
# validation roc= 0.92566 validation ap= 0.92938
# Epoch: 0099 training loss= 0.00058 time= 0.10722
# validation roc= 0.92599 validation ap= 0.92976
# Epoch: 0100 training loss= 0.00058 time= 0.09010
# validation roc= 0.92601 validation ap= 0.92988
# Epoch: 0101 training loss= 0.00058 time= 0.09605
# validation roc= 0.92617 validation ap= 0.93011
# Epoch: 0102 training loss= 0.00058 time= 0.08750
# validation roc= 0.92615 validation ap= 0.93007
# Epoch: 0103 training loss= 0.00058 time= 0.08950
# validation roc= 0.92634 validation ap= 0.93023
# Epoch: 0104 training loss= 0.00058 time= 0.09581
# validation roc= 0.92672 validation ap= 0.93070
# Epoch: 0105 training loss= 0.00058 time= 0.09759
# validation roc= 0.92677 validation ap= 0.93080
# Epoch: 0106 training loss= 0.00058 time= 0.09372
# validation roc= 0.92695 validation ap= 0.93102
# Epoch: 0107 training loss= 0.00058 time= 0.10611
# validation roc= 0.92705 validation ap= 0.93097
# Epoch: 0108 training loss= 0.00058 time= 0.09095
# validation roc= 0.92727 validation ap= 0.93124
# Epoch: 0109 training loss= 0.00057 time= 0.08259
# validation roc= 0.92744 validation ap= 0.93137
# Epoch: 0110 training loss= 0.00057 time= 0.08974
# validation roc= 0.92760 validation ap= 0.93151
# Epoch: 0111 training loss= 0.00057 time= 0.10295
# validation roc= 0.92768 validation ap= 0.93145
# Epoch: 0112 training loss= 0.00057 time= 0.09887
# validation roc= 0.92779 validation ap= 0.93151
# Epoch: 0113 training loss= 0.00057 time= 0.08849
# validation roc= 0.92779 validation ap= 0.93121
# Epoch: 0114 training loss= 0.00057 time= 0.09279
# validation roc= 0.92796 validation ap= 0.93147
# Epoch: 0115 training loss= 0.00057 time= 0.09009
# validation roc= 0.92823 validation ap= 0.93175
# Epoch: 0116 training loss= 0.00057 time= 0.08582
# validation roc= 0.92838 validation ap= 0.93172
# Epoch: 0117 training loss= 0.00057 time= 0.10019
# validation roc= 0.92844 validation ap= 0.93179
# Epoch: 0118 training loss= 0.00057 time= 0.09415
# validation roc= 0.92874 validation ap= 0.93199
# Epoch: 0119 training loss= 0.00057 time= 0.08833
# validation roc= 0.92900 validation ap= 0.93221
# Epoch: 0120 training loss= 0.00057 time= 0.10151
# validation roc= 0.92912 validation ap= 0.93219
# Epoch: 0121 training loss= 0.00057 time= 0.09938
# validation roc= 0.92914 validation ap= 0.93232
# Epoch: 0122 training loss= 0.00057 time= 0.10738
# validation roc= 0.92936 validation ap= 0.93235
# Epoch: 0123 training loss= 0.00057 time= 0.08824
# validation roc= 0.92959 validation ap= 0.93271
# Epoch: 0124 training loss= 0.00057 time= 0.10762
# validation roc= 0.92995 validation ap= 0.93317
# Epoch: 0125 training loss= 0.00057 time= 0.10700
# validation roc= 0.93013 validation ap= 0.93342
# Epoch: 0126 training loss= 0.00057 time= 0.09890
# validation roc= 0.93024 validation ap= 0.93362
# Epoch: 0127 training loss= 0.00056 time= 0.09427
# validation roc= 0.93056 validation ap= 0.93400
# Epoch: 0128 training loss= 0.00056 time= 0.09581
# validation roc= 0.93072 validation ap= 0.93424
# Epoch: 0129 training loss= 0.00056 time= 0.11028
# validation roc= 0.93092 validation ap= 0.93436
# Epoch: 0130 training loss= 0.00056 time= 0.10202
# validation roc= 0.93126 validation ap= 0.93466
# Epoch: 0131 training loss= 0.00056 time= 0.10192
# validation roc= 0.93160 validation ap= 0.93502
# Epoch: 0132 training loss= 0.00056 time= 0.08749
# validation roc= 0.93186 validation ap= 0.93538
# Epoch: 0133 training loss= 0.00056 time= 0.09835
# validation roc= 0.93198 validation ap= 0.93579
# Epoch: 0134 training loss= 0.00056 time= 0.09293
# validation roc= 0.93259 validation ap= 0.93651
# Epoch: 0135 training loss= 0.00056 time= 0.08725
# validation roc= 0.93233 validation ap= 0.93607
# Epoch: 0136 training loss= 0.00056 time= 0.08717
# validation roc= 0.93270 validation ap= 0.93692
# Epoch: 0137 training loss= 0.00056 time= 0.08628
# validation roc= 0.93248 validation ap= 0.93625
# Epoch: 0138 training loss= 0.00056 time= 0.08973
# validation roc= 0.93302 validation ap= 0.93760
# Epoch: 0139 training loss= 0.00056 time= 0.08160
# validation roc= 0.93282 validation ap= 0.93700
# Epoch: 0140 training loss= 0.00056 time= 0.09324
# validation roc= 0.93345 validation ap= 0.93823
# Epoch: 0141 training loss= 0.00056 time= 0.09175
# validation roc= 0.93381 validation ap= 0.93875
# Epoch: 0142 training loss= 0.00056 time= 0.09135
# validation roc= 0.93324 validation ap= 0.93781
# Epoch: 0143 training loss= 0.00056 time= 0.09606
# validation roc= 0.93433 validation ap= 0.93963
# Epoch: 0144 training loss= 0.00056 time= 0.10279
# validation roc= 0.93405 validation ap= 0.93909
# Epoch: 0145 training loss= 0.00056 time= 0.09798
# validation roc= 0.93406 validation ap= 0.93919
# Epoch: 0146 training loss= 0.00056 time= 0.10501
# validation roc= 0.93449 validation ap= 0.94023
# Epoch: 0147 training loss= 0.00056 time= 0.08866
# validation roc= 0.93415 validation ap= 0.93964
# Epoch: 0148 training loss= 0.00056 time= 0.08077
# validation roc= 0.93436 validation ap= 0.94012
# Epoch: 0149 training loss= 0.00055 time= 0.10201
# validation roc= 0.93449 validation ap= 0.94037
# Epoch: 0150 training loss= 0.00055 time= 0.09485
# validation roc= 0.93425 validation ap= 0.93993
# Epoch: 0151 training loss= 0.00055 time= 0.09075
# validation roc= 0.93442 validation ap= 0.94046
# Epoch: 0152 training loss= 0.00055 time= 0.09316
# validation roc= 0.93426 validation ap= 0.94038
# Epoch: 0153 training loss= 0.00055 time= 0.09599
# validation roc= 0.93433 validation ap= 0.94033
# Epoch: 0154 training loss= 0.00055 time= 0.10651
# validation roc= 0.93431 validation ap= 0.94059
# Epoch: 0155 training loss= 0.00055 time= 0.08689
# validation roc= 0.93441 validation ap= 0.94062
# Epoch: 0156 training loss= 0.00055 time= 0.09300
# validation roc= 0.93410 validation ap= 0.94034
# Epoch: 0157 training loss= 0.00055 time= 0.11397
# validation roc= 0.93423 validation ap= 0.94067
# Epoch: 0158 training loss= 0.00055 time= 0.09333
# validation roc= 0.93441 validation ap= 0.94072
# Epoch: 0159 training loss= 0.00055 time= 0.08186
# validation roc= 0.93446 validation ap= 0.94096
# Epoch: 0160 training loss= 0.00055 time= 0.07979
# validation roc= 0.93462 validation ap= 0.94111
# Epoch: 0161 training loss= 0.00055 time= 0.09648
# validation roc= 0.93473 validation ap= 0.94140
# Epoch: 0162 training loss= 0.00055 time= 0.09857
# validation roc= 0.93494 validation ap= 0.94149
# Epoch: 0163 training loss= 0.00055 time= 0.09870
# validation roc= 0.93491 validation ap= 0.94142
# Epoch: 0164 training loss= 0.00055 time= 0.10043
# validation roc= 0.93487 validation ap= 0.94156
# Epoch: 0165 training loss= 0.00055 time= 0.09452
# validation roc= 0.93493 validation ap= 0.94150
# Epoch: 0166 training loss= 0.00055 time= 0.08096
# validation roc= 0.93499 validation ap= 0.94164
# Epoch: 0167 training loss= 0.00055 time= 0.08981
# validation roc= 0.93504 validation ap= 0.94160
# Epoch: 0168 training loss= 0.00055 time= 0.09431
# validation roc= 0.93493 validation ap= 0.94161
# Epoch: 0169 training loss= 0.00055 time= 0.08613
# validation roc= 0.93499 validation ap= 0.94152
# Epoch: 0170 training loss= 0.00055 time= 0.07968
# validation roc= 0.93494 validation ap= 0.94171
# Epoch: 0171 training loss= 0.00055 time= 0.08125
# validation roc= 0.93462 validation ap= 0.94115
# Epoch: 0172 training loss= 0.00055 time= 0.09811
# validation roc= 0.93497 validation ap= 0.94192
# Epoch: 0173 training loss= 0.00055 time= 0.08985
# validation roc= 0.93457 validation ap= 0.94098
# Epoch: 0174 training loss= 0.00055 time= 0.08925
# validation roc= 0.93478 validation ap= 0.94198
# Epoch: 0175 training loss= 0.00055 time= 0.09795
# validation roc= 0.93428 validation ap= 0.94055
# Epoch: 0176 training loss= 0.00055 time= 0.11239
# validation roc= 0.93444 validation ap= 0.94165
# Epoch: 0177 training loss= 0.00055 time= 0.09252
# validation roc= 0.93431 validation ap= 0.94066
# Epoch: 0178 training loss= 0.00055 time= 0.08996
# validation roc= 0.93458 validation ap= 0.94172
# Epoch: 0179 training loss= 0.00055 time= 0.09132
# validation roc= 0.93445 validation ap= 0.94126
# Epoch: 0180 training loss= 0.00055 time= 0.08663
# validation roc= 0.93439 validation ap= 0.94101
# Epoch: 0181 training loss= 0.00055 time= 0.08718
# validation roc= 0.93468 validation ap= 0.94203
# Epoch: 0182 training loss= 0.00055 time= 0.08514
# validation roc= 0.93422 validation ap= 0.94091
# Epoch: 0183 training loss= 0.00054 time= 0.08207
# validation roc= 0.93462 validation ap= 0.94184
# Epoch: 0184 training loss= 0.00054 time= 0.08033
# validation roc= 0.93407 validation ap= 0.94119
# Epoch: 0185 training loss= 0.00054 time= 0.09756
# validation roc= 0.93418 validation ap= 0.94087
# Epoch: 0186 training loss= 0.00054 time= 0.08095
# validation roc= 0.93433 validation ap= 0.94178
# Epoch: 0187 training loss= 0.00054 time= 0.08608
# validation roc= 0.93407 validation ap= 0.94098
# Epoch: 0188 training loss= 0.00054 time= 0.08654
# validation roc= 0.93402 validation ap= 0.94117
# Epoch: 0189 training loss= 0.00054 time= 0.10551
# validation roc= 0.93393 validation ap= 0.94147
# Epoch: 0190 training loss= 0.00054 time= 0.08943
# validation roc= 0.93380 validation ap= 0.94076
# Epoch: 0191 training loss= 0.00054 time= 0.08503
# validation roc= 0.93394 validation ap= 0.94146
# Epoch: 0192 training loss= 0.00054 time= 0.08830
# validation roc= 0.93379 validation ap= 0.94114
# Epoch: 0193 training loss= 0.00054 time= 0.09013
# validation roc= 0.93338 validation ap= 0.94059
# Epoch: 0194 training loss= 0.00054 time= 0.10176
# validation roc= 0.93377 validation ap= 0.94143
# Epoch: 0195 training loss= 0.00054 time= 0.09994
# validation roc= 0.93351 validation ap= 0.94092
# Epoch: 0196 training loss= 0.00054 time= 0.09005
# validation roc= 0.93331 validation ap= 0.94085
# Epoch: 0197 training loss= 0.00054 time= 0.08908
# validation roc= 0.93351 validation ap= 0.94105
# Epoch: 0198 training loss= 0.00054 time= 0.09581
# validation roc= 0.93334 validation ap= 0.94078
# Epoch: 0199 training loss= 0.00054 time= 0.08606
# validation roc= 0.93344 validation ap= 0.94116
# Epoch: 0200 training loss= 0.00054 time= 0.09438
# validation roc= 0.93355 validation ap= 0.94103
# testing roc= 0.93601 testing ap= 0.94335
# Epoch: 0001 training loss= 0.00102 time= 0.67858
# validation roc= 0.68833 validation ap= 0.71974
# Epoch: 0002 training loss= 0.00099 time= 0.10340
# validation roc= 0.67023 validation ap= 0.71050
# Epoch: 0003 training loss= 0.00107 time= 0.09369
# validation roc= 0.75548 validation ap= 0.77681
# Epoch: 0004 training loss= 0.00095 time= 0.09191
# validation roc= 0.71123 validation ap= 0.73253
# Epoch: 0005 training loss= 0.00095 time= 0.08872
# validation roc= 0.68198 validation ap= 0.71119
# Epoch: 0006 training loss= 0.00095 time= 0.08685
# validation roc= 0.73341 validation ap= 0.75283
# Epoch: 0007 training loss= 0.00093 time= 0.09624
# validation roc= 0.78605 validation ap= 0.79780
# Epoch: 0008 training loss= 0.00091 time= 0.09157
# validation roc= 0.81080 validation ap= 0.81405
# Epoch: 0009 training loss= 0.00088 time= 0.09355
# validation roc= 0.82841 validation ap= 0.82826
# Epoch: 0010 training loss= 0.00085 time= 0.09963
# validation roc= 0.84344 validation ap= 0.84288
# Epoch: 0011 training loss= 0.00082 time= 0.09252
# validation roc= 0.85044 validation ap= 0.84946
# Epoch: 0012 training loss= 0.00080 time= 0.08986
# validation roc= 0.85384 validation ap= 0.85308
# Epoch: 0013 training loss= 0.00079 time= 0.10980
# validation roc= 0.86102 validation ap= 0.86269
# Epoch: 0014 training loss= 0.00077 time= 0.08433
# validation roc= 0.86491 validation ap= 0.86726
# Epoch: 0015 training loss= 0.00076 time= 0.09202
# validation roc= 0.86955 validation ap= 0.87065
# Epoch: 0016 training loss= 0.00075 time= 0.09032
# validation roc= 0.87392 validation ap= 0.87407
# Epoch: 0017 training loss= 0.00074 time= 0.09327
# validation roc= 0.87716 validation ap= 0.87717
# Epoch: 0018 training loss= 0.00074 time= 0.09384
# validation roc= 0.88102 validation ap= 0.88030
# Epoch: 0019 training loss= 0.00073 time= 0.09864
# validation roc= 0.88499 validation ap= 0.88306
# Epoch: 0020 training loss= 0.00072 time= 0.09820
# validation roc= 0.88963 validation ap= 0.88665
# Epoch: 0021 training loss= 0.00071 time= 0.10621
# validation roc= 0.89391 validation ap= 0.89048
# Epoch: 0022 training loss= 0.00071 time= 0.09733
# validation roc= 0.89664 validation ap= 0.89368
# Epoch: 0023 training loss= 0.00070 time= 0.09308
# validation roc= 0.89714 validation ap= 0.89255
# Epoch: 0024 training loss= 0.00070 time= 0.09001
# validation roc= 0.89737 validation ap= 0.89130
# Epoch: 0025 training loss= 0.00070 time= 0.10291
# validation roc= 0.89803 validation ap= 0.89062
# Epoch: 0026 training loss= 0.00069 time= 0.08424
# validation roc= 0.89923 validation ap= 0.89111
# Epoch: 0027 training loss= 0.00069 time= 0.08784
# validation roc= 0.90026 validation ap= 0.89241
# Epoch: 0028 training loss= 0.00068 time= 0.08719
# validation roc= 0.90127 validation ap= 0.89484
# Epoch: 0029 training loss= 0.00068 time= 0.08583
# validation roc= 0.90269 validation ap= 0.89779
# Epoch: 0030 training loss= 0.00068 time= 0.09494
# validation roc= 0.90299 validation ap= 0.89944
# Epoch: 0031 training loss= 0.00067 time= 0.08829
# validation roc= 0.90298 validation ap= 0.89982
# Epoch: 0032 training loss= 0.00067 time= 0.09058
# validation roc= 0.90243 validation ap= 0.89920
# Epoch: 0033 training loss= 0.00067 time= 0.08567
# validation roc= 0.90189 validation ap= 0.89840
# Epoch: 0034 training loss= 0.00066 time= 0.09836
# validation roc= 0.90163 validation ap= 0.89930
# Epoch: 0035 training loss= 0.00066 time= 0.09149
# validation roc= 0.90263 validation ap= 0.90122
# Epoch: 0036 training loss= 0.00066 time= 0.09805
# validation roc= 0.90397 validation ap= 0.90390
# Epoch: 0037 training loss= 0.00066 time= 0.08184
# validation roc= 0.90402 validation ap= 0.90477
# Epoch: 0038 training loss= 0.00065 time= 0.10522
# validation roc= 0.90422 validation ap= 0.90547
# Epoch: 0039 training loss= 0.00065 time= 0.08782
# validation roc= 0.90432 validation ap= 0.90566
# Epoch: 0040 training loss= 0.00065 time= 0.10702
# validation roc= 0.90448 validation ap= 0.90609
# Epoch: 0041 training loss= 0.00065 time= 0.09559
# validation roc= 0.90525 validation ap= 0.90733
# Epoch: 0042 training loss= 0.00065 time= 0.08830
# validation roc= 0.90582 validation ap= 0.90827
# Epoch: 0043 training loss= 0.00064 time= 0.10067
# validation roc= 0.90695 validation ap= 0.90964
# Epoch: 0044 training loss= 0.00064 time= 0.11857
# validation roc= 0.90782 validation ap= 0.91056
# Epoch: 0045 training loss= 0.00064 time= 0.08877
# validation roc= 0.90860 validation ap= 0.91146
# Epoch: 0046 training loss= 0.00064 time= 0.09995
# validation roc= 0.90935 validation ap= 0.91194
# Epoch: 0047 training loss= 0.00064 time= 0.08615
# validation roc= 0.90997 validation ap= 0.91247
# Epoch: 0048 training loss= 0.00064 time= 0.09233
# validation roc= 0.91036 validation ap= 0.91281
# Epoch: 0049 training loss= 0.00063 time= 0.10086
# validation roc= 0.91107 validation ap= 0.91347
# Epoch: 0050 training loss= 0.00063 time= 0.09025
# validation roc= 0.91165 validation ap= 0.91435
# Epoch: 0051 training loss= 0.00063 time= 0.10422
# validation roc= 0.91206 validation ap= 0.91511
# Epoch: 0052 training loss= 0.00063 time= 0.09406
# validation roc= 0.91252 validation ap= 0.91593
# Epoch: 0053 training loss= 0.00063 time= 0.08656
# validation roc= 0.91308 validation ap= 0.91650
# Epoch: 0054 training loss= 0.00063 time= 0.09531
# validation roc= 0.91379 validation ap= 0.91713
# Epoch: 0055 training loss= 0.00063 time= 0.09372
# validation roc= 0.91440 validation ap= 0.91785
# Epoch: 0056 training loss= 0.00062 time= 0.09742
# validation roc= 0.91498 validation ap= 0.91875
# Epoch: 0057 training loss= 0.00062 time= 0.08970
# validation roc= 0.91563 validation ap= 0.91942
# Epoch: 0058 training loss= 0.00062 time= 0.10464
# validation roc= 0.91635 validation ap= 0.92040
# Epoch: 0059 training loss= 0.00062 time= 0.09448
# validation roc= 0.91667 validation ap= 0.92067
# Epoch: 0060 training loss= 0.00062 time= 0.10661
# validation roc= 0.91651 validation ap= 0.92040
# Epoch: 0061 training loss= 0.00062 time= 0.10188
# validation roc= 0.91688 validation ap= 0.92071
# Epoch: 0062 training loss= 0.00062 time= 0.09411
# validation roc= 0.91745 validation ap= 0.92120
# Epoch: 0063 training loss= 0.00061 time= 0.09197
# validation roc= 0.91780 validation ap= 0.92145
# Epoch: 0064 training loss= 0.00061 time= 0.09722
# validation roc= 0.91794 validation ap= 0.92174
# Epoch: 0065 training loss= 0.00061 time= 0.09835
# validation roc= 0.91797 validation ap= 0.92180
# Epoch: 0066 training loss= 0.00061 time= 0.09367
# validation roc= 0.91797 validation ap= 0.92153
# Epoch: 0067 training loss= 0.00061 time= 0.09180
# validation roc= 0.91795 validation ap= 0.92127
# Epoch: 0068 training loss= 0.00061 time= 0.08945
# validation roc= 0.91808 validation ap= 0.92138
# Epoch: 0069 training loss= 0.00061 time= 0.09839
# validation roc= 0.91806 validation ap= 0.92140
# Epoch: 0070 training loss= 0.00061 time= 0.08628
# validation roc= 0.91839 validation ap= 0.92206
# Epoch: 0071 training loss= 0.00061 time= 0.08031
# validation roc= 0.91884 validation ap= 0.92249
# Epoch: 0072 training loss= 0.00060 time= 0.10775
# validation roc= 0.91914 validation ap= 0.92266
# Epoch: 0073 training loss= 0.00060 time= 0.08734
# validation roc= 0.91966 validation ap= 0.92317
# Epoch: 0074 training loss= 0.00060 time= 0.08146
# validation roc= 0.92007 validation ap= 0.92341
# Epoch: 0075 training loss= 0.00060 time= 0.08092
# validation roc= 0.92086 validation ap= 0.92446
# Epoch: 0076 training loss= 0.00060 time= 0.09842
# validation roc= 0.92161 validation ap= 0.92526
# Epoch: 0077 training loss= 0.00060 time= 0.08677
# validation roc= 0.92229 validation ap= 0.92614
# Epoch: 0078 training loss= 0.00060 time= 0.08318
# validation roc= 0.92275 validation ap= 0.92666
# Epoch: 0079 training loss= 0.00060 time= 0.09122
# validation roc= 0.92327 validation ap= 0.92720
# Epoch: 0080 training loss= 0.00060 time= 0.09368
# validation roc= 0.92381 validation ap= 0.92791
# Epoch: 0081 training loss= 0.00060 time= 0.09725
# validation roc= 0.92443 validation ap= 0.92863
# Epoch: 0082 training loss= 0.00059 time= 0.09117
# validation roc= 0.92497 validation ap= 0.92923
# Epoch: 0083 training loss= 0.00059 time= 0.08281
# validation roc= 0.92557 validation ap= 0.92993
# Epoch: 0084 training loss= 0.00059 time= 0.09575
# validation roc= 0.92618 validation ap= 0.93058
# Epoch: 0085 training loss= 0.00059 time= 0.09819
# validation roc= 0.92637 validation ap= 0.93089
# Epoch: 0086 training loss= 0.00059 time= 0.08459
# validation roc= 0.92666 validation ap= 0.93147
# Epoch: 0087 training loss= 0.00059 time= 0.09362
# validation roc= 0.92695 validation ap= 0.93173
# Epoch: 0088 training loss= 0.00059 time= 0.08218
# validation roc= 0.92708 validation ap= 0.93202
# Epoch: 0089 training loss= 0.00059 time= 0.09109
# validation roc= 0.92744 validation ap= 0.93269
# Epoch: 0090 training loss= 0.00059 time= 0.09615
# validation roc= 0.92744 validation ap= 0.93295
# Epoch: 0091 training loss= 0.00059 time= 0.11085
# validation roc= 0.92732 validation ap= 0.93332
# Epoch: 0092 training loss= 0.00059 time= 0.09818
# validation roc= 0.92712 validation ap= 0.93341
# Epoch: 0093 training loss= 0.00059 time= 0.09169
# validation roc= 0.92750 validation ap= 0.93388
# Epoch: 0094 training loss= 0.00058 time= 0.11190
# validation roc= 0.92784 validation ap= 0.93437
# Epoch: 0095 training loss= 0.00058 time= 0.08877
# validation roc= 0.92777 validation ap= 0.93475
# Epoch: 0096 training loss= 0.00058 time= 0.09301
# validation roc= 0.92771 validation ap= 0.93499
# Epoch: 0097 training loss= 0.00058 time= 0.08626
# validation roc= 0.92800 validation ap= 0.93548
# Epoch: 0098 training loss= 0.00058 time= 0.08409
# validation roc= 0.92822 validation ap= 0.93598
# Epoch: 0099 training loss= 0.00058 time= 0.09520
# validation roc= 0.92828 validation ap= 0.93613
# Epoch: 0100 training loss= 0.00058 time= 0.08590
# validation roc= 0.92836 validation ap= 0.93642
# Epoch: 0101 training loss= 0.00058 time= 0.08639
# validation roc= 0.92816 validation ap= 0.93647
# Epoch: 0102 training loss= 0.00058 time= 0.08603
# validation roc= 0.92805 validation ap= 0.93650
# Epoch: 0103 training loss= 0.00058 time= 0.08324
# validation roc= 0.92807 validation ap= 0.93672
# Epoch: 0104 training loss= 0.00058 time= 0.08800
# validation roc= 0.92787 validation ap= 0.93656
# Epoch: 0105 training loss= 0.00058 time= 0.10140
# validation roc= 0.92777 validation ap= 0.93659
# Epoch: 0106 training loss= 0.00058 time= 0.08470
# validation roc= 0.92767 validation ap= 0.93667
# Epoch: 0107 training loss= 0.00058 time= 0.09050
# validation roc= 0.92774 validation ap= 0.93681
# Epoch: 0108 training loss= 0.00058 time= 0.09327
# validation roc= 0.92766 validation ap= 0.93682
# Epoch: 0109 training loss= 0.00058 time= 0.09101
# validation roc= 0.92751 validation ap= 0.93669
# Epoch: 0110 training loss= 0.00057 time= 0.08487
# validation roc= 0.92757 validation ap= 0.93673
# Epoch: 0111 training loss= 0.00057 time= 0.08803
# validation roc= 0.92770 validation ap= 0.93693
# Epoch: 0112 training loss= 0.00057 time= 0.08480
# validation roc= 0.92763 validation ap= 0.93688
# Epoch: 0113 training loss= 0.00057 time= 0.09317
# validation roc= 0.92761 validation ap= 0.93688
# Epoch: 0114 training loss= 0.00057 time= 0.08152
# validation roc= 0.92732 validation ap= 0.93662
# Epoch: 0115 training loss= 0.00057 time= 0.08425
# validation roc= 0.92722 validation ap= 0.93656
# Epoch: 0116 training loss= 0.00057 time= 0.09620
# validation roc= 0.92709 validation ap= 0.93648
# Epoch: 0117 training loss= 0.00057 time= 0.08420
# validation roc= 0.92712 validation ap= 0.93656
# Epoch: 0118 training loss= 0.00057 time= 0.09206
# validation roc= 0.92700 validation ap= 0.93653
# Epoch: 0119 training loss= 0.00057 time= 0.08546
# validation roc= 0.92715 validation ap= 0.93666
# Epoch: 0120 training loss= 0.00057 time= 0.08911
# validation roc= 0.92705 validation ap= 0.93675
# Epoch: 0121 training loss= 0.00057 time= 0.08836
# validation roc= 0.92692 validation ap= 0.93674
# Epoch: 0122 training loss= 0.00057 time= 0.08315
# validation roc= 0.92685 validation ap= 0.93670
# Epoch: 0123 training loss= 0.00057 time= 0.10501
# validation roc= 0.92699 validation ap= 0.93683
# Epoch: 0124 training loss= 0.00057 time= 0.09201
# validation roc= 0.92693 validation ap= 0.93679
# Epoch: 0125 training loss= 0.00057 time= 0.09190
# validation roc= 0.92689 validation ap= 0.93676
# Epoch: 0126 training loss= 0.00057 time= 0.09752
# validation roc= 0.92715 validation ap= 0.93700
# Epoch: 0127 training loss= 0.00057 time= 0.09564
# validation roc= 0.92751 validation ap= 0.93738
# Epoch: 0128 training loss= 0.00057 time= 0.09997
# validation roc= 0.92732 validation ap= 0.93724
# Epoch: 0129 training loss= 0.00057 time= 0.09316
# validation roc= 0.92729 validation ap= 0.93735
# Epoch: 0130 training loss= 0.00056 time= 0.09150
# validation roc= 0.92747 validation ap= 0.93753
# Epoch: 0131 training loss= 0.00056 time= 0.09788
# validation roc= 0.92758 validation ap= 0.93768
# Epoch: 0132 training loss= 0.00056 time= 0.08896
# validation roc= 0.92783 validation ap= 0.93793
# Epoch: 0133 training loss= 0.00056 time= 0.09112
# validation roc= 0.92818 validation ap= 0.93824
# Epoch: 0134 training loss= 0.00056 time= 0.08813
# validation roc= 0.92842 validation ap= 0.93863
# Epoch: 0135 training loss= 0.00056 time= 0.08946
# validation roc= 0.92829 validation ap= 0.93859
# Epoch: 0136 training loss= 0.00056 time= 0.09000
# validation roc= 0.92855 validation ap= 0.93884
# Epoch: 0137 training loss= 0.00056 time= 0.08569
# validation roc= 0.92887 validation ap= 0.93925
# Epoch: 0138 training loss= 0.00056 time= 0.08618
# validation roc= 0.92894 validation ap= 0.93947
# Epoch: 0139 training loss= 0.00056 time= 0.08370
# validation roc= 0.92906 validation ap= 0.93971
# Epoch: 0140 training loss= 0.00056 time= 0.09508
# validation roc= 0.92894 validation ap= 0.93966
# Epoch: 0141 training loss= 0.00056 time= 0.08450
# validation roc= 0.92930 validation ap= 0.94032
# Epoch: 0142 training loss= 0.00056 time= 0.08412
# validation roc= 0.92881 validation ap= 0.93946
# Epoch: 0143 training loss= 0.00056 time= 0.08902
# validation roc= 0.93007 validation ap= 0.94155
# Epoch: 0144 training loss= 0.00056 time= 0.08535
# validation roc= 0.92757 validation ap= 0.93809
# Epoch: 0145 training loss= 0.00056 time= 0.08497
# validation roc= 0.93030 validation ap= 0.94230
# Epoch: 0146 training loss= 0.00056 time= 0.08712
# validation roc= 0.92901 validation ap= 0.93986
# Epoch: 0147 training loss= 0.00056 time= 0.09216
# validation roc= 0.92857 validation ap= 0.94024
# Epoch: 0148 training loss= 0.00056 time= 0.09186
# validation roc= 0.93024 validation ap= 0.94192
# Epoch: 0149 training loss= 0.00056 time= 0.09832
# validation roc= 0.92875 validation ap= 0.94007
# Epoch: 0150 training loss= 0.00056 time= 0.09288
# validation roc= 0.92871 validation ap= 0.94056
# Epoch: 0151 training loss= 0.00056 time= 0.10219
# validation roc= 0.92985 validation ap= 0.94156
# Epoch: 0152 training loss= 0.00056 time= 0.09477
# validation roc= 0.92873 validation ap= 0.94056
# Epoch: 0153 training loss= 0.00056 time= 0.08193
# validation roc= 0.92893 validation ap= 0.94088
# Epoch: 0154 training loss= 0.00055 time= 0.09156
# validation roc= 0.92948 validation ap= 0.94148
# Epoch: 0155 training loss= 0.00055 time= 0.08852
# validation roc= 0.92877 validation ap= 0.94061
# Epoch: 0156 training loss= 0.00055 time= 0.09054
# validation roc= 0.92916 validation ap= 0.94134
# Epoch: 0157 training loss= 0.00055 time= 0.09386
# validation roc= 0.92913 validation ap= 0.94128
# Epoch: 0158 training loss= 0.00055 time= 0.08886
# validation roc= 0.92867 validation ap= 0.94056
# Epoch: 0159 training loss= 0.00055 time= 0.08281
# validation roc= 0.92907 validation ap= 0.94146
# Epoch: 0160 training loss= 0.00055 time= 0.09627
# validation roc= 0.92910 validation ap= 0.94144
# Epoch: 0161 training loss= 0.00055 time= 0.09842
# validation roc= 0.92883 validation ap= 0.94079
# Epoch: 0162 training loss= 0.00055 time= 0.08608
# validation roc= 0.92932 validation ap= 0.94187
# Epoch: 0163 training loss= 0.00055 time= 0.08896
# validation roc= 0.92904 validation ap= 0.94138
# Epoch: 0164 training loss= 0.00055 time= 0.09784
# validation roc= 0.92855 validation ap= 0.94094
# Epoch: 0165 training loss= 0.00055 time= 0.09756
# validation roc= 0.92949 validation ap= 0.94199
# Epoch: 0166 training loss= 0.00055 time= 0.08424
# validation roc= 0.92877 validation ap= 0.94132
# Epoch: 0167 training loss= 0.00055 time= 0.09030
# validation roc= 0.92893 validation ap= 0.94140
# Epoch: 0168 training loss= 0.00055 time= 0.08546
# validation roc= 0.92967 validation ap= 0.94214
# Epoch: 0169 training loss= 0.00055 time= 0.10390
# validation roc= 0.92899 validation ap= 0.94189
# Epoch: 0170 training loss= 0.00055 time= 0.08258
# validation roc= 0.92932 validation ap= 0.94175
# Epoch: 0171 training loss= 0.00055 time= 0.10188
# validation roc= 0.92971 validation ap= 0.94246
# Epoch: 0172 training loss= 0.00055 time= 0.08756
# validation roc= 0.92897 validation ap= 0.94191
# Epoch: 0173 training loss= 0.00055 time= 0.08832
# validation roc= 0.92953 validation ap= 0.94231
# Epoch: 0174 training loss= 0.00055 time= 0.08856
# validation roc= 0.92951 validation ap= 0.94254
# Epoch: 0175 training loss= 0.00055 time= 0.08051
# validation roc= 0.92896 validation ap= 0.94194
# Epoch: 0176 training loss= 0.00055 time= 0.09012
# validation roc= 0.92965 validation ap= 0.94255
# Epoch: 0177 training loss= 0.00055 time= 0.09685
# validation roc= 0.92929 validation ap= 0.94233
# Epoch: 0178 training loss= 0.00055 time= 0.08990
# validation roc= 0.92913 validation ap= 0.94227
# Epoch: 0179 training loss= 0.00055 time= 0.08932
# validation roc= 0.92981 validation ap= 0.94269
# Epoch: 0180 training loss= 0.00055 time= 0.08597
# validation roc= 0.92936 validation ap= 0.94254
# Epoch: 0181 training loss= 0.00055 time= 0.09390
# validation roc= 0.92971 validation ap= 0.94250
# Epoch: 0182 training loss= 0.00055 time= 0.08425
# validation roc= 0.93001 validation ap= 0.94317
# Epoch: 0183 training loss= 0.00055 time= 0.09935
# validation roc= 0.92946 validation ap= 0.94229
# Epoch: 0184 training loss= 0.00055 time= 0.08479
# validation roc= 0.93020 validation ap= 0.94342
# Epoch: 0185 training loss= 0.00055 time= 0.09031
# validation roc= 0.92994 validation ap= 0.94257
# Epoch: 0186 training loss= 0.00055 time= 0.08670
# validation roc= 0.92968 validation ap= 0.94337
# Epoch: 0187 training loss= 0.00055 time= 0.08182
# validation roc= 0.93008 validation ap= 0.94236
# Epoch: 0188 training loss= 0.00055 time= 0.09134
# validation roc= 0.92953 validation ap= 0.94368
# Epoch: 0189 training loss= 0.00055 time= 0.08883
# validation roc= 0.92955 validation ap= 0.94140
# Epoch: 0190 training loss= 0.00055 time= 0.09948
# validation roc= 0.92995 validation ap= 0.94382
# Epoch: 0191 training loss= 0.00055 time= 0.08342
# validation roc= 0.92968 validation ap= 0.94241
# Epoch: 0192 training loss= 0.00054 time= 0.09523
# validation roc= 0.93017 validation ap= 0.94291
# Epoch: 0193 training loss= 0.00054 time= 0.08996
# validation roc= 0.92980 validation ap= 0.94342
# Epoch: 0194 training loss= 0.00054 time= 0.10027
# validation roc= 0.92977 validation ap= 0.94196
# Epoch: 0195 training loss= 0.00054 time= 0.08474
# validation roc= 0.93045 validation ap= 0.94384
# Epoch: 0196 training loss= 0.00054 time= 0.09857
# validation roc= 0.92968 validation ap= 0.94270
# Epoch: 0197 training loss= 0.00054 time= 0.08348
# validation roc= 0.93071 validation ap= 0.94321
# Epoch: 0198 training loss= 0.00054 time= 0.08617
# validation roc= 0.92991 validation ap= 0.94345
# Epoch: 0199 training loss= 0.00054 time= 0.08437
# validation roc= 0.93004 validation ap= 0.94256
# Epoch: 0200 training loss= 0.00054 time= 0.08274
# validation roc= 0.93032 validation ap= 0.94331
# testing roc= 0.92896 testing ap= 0.94152
# Epoch: 0001 training loss= 0.00103 time= 0.81617
# validation roc= 0.69556 validation ap= 0.70584
# Epoch: 0002 training loss= 0.00099 time= 0.12492
# validation roc= 0.67838 validation ap= 0.70215
# Epoch: 0003 training loss= 0.00107 time= 0.09071
# validation roc= 0.75330 validation ap= 0.76106
# Epoch: 0004 training loss= 0.00095 time= 0.08628
# validation roc= 0.69718 validation ap= 0.70936
# Epoch: 0005 training loss= 0.00095 time= 0.08802
# validation roc= 0.67620 validation ap= 0.69593
# Epoch: 0006 training loss= 0.00095 time= 0.09047
# validation roc= 0.72989 validation ap= 0.73952
# Epoch: 0007 training loss= 0.00093 time= 0.09960
# validation roc= 0.78537 validation ap= 0.78393
# Epoch: 0008 training loss= 0.00090 time= 0.08957
# validation roc= 0.81242 validation ap= 0.79816
# Epoch: 0009 training loss= 0.00088 time= 0.09871
# validation roc= 0.82862 validation ap= 0.80818
# Epoch: 0010 training loss= 0.00085 time= 0.09690
# validation roc= 0.83983 validation ap= 0.81572
# Epoch: 0011 training loss= 0.00082 time= 0.09498
# validation roc= 0.84366 validation ap= 0.81937
# Epoch: 0012 training loss= 0.00080 time= 0.09223
# validation roc= 0.84947 validation ap= 0.82576
# Epoch: 0013 training loss= 0.00079 time= 0.10174
# validation roc= 0.85853 validation ap= 0.83772
# Epoch: 0014 training loss= 0.00077 time= 0.11944
# validation roc= 0.86287 validation ap= 0.84357
# Epoch: 0015 training loss= 0.00076 time= 0.09780
# validation roc= 0.86701 validation ap= 0.84794
# Epoch: 0016 training loss= 0.00075 time= 0.08299
# validation roc= 0.87273 validation ap= 0.85448
# Epoch: 0017 training loss= 0.00074 time= 0.09277
# validation roc= 0.87954 validation ap= 0.86152
# Epoch: 0018 training loss= 0.00074 time= 0.09891
# validation roc= 0.88596 validation ap= 0.86958
# Epoch: 0019 training loss= 0.00073 time= 0.10510
# validation roc= 0.89090 validation ap= 0.87544
# Epoch: 0020 training loss= 0.00072 time= 0.10042
# validation roc= 0.89474 validation ap= 0.88169
# Epoch: 0021 training loss= 0.00071 time= 0.08556
# validation roc= 0.89711 validation ap= 0.88555
# Epoch: 0022 training loss= 0.00071 time= 0.08820
# validation roc= 0.89769 validation ap= 0.88726
# Epoch: 0023 training loss= 0.00070 time= 0.09259
# validation roc= 0.89770 validation ap= 0.88621
# Epoch: 0024 training loss= 0.00070 time= 0.08729
# validation roc= 0.89836 validation ap= 0.88675
# Epoch: 0025 training loss= 0.00070 time= 0.09674
# validation roc= 0.89952 validation ap= 0.88699
# Epoch: 0026 training loss= 0.00069 time= 0.11414
# validation roc= 0.90049 validation ap= 0.88679
# Epoch: 0027 training loss= 0.00069 time= 0.11375
# validation roc= 0.90056 validation ap= 0.88632
# Epoch: 0028 training loss= 0.00069 time= 0.11714
# validation roc= 0.90160 validation ap= 0.88699
# Epoch: 0029 training loss= 0.00068 time= 0.10429
# validation roc= 0.90189 validation ap= 0.88844
# Epoch: 0030 training loss= 0.00068 time= 0.12104
# validation roc= 0.90191 validation ap= 0.88930
# Epoch: 0031 training loss= 0.00067 time= 0.09407
# validation roc= 0.90186 validation ap= 0.88956
# Epoch: 0032 training loss= 0.00067 time= 0.11150
# validation roc= 0.90204 validation ap= 0.88986
# Epoch: 0033 training loss= 0.00067 time= 0.09314
# validation roc= 0.90367 validation ap= 0.89149
# Epoch: 0034 training loss= 0.00067 time= 0.09165
# validation roc= 0.90499 validation ap= 0.89221
# Epoch: 0035 training loss= 0.00066 time= 0.09073
# validation roc= 0.90613 validation ap= 0.89386
# Epoch: 0036 training loss= 0.00066 time= 0.09624
# validation roc= 0.90743 validation ap= 0.89522
# Epoch: 0037 training loss= 0.00066 time= 0.09939
# validation roc= 0.90792 validation ap= 0.89572
# Epoch: 0038 training loss= 0.00066 time= 0.09358
# validation roc= 0.90877 validation ap= 0.89701
# Epoch: 0039 training loss= 0.00065 time= 0.09423
# validation roc= 0.91005 validation ap= 0.89850
# Epoch: 0040 training loss= 0.00065 time= 0.09343
# validation roc= 0.91097 validation ap= 0.90011
# Epoch: 0041 training loss= 0.00065 time= 0.08153
# validation roc= 0.91208 validation ap= 0.90218
# Epoch: 0042 training loss= 0.00065 time= 0.08212
# validation roc= 0.91284 validation ap= 0.90353
# Epoch: 0043 training loss= 0.00065 time= 0.09264
# validation roc= 0.91411 validation ap= 0.90576
# Epoch: 0044 training loss= 0.00064 time= 0.09985
# validation roc= 0.91483 validation ap= 0.90669
# Epoch: 0045 training loss= 0.00064 time= 0.08861
# validation roc= 0.91567 validation ap= 0.90810
# Epoch: 0046 training loss= 0.00064 time= 0.09702
# validation roc= 0.91674 validation ap= 0.90999
# Epoch: 0047 training loss= 0.00064 time= 0.08195
# validation roc= 0.91717 validation ap= 0.91081
# Epoch: 0048 training loss= 0.00064 time= 0.10269
# validation roc= 0.91804 validation ap= 0.91239
# Epoch: 0049 training loss= 0.00064 time= 0.08204
# validation roc= 0.91939 validation ap= 0.91424
# Epoch: 0050 training loss= 0.00063 time= 0.08598
# validation roc= 0.92111 validation ap= 0.91624
# Epoch: 0051 training loss= 0.00063 time= 0.09382
# validation roc= 0.92249 validation ap= 0.91764
# Epoch: 0052 training loss= 0.00063 time= 0.09412
# validation roc= 0.92364 validation ap= 0.91876
# Epoch: 0053 training loss= 0.00063 time= 0.10023
# validation roc= 0.92487 validation ap= 0.91971
# Epoch: 0054 training loss= 0.00063 time= 0.09309
# validation roc= 0.92592 validation ap= 0.92089
# Epoch: 0055 training loss= 0.00063 time= 0.08985
# validation roc= 0.92755 validation ap= 0.92357
# Epoch: 0056 training loss= 0.00063 time= 0.08431
# validation roc= 0.92919 validation ap= 0.92573
# Epoch: 0057 training loss= 0.00062 time= 0.08487
# validation roc= 0.93091 validation ap= 0.92820
# Epoch: 0058 training loss= 0.00062 time= 0.09413
# validation roc= 0.93222 validation ap= 0.92983
# Epoch: 0059 training loss= 0.00062 time= 0.08151
# validation roc= 0.93377 validation ap= 0.93185
# Epoch: 0060 training loss= 0.00062 time= 0.09484
# validation roc= 0.93512 validation ap= 0.93382
# Epoch: 0061 training loss= 0.00062 time= 0.08605
# validation roc= 0.93668 validation ap= 0.93550
# Epoch: 0062 training loss= 0.00062 time= 0.08742
# validation roc= 0.93827 validation ap= 0.93752
# Epoch: 0063 training loss= 0.00061 time= 0.08847
# validation roc= 0.93942 validation ap= 0.93923
# Epoch: 0064 training loss= 0.00061 time= 0.09275
# validation roc= 0.94065 validation ap= 0.94052
# Epoch: 0065 training loss= 0.00061 time= 0.09570
# validation roc= 0.94169 validation ap= 0.94162
# Epoch: 0066 training loss= 0.00061 time= 0.07975
# validation roc= 0.94249 validation ap= 0.94238
# Epoch: 0067 training loss= 0.00061 time= 0.08456
# validation roc= 0.94317 validation ap= 0.94294
# Epoch: 0068 training loss= 0.00061 time= 0.09340
# validation roc= 0.94353 validation ap= 0.94348
# Epoch: 0069 training loss= 0.00061 time= 0.08658
# validation roc= 0.94362 validation ap= 0.94384
# Epoch: 0070 training loss= 0.00061 time= 0.09741
# validation roc= 0.94391 validation ap= 0.94446
# Epoch: 0071 training loss= 0.00061 time= 0.10483
# validation roc= 0.94392 validation ap= 0.94469
# Epoch: 0072 training loss= 0.00060 time= 0.09676
# validation roc= 0.94408 validation ap= 0.94503
# Epoch: 0073 training loss= 0.00060 time= 0.07803
# validation roc= 0.94443 validation ap= 0.94567
# Epoch: 0074 training loss= 0.00060 time= 0.08730
# validation roc= 0.94472 validation ap= 0.94627
# Epoch: 0075 training loss= 0.00060 time= 0.09694
# validation roc= 0.94493 validation ap= 0.94674
# Epoch: 0076 training loss= 0.00060 time= 0.08882
# validation roc= 0.94537 validation ap= 0.94741
# Epoch: 0077 training loss= 0.00060 time= 0.09966
# validation roc= 0.94557 validation ap= 0.94806
# Epoch: 0078 training loss= 0.00060 time= 0.09353
# validation roc= 0.94539 validation ap= 0.94821
# Epoch: 0079 training loss= 0.00060 time= 0.08822
# validation roc= 0.94544 validation ap= 0.94866
# Epoch: 0080 training loss= 0.00060 time= 0.08549
# validation roc= 0.94567 validation ap= 0.94922
# Epoch: 0081 training loss= 0.00059 time= 0.08676
# validation roc= 0.94560 validation ap= 0.94952
# Epoch: 0082 training loss= 0.00059 time= 0.08260
# validation roc= 0.94547 validation ap= 0.94966
# Epoch: 0083 training loss= 0.00059 time= 0.09092
# validation roc= 0.94545 validation ap= 0.95011
# Epoch: 0084 training loss= 0.00059 time= 0.09405
# validation roc= 0.94545 validation ap= 0.95019
# Epoch: 0085 training loss= 0.00059 time= 0.09436
# validation roc= 0.94529 validation ap= 0.95028
# Epoch: 0086 training loss= 0.00059 time= 0.09122
# validation roc= 0.94482 validation ap= 0.95004
# Epoch: 0087 training loss= 0.00059 time= 0.10778
# validation roc= 0.94431 validation ap= 0.94985
# Epoch: 0088 training loss= 0.00059 time= 0.09560
# validation roc= 0.94402 validation ap= 0.94986
# Epoch: 0089 training loss= 0.00059 time= 0.09149
# validation roc= 0.94373 validation ap= 0.94982
# Epoch: 0090 training loss= 0.00059 time= 0.08440
# validation roc= 0.94356 validation ap= 0.94988
# Epoch: 0091 training loss= 0.00059 time= 0.08111
# validation roc= 0.94323 validation ap= 0.94991
# Epoch: 0092 training loss= 0.00058 time= 0.08009
# validation roc= 0.94324 validation ap= 0.95006
# ...
# Epoch: 0035 training loss= 0.00066 time= 0.12388
# validation roc= 0.89605 validation ap= 0.89066
# Epoch: 0036 training loss= 0.00066 time= 0.12144
# validation roc= 0.89591 validation ap= 0.88928
# Epoch: 0037 training loss= 0.00066 time= 0.12431
# validation roc= 0.89552 validation ap= 0.88810
# Epoch: 0038 training loss= 0.00065 time= 0.12052
# validation roc= 0.89602 validation ap= 0.88840
# Epoch: 0039 training loss= 0.00065 time= 0.10051
# validation roc= 0.89747 validation ap= 0.88923
# Epoch: 0040 training loss= 0.00065 time= 0.13161
# validation roc= 0.89967 validation ap= 0.89257
# Epoch: 0041 training loss= 0.00065 time= 0.08738
# validation roc= 0.90196 validation ap= 0.89595
# Epoch: 0042 training loss= 0.00065 time= 0.09266
# validation roc= 0.90361 validation ap= 0.89852
# Epoch: 0043 training loss= 0.00065 time= 0.13110
# validation roc= 0.90509 validation ap= 0.90065
# Epoch: 0044 training loss= 0.00064 time= 0.11889
# validation roc= 0.90575 validation ap= 0.90151
# Epoch: 0045 training loss= 0.00064 time= 0.09372
# validation roc= 0.90675 validation ap= 0.90266
# Epoch: 0046 training loss= 0.00064 time= 0.13048
# validation roc= 0.90723 validation ap= 0.90318
# Epoch: 0047 training loss= 0.00064 time= 0.10604
# validation roc= 0.90769 validation ap= 0.90380
# Epoch: 0048 training loss= 0.00064 time= 0.10923
# validation roc= 0.90794 validation ap= 0.90392
# Epoch: 0049 training loss= 0.00064 time= 0.13717
# validation roc= 0.90775 validation ap= 0.90379
# Epoch: 0050 training loss= 0.00063 time= 0.10267
# validation roc= 0.90769 validation ap= 0.90321
# Epoch: 0051 training loss= 0.00063 time= 0.15449
# validation roc= 0.90772 validation ap= 0.90313
# Epoch: 0052 training loss= 0.00063 time= 0.13628
# validation roc= 0.90772 validation ap= 0.90341
# Epoch: 0053 training loss= 0.00063 time= 0.11562
# validation roc= 0.90768 validation ap= 0.90303
# Epoch: 0054 training loss= 0.00063 time= 0.14296
# validation roc= 0.90817 validation ap= 0.90364
# Epoch: 0055 training loss= 0.00063 time= 0.12885
# validation roc= 0.90801 validation ap= 0.90305
# Epoch: 0056 training loss= 0.00062 time= 0.21463
# validation roc= 0.90895 validation ap= 0.90390
# Epoch: 0057 training loss= 0.00062 time= 0.33092
# validation roc= 0.90931 validation ap= 0.90375
# Epoch: 0058 training loss= 0.00062 time= 0.16691
# validation roc= 0.91000 validation ap= 0.90412
# Epoch: 0059 training loss= 0.00062 time= 0.17636
# validation roc= 0.91016 validation ap= 0.90445
# Epoch: 0060 training loss= 0.00062 time= 0.15753
# validation roc= 0.91064 validation ap= 0.90518
# Epoch: 0061 training loss= 0.00062 time= 0.10406
# validation roc= 0.91083 validation ap= 0.90557
# Epoch: 0062 training loss= 0.00062 time= 0.14577
# validation roc= 0.91156 validation ap= 0.90621
# Epoch: 0063 training loss= 0.00061 time= 0.22691
# validation roc= 0.91208 validation ap= 0.90676
# Epoch: 0064 training loss= 0.00061 time= 0.12084
# validation roc= 0.91240 validation ap= 0.90749
# Epoch: 0065 training loss= 0.00061 time= 0.15719
# validation roc= 0.91266 validation ap= 0.90780
# Epoch: 0066 training loss= 0.00061 time= 0.19671
# validation roc= 0.91291 validation ap= 0.90825
# Epoch: 0067 training loss= 0.00061 time= 0.08759
# validation roc= 0.91336 validation ap= 0.90871
# Epoch: 0068 training loss= 0.00061 time= 0.09772
# validation roc= 0.91372 validation ap= 0.90946
# Epoch: 0069 training loss= 0.00061 time= 0.21784
# validation roc= 0.91385 validation ap= 0.90980
# Epoch: 0070 training loss= 0.00060 time= 0.10411
# validation roc= 0.91381 validation ap= 0.90966
# Epoch: 0071 training loss= 0.00060 time= 0.11496
# validation roc= 0.91386 validation ap= 0.90977
# Epoch: 0072 training loss= 0.00060 time= 0.50345
# validation roc= 0.91402 validation ap= 0.90999
# Epoch: 0073 training loss= 0.00060 time= 0.10669
# validation roc= 0.91433 validation ap= 0.91013
# Epoch: 0074 training loss= 0.00060 time= 0.10269
# validation roc= 0.91463 validation ap= 0.91032
# Epoch: 0075 training loss= 0.00060 time= 0.13215
# validation roc= 0.91469 validation ap= 0.90995
# Epoch: 0076 training loss= 0.00060 time= 0.12754
# validation roc= 0.91482 validation ap= 0.90995
# Epoch: 0077 training loss= 0.00060 time= 0.14530
# validation roc= 0.91509 validation ap= 0.90987
# Epoch: 0078 training loss= 0.00060 time= 0.17041
# validation roc= 0.91527 validation ap= 0.91040
# Epoch: 0079 training loss= 0.00059 time= 0.13263
# validation roc= 0.91534 validation ap= 0.91092
# Epoch: 0080 training loss= 0.00059 time= 0.12758
# validation roc= 0.91567 validation ap= 0.91173
# Epoch: 0081 training loss= 0.00059 time= 0.15601
# validation roc= 0.91600 validation ap= 0.91234
# Epoch: 0082 training loss= 0.00059 time= 0.14828
# validation roc= 0.91625 validation ap= 0.91240
# Epoch: 0083 training loss= 0.00059 time= 0.12277
# validation roc= 0.91680 validation ap= 0.91337
# Epoch: 0084 training loss= 0.00059 time= 0.13271
# validation roc= 0.91716 validation ap= 0.91415
# Epoch: 0085 training loss= 0.00059 time= 0.09139
# validation roc= 0.91743 validation ap= 0.91515
# Epoch: 0086 training loss= 0.00059 time= 0.10224
# validation roc= 0.91748 validation ap= 0.91547
# Epoch: 0087 training loss= 0.00059 time= 0.14328
# validation roc= 0.91769 validation ap= 0.91583
# Epoch: 0088 training loss= 0.00059 time= 0.10638
# validation roc= 0.91788 validation ap= 0.91629
# Epoch: 0089 training loss= 0.00059 time= 0.10677
# validation roc= 0.91827 validation ap= 0.91686
# Epoch: 0090 training loss= 0.00059 time= 0.21781
# validation roc= 0.91866 validation ap= 0.91744
# Epoch: 0091 training loss= 0.00058 time= 0.09827
# validation roc= 0.91885 validation ap= 0.91797
# Epoch: 0092 training loss= 0.00058 time= 0.09683
# validation roc= 0.91913 validation ap= 0.91823
# Epoch: 0093 training loss= 0.00058 time= 0.24109
# validation roc= 0.91928 validation ap= 0.91839
# Epoch: 0094 training loss= 0.00058 time= 0.13355
# validation roc= 0.91981 validation ap= 0.91923
# Epoch: 0095 training loss= 0.00058 time= 0.11749
# validation roc= 0.92004 validation ap= 0.91965
# Epoch: 0096 training loss= 0.00058 time= 0.14203
# validation roc= 0.92041 validation ap= 0.92038
# Epoch: 0097 training loss= 0.00058 time= 0.10376
# validation roc= 0.92066 validation ap= 0.92086
# Epoch: 0098 training loss= 0.00058 time= 0.11013
# validation roc= 0.92095 validation ap= 0.92122
# Epoch: 0099 training loss= 0.00058 time= 0.15998
# validation roc= 0.92144 validation ap= 0.92176
# Epoch: 0100 training loss= 0.00058 time= 0.10777
# validation roc= 0.92154 validation ap= 0.92202
# Epoch: 0101 training loss= 0.00058 time= 0.13197
# validation roc= 0.92200 validation ap= 0.92255
# Epoch: 0102 training loss= 0.00058 time= 0.10487
# validation roc= 0.92213 validation ap= 0.92268
# Epoch: 0103 training loss= 0.00058 time= 0.12533
# validation roc= 0.92255 validation ap= 0.92298
# Epoch: 0104 training loss= 0.00058 time= 0.16715
# validation roc= 0.92286 validation ap= 0.92336
# Epoch: 0105 training loss= 0.00058 time= 0.14839
# validation roc= 0.92320 validation ap= 0.92366
# Epoch: 0106 training loss= 0.00057 time= 0.13914
# validation roc= 0.92340 validation ap= 0.92380
# Epoch: 0107 training loss= 0.00057 time= 0.17258
# validation roc= 0.92346 validation ap= 0.92394
# Epoch: 0108 training loss= 0.00057 time= 0.13659
# validation roc= 0.92351 validation ap= 0.92392
# Epoch: 0109 training loss= 0.00057 time= 0.15438
# validation roc= 0.92358 validation ap= 0.92402
# Epoch: 0110 training loss= 0.00057 time= 0.16473
# validation roc= 0.92369 validation ap= 0.92402
# Epoch: 0111 training loss= 0.00057 time= 0.16794
# validation roc= 0.92406 validation ap= 0.92429
# Epoch: 0112 training loss= 0.00057 time= 0.18612
# validation roc= 0.92427 validation ap= 0.92483
# Epoch: 0113 training loss= 0.00057 time= 0.13978
# validation roc= 0.92430 validation ap= 0.92491
# Epoch: 0114 training loss= 0.00057 time= 0.13000
# validation roc= 0.92453 validation ap= 0.92528
# Epoch: 0115 training loss= 0.00057 time= 0.16413
# validation roc= 0.92450 validation ap= 0.92537
# Epoch: 0116 training loss= 0.00057 time= 0.14151
# validation roc= 0.92466 validation ap= 0.92552
# Epoch: 0117 training loss= 0.00057 time= 0.11443
# validation roc= 0.92456 validation ap= 0.92554
# Epoch: 0118 training loss= 0.00057 time= 0.19672
# validation roc= 0.92442 validation ap= 0.92546
# Epoch: 0119 training loss= 0.00057 time= 0.15946
# validation roc= 0.92437 validation ap= 0.92550
# Epoch: 0120 training loss= 0.00057 time= 0.16490
# validation roc= 0.92434 validation ap= 0.92562
# Epoch: 0121 training loss= 0.00057 time= 0.14221
# validation roc= 0.92436 validation ap= 0.92589
# Epoch: 0122 training loss= 0.00057 time= 0.14909
# validation roc= 0.92430 validation ap= 0.92621
# Epoch: 0123 training loss= 0.00057 time= 0.12897
# validation roc= 0.92419 validation ap= 0.92608
# Epoch: 0124 training loss= 0.00056 time= 0.11738
# validation roc= 0.92426 validation ap= 0.92619
# Epoch: 0125 training loss= 0.00056 time= 0.09925
# validation roc= 0.92419 validation ap= 0.92616
# Epoch: 0126 training loss= 0.00056 time= 0.08667
# validation roc= 0.92407 validation ap= 0.92606
# Epoch: 0127 training loss= 0.00056 time= 0.15053
# validation roc= 0.92397 validation ap= 0.92600
# Epoch: 0128 training loss= 0.00056 time= 0.09244
# validation roc= 0.92385 validation ap= 0.92591
# Epoch: 0129 training loss= 0.00056 time= 0.09457
# validation roc= 0.92361 validation ap= 0.92565
# Epoch: 0130 training loss= 0.00056 time= 0.19376
# validation roc= 0.92342 validation ap= 0.92562
# Epoch: 0131 training loss= 0.00056 time= 0.18116
# validation roc= 0.92338 validation ap= 0.92551
# Epoch: 0132 training loss= 0.00056 time= 0.13391
# validation roc= 0.92351 validation ap= 0.92572
# Epoch: 0133 training loss= 0.00056 time= 0.12941
# validation roc= 0.92329 validation ap= 0.92557
# Epoch: 0134 training loss= 0.00056 time= 0.11264
# validation roc= 0.92296 validation ap= 0.92521
# Epoch: 0135 training loss= 0.00056 time= 0.12799
# validation roc= 0.92280 validation ap= 0.92503
# Epoch: 0136 training loss= 0.00056 time= 0.14166
# validation roc= 0.92270 validation ap= 0.92496
# Epoch: 0137 training loss= 0.00056 time= 0.09354
# validation roc= 0.92271 validation ap= 0.92491
# Epoch: 0138 training loss= 0.00056 time= 0.09217
# validation roc= 0.92248 validation ap= 0.92470
# Epoch: 0139 training loss= 0.00056 time= 0.13509
# validation roc= 0.92261 validation ap= 0.92474
# Epoch: 0140 training loss= 0.00056 time= 0.11103
# validation roc= 0.92255 validation ap= 0.92472
# Epoch: 0141 training loss= 0.00056 time= 0.12139
# validation roc= 0.92303 validation ap= 0.92515
# Epoch: 0142 training loss= 0.00056 time= 0.15037
# validation roc= 0.92252 validation ap= 0.92489
# Epoch: 0143 training loss= 0.00056 time= 0.11777
# validation roc= 0.92312 validation ap= 0.92504
# Epoch: 0144 training loss= 0.00056 time= 0.13825
# validation roc= 0.92210 validation ap= 0.92522
# Epoch: 0145 training loss= 0.00056 time= 0.11894
# validation roc= 0.92395 validation ap= 0.92573
# Epoch: 0146 training loss= 0.00056 time= 0.10184
# validation roc= 0.92105 validation ap= 0.92481
# Epoch: 0147 training loss= 0.00056 time= 0.11816
# validation roc= 0.92380 validation ap= 0.92558
# Epoch: 0148 training loss= 0.00056 time= 0.11985
# validation roc= 0.92222 validation ap= 0.92520
# Epoch: 0149 training loss= 0.00055 time= 0.11663
# validation roc= 0.92196 validation ap= 0.92505
# Epoch: 0150 training loss= 0.00055 time= 0.15309
# validation roc= 0.92343 validation ap= 0.92559
# Epoch: 0151 training loss= 0.00055 time= 0.15334
# validation roc= 0.92207 validation ap= 0.92538
# Epoch: 0152 training loss= 0.00055 time= 0.12163
# validation roc= 0.92215 validation ap= 0.92511
# Epoch: 0153 training loss= 0.00055 time= 0.17266
# validation roc= 0.92377 validation ap= 0.92630
# Epoch: 0154 training loss= 0.00055 time= 0.13274
# validation roc= 0.92161 validation ap= 0.92502
# Epoch: 0155 training loss= 0.00055 time= 0.13062
# validation roc= 0.92239 validation ap= 0.92521
# Epoch: 0156 training loss= 0.00055 time= 0.18991
# validation roc= 0.92283 validation ap= 0.92556
# Epoch: 0157 training loss= 0.00055 time= 0.13938
# validation roc= 0.92184 validation ap= 0.92528
# Epoch: 0158 training loss= 0.00055 time= 0.14580
# validation roc= 0.92283 validation ap= 0.92593
# Epoch: 0159 training loss= 0.00055 time= 0.23050
# validation roc= 0.92254 validation ap= 0.92575
# Epoch: 0160 training loss= 0.00055 time= 0.14162
# validation roc= 0.92203 validation ap= 0.92560
# Epoch: 0161 training loss= 0.00055 time= 0.11099
# validation roc= 0.92319 validation ap= 0.92644
# Epoch: 0162 training loss= 0.00055 time= 0.11021
# validation roc= 0.92245 validation ap= 0.92580
# Epoch: 0163 training loss= 0.00055 time= 0.11315
# validation roc= 0.92226 validation ap= 0.92577
# Epoch: 0164 training loss= 0.00055 time= 0.12750
# validation roc= 0.92258 validation ap= 0.92605
# Epoch: 0165 training loss= 0.00055 time= 0.09783
# validation roc= 0.92223 validation ap= 0.92602
# Epoch: 0166 training loss= 0.00055 time= 0.09227
# validation roc= 0.92245 validation ap= 0.92626
# Epoch: 0167 training loss= 0.00055 time= 0.11998
# validation roc= 0.92215 validation ap= 0.92609
# Epoch: 0168 training loss= 0.00055 time= 0.09127
# validation roc= 0.92203 validation ap= 0.92625
# Epoch: 0169 training loss= 0.00055 time= 0.08995
# validation roc= 0.92231 validation ap= 0.92620
# Epoch: 0170 training loss= 0.00055 time= 0.11843
# validation roc= 0.92222 validation ap= 0.92641
# Epoch: 0171 training loss= 0.00055 time= 0.10364
# validation roc= 0.92197 validation ap= 0.92623
# Epoch: 0172 training loss= 0.00055 time= 0.14811
# validation roc= 0.92254 validation ap= 0.92662
# Epoch: 0173 training loss= 0.00055 time= 0.16141
# validation roc= 0.92190 validation ap= 0.92622
# Epoch: 0174 training loss= 0.00055 time= 0.14441
# validation roc= 0.92228 validation ap= 0.92643
# Epoch: 0175 training loss= 0.00055 time= 0.12876
# validation roc= 0.92216 validation ap= 0.92652
# Epoch: 0176 training loss= 0.00055 time= 0.11033
# validation roc= 0.92190 validation ap= 0.92622
# Epoch: 0177 training loss= 0.00055 time= 0.12964
# validation roc= 0.92232 validation ap= 0.92669
# Epoch: 0178 training loss= 0.00055 time= 0.14025
# validation roc= 0.92229 validation ap= 0.92662
# Epoch: 0179 training loss= 0.00055 time= 0.17572
# validation roc= 0.92147 validation ap= 0.92618
# Epoch: 0180 training loss= 0.00055 time= 0.13696
# validation roc= 0.92306 validation ap= 0.92727
# Epoch: 0181 training loss= 0.00055 time= 0.13933
# validation roc= 0.92099 validation ap= 0.92598
# Epoch: 0182 training loss= 0.00054 time= 0.15978
# validation roc= 0.92260 validation ap= 0.92686
# Epoch: 0183 training loss= 0.00054 time= 0.12087
# validation roc= 0.92167 validation ap= 0.92635
# Epoch: 0184 training loss= 0.00054 time= 0.13308
# validation roc= 0.92147 validation ap= 0.92632
# Epoch: 0185 training loss= 0.00054 time= 0.16556
# validation roc= 0.92236 validation ap= 0.92683
# Epoch: 0186 training loss= 0.00054 time= 0.13617
# validation roc= 0.92096 validation ap= 0.92600
# Epoch: 0187 training loss= 0.00054 time= 0.12880
# validation roc= 0.92196 validation ap= 0.92666
# Epoch: 0188 training loss= 0.00054 time= 0.16861
# validation roc= 0.92115 validation ap= 0.92622
# Epoch: 0189 training loss= 0.00054 time= 0.12393
# validation roc= 0.92170 validation ap= 0.92656
# Epoch: 0190 training loss= 0.00054 time= 0.11990
# validation roc= 0.92095 validation ap= 0.92606
# Epoch: 0191 training loss= 0.00054 time= 0.11232
# validation roc= 0.92147 validation ap= 0.92640
# Epoch: 0192 training loss= 0.00054 time= 0.12466
# validation roc= 0.92053 validation ap= 0.92603
# Epoch: 0193 training loss= 0.00054 time= 0.12167
# validation roc= 0.92128 validation ap= 0.92637
# Epoch: 0194 training loss= 0.00054 time= 0.14321
# validation roc= 0.92073 validation ap= 0.92624
# Epoch: 0195 training loss= 0.00054 time= 0.15208
# validation roc= 0.92074 validation ap= 0.92621
# Epoch: 0196 training loss= 0.00054 time= 0.11862
# validation roc= 0.92070 validation ap= 0.92613
# Epoch: 0197 training loss= 0.00054 time= 0.10783
# validation roc= 0.92008 validation ap= 0.92572
# Epoch: 0198 training loss= 0.00054 time= 0.15007
# validation roc= 0.92090 validation ap= 0.92627
# Epoch: 0199 training loss= 0.00054 time= 0.16603
# validation roc= 0.91957 validation ap= 0.92545
# Epoch: 0200 training loss= 0.00054 time= 0.12237
# validation roc= 0.92099 validation ap= 0.92636
# testing roc= 0.94728 testing ap= 0.95428

# %% [markdown]
# # Results

# %%
time_10run=results_output_path+"layers_"+str(layers_no)+"_time_10run.csv"
roc_10run=results_output_path+"layers_"+str(layers_no)+"_roc_10run.csv"
ap_10run=results_output_path+"layers_"+str(layers_no)+"_ap_10run.csv"

mean_time_read=np.array(pd.read_csv(time_10run,header=None))
mean_roc_read=np.array(pd.read_csv(roc_10run,header=None))
mean_ap_read=np.array(pd.read_csv(ap_10run,header=None))

p_used_number=10
time_test=mean_time_read[:,-1][0:p_used_number]
roc_test=mean_roc_read[:,-1][0:p_used_number]
ap_test=mean_ap_read[:,-1][0:p_used_number]

print("Time: ", time_test)
print("\n")
print("AUC: ", roc_test)
print("\n")
print("AP: ", ap_test)
# Out:
# Time:  [35.24662971 34.13200545 30.5352509  31.66198611 31.93715286 32.19939184
#  33.66486263 32.78427005 34.05558872 34.24991775]
#
#
# AUC:  [0.93601316 0.92895592 0.92456675 0.92691797 0.94500394 0.933914
#  0.92839423 0.95096299 0.93083906 0.94727954]
#
#
# AP:  [0.94335307 0.94151708 0.93447928 0.93964511 0.9525654  0.94923421
#  0.94210973 0.9561103  0.93159187 0.9542788 ]

# %%
print("Averaged AUC: ", str(np.mean(roc_test))+'±'+str(np.std(roc_test)))
print("\n")
print("Averaged AP: ",  str(np.mean(ap_test))+'±'+str(np.std(ap_test)))
# Out:
# Averaged AUC:  0.9352847560031542±0.008824571027356313
#
#
# Averaged AP:  0.9444884847329768±0.00790200676443606
