# %% [markdown]
# # Import libraries

# %%
import numpy as np
import random as rn
import os
from keras import backend as K
import  tensorflow.compat.v1  as tf
tf.disable_v2_behavior() 
import tensorflow as tf

#--------------------------------------------------------------------------------------------------------------------
# Reproducible
seed=0
os.environ['PYTHONHASHSEED'] = str(seed)

np.random.seed(seed)
rn.seed(seed)
session_conf =tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
tf.compat.v1.set_random_seed(seed)
#--------------------------------------------------------------------------------------------------------------------

import scipy.sparse as sp
import time
import pandas as pd
import sys

from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

sys.path.append(r"../../")

from dgae_alpha_beta.evaluation import get_roc_score
from dgae_alpha_beta.input_data import load_data, load_label
from dgae_alpha_beta.model import *
from dgae_alpha_beta.optimizer import *
from dgae_alpha_beta.preprocessing import *
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.8/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %% [markdown]
# # Parameters setting

# %%
layers_no=72
data_path="../../Datasets/"
path_now="./log/"

dataset='cora'
model_name='DGAE_alpha_beta_feature'

dropout=0.0
epochs=200
features_used=True
learning_rate=0.01
nb_run=1
prop_val=5
prop_test=10
validation=True
verbose=True

# %% [markdown]
# # Load data

# %%
adj_init, features_init = load_data(dataset,data_path)
num_adj=adj_init.shape[1]

# %% [markdown]
# # Training and testing

# %%
loss_coeff_adj=0.001
loss_coeff_AE=0.1
results_output_path = path_now+model_name+"/"
mkdir(results_output_path)

for seed_i in np.arange(nb_run):
    
    seed=seed_i
    lost_list=[]
    roc_list=[]
    ap_list=[]
    mean_time=[]
    
    adj, val_edges, val_edges_false, test_edges, test_edges_false =mask_test_edges(adj_init, seed,prop_test, prop_val)
                
    t_start = time.time()

    if features_used:
        features = features_init
    
    num_nodes = adj.shape[0]

    if not features_used:
        features = sp.identity(adj.shape[0])

    features = sparse_to_tuple(features)
    num_features = features[2][1]
    features_nonzero = features[1].shape[0]
        
    placeholders = {
        'features': tf.sparse_placeholder(tf.float32),
        'adj': tf.sparse_placeholder(tf.float32),
        'adj_orig': tf.sparse_placeholder(tf.float32),
        'dropout': tf.placeholder_with_default(0., shape = ())
    }

#--------------------------------------------------------------------------------------------------------------------
# Create model
    if model_name=='DGAE_alpha_beta_feature':
        model = DGAE_alpha_beta_feature(placeholders, layers_no,num_features, features_nonzero)
    elif model_name=='DGAE_alpha_beta_no_feature':
        model=DGAE_alpha_beta_no_feature(placeholders, layers_no,num_features, num_adj,features_nonzero)
    elif model_name == 'deep_gcn_ae':
        model = DeepGCNModelAE(placeholders, layers_no,num_features, features_nonzero)
    elif model_name == 'linear_ae':
        model = LinearModelAE(placeholders, num_features, features_nonzero)
    elif model_name == 'gcn_ae':
        model = GCNModelAE(placeholders, num_features, features_nonzero)
    else:
        raise ValueError('Undefined model!')

    pos_weight = float(adj.shape[0] * adj.shape[0] - adj.sum()) / adj.sum()
    norm = adj.shape[0] * adj.shape[0] / float((adj.shape[0] * adj.shape[0]- adj.sum()) * 2)
    
    with tf.name_scope('optimizer'):
        if model_name in ('DGAE_alpha_beta_feature'):
            opt =OptimizerAE_FeatureReconstrution(preds_adj = model.reconstructions,\
                                                  preds_Features=model.feature_reconstruction,\
                                                  labels_adj = tf.reshape(tf.sparse_tensor_to_dense(placeholders['adj_orig'],\
                                                                                                    validate_indices = False), [-1]),\
                                                  labels_Features=placeholders['features'],\
                                                  labels_adj_rec=placeholders['adj'],\
                                                  loss_coeff_adj=loss_coeff_adj,\
                                                  loss_coeff_AE=loss_coeff_AE,\
                                                  pos_weight = pos_weight,\
                                                  norm = norm)
                
        elif model_name in ('DGAE_alpha_beta_no_feature'):
            opt =OptimizerAE_AdjReconstrution(preds_adj = model.reconstructions,\
                                              preds_adj_rec=model.adj_reconstruction,\
                                              labels_adj = tf.reshape(tf.sparse_tensor_to_dense(placeholders['adj_orig'],
                                                                                                validate_indices = False), [-1]),\
                                              labels_Features=placeholders['features'],\
                                              labels_adj_rec=placeholders['adj'],\
                                              loss_coeff_adj=loss_coeff_adj,\
                                              loss_coeff_AE=loss_coeff_AE,\
                                              pos_weight = pos_weight,\
                                              norm = norm)
            
        elif model_name in ('gcn_ae', 'linear_ae', 'deep_gcn_ae'):
            opt = OptimizerAE(preds = model.reconstructions,\
                              labels = tf.reshape(tf.sparse_tensor_to_dense(placeholders['adj_orig'],\
                                                                            validate_indices = False), [-1]),
                              pos_weight = pos_weight,
                              norm = norm)

    adj_norm = preprocess_graph(adj)
    adj_label = sparse_to_tuple(adj + sp.eye(adj.shape[0]))

    sess = tf.Session()
    sess.run(tf.global_variables_initializer())
    
    for epoch in range(epochs):
        t = time.time()
        feed_dict = construct_feed_dict(adj_norm, adj_label, features,placeholders)
        feed_dict.update({placeholders['dropout']: dropout})
        outs = sess.run([opt.opt_op, opt.cost, opt.accuracy],feed_dict = feed_dict)
        avg_cost = outs[1]
        if verbose:
            lost_list.append(avg_cost)
            print("Epoch:", '%04d' % (epoch + 1), "training loss=", "{:.5f}".format(avg_cost),"time=", "{:.5f}".format(time.time() - t))
                    
            if validation:
                feed_dict.update({placeholders['dropout']: 0})
                emb = sess.run(model.z_mean, feed_dict = feed_dict)
                feed_dict.update({placeholders['dropout']: dropout})
                val_roc, val_ap = get_roc_score(val_edges, val_edges_false, emb)
                roc_list.append(val_roc)
                ap_list.append(val_ap)
                print("validation roc=", "{:.5f}".format(val_roc), "validation ap=", "{:.5f}".format(val_ap))

    emb = sess.run(model.z_mean, feed_dict = feed_dict)   
    mean_time.append(time.time() - t_start)
    
    roc_score, ap_score = get_roc_score(test_edges, test_edges_false, emb)
    print("testing roc=", "{:.5f}".format(roc_score), "testing ap=", "{:.5f}".format(ap_score))
    
    roc_list.append(roc_score)
    ap_list.append(ap_score)
    
    mean_time_=np.array(mean_time)
    write_to_csv(mean_time_.reshape(1,len(mean_time_)),results_output_path+"layers_"+str(layers_no)+"_time.csv")

    roc_list_=np.array(roc_list)
    write_to_csv(roc_list_.reshape(1,len(roc_list_)),results_output_path+"layers_"+str(layers_no)+"_roc.csv")

    ap_list_=np.array(ap_list)
    write_to_csv(ap_list_.reshape(1,len(ap_list_)),results_output_path+"layers_"+str(layers_no)+"_ap.csv")
# Out:
# Failure
# WARNING:tensorflow:From /usr/local/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:201: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:201: calling weighted_cross_entropy_with_logits (from tensorflow.python.ops.nn_impl) with targets is deprecated and will be removed in a future version.
# Instructions for updating:
# targets is deprecated, use labels instead
# Epoch: 0001 training loss= 0.00126 time= 12.62890
# validation roc= 0.71093 validation ap= 0.75420
# Epoch: 0002 training loss= 0.00122 time= 0.82389
# validation roc= 0.69572 validation ap= 0.74381
# Epoch: 0003 training loss= 0.00129 time= 0.63370
# validation roc= 0.76605 validation ap= 0.79791
# Epoch: 0004 training loss= 0.00117 time= 0.66855
# validation roc= 0.69667 validation ap= 0.72317
# Epoch: 0005 training loss= 0.00117 time= 0.60010
# validation roc= 0.67561 validation ap= 0.70813
# Epoch: 0006 training loss= 0.00117 time= 0.54676
# validation roc= 0.72439 validation ap= 0.74427
# Epoch: 0007 training loss= 0.00114 time= 0.62867
# validation roc= 0.78370 validation ap= 0.78635
# Epoch: 0008 training loss= 0.00111 time= 0.46144
# validation roc= 0.81200 validation ap= 0.80326
# Epoch: 0009 training loss= 0.00108 time= 0.48047
# validation roc= 0.82968 validation ap= 0.81803
# Epoch: 0010 training loss= 0.00105 time= 0.62537
# validation roc= 0.84268 validation ap= 0.83290
# Epoch: 0011 training loss= 0.00102 time= 0.53473
# validation roc= 0.84688 validation ap= 0.83855
# Epoch: 0012 training loss= 0.00100 time= 0.62516
# validation roc= 0.84870 validation ap= 0.84063
# Epoch: 0013 training loss= 0.00098 time= 0.46564
# validation roc= 0.85389 validation ap= 0.84598
# Epoch: 0014 training loss= 0.00096 time= 0.34557
# validation roc= 0.85700 validation ap= 0.84881
# Epoch: 0015 training loss= 0.00094 time= 0.51221
# validation roc= 0.86134 validation ap= 0.85316
# Epoch: 0016 training loss= 0.00093 time= 0.41084
# validation roc= 0.86461 validation ap= 0.85727
# Epoch: 0017 training loss= 0.00093 time= 0.60468
# validation roc= 0.86487 validation ap= 0.86016
# Epoch: 0018 training loss= 0.00092 time= 0.46164
# validation roc= 0.86691 validation ap= 0.86282
# Epoch: 0019 training loss= 0.00091 time= 0.52353
# validation roc= 0.87062 validation ap= 0.86713
# Epoch: 0020 training loss= 0.00091 time= 0.51520
# validation roc= 0.87500 validation ap= 0.87123
# Epoch: 0021 training loss= 0.00090 time= 0.55539
# validation roc= 0.88003 validation ap= 0.87478
# Epoch: 0022 training loss= 0.00089 time= 0.48446
# validation roc= 0.88287 validation ap= 0.87587
# Epoch: 0023 training loss= 0.00089 time= 0.45811
# validation roc= 0.88485 validation ap= 0.87594
# Epoch: 0024 training loss= 0.00088 time= 0.42473
# validation roc= 0.88584 validation ap= 0.87617
# Epoch: 0025 training loss= 0.00087 time= 0.53839
# validation roc= 0.88638 validation ap= 0.87708
# Epoch: 0026 training loss= 0.00087 time= 0.47704
# validation roc= 0.88748 validation ap= 0.87985
# Epoch: 0027 training loss= 0.00086 time= 0.46097
# validation roc= 0.89010 validation ap= 0.88464
# Epoch: 0028 training loss= 0.00086 time= 0.51742
# validation roc= 0.89325 validation ap= 0.89007
# Epoch: 0029 training loss= 0.00085 time= 0.46370
# validation roc= 0.89628 validation ap= 0.89416
# Epoch: 0030 training loss= 0.00085 time= 0.44658
# validation roc= 0.89909 validation ap= 0.89676
# Epoch: 0031 training loss= 0.00084 time= 0.47956
# validation roc= 0.90215 validation ap= 0.89946
# Epoch: 0032 training loss= 0.00084 time= 0.46356
# validation roc= 0.90438 validation ap= 0.90098
# Epoch: 0033 training loss= 0.00083 time= 0.45619
# validation roc= 0.90671 validation ap= 0.90277
# Epoch: 0034 training loss= 0.00083 time= 0.47582
# validation roc= 0.90850 validation ap= 0.90448
# Epoch: 0035 training loss= 0.00082 time= 0.47237
# validation roc= 0.90958 validation ap= 0.90502
# Epoch: 0036 training loss= 0.00082 time= 0.45620
# validation roc= 0.91103 validation ap= 0.90624
# Epoch: 0037 training loss= 0.00082 time= 0.46567
# validation roc= 0.91291 validation ap= 0.90865
# Epoch: 0038 training loss= 0.00081 time= 0.52318
# validation roc= 0.91475 validation ap= 0.91114
# Epoch: 0039 training loss= 0.00081 time= 0.45290
# validation roc= 0.91619 validation ap= 0.91297
# Epoch: 0040 training loss= 0.00081 time= 0.45552
# validation roc= 0.91748 validation ap= 0.91504
# Epoch: 0041 training loss= 0.00080 time= 0.44582
# validation roc= 0.91862 validation ap= 0.91718
# Epoch: 0042 training loss= 0.00080 time= 0.46663
# validation roc= 0.91947 validation ap= 0.91921
# Epoch: 0043 training loss= 0.00080 time= 0.43914
# validation roc= 0.92056 validation ap= 0.92152
# Epoch: 0044 training loss= 0.00079 time= 0.48886
# validation roc= 0.92173 validation ap= 0.92341
# Epoch: 0045 training loss= 0.00079 time= 0.52091
# validation roc= 0.92304 validation ap= 0.92527
# Epoch: 0046 training loss= 0.00079 time= 0.47189
# validation roc= 0.92447 validation ap= 0.92685
# Epoch: 0047 training loss= 0.00079 time= 0.43739
# validation roc= 0.92510 validation ap= 0.92774
# Epoch: 0048 training loss= 0.00078 time= 0.48200
# validation roc= 0.92580 validation ap= 0.92865
# Epoch: 0049 training loss= 0.00078 time= 0.47446
# validation roc= 0.92615 validation ap= 0.92913
# Epoch: 0050 training loss= 0.00078 time= 0.45127
# validation roc= 0.92689 validation ap= 0.93004
# Epoch: 0051 training loss= 0.00078 time= 0.47965
# validation roc= 0.92731 validation ap= 0.93017
# Epoch: 0052 training loss= 0.00077 time= 0.41391
# validation roc= 0.92789 validation ap= 0.93043
# Epoch: 0053 training loss= 0.00077 time= 0.42388
# validation roc= 0.92855 validation ap= 0.93120
# Epoch: 0054 training loss= 0.00077 time= 0.45944
# validation roc= 0.92896 validation ap= 0.93159
# Epoch: 0055 training loss= 0.00077 time= 0.50885
# validation roc= 0.92899 validation ap= 0.93196
# Epoch: 0056 training loss= 0.00076 time= 0.45858
# validation roc= 0.92896 validation ap= 0.93168
# Epoch: 0057 training loss= 0.00076 time= 0.45800
# validation roc= 0.92854 validation ap= 0.93108
# Epoch: 0058 training loss= 0.00076 time= 0.44740
# validation roc= 0.92886 validation ap= 0.93144
# Epoch: 0059 training loss= 0.00076 time= 0.44020
# validation roc= 0.92878 validation ap= 0.93183
# Epoch: 0060 training loss= 0.00075 time= 0.46759
# validation roc= 0.92842 validation ap= 0.93160
# Epoch: 0061 training loss= 0.00075 time= 0.45771
# validation roc= 0.92803 validation ap= 0.93105
# Epoch: 0062 training loss= 0.00075 time= 0.43085
# validation roc= 0.92816 validation ap= 0.93118
# Epoch: 0063 training loss= 0.00075 time= 0.42527
# validation roc= 0.92839 validation ap= 0.93135
# Epoch: 0064 training loss= 0.00075 time= 0.45056
# validation roc= 0.92809 validation ap= 0.93109
# Epoch: 0065 training loss= 0.00074 time= 0.42923
# validation roc= 0.92764 validation ap= 0.93068
# Epoch: 0066 training loss= 0.00074 time= 0.46044
# validation roc= 0.92740 validation ap= 0.93049
# Epoch: 0067 training loss= 0.00074 time= 0.44614
# validation roc= 0.92748 validation ap= 0.93058
# Epoch: 0068 training loss= 0.00074 time= 0.46851
# validation roc= 0.92766 validation ap= 0.93079
# Epoch: 0069 training loss= 0.00074 time= 0.48863
# validation roc= 0.92771 validation ap= 0.93088
# Epoch: 0070 training loss= 0.00073 time= 0.43339
# validation roc= 0.92767 validation ap= 0.93084
# Epoch: 0071 training loss= 0.00073 time= 0.43207
# validation roc= 0.92781 validation ap= 0.93109
# Epoch: 0072 training loss= 0.00073 time= 0.43426
# validation roc= 0.92825 validation ap= 0.93165
# Epoch: 0073 training loss= 0.00073 time= 0.43020
# validation roc= 0.92842 validation ap= 0.93221
# Epoch: 0074 training loss= 0.00073 time= 0.47919
# validation roc= 0.92816 validation ap= 0.93225
# Epoch: 0075 training loss= 0.00073 time= 0.46225
# validation roc= 0.92813 validation ap= 0.93227
# Epoch: 0076 training loss= 0.00073 time= 0.43160
# validation roc= 0.92797 validation ap= 0.93211
# Epoch: 0077 training loss= 0.00072 time= 0.46171
# validation roc= 0.92836 validation ap= 0.93262
# Epoch: 0078 training loss= 0.00072 time= 0.46365
# validation roc= 0.92849 validation ap= 0.93297
# Epoch: 0079 training loss= 0.00072 time= 0.44958
# validation roc= 0.92841 validation ap= 0.93291
# Epoch: 0080 training loss= 0.00072 time= 0.43354
# validation roc= 0.92903 validation ap= 0.93351
# Epoch: 0081 training loss= 0.00072 time= 0.44346
# validation roc= 0.92893 validation ap= 0.93351
# Epoch: 0082 training loss= 0.00072 time= 0.43740
# validation roc= 0.92916 validation ap= 0.93369
# Epoch: 0083 training loss= 0.00072 time= 0.41938
# validation roc= 0.92942 validation ap= 0.93409
# Epoch: 0084 training loss= 0.00071 time= 0.42643
# validation roc= 0.92938 validation ap= 0.93404
# Epoch: 0085 training loss= 0.00071 time= 0.42460
# validation roc= 0.92977 validation ap= 0.93443
# Epoch: 0086 training loss= 0.00071 time= 0.47172
# validation roc= 0.92967 validation ap= 0.93441
# Epoch: 0087 training loss= 0.00071 time= 0.45167
# validation roc= 0.92984 validation ap= 0.93451
# Epoch: 0088 training loss= 0.00071 time= 0.44014
# validation roc= 0.93004 validation ap= 0.93473
# Epoch: 0089 training loss= 0.00071 time= 0.45104
# validation roc= 0.93023 validation ap= 0.93487
# Epoch: 0090 training loss= 0.00071 time= 0.46982
# validation roc= 0.93050 validation ap= 0.93521
# Epoch: 0091 training loss= 0.00071 time= 0.42684
# validation roc= 0.93052 validation ap= 0.93507
# Epoch: 0092 training loss= 0.00070 time= 0.43943
# validation roc= 0.93072 validation ap= 0.93537
# Epoch: 0093 training loss= 0.00070 time= 0.45274
# validation roc= 0.93071 validation ap= 0.93541
# Epoch: 0094 training loss= 0.00070 time= 0.43484
# validation roc= 0.93076 validation ap= 0.93554
# Epoch: 0095 training loss= 0.00070 time= 0.43556
# validation roc= 0.93072 validation ap= 0.93544
# Epoch: 0096 training loss= 0.00070 time= 0.44241
# validation roc= 0.93094 validation ap= 0.93562
# Epoch: 0097 training loss= 0.00070 time= 0.44454
# validation roc= 0.93089 validation ap= 0.93567
# Epoch: 0098 training loss= 0.00070 time= 0.42498
# validation roc= 0.93130 validation ap= 0.93603
# Epoch: 0099 training loss= 0.00070 time= 0.41094
# validation roc= 0.93101 validation ap= 0.93564
# Epoch: 0100 training loss= 0.00070 time= 0.45048
# validation roc= 0.93167 validation ap= 0.93634
# Epoch: 0101 training loss= 0.00070 time= 0.41885
# validation roc= 0.93097 validation ap= 0.93570
# Epoch: 0102 training loss= 0.00069 time= 0.45981
# validation roc= 0.93220 validation ap= 0.93655
# Epoch: 0103 training loss= 0.00069 time= 0.46146
# validation roc= 0.93045 validation ap= 0.93533
# Epoch: 0104 training loss= 0.00069 time= 0.48119
# validation roc= 0.93201 validation ap= 0.93632
# Epoch: 0105 training loss= 0.00069 time= 0.43131
# validation roc= 0.93179 validation ap= 0.93662
# Epoch: 0106 training loss= 0.00069 time= 0.41755
# validation roc= 0.93123 validation ap= 0.93572
# Epoch: 0107 training loss= 0.00069 time= 0.43556
# validation roc= 0.93209 validation ap= 0.93665
# Epoch: 0108 training loss= 0.00069 time= 0.43330
# validation roc= 0.93120 validation ap= 0.93599
# Epoch: 0109 training loss= 0.00069 time= 0.43614
# validation roc= 0.93117 validation ap= 0.93549
# Epoch: 0110 training loss= 0.00069 time= 0.42340
# validation roc= 0.93163 validation ap= 0.93631
# Epoch: 0111 training loss= 0.00069 time= 0.45554
# validation roc= 0.93124 validation ap= 0.93599
# Epoch: 0112 training loss= 0.00069 time= 0.43844
# validation roc= 0.93130 validation ap= 0.93622
# Epoch: 0113 training loss= 0.00068 time= 0.44476
# validation roc= 0.93120 validation ap= 0.93620
# Epoch: 0114 training loss= 0.00068 time= 0.42250
# validation roc= 0.93097 validation ap= 0.93598
# Epoch: 0115 training loss= 0.00068 time= 0.47329
# validation roc= 0.93082 validation ap= 0.93610
# Epoch: 0116 training loss= 0.00068 time= 0.41970
# validation roc= 0.93105 validation ap= 0.93617
# Epoch: 0117 training loss= 0.00068 time= 0.45754
# validation roc= 0.93092 validation ap= 0.93632
# Epoch: 0118 training loss= 0.00068 time= 0.47328
# validation roc= 0.93069 validation ap= 0.93602
# Epoch: 0119 training loss= 0.00068 time= 0.48228
# validation roc= 0.93097 validation ap= 0.93653
# Epoch: 0120 training loss= 0.00068 time= 0.43863
# validation roc= 0.93060 validation ap= 0.93633
# Epoch: 0121 training loss= 0.00068 time= 0.44246
# validation roc= 0.93060 validation ap= 0.93619
# Epoch: 0122 training loss= 0.00068 time= 0.43603
# validation roc= 0.93066 validation ap= 0.93646
# Epoch: 0123 training loss= 0.00068 time= 0.43710
# validation roc= 0.93060 validation ap= 0.93631
# Epoch: 0124 training loss= 0.00068 time= 0.46070
# validation roc= 0.93046 validation ap= 0.93637
# Epoch: 0125 training loss= 0.00068 time= 0.45717
# validation roc= 0.93114 validation ap= 0.93686
# Epoch: 0126 training loss= 0.00067 time= 0.46474
# validation roc= 0.93055 validation ap= 0.93681
# Epoch: 0127 training loss= 0.00067 time= 0.44647
# validation roc= 0.93068 validation ap= 0.93632
# Epoch: 0128 training loss= 0.00067 time= 0.43632
# validation roc= 0.93081 validation ap= 0.93716
# Epoch: 0129 training loss= 0.00067 time= 0.44878
# validation roc= 0.93071 validation ap= 0.93635
# Epoch: 0130 training loss= 0.00067 time= 0.43902
# validation roc= 0.93045 validation ap= 0.93706
# Epoch: 0131 training loss= 0.00067 time= 0.43697
# validation roc= 0.93097 validation ap= 0.93664
# Epoch: 0132 training loss= 0.00067 time= 0.44357
# validation roc= 0.93040 validation ap= 0.93726
# Epoch: 0133 training loss= 0.00067 time= 0.44131
# validation roc= 0.93128 validation ap= 0.93691
# Epoch: 0134 training loss= 0.00067 time= 0.46233
# validation roc= 0.93049 validation ap= 0.93734
# Epoch: 0135 training loss= 0.00067 time= 0.45782
# validation roc= 0.93126 validation ap= 0.93719
# Epoch: 0136 training loss= 0.00067 time= 0.45846
# validation roc= 0.93128 validation ap= 0.93780
# Epoch: 0137 training loss= 0.00067 time= 0.44734
# validation roc= 0.93121 validation ap= 0.93791
# Epoch: 0138 training loss= 0.00067 time= 0.44541
# validation roc= 0.93178 validation ap= 0.93795
# Epoch: 0139 training loss= 0.00067 time= 0.45183
# validation roc= 0.93152 validation ap= 0.93822
# Epoch: 0140 training loss= 0.00067 time= 0.42426
# validation roc= 0.93202 validation ap= 0.93834
# Epoch: 0141 training loss= 0.00067 time= 0.44842
# validation roc= 0.93201 validation ap= 0.93875
# Epoch: 0142 training loss= 0.00067 time= 0.44147
# validation roc= 0.93231 validation ap= 0.93897
# Epoch: 0143 training loss= 0.00066 time= 0.45210
# validation roc= 0.93231 validation ap= 0.93895
# Epoch: 0144 training loss= 0.00066 time= 0.44452
# validation roc= 0.93217 validation ap= 0.93901
# Epoch: 0145 training loss= 0.00066 time= 0.42810
# validation roc= 0.93274 validation ap= 0.93932
# Epoch: 0146 training loss= 0.00066 time= 0.46013
# validation roc= 0.93254 validation ap= 0.93948
# Epoch: 0147 training loss= 0.00066 time= 0.43634
# validation roc= 0.93282 validation ap= 0.93960
# Epoch: 0148 training loss= 0.00066 time= 0.43458
# validation roc= 0.93285 validation ap= 0.93982
# Epoch: 0149 training loss= 0.00066 time= 0.46033
# validation roc= 0.93283 validation ap= 0.93970
# Epoch: 0150 training loss= 0.00066 time= 0.44025
# validation roc= 0.93300 validation ap= 0.94000
# Epoch: 0151 training loss= 0.00066 time= 0.42535
# validation roc= 0.93324 validation ap= 0.94019
# Epoch: 0152 training loss= 0.00066 time= 0.43892
# validation roc= 0.93299 validation ap= 0.93992
# Epoch: 0153 training loss= 0.00066 time= 0.46848
# validation roc= 0.93348 validation ap= 0.94051
# Epoch: 0154 training loss= 0.00066 time= 0.43231
# validation roc= 0.93328 validation ap= 0.94016
# Epoch: 0155 training loss= 0.00066 time= 0.49713
# validation roc= 0.93331 validation ap= 0.94051
# Epoch: 0156 training loss= 0.00066 time= 0.46659
# validation roc= 0.93355 validation ap= 0.94074
# Epoch: 0157 training loss= 0.00066 time= 0.47896
# validation roc= 0.93358 validation ap= 0.94099
# Epoch: 0158 training loss= 0.00066 time= 0.46873
# validation roc= 0.93384 validation ap= 0.94131
# Epoch: 0159 training loss= 0.00066 time= 0.46402
# validation roc= 0.93364 validation ap= 0.94111
# Epoch: 0160 training loss= 0.00066 time= 0.47433
# validation roc= 0.93402 validation ap= 0.94171
# Epoch: 0161 training loss= 0.00066 time= 0.49294
# validation roc= 0.93387 validation ap= 0.94150
# Epoch: 0162 training loss= 0.00066 time= 0.47601
# validation roc= 0.93403 validation ap= 0.94182
# Epoch: 0163 training loss= 0.00066 time= 0.45099
# validation roc= 0.93422 validation ap= 0.94190
# Epoch: 0164 training loss= 0.00066 time= 0.49370
# validation roc= 0.93455 validation ap= 0.94237
# Epoch: 0165 training loss= 0.00066 time= 0.46450
# validation roc= 0.93436 validation ap= 0.94206
# Epoch: 0166 training loss= 0.00065 time= 0.48496
# validation roc= 0.93459 validation ap= 0.94244
# Epoch: 0167 training loss= 0.00065 time= 0.44311
# validation roc= 0.93448 validation ap= 0.94213
# Epoch: 0168 training loss= 0.00065 time= 0.48167
# validation roc= 0.93465 validation ap= 0.94253
# Epoch: 0169 training loss= 0.00065 time= 0.47852
# validation roc= 0.93477 validation ap= 0.94227
# Epoch: 0170 training loss= 0.00065 time= 0.47224
# validation roc= 0.93452 validation ap= 0.94259
# Epoch: 0171 training loss= 0.00065 time= 0.47102
# validation roc= 0.93484 validation ap= 0.94215
# Epoch: 0172 training loss= 0.00065 time= 0.45448
# validation roc= 0.93441 validation ap= 0.94276
# Epoch: 0173 training loss= 0.00065 time= 0.51257
# validation roc= 0.93507 validation ap= 0.94212
# Epoch: 0174 training loss= 0.00065 time= 0.46055
# validation roc= 0.93429 validation ap= 0.94281
# Epoch: 0175 training loss= 0.00065 time= 0.47869
# validation roc= 0.93501 validation ap= 0.94208
# Epoch: 0176 training loss= 0.00065 time= 0.46653
# validation roc= 0.93420 validation ap= 0.94265
# Epoch: 0177 training loss= 0.00065 time= 0.47333
# validation roc= 0.93480 validation ap= 0.94218
# Epoch: 0178 training loss= 0.00065 time= 0.45961
# validation roc= 0.93462 validation ap= 0.94258
# Epoch: 0179 training loss= 0.00065 time= 0.48881
# validation roc= 0.93468 validation ap= 0.94255
# Epoch: 0180 training loss= 0.00065 time= 0.47766
# validation roc= 0.93467 validation ap= 0.94212
# Epoch: 0181 training loss= 0.00065 time= 0.48301
# validation roc= 0.93444 validation ap= 0.94272
# Epoch: 0182 training loss= 0.00065 time= 0.50331
# validation roc= 0.93480 validation ap= 0.94240
# Epoch: 0183 training loss= 0.00065 time= 0.47347
# validation roc= 0.93441 validation ap= 0.94229
# Epoch: 0184 training loss= 0.00065 time= 0.45879
# validation roc= 0.93462 validation ap= 0.94278
# Epoch: 0185 training loss= 0.00065 time= 0.48133
# validation roc= 0.93402 validation ap= 0.94168
# Epoch: 0186 training loss= 0.00065 time= 0.47833
# validation roc= 0.93444 validation ap= 0.94270
# Epoch: 0187 training loss= 0.00065 time= 0.48030
# validation roc= 0.93446 validation ap= 0.94230
# Epoch: 0188 training loss= 0.00065 time= 0.47201
# validation roc= 0.93396 validation ap= 0.94197
# Epoch: 0189 training loss= 0.00065 time= 0.49883
# validation roc= 0.93459 validation ap= 0.94273
# Epoch: 0190 training loss= 0.00065 time= 0.46088
# validation roc= 0.93373 validation ap= 0.94146
# Epoch: 0191 training loss= 0.00065 time= 0.46820
# validation roc= 0.93422 validation ap= 0.94243
# Epoch: 0192 training loss= 0.00065 time= 0.45836
# validation roc= 0.93400 validation ap= 0.94195
# Epoch: 0193 training loss= 0.00065 time= 0.49576
# validation roc= 0.93368 validation ap= 0.94177
# Epoch: 0194 training loss= 0.00065 time= 0.55773
# validation roc= 0.93420 validation ap= 0.94249
# Epoch: 0195 training loss= 0.00065 time= 0.46557
# validation roc= 0.93354 validation ap= 0.94154
# Epoch: 0196 training loss= 0.00065 time= 0.51987
# validation roc= 0.93368 validation ap= 0.94205
# Epoch: 0197 training loss= 0.00065 time= 0.47964
# validation roc= 0.93366 validation ap= 0.94174
# Epoch: 0198 training loss= 0.00065 time= 0.48216
# validation roc= 0.93342 validation ap= 0.94167
# Epoch: 0199 training loss= 0.00065 time= 0.47038
# validation roc= 0.93361 validation ap= 0.94177
# Epoch: 0200 training loss= 0.00065 time= 0.50951
# validation roc= 0.93329 validation ap= 0.94142
# testing roc= 0.93340 testing ap= 0.94203

# %% [markdown]
# # Visulization

# %%
emb=emb
labels=load_label(dataset,data_path)

X_embedded = TSNE(n_components=2, init='pca', random_state=seed).fit_transform(emb)

cs=['orange','blue','darkcyan','fuchsia','chocolate','dodgerblue','aqua','green','red','purple']
markers=['o','+','v','2','s','X','d','>','*','<']

fig, ax = plt.subplots(1,figsize=(8,6))
for i in np.arange(X_embedded.shape[0]):
    scatter = ax.scatter(X_embedded[i,0],X_embedded[i,1],label=labels[i],marker=markers[labels[i]],color=cs[labels[i]], s=10, alpha = 1)
plt.xticks([])
plt.yticks([])
plt.xlabel("")
plt.ylabel("")
plt.axis('off')
plt.show()
