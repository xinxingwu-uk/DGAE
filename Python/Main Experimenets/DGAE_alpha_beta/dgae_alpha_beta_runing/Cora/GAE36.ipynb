# %% [markdown]
# # Import libraries

# %%
import numpy as np
import random as rn
import os
from keras import backend as K
import  tensorflow.compat.v1  as tf
tf.disable_v2_behavior() 
import tensorflow as tf

#--------------------------------------------------------------------------------------------------------------------
# Reproducible
seed=0
os.environ['PYTHONHASHSEED'] = str(seed)

np.random.seed(seed)
rn.seed(seed)
session_conf =tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
tf.compat.v1.set_random_seed(seed)
#--------------------------------------------------------------------------------------------------------------------

import scipy.sparse as sp
import time
import pandas as pd
import sys

from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

sys.path.append(r"../../")

from dgae_alpha_beta.evaluation import get_roc_score
from dgae_alpha_beta.input_data import load_data, load_label
from dgae_alpha_beta.model import *
from dgae_alpha_beta.optimizer import *
from dgae_alpha_beta.preprocessing import *
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.8/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %% [markdown]
# # Parameters setting

# %%
layers_no=36
data_path="../../Datasets/"
path_now="./log/"

dataset='cora'
model_name='deep_gcn_ae'

dropout=0.0
epochs=200
features_used=True
learning_rate=0.01
nb_run=1
prop_val=5
prop_test=10
validation=True
verbose=True

# %% [markdown]
# # Load data

# %%
adj_init, features_init = load_data(dataset,data_path)
num_adj=adj_init.shape[1]

# %% [markdown]
# # Training and testing

# %%
#loss_coeff_adj=0.001
#loss_coeff_AE=0.05
results_output_path = path_now+model_name+"/"
mkdir(results_output_path)

for seed_i in np.arange(nb_run):
    
    seed=seed_i
    lost_list=[]
    roc_list=[]
    ap_list=[]
    mean_time=[]
    
    adj, val_edges, val_edges_false, test_edges, test_edges_false =mask_test_edges(adj_init, seed,prop_test, prop_val)
                
    t_start = time.time()

    if features_used:
        features = features_init
    
    num_nodes = adj.shape[0]

    if not features_used:
        features = sp.identity(adj.shape[0])

    features = sparse_to_tuple(features)
    num_features = features[2][1]
    features_nonzero = features[1].shape[0]
        
    placeholders = {
        'features': tf.sparse_placeholder(tf.float32),
        'adj': tf.sparse_placeholder(tf.float32),
        'adj_orig': tf.sparse_placeholder(tf.float32),
        'dropout': tf.placeholder_with_default(0., shape = ())
    }

#--------------------------------------------------------------------------------------------------------------------
# Create model
    if model_name=='DGAE_alpha_beta_feature':
        model = DGAE_alpha_beta_feature(placeholders, layers_no,num_features, features_nonzero)
    elif model_name=='DGAE_alpha_beta_no_feature':
        model=DGAE_alpha_beta_no_feature(placeholders, layers_no,num_features, num_adj,features_nonzero)
    elif model_name == 'deep_gcn_ae':
        model = DeepGCNModelAE(placeholders, layers_no,num_features, features_nonzero)
    elif model_name == 'linear_ae':
        model = LinearModelAE(placeholders, num_features, features_nonzero)
    elif model_name == 'gcn_ae':
        model = GCNModelAE(placeholders, num_features, features_nonzero)
    else:
        raise ValueError('Undefined model!')

    pos_weight = float(adj.shape[0] * adj.shape[0] - adj.sum()) / adj.sum()
    norm = adj.shape[0] * adj.shape[0] / float((adj.shape[0] * adj.shape[0]- adj.sum()) * 2)
    
    with tf.name_scope('optimizer'):
        if model_name in ('DGAE_alpha_beta_feature'):
            opt =OptimizerAE_FeatureReconstrution(preds_adj = model.reconstructions,\
                                                  preds_Features=model.feature_reconstruction,\
                                                  labels_adj = tf.reshape(tf.sparse_tensor_to_dense(placeholders['adj_orig'],\
                                                                                                    validate_indices = False), [-1]),\
                                                  labels_Features=placeholders['features'],\
                                                  labels_adj_rec=placeholders['adj'],\
                                                  loss_coeff_adj=loss_coeff_adj,\
                                                  loss_coeff_AE=loss_coeff_AE,\
                                                  pos_weight = pos_weight,\
                                                  norm = norm)
                
        elif model_name in ('DGAE_alpha_beta_no_feature'):
            opt =OptimizerAE_AdjReconstrution(preds_adj = model.reconstructions,\
                                              preds_adj_rec=model.adj_reconstruction,\
                                              labels_adj = tf.reshape(tf.sparse_tensor_to_dense(placeholders['adj_orig'],
                                                                                                validate_indices = False), [-1]),\
                                              labels_Features=placeholders['features'],\
                                              labels_adj_rec=placeholders['adj'],\
                                              loss_coeff_adj=loss_coeff_adj,\
                                              loss_coeff_AE=loss_coeff_AE,\
                                              pos_weight = pos_weight,\
                                              norm = norm)
            
        elif model_name in ('gcn_ae', 'linear_ae', 'deep_gcn_ae'):
            opt = OptimizerAE(preds = model.reconstructions,\
                              labels = tf.reshape(tf.sparse_tensor_to_dense(placeholders['adj_orig'],\
                                                                            validate_indices = False), [-1]),
                              pos_weight = pos_weight,
                              norm = norm)

    adj_norm = preprocess_graph(adj)
    adj_label = sparse_to_tuple(adj + sp.eye(adj.shape[0]))

    sess = tf.Session()
    sess.run(tf.global_variables_initializer())
    
    for epoch in range(epochs):
        t = time.time()
        feed_dict = construct_feed_dict(adj_norm, adj_label, features,placeholders)
        feed_dict.update({placeholders['dropout']: dropout})
        outs = sess.run([opt.opt_op, opt.cost, opt.accuracy],feed_dict = feed_dict)
        avg_cost = outs[1]
        if verbose:
            lost_list.append(avg_cost)
            print("Epoch:", '%04d' % (epoch + 1), "training loss=", "{:.5f}".format(avg_cost),"time=", "{:.5f}".format(time.time() - t))
                    
            if validation:
                feed_dict.update({placeholders['dropout']: 0})
                emb = sess.run(model.z_mean, feed_dict = feed_dict)
                feed_dict.update({placeholders['dropout']: dropout})
                val_roc, val_ap = get_roc_score(val_edges, val_edges_false, emb)
                roc_list.append(val_roc)
                ap_list.append(val_ap)
                print("validation roc=", "{:.5f}".format(val_roc), "validation ap=", "{:.5f}".format(val_ap))

    emb = sess.run(model.z_mean, feed_dict = feed_dict)   
    mean_time.append(time.time() - t_start)
    
    roc_score, ap_score = get_roc_score(test_edges, test_edges_false, emb)
    print("testing roc=", "{:.5f}".format(roc_score), "testing ap=", "{:.5f}".format(ap_score))
    
    roc_list.append(roc_score)
    ap_list.append(ap_score)
    
    mean_time_=np.array(mean_time)
    write_to_csv(mean_time_.reshape(1,len(mean_time_)),results_output_path+"layers_"+str(layers_no)+"_time.csv")

    roc_list_=np.array(roc_list)
    write_to_csv(roc_list_.reshape(1,len(roc_list_)),results_output_path+"layers_"+str(layers_no)+"_roc.csv")

    ap_list_=np.array(ap_list)
    write_to_csv(ap_list_.reshape(1,len(ap_list_)),results_output_path+"layers_"+str(layers_no)+"_ap.csv")
# Out:
# Failure
# WARNING:tensorflow:From /usr/local/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:201: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:201: calling weighted_cross_entropy_with_logits (from tensorflow.python.ops.nn_impl) with targets is deprecated and will be removed in a future version.
# Instructions for updating:
# targets is deprecated, use labels instead
# Epoch: 0001 training loss= 0.79758 time= 1.19801
# validation roc= 0.61961 validation ap= 0.66316
# Epoch: 0002 training loss= 0.78469 time= 0.37819
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0003 training loss= 942.08466 time= 0.28897
# validation roc= 0.65745 validation ap= 0.71135
# Epoch: 0004 training loss= 0.78209 time= 0.43359
# validation roc= 0.67345 validation ap= 0.72445
# Epoch: 0005 training loss= 0.79658 time= 0.36574
# validation roc= 0.66244 validation ap= 0.71736
# Epoch: 0006 training loss= 0.79757 time= 0.20364
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0007 training loss= 0.79758 time= 0.24051
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0008 training loss= 0.79758 time= 0.22204
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0009 training loss= 0.79758 time= 0.16199
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0010 training loss= 0.79758 time= 0.18834
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0011 training loss= 0.79758 time= 0.28976
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0012 training loss= 0.79758 time= 0.51066
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0013 training loss= 0.79758 time= 0.29174
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0014 training loss= 0.79758 time= 0.20001
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0015 training loss= 0.79758 time= 0.17820
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0016 training loss= 0.79758 time= 0.17316
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0017 training loss= 0.79758 time= 0.16541
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0018 training loss= 0.79758 time= 0.36477
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0019 training loss= 0.79758 time= 4.95450
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0020 training loss= 0.79758 time= 0.19952
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0021 training loss= 0.79758 time= 0.21844
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0022 training loss= 0.79758 time= 0.36986
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0023 training loss= 0.79758 time= 0.33639
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0024 training loss= 0.79758 time= 0.26581
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0025 training loss= 0.79758 time= 0.25436
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0026 training loss= 0.79758 time= 0.20957
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0027 training loss= 0.79758 time= 0.20055
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0028 training loss= 0.79758 time= 0.23373
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0029 training loss= 0.79758 time= 0.41684
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0030 training loss= 0.79758 time= 0.29008
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0031 training loss= 0.79758 time= 0.20323
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0032 training loss= 0.79758 time= 0.18614
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0033 training loss= 0.79758 time= 0.17814
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0034 training loss= 0.79758 time= 0.18804
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0035 training loss= 0.79758 time= 0.35779
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0036 training loss= 0.79758 time= 3.58419
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0037 training loss= 0.79758 time= 0.21994
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0038 training loss= 0.79758 time= 0.28358
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0039 training loss= 0.79758 time= 0.38562
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0040 training loss= 0.79758 time= 0.36366
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0041 training loss= 0.79758 time= 0.25609
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0042 training loss= 0.79758 time= 0.23842
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0043 training loss= 0.79758 time= 0.23934
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0044 training loss= 0.79758 time= 0.20166
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0045 training loss= 0.79758 time= 0.24243
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0046 training loss= 0.79758 time= 0.25817
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0047 training loss= 0.79758 time= 0.33093
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0048 training loss= 0.79758 time= 0.31691
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0049 training loss= 0.79758 time= 0.18523
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0050 training loss= 0.79758 time= 0.18364
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0051 training loss= 0.79758 time= 0.19241
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0052 training loss= 0.79758 time= 0.25428
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0053 training loss= 0.79758 time= 1.59730
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0054 training loss= 0.79758 time= 0.51551
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0055 training loss= 0.79758 time= 0.17467
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0056 training loss= 0.79758 time= 0.23375
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0057 training loss= 0.79758 time= 0.28964
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0058 training loss= 0.79758 time= 0.17530
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0059 training loss= 0.79758 time= 0.33387
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0060 training loss= 0.79758 time= 0.25055
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0061 training loss= 0.79758 time= 0.19394
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0062 training loss= 0.79758 time= 0.21827
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0063 training loss= 0.79758 time= 0.18773
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0064 training loss= 0.79758 time= 0.25735
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0065 training loss= 0.79758 time= 0.40086
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0066 training loss= 0.79758 time= 0.22079
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0067 training loss= 0.79758 time= 0.16882
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0068 training loss= 0.79758 time= 0.18015
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0069 training loss= 0.79758 time= 0.15192
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0070 training loss= 0.79758 time= 0.18785
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0071 training loss= 0.79758 time= 0.43156
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0072 training loss= 0.79758 time= 3.72561
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0073 training loss= 0.79758 time= 0.19574
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0074 training loss= 0.79758 time= 0.27220
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0075 training loss= 0.79758 time= 0.26674
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0076 training loss= 0.79758 time= 0.29567
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0077 training loss= 0.79758 time= 0.36185
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0078 training loss= 0.79758 time= 0.26258
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0079 training loss= 0.79758 time= 0.24145
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0080 training loss= 0.79758 time= 0.22339
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0081 training loss= 0.79758 time= 0.19119
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0082 training loss= 0.79758 time= 0.17344
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0083 training loss= 0.79758 time= 0.36183
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0084 training loss= 0.79758 time= 0.28375
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0085 training loss= 0.79758 time= 0.32212
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0086 training loss= 0.79758 time= 0.18079
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0087 training loss= 0.79758 time= 0.17012
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0088 training loss= 0.79758 time= 0.17308
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0089 training loss= 0.79758 time= 0.19988
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0090 training loss= 0.79758 time= 0.33032
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0091 training loss= 0.79758 time= 0.33458
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0092 training loss= 0.79758 time= 0.22215
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0093 training loss= 0.79758 time= 0.16495
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0094 training loss= 0.79758 time= 0.35010
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0095 training loss= 0.79758 time= 0.24459
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0096 training loss= 0.79758 time= 0.24721
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0097 training loss= 0.79758 time= 0.25289
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0098 training loss= 0.79758 time= 0.22331
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0099 training loss= 0.79758 time= 0.17516
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0100 training loss= 0.79758 time= 0.19180
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0101 training loss= 0.79758 time= 0.18291
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0102 training loss= 0.79758 time= 0.39048
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0103 training loss= 0.79758 time= 0.22637
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0104 training loss= 0.79758 time= 0.33118
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0105 training loss= 0.79758 time= 0.16652
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0106 training loss= 0.79758 time= 0.15484
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0107 training loss= 0.79758 time= 0.18431
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0108 training loss= 0.79758 time= 0.16605
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0109 training loss= 0.79758 time= 0.52607
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0110 training loss= 0.79758 time= 0.31239
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0111 training loss= 0.79758 time= 0.16737
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0112 training loss= 0.79758 time= 0.21305
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0113 training loss= 0.79758 time= 0.30596
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0114 training loss= 0.79758 time= 0.16761
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0115 training loss= 0.79758 time= 0.26972
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0116 training loss= 0.79758 time= 0.29367
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0117 training loss= 0.79758 time= 0.18154
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0118 training loss= 0.79758 time= 0.16149
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0119 training loss= 0.79758 time= 0.20080
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0120 training loss= 0.79758 time= 0.30004
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0121 training loss= 0.79758 time= 0.39913
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0122 training loss= 0.79758 time= 0.30646
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0123 training loss= 0.79758 time= 0.17362
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0124 training loss= 0.79758 time= 0.17231
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0125 training loss= 0.79758 time= 0.16394
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0126 training loss= 0.79758 time= 0.18421
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0127 training loss= 0.79758 time= 0.30587
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0128 training loss= 0.79758 time= 3.58095
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0129 training loss= 0.79758 time= 0.17181
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0130 training loss= 0.79758 time= 0.21768
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0131 training loss= 0.79758 time= 0.28939
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0132 training loss= 0.79758 time= 0.16402
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0133 training loss= 0.79758 time= 0.30728
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0134 training loss= 0.79758 time= 0.23885
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0135 training loss= 0.79758 time= 0.15990
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0136 training loss= 0.79758 time= 0.20510
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0137 training loss= 0.79758 time= 0.18653
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0138 training loss= 0.79758 time= 0.20954
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0139 training loss= 0.79758 time= 0.42460
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0140 training loss= 0.79758 time= 0.23528
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0141 training loss= 0.79758 time= 0.31467
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0142 training loss= 0.79758 time= 0.18251
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0143 training loss= 0.79758 time= 0.17329
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0144 training loss= 0.79758 time= 0.15213
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0145 training loss= 0.79758 time= 0.15824
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0146 training loss= 0.79758 time= 0.31417
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0147 training loss= 0.79758 time= 0.17517
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0148 training loss= 0.79758 time= 0.31089
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0149 training loss= 0.79758 time= 0.30753
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0150 training loss= 0.79758 time= 0.24371
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0151 training loss= 0.79758 time= 0.28419
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0152 training loss= 0.79758 time= 0.23565
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0153 training loss= 0.79758 time= 0.17200
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0154 training loss= 0.79758 time= 0.19631
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0155 training loss= 0.79758 time= 0.17577
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0156 training loss= 0.79758 time= 0.22691
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0157 training loss= 0.79758 time= 0.32889
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0158 training loss= 0.79758 time= 0.27317
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0159 training loss= 0.79758 time= 0.34918
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0160 training loss= 0.79758 time= 0.17509
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0161 training loss= 0.79758 time= 0.15583
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0162 training loss= 0.79758 time= 0.18911
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0163 training loss= 0.79758 time= 0.20229
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0164 training loss= 0.79758 time= 0.26557
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0165 training loss= 0.79758 time= 1.61470
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0166 training loss= 0.79758 time= 0.30846
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0167 training loss= 0.79758 time= 0.17765
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0168 training loss= 0.79758 time= 0.25106
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0169 training loss= 0.79758 time= 0.40936
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0170 training loss= 0.79758 time= 0.16587
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0171 training loss= 0.79758 time= 0.22014
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0172 training loss= 0.79758 time= 0.25279
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0173 training loss= 0.79758 time= 0.21633
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0174 training loss= 0.79758 time= 0.17620
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0175 training loss= 0.79758 time= 0.17622
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0176 training loss= 0.79758 time= 0.24415
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0177 training loss= 0.79758 time= 0.34920
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0178 training loss= 0.79758 time= 0.16279
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0179 training loss= 0.79758 time= 0.25477
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0180 training loss= 0.79758 time= 0.17531
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0181 training loss= 0.79758 time= 0.17019
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0182 training loss= 0.79758 time= 0.17065
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0183 training loss= 0.79758 time= 0.17495
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0184 training loss= 0.79758 time= 0.39055
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0185 training loss= 0.79758 time= 0.15810
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0186 training loss= 0.79758 time= 0.23961
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0187 training loss= 0.79758 time= 0.29822
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0188 training loss= 0.79758 time= 0.24959
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0189 training loss= 0.79758 time= 0.31109
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0190 training loss= 0.79758 time= 0.25140
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0191 training loss= 0.79758 time= 0.21980
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0192 training loss= 0.79758 time= 0.19045
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0193 training loss= 0.79758 time= 0.19826
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0194 training loss= 0.79758 time= 0.19690
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0195 training loss= 0.79758 time= 0.36343
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0196 training loss= 0.79758 time= 0.27482
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0197 training loss= 0.79758 time= 0.26656
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0198 training loss= 0.79758 time= 0.18721
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0199 training loss= 0.79758 time= 0.16165
# validation roc= 0.50000 validation ap= 0.50000
# Epoch: 0200 training loss= 0.79758 time= 0.16184
# validation roc= 0.50000 validation ap= 0.50000
# testing roc= 0.50000 testing ap= 0.50000

# %% [markdown]
# # Visulization

# %%
emb=emb
labels=load_label(dataset,data_path)

X_embedded = TSNE(n_components=2, init='pca', random_state=seed).fit_transform(emb)

cs=['orange','blue','darkcyan','fuchsia','chocolate','dodgerblue','aqua','green','red','purple']
markers=['o','+','v','2','s','X','d','>','*','<']

fig, ax = plt.subplots(1,figsize=(8,6))
for i in np.arange(X_embedded.shape[0]):
    scatter = ax.scatter(X_embedded[i,0],X_embedded[i,1],label=labels[i],marker=markers[labels[i]],color=cs[labels[i]], s=10, alpha = 1)
plt.xticks([])
plt.yticks([])
plt.xlabel("")
plt.ylabel("")
plt.axis('off')
plt.show()
